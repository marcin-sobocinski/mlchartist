# %%
import pandas as pd
import glob

# %%
# !ls ../raw_data/data
# Out:
# daily

# %%
list_of_files = glob.glob("../raw_data/processed/*.csv")

# %%
len(list_of_files)
# Out:
# 2115

# %%
one_company = pd.read_csv(list_of_files[0])
one_company.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0   AACG  2008-03-14  66.861108   68.884120          74.893569 -1.569709e+07
# 1   AACG  2008-03-17  50.654450   33.333333          58.207145 -1.580640e+07
# 2   AACG  2008-03-18  47.545411   24.427754          42.215069 -1.611870e+07
# 3   AACG  2008-03-19  41.555477    3.418182          20.393090 -1.644262e+07
# 4   AACG  2008-03-20  42.004691    5.337180          11.061039 -1.663177e+07
#
#         OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0 -18339367  0.045513  28.037975  37.880090  16.131439  0.053424   0.015231
# 1 -18448679  0.050419  27.008663  31.831430  24.196200  0.045446   0.005803
# 2 -18760972  0.050868  25.543792  29.327485  25.747360  0.036691  -0.002362
# 3 -19189708  0.052727  24.375783  26.305184  31.630428  0.025082  -0.011177
# 4 -18929868  0.056733  22.755613  26.427417  27.337881  0.015948  -0.016249
#
# ...

# %%
for company in list_of_files:
    one_company = pd.read_csv(company)
# Out:
#        ticker per      date  time    open    high     low   close       vol  \
# 0     AACG.US   D  20080128     0  0.7380  0.7380  0.7380  0.7380         0
# 1     AACG.US   D  20080129     0  0.7380  0.7760  0.6657  0.6797  19169939
# 2     AACG.US   D  20080130     0  0.6797  0.7108  0.6448  0.6603   2818723
# 3     AACG.US   D  20080131     0  0.6595  0.8001  0.6595  0.7418   2345961
# 4     AACG.US   D  20080201     0  0.7714  0.7721  0.7380  0.7387    361853
# ...       ...  ..       ...   ...     ...     ...     ...     ...       ...
# 3160  AACG.US   D  20210119     0  1.3000  1.3940  1.2700  1.3038     63308
# 3161  AACG.US   D  20210120     0  1.3100  1.5100  1.3000  1.3800    206115
# 3162  AACG.US   D  20210121     0  1.4100  1.4200  1.3503  1.4000     45028
# 3163  AACG.US   D  20210122     0  1.4800  1.4899  1.3000  1.3500     80833
# 3164  AACG.US   D  20210125     0  1.4400  1.4600  1.3320  1.3882     32156
#
#       openint
# 0           0
# 1           0
# ...

# %%
one_company.describe()
# Out:
#                RSI   Stochastic  Stochastic_signal           ADI  \
# count  3112.000000  3112.000000        3112.000000  3.112000e+03
# mean     49.366805    44.016195          44.017273 -9.294597e+06
# std      11.695490    28.043625          25.670810  1.236305e+07
# min      15.967490     0.000000           0.000000 -3.064519e+07
# 25%      41.772851    20.281238          21.730139 -2.240242e+07
# 50%      48.602904    41.104998          41.772141 -7.267673e+06
# 75%      55.863888    65.534247          64.668891 -4.114927e+05
# max      96.303699   100.000000         100.000000  2.121524e+07
#
#                 OBV          ATR          ADX      ADX_pos      ADX_neg  \
# count  3.112000e+03  3112.000000  3112.000000  3112.000000  3112.000000
# mean   3.711968e+07     0.047116    27.302153    24.776736    21.477566
# std    5.892972e+07     0.054443    11.762190     9.714352     8.696088
# min   -2.594908e+07     0.006176     7.507341     4.246955     1.429173
# ...

# %%
sns.lineplot(data=one_company, x="date", y="5TD_return")
# Out:
# <AxesSubplot:xlabel='date', ylabel='5TD_return'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

file = list_of_files[0]
print(file)

#test = pd.read_csv(file)
test = pd.read_csv('../raw_data/processed/AAPL.csv')

sns.set_style("darkgrid")
plt.plot(test['5TD_return'])
plt.show()
# Out:
# ../raw_data/processed\aacg.csv

# %%
one_company[one_company['5TD_return'] > 1]
# Out:
#      ticker        date        RSI  Stochastic  Stochastic_signal  \
# 2520   AACG  2018-08-20  65.729462   80.706047          88.698590
# 2521   AACG  2018-08-21  66.124968   81.999301          82.698357
# 2522   AACG  2018-08-22  66.957404   84.620762          82.442037
# 2523   AACG  2018-08-23  67.698259   86.892695          84.504253
# 2524   AACG  2018-08-24  70.077014   94.372597          88.628685
# 2674   AACG  2019-04-02  41.375854   25.806452          26.344086
# 2675   AACG  2019-04-03  40.624637   27.507837          27.534870
# 2676   AACG  2019-04-04  43.445516   38.080000          30.464763
# 2677   AACG  2019-04-05  42.988034   36.000000          33.862612
# 2678   AACG  2019-04-08  47.562226   61.904762          45.328254
#
#                ADI       OBV       ATR        ADX    ADX_pos    ADX_neg  \
# 2520 -2.066387e+07  30598888  0.037130  28.430038  40.316784  20.320867
# 2521 -2.149049e+07  33040740  0.036313  28.754755  38.278686  19.293604
# ...
