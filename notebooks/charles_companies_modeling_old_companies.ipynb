# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import joblib
import os
import random

# %% [markdown]
# ====================================================================================================
#
# **Goal : gather similar companies according to their features and number of trading days**
#
# **Use : provide coherent and meaningful data to model**
#
#
# **(_Ideal_ : develop tailored model to each type of groups)**
#
# ====================================================================================================

# %% [markdown]
# # Anaysis of Companies Age from `nasdaq_us_stats.xls`

# %%
#!!!Path might not be the same!!!

meta_df = pd.read_csv('../raw_data/metadata/nasdaq_us_stats.xls')

# %%
meta_df.head()
# Out:
#    Unnamed: 0     stock  days  min_close  max_close  start_date    end_date
# 0           0   AACG.US  3165    0.21703      3.850  2008-01-28  2021-01-25
# 1           1   AACQ.US    96    9.62000     11.070  2020-09-08  2021-01-25
# 2           2  AACQU.US   134   10.00000     11.900  2020-07-15  2021-01-25
# 3           3  AACQW.US    95    1.07500      2.580  2020-09-09  2021-01-25
# 4           4    AAL.US  1793    9.04000     56.989  2013-12-10  2021-01-25

# %%
meta_df.describe()
# Out:
#         Unnamed: 0          days    min_close     max_close
# count  3921.000000   3921.000000  3921.000000  3.921000e+03
# mean   1960.000000   1876.186942     8.257047  6.181576e+06
# std    1132.039531   1795.084440    16.268917  3.863434e+08
# min       0.000000      1.000000     0.001000  2.400000e-01
# 25%     980.000000    312.000000     1.490000  1.438700e+01
# 50%    1960.000000   1286.000000     5.010000  2.880000e+01
# 75%    2940.000000   3775.000000    10.384000  6.533000e+01
# max    3920.000000  12879.000000   647.290000  2.419200e+10

# %%
meta_df = meta_df[['stock', 'days', 'min_close', 'max_close']]

# %% [markdown]
# ## Company age classification

# %%
meta_df['range_price'] = meta_df['max_close'] - meta_df['min_close']
meta_df['years'] = meta_df['days']/365

# %%
clean_meta_df = meta_df[['stock', 'years', 'range_price']]

# %%
sns.histplot(clean_meta_df['years'], binwidth=1)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %% [markdown]
# 👆👆**Anomaly at less than 1 year and 10 year old companies**👆👆

# %%
bins = [0, 1, 5, 10, 15, 20, 25, 30, 40]

clean_meta_df['company_vintage'] = pd.cut(meta_df['years'].copy(), 
                                          bins)                            # A company aged of 1Y and one day is
                                          #labels=['(0, 1]','(1, 5]',       # part of the '(1, 5]' class
                                          #        '(5, 10]', '(10, 15]',
                                          #        '(15, 20]', '(20, 25]',
                                          #        '(25, 30]', '(30, 40]'])
print(clean_meta_df['company_vintage'])
# Out:
# 0        (5, 10]
# 1         (0, 1]
# 2         (0, 1]
# 3         (0, 1]
# 4         (1, 5]
# 5        (5, 10]
# 6        (5, 10]
# 7       (10, 15]
# 8       (25, 30]
# 9       (10, 15]
# 10      (10, 15]
# 11      (10, 15]
# 12        (0, 1]
# 13        (0, 1]
# 14        (1, 5]
# 15      (10, 15]
# 16      (10, 15]
# 17        (0, 1]
# 18        (0, 1]
# 19        (1, 5]
# 20       (5, 10]
# 21        (0, 1]
# 22        (0, 1]
# 23        (0, 1]
# 24      (10, 15]
# 25        (0, 1]
# 26        (0, 1]
# 27        (0, 1]
# 28        (1, 5]
# 29        (0, 1]
#           ...
# 3891     (5, 10]
# 3892     (5, 10]
# 3893      (0, 1]
# 3894      (0, 1]
# 3895      (0, 1]
# 3896      (0, 1]
# 3897      (0, 1]
# 3898      (1, 5]
# 3899    (20, 25]
# 3900      (1, 5]
# 3901      (0, 1]
# 3902      (0, 1]
# 3903      (0, 1]
# 3904    (10, 15]
# 3905    (10, 15]
# 3906      (1, 5]
# 3907      (1, 5]
# 3908      (1, 5]
# 3909     (5, 10]
# 3910      (0, 1]
# 3911      (0, 1]
# 3912      (0, 1]
# 3913      (0, 1]
# 3914      (1, 5]
# 3915      (1, 5]
# 3916    (10, 15]
# 3917     (5, 10]
# 3918      (1, 5]
# 3919      (1, 5]
# 3920      (1, 5]
# Name: company_vintage, Length: 3921, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 5] < (5, 10] < (10, 15] < (15, 20] < (20, 25] < (25, 30] < (30, 40]]
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
clean_meta_df['company_vintage'].apply(str)
print(clean_meta_df.info())
clean_meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
# stock              3921 non-null object
# years              3921 non-null float64
# range_price        3921 non-null float64
# company_vintage    3921 non-null category
# dtypes: category(1), float64(2), object(1)
# memory usage: 95.9+ KB
# None
#       stock     years  range_price company_vintage
# 0   AACG.US  8.671233      3.63297         (5, 10]
# 1   AACQ.US  0.263014      1.45000          (0, 1]
# 2  AACQU.US  0.367123      1.90000          (0, 1]
# 3  AACQW.US  0.260274      1.50500          (0, 1]
# 4    AAL.US  4.912329     47.94900          (1, 5]

# %% [markdown]
# ## Classification Results

# %%
sns.histplot(data=clean_meta_df, x='years', binwidth=1, hue='company_vintage')
#plt.savefig('companies_age_classification.pdf', dpi=1200)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %%
clean_meta_df.groupby('company_vintage')['stock'].count()
# Out:
# company_vintage
# (0, 1]      1069
# (1, 5]      1252
# (5, 10]      564
# (10, 15]     950
# (15, 20]      32
# (20, 25]      37
# (25, 30]      13
# (30, 40]       4
# Name: stock, dtype: int64

# %% [markdown]
# ### Saving List of Companies Name via `joblib`

# %%
stocks_bin_1 = []
stocks_bin_2 = []
stocks_bin_3 = []
stocks_bin_4 = []
stocks_bin_5 = []
stocks_bin_6 = []
stocks_bin_7 = []
stocks_bin_8 = []

for idx, row in clean_meta_df.iterrows():
    x = row['years']                                            # <=> ['days']/365
    st = row['stock'].replace('.US', '')
    
    #print(idx, x, row['stock'])
    if x <= 1 : stocks_bin_1.append(st)
    elif x > 1 and x <= 5: stocks_bin_2.append(st)
    elif x > 5 and x <= 10: stocks_bin_3.append(st)
    elif x > 10 and x <= 15: stocks_bin_4.append(st)        
    elif x > 15 and x <= 20: stocks_bin_5.append(st)        
    elif x > 20 and x <= 25: stocks_bin_6.append(st)        
    elif x > 25 and x <= 30: stocks_bin_7.append(st)        
    elif x > 30: stocks_bin_8.append(st)
    
print(f"Number of companies with less than a year of history: {len(stocks_bin_1)}")
print(f"Number of companies with between a year and 5 years of history: {len(stocks_bin_2)}")    
print(f"Number of companies with between 5 years and 10 years of history: {len(stocks_bin_3)}")
print(f"Number of companies with between 10 years and 15 years of history: {len(stocks_bin_4)}")
print(f"Number of companies with between 15 years and 20 years of history: {len(stocks_bin_5)}")
print(f"Number of companies with between 20 years and 25 years of history: {len(stocks_bin_6)}")
print(f"Number of companies with between 25 years and 30 years of history: {len(stocks_bin_7)}")
print(f"Number of companies with more than 30 years of history: {len(stocks_bin_8)}")

stock_bins = [stocks_bin_1, stocks_bin_2, stocks_bin_3,
              stocks_bin_4, stocks_bin_5, stocks_bin_6,
              stocks_bin_7, stocks_bin_8]
# Out:
# Number of companies with less than a year of history: 1069
# Number of companies with between a year and 5 years of history: 1252
# Number of companies with between 5 years and 10 years of history: 564
# Number of companies with between 10 years and 15 years of history: 950
# Number of companies with between 15 years and 20 years of history: 32
# Number of companies with between 20 years and 25 years of history: 37
# Number of companies with between 25 years and 30 years of history: 13
# Number of companies with more than 30 years of history: 4

# %%
stock_bins
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# ❗❗❗**You should check the path you want to save the `stock_bins` list**❗❗❗
#
# (The `metadata` directory is where I saved the `nasdaq_us_stats.xls` csv file of Ian)

# %%
joblib.dump(stock_bins, '../raw_data/metadata/tickers_per_history_lenght__list')
# Out:
# ['../raw_data/metadata/tickers_per_history_lenght__list']

# %%
stocks_tickers = joblib.load('../raw_data/metadata/tickers_per_history_lenght__list')
stocks_tickers
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# # Modeling Companies per Vintage - (0, 1] - The youngest ones

# %% [markdown]
# ## Functions definitions & Imports

# %% [markdown]
# ### `precise_stocks_selector_local()`

# %%
from termcolor import colored

def precise_stocks_selector_local(tickers_list=[], path_files='../raw_data/processed/',
                                  random_sample=False, num_samp = 2, verbose=1):
    """
    Returns a concatened DataFrame of the stocks data which tickers' list were passed
    
    If random_sample = True, return a DataFrame with random sample of stocks from the tickers' list passed
    
    Example:
    INPUT: ['AEP', 'GT', 'INTC', 'PEP']
    OUTPUT: df.tickers.unique() ==> ['GT', 'INTC']
   
    """
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        
    t = []
    for ticker in tickers_list:
        ticker = f"{ticker}.csv".lower()
        t.append(ticker)
    tickers_list = t
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        print()
        print()
    
    if verbose >= 1:
        print(colored(f"****** Starting browsing the '{path_files}' directory ******", 'magenta'))
        
    filenames = []
    missing_stock_csv = []

    
    if random_sample:
        for file in os.listdir(path_files):
            if file.endswith('.csv'):
                if file in tickers_list:
                    filenames.append(file)
        
        for ticker in tickers_list:
            #print(ticker)
            #print(missing_stock_csv)
            if ticker not in filenames:
                missing_stock_csv.append(ticker)
                print(colored(f"{ticker} missing", 'red'))
            else:
                pass
        
        #print(missing_stock_csv)
        
        for missed in missing_stock_csv:
            if missed not in tickers_list:
                missing_stock_csv.remove(missed)
        #print(missing_stock_csv)
        
        if len(filenames) < num_samp:
            print(colored('\nSample size bigger that nuber of companies available\n','red'))
        else:
            sample = random.sample(filenames, num_samp)
            
        if verbose >= 1:
            print(colored("\n   *** Complete sampling ***", 'green'))
            
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting stocks DataFrame creation the sample ******", 'magenta'))
        
        dfs = []

        for ticker in sample:
            ticker_df = pd.read_csv('../raw_data/processed/'+ticker)
            dfs.append(ticker_df)
            if verbose == 2:
                print(colored(f"{ticker} DataFrame created", 'yellow'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
            
            
    else: 
        for file in os.listdir(path_files):
            if (file.endswith('.csv')):
                filenames.append(file)
                #print(f"{file}")
        
        if verbose >= 1:
            print(colored("\n   *** Complete file selection ***", 'green'))
        
        dfs = []
        
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"****** Starting stocks DataFrame creation the sample ******", 'magenta'))
      
        for ticker in tickers_list:
            if ticker in filenames:
                #print(f"{ticker}")
                ticker_df = pd.read_csv('../raw_data/processed/'+ticker)
                dfs.append(ticker_df)
                if verbose == 2:
                    print(colored(f"{ticker} DataFrame created", 'yellow'))
            else:
                missing_stock_csv.append(ticker)
                print(colored(f"\n{ticker} missing", 'red'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
    
    
    if len(missing_stock_csv) !=0:
        
        print(colored("""\n\n##### Problematic Issue: following stocks not in local database! #####""", "red"))
        print(colored(f"Number of missed stocks: {len(missing_stock_csv)}", "red"))
        print(colored(f"""\n{missing_stock_csv}""", "red"))
    
    return pd.concat(dfs)

# %% [markdown]
# ### Preprocessing Functions

# %%
from sklearn.preprocessing import StandardScaler

def std_scaler(df):
    """
    Scale the data with SKlearn StandardScaler
    """
    
    scaler = StandardScaler()
    
    col_to_scale_df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    col_to_scale = list(col_to_scale_df)
    
    scaled_df = df
    
    for col in col_to_scale:
        scaled_df[col] = scaler.fit_transform(scaled_df[[col]])
    
    return scaled_df

# %%
#Marcin's Function

def build_input_arrays(df, time_window=5, stride=3, input_cols=['RSI', 'Stochastic', 'Stochastic_signal', 'ADI',
       'OBV', 'ATR', 'ADX', 'ADX_pos', 'ADX_neg', 'MACD', 'MACD_diff',
       'MACD_signal'] , target_col='5TD_return'):
    output_array = []
    target_array = []
    df_sorted = df.sort_values('date', ascending=False)
    df_sorted.reset_index(drop=True, inplace=True)
    for row in range(0, len(df), stride):
        df_slice = df_sorted.iloc[row: row + time_window]
        if df_slice.shape[0]==time_window:
            output_array.append(np.array(df_slice[input_cols].values))
            target_array.append(df_slice[target_col].iloc[0])
    return np.array(output_array), np.array(target_array)

# %%
#Ian's Function

def train_test_split(df, test_set_size='3Y'):
    """
    Split the preprocessed stock data file into a train and test dataset
    INPUT: the dataframe to be split, and size of the test set in months or years ('3M' or '2Y')
    OUTPUT: returns a train_set and test_set dataframe, index is set to the date
    
    EXAMPLE: train_set, test_set = train_test_split(input_df, '3Y')
    """
    if not np.issubdtype(df['date'].dtype, np.datetime64):
        df['date'] = pd.to_datetime(df['date'], format=('%Y-%m-%d'))
    test_set = df.sort_values(by="date",ascending=True).set_index("date").last(test_set_size)
    train_set = df.drop(df.tail(len(test_set)).index).set_index("date")
    test_set.reset_index(inplace=True)
    train_set.reset_index(inplace=True)
    return train_set, test_set

# %%
def thresholds_encoding(df, r5d=0.0006, same_thresholds=True, r10d=0.0012, r20d=0.0024):
    """
    Binary encode the 5, 10 and 20 days return columns according to the thresholds
    
    INPUT: dataframe with '5TD_return', '10TD_return' and '20TD_return' columns
    OUTPUT: dataframe with binary encoded aforementionned columns
    
    If the thresolds returns are the same on a yearly basis for the different period use:
                r10d = r5d * 2 
            and
                r20d = r10d * 2
            keep same_thresholds=True
        Otherwise, define manually r10d and r20d
    """
    wk_df = df.copy()
    
    if same_thresholds:
        r10d = r5d * 2
        r20d = r10d * 2
    
    wk_df['5TD_return'] = wk_df['5TD_return'].apply(lambda x: 1 if x > r5d else 0)
    wk_df['10TD_return'] = wk_df['10TD_return'].apply(lambda x: 1 if x > r10d else 0)
    wk_df['20TD_return'] = wk_df['20TD_return'].apply(lambda x: 1 if x > r20d else 0)
    
    return wk_df

# %% [markdown]
# ### Visualisation Functions

# %%
def plot_loss_accuracy(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Importing the (0,1] Companies Sample

# %%
companies_0_1 = stocks_tickers[1]
companies_0_1
# Out:
# ['AAL',
#  'ABEO',
#  'ABTX',
#  'ACBI',
#  'ACET',
#  'ACGLO',
#  'ACGLP',
#  'ACIA',
#  'ACIU',
#  'ACMR',
#  'ACRS',
#  'ADAP',
#  'ADES',
#  'ADIL',
#  'ADMA',
#  'ADMS',
#  'ADPT',
#  'ADVM',
#  'AEMD',
#  'AEPPL',
#  'AERI',
#  'AESE',
#  'AEYE',
#  'AFIN',
#  'AFINP',
#  'AFMD',
#  'AFYA',
#  'AGFS',
#  'AGLE',
#  'AGMH',
#  'AGNCM',
#  'AGNCN',
#  'AGRX',
#  'AGTC',
#  'AHCO',
#  'AIHS',
#  'AIQ',
#  'AIRG',
#  'AKBA',
#  'AKER',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'ALACW',
#  'ALDX',
#  'ALEC',
#  'ALJJ',
#  'ALLK',
#  'ALLO',
#  'ALNA',
#  'ALPN',
#  'ALRM',
#  'ALRN',
#  'ALTA',
#  'ALTM',
#  'ALTR',
#  'ALTY',
#  'ALYA',
#  'AMAL',
#  'AMCA',
#  'AMCI',
#  'AMEH',
#  'AMPH',
#  'AMRHW',
#  'AMRK',
#  'AMTB',
#  'AMTBB',
#  'ANAB',
#  'ANCN',
#  'ANY',
#  'APHA',
#  'APLS',
#  'APLT',
#  'APM',
#  'APOP',
#  'APOPW',
#  'APPF',
#  'APPN',
#  'APTX',
#  'APVO',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'ARAV',
#  'ARCE',
#  'ARDS',
#  'ARDX',
#  'AREC',
#  'ARGX',
#  'ARPO',
#  'ARTL',
#  'ARVN',
#  'ASET',
#  'ASLN',
#  'ASND',
#  'ASPU',
#  'ASRVP',
#  'ATCX',
#  'ATEX',
#  'ATIF',
#  'ATNFW',
#  'ATNX',
#  'ATOM',
#  'ATRA',
#  'ATXI',
#  'AUPH',
#  'AUTL',
#  'AVCO',
#  'AVCT',
#  'AVGR',
#  'AVRO',
#  'AVXL',
#  'AXLA',
#  'AXNX',
#  'AXSM',
#  'AY',
#  'AYTU',
#  'AZRX',
#  'BAND',
#  'BANFP',
#  'BANX',
#  'BATRA',
#  'BATRK',
#  'BBCP',
#  'BBIG',
#  'BBIO',
#  'BCEL',
#  'BCLI',
#  'BCOW',
#  'BCYC',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIT',
#  'BFST',
#  'BGNE',
#  'BGRN',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAP',
#  'BHTG',
#  'BILI',
#  'BIOC',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLCM',
#  'BLCN',
#  'BLFS',
#  'BLNK',
#  'BLNKW',
#  'BLPH',
#  'BMLP',
#  'BMRA',
#  'BNDW',
#  'BNGO',
#  'BNGOW',
#  'BNTC',
#  'BOKFL',
#  'BOMN',
#  'BOTZ',
#  'BOXL',
#  'BPMC',
#  'BPRN',
#  'BPYPP',
#  'BPYU',
#  'BPYUP',
#  'BROG',
#  'BROGW',
#  'BRY',
#  'BSGM',
#  'BSJQ',
#  'BSVN',
#  'BTAI',
#  'BTEC',
#  'BVXV',
#  'BWAY',
#  'BWB',
#  'BWFG',
#  'BYND',
#  'BYSI',
#  'BZUN',
#  'CACG',
#  'CALA',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARV',
#  'CASA',
#  'CATB',
#  'CATC',
#  'CATH',
#  'CBAY',
#  'CBFV',
#  'CBMB',
#  'CBNK',
#  'CBTX',
#  'CCAP',
#  'CCB',
#  'CCD',
#  'CCNC',
#  'CCRC',
#  'CDC',
#  'CDEV',
#  'CDK',
#  'CDL',
#  'CDLX',
#  'CDMOP',
#  'CDNA',
#  'CDTX',
#  'CELC',
#  'CELH',
#  'CERC',
#  'CETX',
#  'CETXP',
#  'CETXW',
#  'CEY',
#  'CEZ',
#  'CFA',
#  'CFBI',
#  'CFMS',
#  'CFO',
#  'CFRX',
#  'CGBD',
#  'CGC',
#  'CHEK',
#  'CHEKZ',
#  'CHMA',
#  'CHNA',
#  'CHNG',
#  'CHNGU',
#  'CHRS',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHX',
#  'CIBR',
#  'CID',
#  'CIGI',
#  'CIH',
#  'CIL',
#  'CIZ',
#  'CKPT',
#  'CLBK',
#  'CLGN',
#  'CLLS',
#  'CLOU',
#  'CLPS',
#  'CLPT',
#  'CLRBZ',
#  'CLRG',
#  'CLSD',
#  'CLXT',
#  'CMBM',
#  'CMFNL',
#  'CMLS',
#  'CNCE',
#  'CNCR',
#  'CNDT',
#  'CNFR',
#  'CNFRL',
#  'CNST',
#  'COCP',
#  'CODA',
#  'CODX',
#  'COGT',
#  'COLL',
#  'COMM',
#  'COOP',
#  'COUP',
#  'COWNL',
#  'COWNZ',
#  'CPSH',
#  'CPTAG',
#  'CPTAL',
#  'CRBP',
#  'CREX',
#  'CRNX',
#  'CRON',
#  'CRSP',
#  'CRTO',
#  'CRTX',
#  'CRVS',
#  'CRWD',
#  'CSA',
#  'CSB',
#  'CSBR',
#  'CSF',
#  'CSML',
#  'CSSE',
#  'CSSEP',
#  'CSTL',
#  'CSTR',
#  'CSWCL',
#  'CSWI',
#  'CTMX',
#  'CTRE',
#  'CTRM',
#  'CTXR',
#  'CTXRW',
#  'CUE',
#  'CVET',
#  'CWBR',
#  'CYAD',
#  'CYBR',
#  'CYCCP',
#  'CYCN',
#  'CZR',
#  'DALI',
#  'DARE',
#  'DAX',
#  'DBVT',
#  'DBX',
#  'DCPH',
#  'DDIV',
#  'DFFN',
#  'DFNL',
#  'DGICB',
#  'DHCNI',
#  'DHCNL',
#  'DINT',
#  'DISCB',
#  'DLPN',
#  'DLTH',
#  'DMAC',
#  'DMTK',
#  'DNLI',
#  'DOCU',
#  'DOGZ',
#  'DOMO',
#  'DOOO',
#  'DOYU',
#  'DRIOW',
#  'DRIV',
#  'DRNA',
#  'DSKE',
#  'DSKEW',
#  'DTEA',
#  'DTIL',
#  'DTSS',
#  'DUSA',
#  'DVLU',
#  'DVOL',
#  'DWAT',
#  'DWFI',
#  'DWLD',
#  'DWMC',
#  'DWPP',
#  'DWSH',
#  'DYAI',
#  'EARS',
#  'EAST',
#  'EBAYL',
#  'EBIZ',
#  'ECOR',
#  'EDIT',
#  'EDRY',
#  'EDSA',
#  'EFAS',
#  'EGRX',
#  'EIDX',
#  'EIGI',
#  'EIGR',
#  'EKSO',
#  'ELOX',
#  'EMXC',
#  'ENLV',
#  'ENOB',
#  'ENTX',
#  'ENVB',
#  'EOLS',
#  'EPIX',
#  'EPSN',
#  'EQ',
#  'EQBK',
#  'EQRR',
#  'ERYP',
#  'ESGD',
#  'ESGE',
#  'ESGRO',
#  'ESGRP',
#  'ESGU',
#  'ESPO',
#  'ESQ',
#  'ESTA',
#  'ETON',
#  'ETSY',
#  'ETTX',
#  'EVBG',
#  'EVER',
#  'EVFM',
#  'EVGN',
#  'EVLO',
#  'EVOP',
#  'EXPI',
#  'EYE',
#  'EYEG',
#  'EYEN',
#  'EYES',
#  'EYESW',
#  'FAAR',
#  'FALN',
#  'FAMI',
#  'FAT',
#  'FBIOP',
#  'FBRX',
#  'FCAL',
#  'FCBP',
#  'FCEF',
#  'FCVT',
#  'FDBC',
#  'FDNI',
#  'FDUSL',
#  'FDUSZ',
#  'FENC',
#  'FFBW',
#  'FFWM',
#  'FGBI',
#  'FGEN',
#  'FGF',
#  'FGFPP',
#  'FHB',
#  'FID',
#  'FINX',
#  'FITBI',
#  'FIVN',
#  'FIXD',
#  'FIXX',
#  'FLGT',
#  'FLMN',
#  'FLMNW',
#  'FLXN',
#  'FMAO',
#  'FMHI',
#  'FNCB',
#  'FNKO',
#  'FNWB',
#  'FOCS',
#  'FORK',
#  'FOX',
#  'FOXA',
#  'FPAY',
#  'FRAF',
#  'FRPT',
#  'FRSX',
#  'FRTA',
#  'FSTX',
#  'FSV',
#  'FTDR',
#  'FTXD',
#  'FTXG',
#  'FTXH',
#  'FTXL',
#  'FTXN',
#  'FTXO',
#  'FTXR',
#  'FULC',
#  'FUTU',
#  'FUV',
#  'FVC',
#  'FVCB',
#  'FWONK',
#  'FWP',
#  'GAINL',
#  'GAINM',
#  'GBLIL',
#  'GBT',
#  'GCMGW',
#  'GDS',
#  'GDYN',
#  'GECC',
#  'GECCL',
#  'GECCM',
#  'GECCN',
#  'GENY',
#  'GFNCP',
#  'GFNSL',
#  'GH',
#  'GHSI',
#  'GIGE',
#  'GLADD',
#  'GLG',
#  'GLIBA',
#  'GLIBP',
#  'GLMD',
#  'GLPI',
#  'GLYC',
#  'GMAB',
#  'GMDA',
#  'GMLPP',
#  'GNCA',
#  'GNFT',
#  'GNLN',
#  'GNOM',
#  'GNPX',
#  'GNTY',
#  'GNUS',
#  'GO',
#  'GOEV',
#  'GOEVW',
#  'GOODM',
#  'GOOG',
#  'GOSS',
#  'GPP',
#  'GPRO',
#  'GRIN',
#  'GRNQ',
#  'GRTS',
#  'GSHD',
#  'GSKY',
#  'GSMG',
#  'GSMGW',
#  'GSUM',
#  'GTEC',
#  'GTHX',
#  'GTYH',
#  'GWGH',
#  'GWRS',
#  'HARP',
#  'HBANN',
#  'HBANO',
#  'HBMD',
#  'HBP',
#  'HCAPZ',
#  'HCAT',
#  'HCM',
#  'HEPA',
#  'HFFG',
#  'HGEN',
#  'HHR',
#  'HJLI',
#  'HJLIW',
#  'HLAL',
#  'HLG',
#  'HLNE',
#  'HMHC',
#  'HNDL',
#  'HNNA',
#  'HOFV',
#  'HOFVW',
#  'HONE',
#  'HOOK',
#  'HOTH',
#  'HPK',
#  'HPKEW',
#  'HQI',
#  'HQY',
#  'HRTX',
#  'HSDT',
#  'HTGM',
#  'HUSN',
#  'HVBC',
#  'HWCPL',
#  'HX',
#  'HYMC',
#  'HYMCW',
#  'HYRE',
#  'HYXF',
#  'ICBK',
#  'ICCH',
#  'ICHR',
#  'ICLK',
#  'ICMB',
#  'IDLB',
#  'IDYA',
#  'IEA',
#  'IEAWW',
#  'IFMK',
#  'IFRX',
#  'IGIC',
#  'IGICW',
#  'IHRT',
#  'IIIV',
#  'ILPT',
#  'IMAC',
#  'IMRN',
#  'IMRNW',
#  'IMTE',
#  'IMTX',
#  'IMUX',
#  'IMV',
#  'IMXI',
#  'INBKL',
#  'INFR',
#  'INGN',
#  'INMB',
#  'INMD',
#  'INOV',
#  'INSE',
#  'IPLDP',
#  'IPWR',
#  'IQ',
#  'IRMD',
#  'IRTC',
#  'ISDX',
#  'ISEM',
#  'ISTR',
#  'ITCI',
#  'ITMR',
#  'ITRM',
#  'IUS',
#  'IUSS',
#  'IZEA',
#  'JAGX',
#  'JD',
#  'JFIN',
#  'JG',
#  'JMPNL',
#  'JNCE',
#  'JRSH',
#  'JRVR',
#  'JSMD',
#  'JSML',
#  'JYNT',
#  'KALA',
#  'KALV',
#  'KBLMR',
#  'KBSF',
#  'KCAPL',
#  'KDMN',
#  'KDNY',
#  'KE',
#  'KERN',
#  'KERNW',
#  'KHC',
#  'KIDS',
#  'KIN',
#  'KLDO',
#  'KLXE',
#  'KNSA',
#  'KNSL',
#  'KOD',
#  'KPTI',
#  'KRMA',
#  'KRNT',
#  'KRTX',
#  'KRUS',
#  'KRYS',
#  'KTOVW',
#  'KTRA',
#  'KURA',
#  'KXIN',
#  'KZR',
#  'LACQ',
#  'LACQW',
#  'LANDP',
#  'LASR',
#  'LAUR',
#  'LAZY',
#  'LBC',
#  'LBRDA',
#  'LBRDK',
#  'LDSF',
#  'LE',
#  'LEGH',
#  'LEGR',
#  'LEVL',
#  'LFAC',
#  'LGIH',
#  'LIFE',
#  'LILA',
#  'LILAK',
#  'LIND',
#  'LIQT',
#  'LITE',
#  'LIVN',
#  'LIVX',
#  'LJPC',
#  'LKCO',
#  'LMB',
#  'LMFA',
#  'LMRK',
#  'LMRKN',
#  'LMRKO',
#  'LMRKP',
#  'LNGR',
#  'LNTH',
#  'LOB',
#  'LOCO',
#  'LOGC',
#  'LOOP',
#  'LOVE',
#  'LPCN',
#  'LPTX',
#  'LQDA',
#  'LRGE',
#  'LRMR',
#  'LSXMA',
#  'LSXMK',
#  'LTRPA',
#  'LVHD',
#  'LX',
#  'LYFT',
#  'LYL',
#  'MARA',
#  'MBCN',
#  'MBIN',
#  'MBINP',
#  'MBIO',
#  'MBRX',
#  'MBUU',
#  'MCEF',
#  'MCFT',
#  'MCRB',
#  'MDB',
#  'MDGS',
#  'MDJH',
#  'MDRR',
#  'MDWD',
#  'MEDP',
#  'MEDS',
#  'MESA',
#  'MESO',
#  'METC',
#  'METX',
#  'MFH',
#  'MFINL',
#  'MGEN',
#  'MGNI',
#  'MGTA',
#  'MGTX',
#  'MIK',
#  'MILN',
#  'MIME',
#  'MINDP',
#  'MIRM',
#  'MIST',
#  'MITO',
#  'MKGI',
#  'MMAC',
#  'MNSB',
#  'MOBL',
#  'MOGO',
#  'MOMO',
#  'MOR',
#  'MORF',
#  'MOTS',
#  'MOXC',
#  'MRAM',
#  'MRBK',
#  'MRCCL',
#  'MREO',
#  'MRKR',
#  'MRNA',
#  'MRNS',
#  'MRSN',
#  'MRUS',
#  'MSBI',
#  'MSVB',
#  'MTBC',
#  'MTBCP',
#  'MTC',
#  'MTCH',
#  'MTLS',
#  'MTP',
#  'MVBF',
#  'MWK',
#  'MYFW',
#  'MYOK',
#  'MYSZ',
#  'MYT',
#  'NAKD',
#  'NAOV',
#  'NAVI',
#  'NBEV',
#  'NBLX',
#  'NBRV',
#  'NCBS',
#  'NCNA',
#  'NCSM',
#  'NDRA',
#  'NDRAW',
#  'NEOS',
#  'NERV',
#  'NESR',
#  'NESRW',
#  'NEWA',
#  'NEWTI',
#  'NEWTL',
#  'NEXT',
#  'NFE',
#  'NFTY',
#  'NGHC',
#  'NGHCN',
#  'NGHCO',
#  'NGHCP',
#  'NGHCZ',
#  'NGM',
#  'NH',
#  'NHLD',
#  'NHLDW',
#  'NHTC',
#  'NISN',
#  'NIU',
#  'NK',
#  'NKLA',
#  'NLTX',
#  'NMCI',
#  'NMFCL',
#  'NMIH',
#  'NMRD',
#  'NMRK',
#  'NNDM',
#  'NODK',
#  'NOVN',
#  'NRBO',
#  'NTEC',
#  'NTLA',
#  'NTNX',
#  'NTRA',
#  'NTRP',
#  'NVCR',
#  'NVEE',
#  'NVFY',
#  'NVUS',
#  'NXTC',
#  'NYMTN',
#  'NYMTO',
#  'OBLN',
#  'OBNK',
#  'OBSV',
#  'OCCI',
#  'OCCIP',
#  'OCGN',
#  'OCUL',
#  'ODT',
#  'OFED',
#  'OFSSL',
#  'OFSSZ',
#  'OGI',
#  'OKTA',
#  'OLD',
#  'OLLI',
#  'OMP',
#  'ONCY',
#  'ONTXW',
#  'OPBK',
#  'OPGN',
#  'OPINI',
#  'OPNT',
#  'OPRA',
#  'OPRX',
#  'OPTN',
#  'ORGO',
#  'ORGS',
#  'ORTX',
#  'OSMT',
#  'OSS',
#  'OSW',
#  'OTIC',
#  'OTLK',
#  'OTLKW',
#  'OVID',
#  'OXBR',
#  'OXBRW',
#  'OXFD',
#  'OXLCM',
#  'OXSQL',
#  'OXSQZ',
#  'PAE',
#  'PAHC',
#  'PANL',
#  'PATI',
#  'PAVM',
#  'PAVMW',
#  'PAVMZ',
#  'PAYS',
#  'PBCTP',
#  'PBFS',
#  'PBTS',
#  'PCB',
#  'PCSB',
#  'PCTY',
#  'PDD',
#  'PDLB',
#  'PDSB',
#  'PECK',
#  'PETQ',
#  'PETZ',
#  'PFIE',
#  'PFIS',
#  'PHAS',
#  'PHCF',
#  'PHIOW',
#  'PHUN',
#  'PHUNW',
#  'PI',
#  'PIRS',
#  'PIXY',
#  'PLAY',
#  'PLL',
#  'PLMR',
#  'PLSE',
#  'PLXP',
#  'PLYA',
#  'POLA',
#  'PPBT',
#  'PPSI',
#  'PRAH',
#  'PROF',
#  'PRPL',
#  'PRPO',
#  'PRQR',
#  'PRTH',
#  'PRVB',
#  'PRVL',
#  'PS',
#  'PSC',
#  'PSET',
#  'PSNL',
#  'PT',
#  'PTC',
#  'PTGX',
#  'PULM',
#  'PUYI',
#  'PVAC',
#  'PVBC',
#  'PXS',
#  'PY',
#  'PYPL',
#  'QFIN',
#  'QLGN',
#  'QRVO',
#  'QTNT',
#  'QTRX',
#  'QTT',
#  'QURE',
#  'RARE',
#  'RBB',
#  'RBKB',
#  'RBNC',
#  'RCKT',
#  'RCM',
#  'RDFN',
#  'RDUS',
#  'RDVT',
#  'REAL',
#  'REDU',
#  'REKR',
#  'REPH',
#  'REPL',
#  'RESN',
#  'RETA',
#  'RETO',
#  'RFAP',
#  'RFDI',
#  'RFEM',
#  'RFEU',
#  'RGNX',
#  'RIBT',
#  'RILY',
#  'RILYG',
#  'RILYH',
#  'RILYI',
#  'RILYO',
#  'RILYZ',
#  'RIVE',
#  'RKDA',
#  'RLMD',
#  'RMBI',
#  'RMBL',
#  'RMNI',
#  'RMR',
#  'RNDB',
#  'RNDM',
#  'RNDV',
#  'RNEM',
#  'RNLC',
#  'RNMC',
#  'RNSC',
#  'ROAD',
#  'ROBT',
#  'ROKU',
#  'RPAY',
#  'RPD',
#  'RRBI',
#  'RRR',
#  'RTLR',
#  'RUBY',
#  'RUHN',
#  'RUN',
#  'RVNC',
#  'RWLK',
#  'RYTM',
#  'SABR',
#  'SAGE',
#  'SBBP',
#  'SBLKZ',
#  'SBT',
#  'SCKT',
#  'SCOR',
#  'SCPH',
#  'SCPL',
#  'SCWX',
#  'SCYX',
#  'SDG',
#  'SDVY',
#  'SECO',
#  'SEDG',
#  ...]

# %%
stocks_0_1_df = precise_stocks_selector_local(tickers_list=companies_0_1, random_sample=True, num_samp = 4, verbose=1)
# Out:
# ****** Starting browsing the '../raw_data/processed/' directory ******
# abtx.csv missing
# acet.csv missing
# aciu.csv missing
# acrs.csv missing
# ades.csv missing
# adms.csv missing
# adpt.csv missing
# agfs.csv missing
# agrx.csv missing
# aihs.csv missing
# akts.csv missing
# aktx.csv missing
# aldx.csv missing
# apls.csv missing
# aplt.csv missing
# aptx.csv missing
# aqms.csv missing
# aqst.csv missing
# ards.csv missing
# ardx.csv missing
# argx.csv missing
# aset.csv missing
# aspu.csv missing
# atcx.csv missing
# atex.csv missing
# atnx.csv missing
# avct.csv missing
# axnx.csv missing
# aytu.csv missing
# azrx.csv missing
# banx.csv missing
# bfit.csv missing
# bfst.csv missing
# bhat.csv missing
# blfs.csv missing
# bpyu.csv missing
# cbtx.csv missing
# cdlx.csv missing
# cdtx.csv missing
# cetx.csv missing
# cfms.csv missing
# cfrx.csv missing
# chngu.csv missing
# chrs.csv missing
# chx.csv missing
# ckpt.csv missing
# clls.csv missing
# clou.csv missing
# clps.csv missing
# clpt.csv missing
# clxt.csv missing
# cmls.csv missing
# cndt.csv missing
# cnst.csv missing
# codx.csv missing
# cogt.csv missing
# crex.csv missing
# crnx.csv missing
# crtx.csv missing
# crvs.csv missing
# ctmx.csv missing
# cvet.csv missing
# dax.csv missing
# dbvt.csv missing
# dbx.csv missing
# dint.csv missing
# docu.csv missing
# doyu.csv missing
# dtss.csv missing
# dvlu.csv missing
# dwat.csv missing
# ears.csv missing
# east.csv missing
# edit.csv missing
# efas.csv missing
# egrx.csv missing
# eidx.csv missing
# elox.csv missing
# entx.csv missing
# eols.csv missing
# epix.csv missing
# esgu.csv missing
# ettx.csv missing
# eyes.csv missing
# fat.csv missing
# fbrx.csv missing
# fcvt.csv missing
# finx.csv missing
# fixx.csv missing
# flgt.csv missing
# focs.csv missing
# fox.csv missing
# frpt.csv missing
# frsx.csv missing
# fstx.csv missing
# futu.csv missing
# gbt.csv missing
# gds.csv missing
# gnft.csv missing
# gnpx.csv missing
# gnus.csv missing
# goss.csv missing
# grts.csv missing
# gthx.csv missing
# gwrs.csv missing
# hcat.csv missing
# hrtx.csv missing
# hsdt.csv missing
# hx.csv missing
# ifrx.csv missing
# ihrt.csv missing
# ilpt.csv missing
# imtx.csv missing
# imux.csv missing
# isdx.csv missing
# ius.csv missing
# iuss.csv missing
# jagx.csv missing
# jynt.csv missing
# kids.csv missing
# krnt.csv missing
# krtx.csv missing
# krus.csv missing
# krys.csv missing
# liqt.csv missing
# livx.csv missing
# lptx.csv missing
# lx.csv missing
# lyft.csv missing
# mbrx.csv missing
# mbuu.csv missing
# mcft.csv missing
# mdgs.csv missing
# meds.csv missing
# metx.csv missing
# mgtx.csv missing
# mist.csv missing
# mots.csv missing
# mrns.csv missing
# mrus.csv missing
# mtls.csv missing
# myt.csv missing
# nblx.csv missing
# ncbs.csv missing
# neos.csv missing
# next.csv missing
# niu.csv missing
# nltx.csv missing
# ntnx.csv missing
# nvus.csv missing
# odt.csv missing
# opnt.csv missing
# oprx.csv missing
# orgs.csv missing
# ortx.csv missing
# osmt.csv missing
# oss.csv missing
# pays.csv missing
# pbfs.csv missing
# pbts.csv missing
# pfis.csv missing
# phas.csv missing
# pirs.csv missing
# ppbt.csv missing
# ps.csv missing
# pset.csv missing
# pt.csv missing
# ptgx.csv missing
# pxs.csv missing
# qtnt.csv missing
# qtrx.csv missing
# qtt.csv missing
# rckt.csv missing
# rdus.csv missing
# rdvt.csv missing
# redu.csv missing
# rfeu.csv missing
# rgnx.csv missing
# ribt.csv missing
# robt.csv missing
# roku.csv missing
# sbt.csv missing
# sckt.csv missing
# scwx.csv missing
# scyx.csv missing
# sfbs.csv missing
# sfet.csv missing
# sfix.csv missing
# sgbx.csv missing
# sint.csv missing
# siox.csv missing
# slrx.csv missing
# smmt.csv missing
# sndx.csv missing
# snes.csv missing
# sngx.csv missing
# srax.csv missing
# srts.csv missing
# ssnt.csv missing
# stks.csv missing
# sybx.csv missing
# syrs.csv missing
# tblt.csv missing
# tedu.csv missing
# tmdx.csv missing
# tptx.csv missing
# trmt.csv missing
# twou.csv missing
# twst.csv missing
# tyht.csv missing
# ubx.csv missing
# unit.csv missing
# usws.csv missing
# vblt.csv missing
# vbtx.csv missing
# vcnx.csv missing
# vcyt.csv missing
# viot.csv missing
# virt.csv missing
# vktx.csv missing
# vrex.csv missing
# vrns.csv missing
# vtvt.csv missing
# wafu.csv missing
# watt.csv missing
# wix.csv missing
# wkhs.csv missing
# worx.csv missing
# xbit.csv missing
# xent.csv missing
# xers.csv missing
# xnet.csv missing
# ymtx.csv missing
# ziext.csv missing
# zs.csv missing
#
#    *** Complete sampling ***
#
#
# ****** Starting stocks DataFrame creation the sample ******
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 235
#
# ['abtx.csv', 'acet.csv', 'aciu.csv', 'acrs.csv', 'ades.csv', 'adms.csv', 'adpt.csv', 'agfs.csv', 'agrx.csv', 'aihs.csv', 'akts.csv', 'aktx.csv', 'aldx.csv', 'apls.csv', 'aplt.csv', 'aptx.csv', 'aqms.csv', 'aqst.csv', 'ards.csv', 'ardx.csv', 'argx.csv', 'aset.csv', 'aspu.csv', 'atcx.csv', 'atex.csv', 'atnx.csv', 'avct.csv', 'axnx.csv', 'aytu.csv', 'azrx.csv', 'banx.csv', 'bfit.csv', 'bfst.csv', 'bhat.csv', 'blfs.csv', 'bpyu.csv', 'cbtx.csv', 'cdlx.csv', 'cdtx.csv', 'cetx.csv', 'cfms.csv', 'cfrx.csv', 'chngu.csv', 'chrs.csv', 'chx.csv', 'ckpt.csv', 'clls.csv', 'clou.csv', 'clps.csv', 'clpt.csv', 'clxt.csv', 'cmls.csv', 'cndt.csv', 'cnst.csv', 'codx.csv', 'cogt.csv', 'crex.csv', 'crnx.csv', 'crtx.csv', 'crvs.csv', 'ctmx.csv', 'cvet.csv', 'dax.csv', 'dbvt.csv', 'dbx.csv', 'dint.csv', 'docu.csv', 'doyu.csv', 'dtss.csv', 'dvlu.csv', 'dwat.csv', 'ears.csv', 'east.csv', 'edit.csv', 'efas.csv', 'egrx.csv', 'eidx.csv', 'elox.csv', 'entx.csv', 'eols.csv', 'epix.csv', 'esgu.csv', 'ettx.csv', 'eyes.csv', 'fat.csv', 'fbrx.csv', 'fcvt.csv', 'finx.csv', 'fixx.csv', 'flgt.csv', 'focs.csv', 'fox.csv', 'frpt.csv', 'frsx.csv', 'fstx.csv', 'futu.csv', 'gbt.csv', 'gds.csv', 'gnft.csv', 'gnpx.csv', 'gnus.csv', 'goss.csv', 'grts.csv', 'gthx.csv', 'gwrs.csv', 'hcat.csv', 'hrtx.csv', 'hsdt.csv', 'hx.csv', 'ifrx.csv', 'ihrt.csv', 'ilpt.csv', 'imtx.csv', 'imux.csv', 'isdx.csv', 'ius.csv', 'iuss.csv', 'jagx.csv', 'jynt.csv', 'kids.csv', 'krnt.csv', 'krtx.csv', 'krus.csv', 'krys.csv', 'liqt.csv', 'livx.csv', 'lptx.csv', 'lx.csv', 'lyft.csv', 'mbrx.csv', 'mbuu.csv', 'mcft.csv', 'mdgs.csv', 'meds.csv', 'metx.csv', 'mgtx.csv', 'mist.csv', 'mots.csv', 'mrns.csv', 'mrus.csv', 'mtls.csv', 'myt.csv', 'nblx.csv', 'ncbs.csv', 'neos.csv', 'next.csv', 'niu.csv', 'nltx.csv', 'ntnx.csv', 'nvus.csv', 'odt.csv', 'opnt.csv', 'oprx.csv', 'orgs.csv', 'ortx.csv', 'osmt.csv', 'oss.csv', 'pays.csv', 'pbfs.csv', 'pbts.csv', 'pfis.csv', 'phas.csv', 'pirs.csv', 'ppbt.csv', 'ps.csv', 'pset.csv', 'pt.csv', 'ptgx.csv', 'pxs.csv', 'qtnt.csv', 'qtrx.csv', 'qtt.csv', 'rckt.csv', 'rdus.csv', 'rdvt.csv', 'redu.csv', 'rfeu.csv', 'rgnx.csv', 'ribt.csv', 'robt.csv', 'roku.csv', 'sbt.csv', 'sckt.csv', 'scwx.csv', 'scyx.csv', 'sfbs.csv', 'sfet.csv', 'sfix.csv', 'sgbx.csv', 'sint.csv', 'siox.csv', 'slrx.csv', 'smmt.csv', 'sndx.csv', 'snes.csv', 'sngx.csv', 'srax.csv', 'srts.csv', 'ssnt.csv', 'stks.csv', 'sybx.csv', 'syrs.csv', 'tblt.csv', 'tedu.csv', 'tmdx.csv', 'tptx.csv', 'trmt.csv', 'twou.csv', 'twst.csv', 'tyht.csv', 'ubx.csv', 'unit.csv', 'usws.csv', 'vblt.csv', 'vbtx.csv', 'vcnx.csv', 'vcyt.csv', 'viot.csv', 'virt.csv', 'vktx.csv', 'vrex.csv', 'vrns.csv', 'vtvt.csv', 'wafu.csv', 'watt.csv', 'wix.csv', 'wkhs.csv', 'worx.csv', 'xbit.csv', 'xent.csv', 'xers.csv', 'xnet.csv', 'ymtx.csv', 'ziext.csv', 'zs.csv']

# %%
stocks_0_1_df.ticker.unique()
# Out:
# array(['DWPP', 'LOGC', 'FTXL', 'BWFG'], dtype=object)

# %% [markdown]
# ### Setting date to `datetime` type

# %%
stocks_0_1_df['date'] = pd.to_datetime(stocks_0_1_df['date'])

# %% [markdown]
# ### Standard Scaling

# %%
scaled_stocks_0_1_df = std_scaler(stocks_0_1_df)
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# ### Encoding the Returns

# %%
clean_stocks_0_1_df = thresholds_encoding(scaled_stocks_0_1_df)

# %% [markdown]
# ### Getting `X_train`, `y_train`, `X_test`, `y_test`

# %%
train, test = train_test_split(clean_stocks_0_1_df)

# %%
X_train, y_train = build_input_arrays(train)
X_test, y_test = build_input_arrays(test)

# %% [markdown]
# ## Model Initialisation

# %%
X_train.shape[1:]
# Out:
# (5, 12)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers, models 
from tensorflow.keras.optimizers import RMSprop, Adam

optim = RMSprop(learning_rate=0.000001)

def init_model(X_train):
    model = Sequential()
    model.add(layers.LSTM(200, return_sequences=True, input_shape=X_train.shape[1:], activation='tanh'))
    model.add(layers.LSTM(200, activation='tanh'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(200, activation='relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
    
    return model

# %%
model = init_model(X_train)

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=5, restore_best_weights=True)

model.fit(X_train, y_train, 
          epochs=500, 
          batch_size=8,
          validation_split=0.2,
          callbacks=[es]
         )
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 611ms/step - loss: 0.7012 - accuracy: 0.4167 - val_loss: 0.7147 - val_accuracy: 0.2500
# Epoch 2/500
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7100 - accuracy: 0.2500 - val_loss: 0.7146 - val_accuracy: 0.2500
# Epoch 3/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7058 - accuracy: 0.4167 - val_loss: 0.7145 - val_accuracy: 0.2500
# Epoch 4/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7010 - accuracy: 0.3333 - val_loss: 0.7144 - val_accuracy: 0.2500
# Epoch 5/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7023 - accuracy: 0.4167 - val_loss: 0.7143 - val_accuracy: 0.2500
# Epoch 6/500
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6975 - accuracy: 0.3333 - val_loss: 0.7142 - val_accuracy: 0.2500
# Epoch 7/500
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6970 - accuracy: 0.5000 - val_loss: 0.7142 - val_accuracy: 0.2500
# Epoch 8/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6968 - accuracy: 0.5000 - val_loss: 0.7141 - val_accuracy: 0.2500
# Epoch 9/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7012 - accuracy: 0.2500 - val_loss: 0.7141 - val_accuracy: 0.2500
# Epoch 10/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6946 - accuracy: 0.4167 - val_loss: 0.7140 - val_accuracy: 0.2500
# Epoch 11/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6965 - accuracy: 0.3333 - val_loss: 0.7139 - val_accuracy: 0.2500
# Epoch 12/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7009 - accuracy: 0.5000 - val_loss: 0.7139 - val_accuracy: 0.2500
# Epoch 13/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6999 - accuracy: 0.2500 - val_loss: 0.7138 - val_accuracy: 0.2500
# Epoch 14/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6984 - accuracy: 0.3333 - val_loss: 0.7137 - val_accuracy: 0.2500
# Epoch 15/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6983 - accuracy: 0.4167 - val_loss: 0.7137 - val_accuracy: 0.2500
# Epoch 16/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.7006 - accuracy: 0.3333 - val_loss: 0.7136 - val_accuracy: 0.2500
# Epoch 17/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7075 - accuracy: 0.1667 - val_loss: 0.7135 - val_accuracy: 0.2500
# Epoch 18/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6999 - accuracy: 0.4167 - val_loss: 0.7135 - val_accuracy: 0.2500
# Epoch 19/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6967 - accuracy: 0.5000 - val_loss: 0.7134 - val_accuracy: 0.2500
# Epoch 20/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7016 - accuracy: 0.2500 - val_loss: 0.7134 - val_accuracy: 0.2500
# Epoch 21/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.7075 - accuracy: 0.0833 - val_loss: 0.7133 - val_accuracy: 0.2500
# Epoch 22/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6983 - accuracy: 0.5000 - val_loss: 0.7133 - val_accuracy: 0.2500
# Epoch 23/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7044 - accuracy: 0.0833 - val_loss: 0.7133 - val_accuracy: 0.2500
# Epoch 24/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7011 - accuracy: 0.3333 - val_loss: 0.7132 - val_accuracy: 0.2500
# Epoch 25/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7055 - accuracy: 0.2500 - val_loss: 0.7131 - val_accuracy: 0.2500
# Epoch 26/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7039 - accuracy: 0.2500 - val_loss: 0.7130 - val_accuracy: 0.2500
# Epoch 27/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7010 - accuracy: 0.5000 - val_loss: 0.7130 - val_accuracy: 0.2500
# Epoch 28/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6925 - accuracy: 0.5833 - val_loss: 0.7129 - val_accuracy: 0.2500
# Epoch 29/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7000 - accuracy: 0.2500 - val_loss: 0.7129 - val_accuracy: 0.2500
# Epoch 30/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6973 - accuracy: 0.4167 - val_loss: 0.7128 - val_accuracy: 0.2500
# Epoch 31/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.7128 - val_accuracy: 0.2500
# Epoch 32/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7025 - accuracy: 0.2500 - val_loss: 0.7127 - val_accuracy: 0.2500
# Epoch 33/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6996 - accuracy: 0.2500 - val_loss: 0.7127 - val_accuracy: 0.2500
# Epoch 34/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6969 - accuracy: 0.1667 - val_loss: 0.7126 - val_accuracy: 0.2500
# Epoch 35/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7041 - accuracy: 0.2500 - val_loss: 0.7125 - val_accuracy: 0.2500
# Epoch 36/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6953 - accuracy: 0.5000 - val_loss: 0.7125 - val_accuracy: 0.2500
# Epoch 37/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7010 - accuracy: 0.3333 - val_loss: 0.7124 - val_accuracy: 0.2500
# Epoch 38/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6990 - accuracy: 0.4167 - val_loss: 0.7124 - val_accuracy: 0.2500
# Epoch 39/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6942 - accuracy: 0.3333 - val_loss: 0.7123 - val_accuracy: 0.2500
# Epoch 40/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6993 - accuracy: 0.4167 - val_loss: 0.7122 - val_accuracy: 0.2500
# Epoch 41/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7156 - accuracy: 0.2500 - val_loss: 0.7122 - val_accuracy: 0.2500
# Epoch 42/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7025 - accuracy: 0.3333 - val_loss: 0.7121 - val_accuracy: 0.2500
# Epoch 43/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6957 - accuracy: 0.2500 - val_loss: 0.7121 - val_accuracy: 0.2500
# Epoch 44/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6937 - accuracy: 0.5833 - val_loss: 0.7120 - val_accuracy: 0.2500
# Epoch 45/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7035 - accuracy: 0.3333 - val_loss: 0.7119 - val_accuracy: 0.2500
# Epoch 46/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6933 - accuracy: 0.3333 - val_loss: 0.7119 - val_accuracy: 0.2500
# Epoch 47/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6983 - accuracy: 0.3333 - val_loss: 0.7118 - val_accuracy: 0.2500
# Epoch 48/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7039 - accuracy: 0.3333 - val_loss: 0.7118 - val_accuracy: 0.2500
# Epoch 49/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7029 - accuracy: 0.2500 - val_loss: 0.7117 - val_accuracy: 0.2500
# Epoch 50/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6945 - accuracy: 0.5000 - val_loss: 0.7117 - val_accuracy: 0.2500
# Epoch 51/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6989 - accuracy: 0.4167 - val_loss: 0.7116 - val_accuracy: 0.2500
# Epoch 52/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6991 - accuracy: 0.2500 - val_loss: 0.7115 - val_accuracy: 0.2500
# Epoch 53/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6989 - accuracy: 0.3333 - val_loss: 0.7115 - val_accuracy: 0.2500
# Epoch 54/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6967 - accuracy: 0.4167 - val_loss: 0.7114 - val_accuracy: 0.2500
# Epoch 55/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6966 - accuracy: 0.3333 - val_loss: 0.7114 - val_accuracy: 0.2500
# Epoch 56/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6943 - accuracy: 0.6667 - val_loss: 0.7113 - val_accuracy: 0.2500
# Epoch 57/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7035 - accuracy: 0.0833 - val_loss: 0.7112 - val_accuracy: 0.2500
# Epoch 58/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7040 - accuracy: 0.1667 - val_loss: 0.7111 - val_accuracy: 0.2500
# Epoch 59/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7019 - accuracy: 0.3333 - val_loss: 0.7111 - val_accuracy: 0.2500
# Epoch 60/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6951 - accuracy: 0.4167 - val_loss: 0.7110 - val_accuracy: 0.2500
# Epoch 61/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6949 - accuracy: 0.4167 - val_loss: 0.7110 - val_accuracy: 0.2500
# Epoch 62/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7034 - accuracy: 0.2500 - val_loss: 0.7109 - val_accuracy: 0.2500
# Epoch 63/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7047 - accuracy: 0.2500 - val_loss: 0.7109 - val_accuracy: 0.2500
# Epoch 64/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7026 - accuracy: 0.3333 - val_loss: 0.7108 - val_accuracy: 0.2500
# Epoch 65/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6916 - accuracy: 0.5833 - val_loss: 0.7107 - val_accuracy: 0.2500
# Epoch 66/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.7106 - val_accuracy: 0.2500
# Epoch 67/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6966 - accuracy: 0.4167 - val_loss: 0.7106 - val_accuracy: 0.2500
# Epoch 68/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6960 - accuracy: 0.4167 - val_loss: 0.7105 - val_accuracy: 0.2500
# Epoch 69/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.7105 - val_accuracy: 0.2500
# Epoch 70/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7002 - accuracy: 0.3333 - val_loss: 0.7104 - val_accuracy: 0.2500
# Epoch 71/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6940 - accuracy: 0.4167 - val_loss: 0.7104 - val_accuracy: 0.2500
# Epoch 72/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6983 - accuracy: 0.3333 - val_loss: 0.7103 - val_accuracy: 0.2500
# Epoch 73/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6964 - accuracy: 0.4167 - val_loss: 0.7103 - val_accuracy: 0.2500
# Epoch 74/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6928 - accuracy: 0.5833 - val_loss: 0.7102 - val_accuracy: 0.2500
# Epoch 75/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6898 - accuracy: 0.5833 - val_loss: 0.7102 - val_accuracy: 0.2500
# Epoch 76/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6969 - accuracy: 0.4167 - val_loss: 0.7101 - val_accuracy: 0.2500
# Epoch 77/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6941 - accuracy: 0.4167 - val_loss: 0.7101 - val_accuracy: 0.2500
# Epoch 78/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6958 - accuracy: 0.5000 - val_loss: 0.7100 - val_accuracy: 0.2500
# Epoch 79/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6898 - accuracy: 0.5833 - val_loss: 0.7099 - val_accuracy: 0.2500
# Epoch 80/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6988 - accuracy: 0.4167 - val_loss: 0.7099 - val_accuracy: 0.2500
# Epoch 81/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.7098 - val_accuracy: 0.2500
# Epoch 82/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6934 - accuracy: 0.4167 - val_loss: 0.7098 - val_accuracy: 0.2500
# Epoch 83/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7029 - accuracy: 0.3333 - val_loss: 0.7097 - val_accuracy: 0.2500
# Epoch 84/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6982 - accuracy: 0.4167 - val_loss: 0.7096 - val_accuracy: 0.2500
# Epoch 85/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6966 - accuracy: 0.4167 - val_loss: 0.7096 - val_accuracy: 0.2500
# Epoch 86/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6947 - accuracy: 0.3333 - val_loss: 0.7095 - val_accuracy: 0.2500
# Epoch 87/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6948 - accuracy: 0.5000 - val_loss: 0.7095 - val_accuracy: 0.2500
# Epoch 88/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.7035 - accuracy: 0.2500 - val_loss: 0.7094 - val_accuracy: 0.2500
# Epoch 89/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7012 - accuracy: 0.4167 - val_loss: 0.7093 - val_accuracy: 0.2500
# Epoch 90/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6914 - accuracy: 0.4167 - val_loss: 0.7092 - val_accuracy: 0.2500
# Epoch 91/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6955 - accuracy: 0.5833 - val_loss: 0.7092 - val_accuracy: 0.2500
# Epoch 92/500
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6980 - accuracy: 0.3333 - val_loss: 0.7091 - val_accuracy: 0.2500
# Epoch 93/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6932 - accuracy: 0.3333 - val_loss: 0.7091 - val_accuracy: 0.2500
# Epoch 94/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6863 - accuracy: 0.5000 - val_loss: 0.7090 - val_accuracy: 0.2500
# Epoch 95/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7006 - accuracy: 0.3333 - val_loss: 0.7090 - val_accuracy: 0.2500
# Epoch 96/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6943 - accuracy: 0.4167 - val_loss: 0.7089 - val_accuracy: 0.2500
# Epoch 97/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7054 - accuracy: 0.2500 - val_loss: 0.7088 - val_accuracy: 0.2500
# Epoch 98/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6994 - accuracy: 0.3333 - val_loss: 0.7088 - val_accuracy: 0.2500
# Epoch 99/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6999 - accuracy: 0.5000 - val_loss: 0.7087 - val_accuracy: 0.2500
# Epoch 100/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6968 - accuracy: 0.3333 - val_loss: 0.7086 - val_accuracy: 0.2500
# Epoch 101/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.7086 - val_accuracy: 0.2500
# Epoch 102/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6982 - accuracy: 0.3333 - val_loss: 0.7085 - val_accuracy: 0.2500
# Epoch 103/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6962 - accuracy: 0.3333 - val_loss: 0.7085 - val_accuracy: 0.2500
# Epoch 104/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6970 - accuracy: 0.4167 - val_loss: 0.7084 - val_accuracy: 0.2500
# Epoch 105/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6941 - accuracy: 0.5000 - val_loss: 0.7084 - val_accuracy: 0.2500
# Epoch 106/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7043 - accuracy: 0.2500 - val_loss: 0.7083 - val_accuracy: 0.2500
# Epoch 107/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6919 - accuracy: 0.6667 - val_loss: 0.7082 - val_accuracy: 0.2500
# Epoch 108/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7031 - accuracy: 0.2500 - val_loss: 0.7082 - val_accuracy: 0.2500
# Epoch 109/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6972 - accuracy: 0.5833 - val_loss: 0.7081 - val_accuracy: 0.2500
# Epoch 110/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6963 - accuracy: 0.5000 - val_loss: 0.7081 - val_accuracy: 0.2500
# Epoch 111/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7042 - accuracy: 0.2500 - val_loss: 0.7080 - val_accuracy: 0.2500
# Epoch 112/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6935 - accuracy: 0.5833 - val_loss: 0.7080 - val_accuracy: 0.2500
# Epoch 113/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7040 - accuracy: 0.3333 - val_loss: 0.7079 - val_accuracy: 0.2500
# Epoch 114/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7038 - accuracy: 0.4167 - val_loss: 0.7078 - val_accuracy: 0.2500
# Epoch 115/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6915 - accuracy: 0.5000 - val_loss: 0.7078 - val_accuracy: 0.2500
# Epoch 116/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6961 - accuracy: 0.5833 - val_loss: 0.7077 - val_accuracy: 0.2500
# Epoch 117/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.7077 - val_accuracy: 0.2500
# Epoch 118/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6974 - accuracy: 0.2500 - val_loss: 0.7076 - val_accuracy: 0.2500
# Epoch 119/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6959 - accuracy: 0.3333 - val_loss: 0.7075 - val_accuracy: 0.2500
# Epoch 120/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6975 - accuracy: 0.3333 - val_loss: 0.7075 - val_accuracy: 0.2500
# Epoch 121/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6929 - accuracy: 0.5833 - val_loss: 0.7074 - val_accuracy: 0.2500
# Epoch 122/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7042 - accuracy: 0.1667 - val_loss: 0.7073 - val_accuracy: 0.2500
# Epoch 123/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6994 - accuracy: 0.4167 - val_loss: 0.7073 - val_accuracy: 0.2500
# Epoch 124/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.7072 - val_accuracy: 0.2500
# Epoch 125/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6916 - accuracy: 0.5000 - val_loss: 0.7072 - val_accuracy: 0.2500
# Epoch 126/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6913 - accuracy: 0.5833 - val_loss: 0.7071 - val_accuracy: 0.2500
# Epoch 127/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7014 - accuracy: 0.3333 - val_loss: 0.7071 - val_accuracy: 0.2500
# Epoch 128/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7028 - accuracy: 0.2500 - val_loss: 0.7070 - val_accuracy: 0.2500
# Epoch 129/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6990 - accuracy: 0.2500 - val_loss: 0.7070 - val_accuracy: 0.2500
# Epoch 130/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6973 - accuracy: 0.5000 - val_loss: 0.7069 - val_accuracy: 0.2500
# Epoch 131/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7022 - accuracy: 0.2500 - val_loss: 0.7069 - val_accuracy: 0.2500
# Epoch 132/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6869 - accuracy: 0.7500 - val_loss: 0.7068 - val_accuracy: 0.2500
# Epoch 133/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6985 - accuracy: 0.5000 - val_loss: 0.7068 - val_accuracy: 0.2500
# Epoch 134/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6961 - accuracy: 0.3333 - val_loss: 0.7067 - val_accuracy: 0.2500
# Epoch 135/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6954 - accuracy: 0.3333 - val_loss: 0.7067 - val_accuracy: 0.2500
# Epoch 136/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6940 - accuracy: 0.4167 - val_loss: 0.7066 - val_accuracy: 0.2500
# Epoch 137/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6945 - accuracy: 0.5000 - val_loss: 0.7065 - val_accuracy: 0.2500
# Epoch 138/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7034 - accuracy: 0.2500 - val_loss: 0.7065 - val_accuracy: 0.2500
# Epoch 139/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6979 - accuracy: 0.5000 - val_loss: 0.7064 - val_accuracy: 0.2500
# Epoch 140/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7008 - accuracy: 0.4167 - val_loss: 0.7063 - val_accuracy: 0.2500
# Epoch 141/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6958 - accuracy: 0.4167 - val_loss: 0.7063 - val_accuracy: 0.2500
# Epoch 142/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6941 - accuracy: 0.4167 - val_loss: 0.7062 - val_accuracy: 0.2500
# Epoch 143/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6902 - accuracy: 0.5000 - val_loss: 0.7062 - val_accuracy: 0.2500
# Epoch 144/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6946 - accuracy: 0.5000 - val_loss: 0.7061 - val_accuracy: 0.2500
# Epoch 145/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6912 - accuracy: 0.5000 - val_loss: 0.7061 - val_accuracy: 0.2500
# Epoch 146/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6998 - accuracy: 0.4167 - val_loss: 0.7060 - val_accuracy: 0.2500
# Epoch 147/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7020 - accuracy: 0.3333 - val_loss: 0.7059 - val_accuracy: 0.2500
# Epoch 148/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6870 - accuracy: 0.7500 - val_loss: 0.7059 - val_accuracy: 0.2500
# Epoch 149/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.7058 - val_accuracy: 0.2500
# Epoch 150/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6920 - accuracy: 0.4167 - val_loss: 0.7057 - val_accuracy: 0.2500
# Epoch 151/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6956 - accuracy: 0.5833 - val_loss: 0.7057 - val_accuracy: 0.2500
# Epoch 152/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6984 - accuracy: 0.3333 - val_loss: 0.7056 - val_accuracy: 0.2500
# Epoch 153/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6972 - accuracy: 0.3333 - val_loss: 0.7055 - val_accuracy: 0.2500
# Epoch 154/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7032 - accuracy: 0.2500 - val_loss: 0.7055 - val_accuracy: 0.2500
# Epoch 155/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6924 - accuracy: 0.5000 - val_loss: 0.7054 - val_accuracy: 0.2500
# Epoch 156/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6946 - accuracy: 0.5833 - val_loss: 0.7054 - val_accuracy: 0.2500
# Epoch 157/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6951 - accuracy: 0.3333 - val_loss: 0.7053 - val_accuracy: 0.2500
# Epoch 158/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.7053 - val_accuracy: 0.2500
# Epoch 159/500
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6879 - accuracy: 0.5833 - val_loss: 0.7052 - val_accuracy: 0.2500
# Epoch 160/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6954 - accuracy: 0.5000 - val_loss: 0.7051 - val_accuracy: 0.2500
# Epoch 161/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7005 - accuracy: 0.3333 - val_loss: 0.7051 - val_accuracy: 0.2500
# Epoch 162/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6887 - accuracy: 0.5000 - val_loss: 0.7050 - val_accuracy: 0.2500
# Epoch 163/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.7050 - val_accuracy: 0.2500
# Epoch 164/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6954 - accuracy: 0.3333 - val_loss: 0.7049 - val_accuracy: 0.2500
# Epoch 165/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6991 - accuracy: 0.2500 - val_loss: 0.7049 - val_accuracy: 0.2500
# Epoch 166/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.7048 - val_accuracy: 0.2500
# Epoch 167/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6954 - accuracy: 0.4167 - val_loss: 0.7047 - val_accuracy: 0.2500
# Epoch 168/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7011 - accuracy: 0.4167 - val_loss: 0.7047 - val_accuracy: 0.2500
# Epoch 169/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6959 - accuracy: 0.5000 - val_loss: 0.7046 - val_accuracy: 0.2500
# Epoch 170/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6958 - accuracy: 0.4167 - val_loss: 0.7046 - val_accuracy: 0.2500
# Epoch 171/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6988 - accuracy: 0.2500 - val_loss: 0.7045 - val_accuracy: 0.2500
# Epoch 172/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7014 - accuracy: 0.1667 - val_loss: 0.7045 - val_accuracy: 0.2500
# Epoch 173/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6970 - accuracy: 0.2500 - val_loss: 0.7044 - val_accuracy: 0.2500
# Epoch 174/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7006 - accuracy: 0.2500 - val_loss: 0.7043 - val_accuracy: 0.2500
# Epoch 175/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.7043 - val_accuracy: 0.2500
# Epoch 176/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6896 - accuracy: 0.5833 - val_loss: 0.7042 - val_accuracy: 0.2500
# Epoch 177/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7031 - accuracy: 0.5000 - val_loss: 0.7041 - val_accuracy: 0.2500
# Epoch 178/500
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7048 - accuracy: 0.0833 - val_loss: 0.7041 - val_accuracy: 0.2500
# Epoch 179/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6959 - accuracy: 0.4167 - val_loss: 0.7040 - val_accuracy: 0.2500
# Epoch 180/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6915 - accuracy: 0.5833 - val_loss: 0.7040 - val_accuracy: 0.2500
# Epoch 181/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.7013 - accuracy: 0.3333 - val_loss: 0.7039 - val_accuracy: 0.2500
# Epoch 182/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6879 - accuracy: 0.6667 - val_loss: 0.7038 - val_accuracy: 0.2500
# Epoch 183/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6843 - accuracy: 0.8333 - val_loss: 0.7038 - val_accuracy: 0.2500
# Epoch 184/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6891 - accuracy: 0.5833 - val_loss: 0.7037 - val_accuracy: 0.2500
# Epoch 185/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6870 - accuracy: 0.6667 - val_loss: 0.7037 - val_accuracy: 0.2500
# Epoch 186/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6957 - accuracy: 0.3333 - val_loss: 0.7036 - val_accuracy: 0.2500
# Epoch 187/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6966 - accuracy: 0.3333 - val_loss: 0.7036 - val_accuracy: 0.2500
# Epoch 188/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7016 - accuracy: 0.4167 - val_loss: 0.7036 - val_accuracy: 0.2500
# Epoch 189/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6871 - accuracy: 0.5000 - val_loss: 0.7035 - val_accuracy: 0.2500
# Epoch 190/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6918 - accuracy: 0.5833 - val_loss: 0.7034 - val_accuracy: 0.2500
# Epoch 191/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6938 - accuracy: 0.4167 - val_loss: 0.7034 - val_accuracy: 0.2500
# Epoch 192/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6973 - accuracy: 0.3333 - val_loss: 0.7033 - val_accuracy: 0.2500
# Epoch 193/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6918 - accuracy: 0.3333 - val_loss: 0.7032 - val_accuracy: 0.2500
# Epoch 194/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6958 - accuracy: 0.3333 - val_loss: 0.7032 - val_accuracy: 0.2500
# Epoch 195/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6908 - accuracy: 0.4167 - val_loss: 0.7031 - val_accuracy: 0.2500
# Epoch 196/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6986 - accuracy: 0.3333 - val_loss: 0.7031 - val_accuracy: 0.2500
# Epoch 197/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6960 - accuracy: 0.5833 - val_loss: 0.7030 - val_accuracy: 0.2500
# Epoch 198/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6919 - accuracy: 0.2500 - val_loss: 0.7030 - val_accuracy: 0.2500
# Epoch 199/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6888 - accuracy: 0.5833 - val_loss: 0.7029 - val_accuracy: 0.2500
# Epoch 200/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6958 - accuracy: 0.5000 - val_loss: 0.7029 - val_accuracy: 0.2500
# Epoch 201/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6960 - accuracy: 0.4167 - val_loss: 0.7029 - val_accuracy: 0.2500
# Epoch 202/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6955 - accuracy: 0.5000 - val_loss: 0.7028 - val_accuracy: 0.2500
# Epoch 203/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6961 - accuracy: 0.5000 - val_loss: 0.7028 - val_accuracy: 0.2500
# Epoch 204/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6932 - accuracy: 0.5833 - val_loss: 0.7027 - val_accuracy: 0.2500
# Epoch 205/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6884 - accuracy: 0.7500 - val_loss: 0.7027 - val_accuracy: 0.2500
# Epoch 206/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6942 - accuracy: 0.4167 - val_loss: 0.7026 - val_accuracy: 0.2500
# Epoch 207/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6911 - accuracy: 0.4167 - val_loss: 0.7026 - val_accuracy: 0.2500
# Epoch 208/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6926 - accuracy: 0.5000 - val_loss: 0.7025 - val_accuracy: 0.2500
# Epoch 209/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.7024 - val_accuracy: 0.2500
# Epoch 210/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6930 - accuracy: 0.5833 - val_loss: 0.7024 - val_accuracy: 0.2500
# Epoch 211/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6960 - accuracy: 0.5833 - val_loss: 0.7023 - val_accuracy: 0.2500
# Epoch 212/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6975 - accuracy: 0.4167 - val_loss: 0.7023 - val_accuracy: 0.2500
# Epoch 213/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6976 - accuracy: 0.4167 - val_loss: 0.7022 - val_accuracy: 0.2500
# Epoch 214/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6907 - accuracy: 0.5833 - val_loss: 0.7021 - val_accuracy: 0.2500
# Epoch 215/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6927 - accuracy: 0.4167 - val_loss: 0.7021 - val_accuracy: 0.2500
# Epoch 216/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6967 - accuracy: 0.5000 - val_loss: 0.7021 - val_accuracy: 0.2500
# Epoch 217/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7028 - accuracy: 0.3333 - val_loss: 0.7020 - val_accuracy: 0.2500
# Epoch 218/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6959 - accuracy: 0.4167 - val_loss: 0.7019 - val_accuracy: 0.2500
# Epoch 219/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6918 - accuracy: 0.6667 - val_loss: 0.7019 - val_accuracy: 0.2500
# Epoch 220/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6984 - accuracy: 0.5833 - val_loss: 0.7018 - val_accuracy: 0.2500
# Epoch 221/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6992 - accuracy: 0.4167 - val_loss: 0.7018 - val_accuracy: 0.2500
# Epoch 222/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6868 - accuracy: 0.5833 - val_loss: 0.7017 - val_accuracy: 0.2500
# Epoch 223/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6944 - accuracy: 0.5000 - val_loss: 0.7016 - val_accuracy: 0.2500
# Epoch 224/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6873 - accuracy: 0.5833 - val_loss: 0.7016 - val_accuracy: 0.2500
# Epoch 225/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6925 - accuracy: 0.5833 - val_loss: 0.7015 - val_accuracy: 0.2500
# Epoch 226/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6871 - accuracy: 0.7500 - val_loss: 0.7015 - val_accuracy: 0.2500
# Epoch 227/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6891 - accuracy: 0.5000 - val_loss: 0.7014 - val_accuracy: 0.2500
# Epoch 228/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6894 - accuracy: 0.6667 - val_loss: 0.7014 - val_accuracy: 0.2500
# Epoch 229/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6971 - accuracy: 0.3333 - val_loss: 0.7013 - val_accuracy: 0.2500
# Epoch 230/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6991 - accuracy: 0.4167 - val_loss: 0.7013 - val_accuracy: 0.2500
# Epoch 231/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6915 - accuracy: 0.4167 - val_loss: 0.7012 - val_accuracy: 0.2500
# Epoch 232/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6891 - accuracy: 0.5000 - val_loss: 0.7012 - val_accuracy: 0.2500
# Epoch 233/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6972 - accuracy: 0.5000 - val_loss: 0.7011 - val_accuracy: 0.2500
# Epoch 234/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6975 - accuracy: 0.4167 - val_loss: 0.7010 - val_accuracy: 0.2500
# Epoch 235/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7009 - accuracy: 0.4167 - val_loss: 0.7010 - val_accuracy: 0.2500
# Epoch 236/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6868 - accuracy: 0.6667 - val_loss: 0.7010 - val_accuracy: 0.2500
# Epoch 237/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6992 - accuracy: 0.4167 - val_loss: 0.7009 - val_accuracy: 0.2500
# Epoch 238/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6969 - accuracy: 0.4167 - val_loss: 0.7009 - val_accuracy: 0.2500
# Epoch 239/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6963 - accuracy: 0.5000 - val_loss: 0.7008 - val_accuracy: 0.2500
# Epoch 240/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6931 - accuracy: 0.3333 - val_loss: 0.7008 - val_accuracy: 0.2500
# Epoch 241/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.7007 - val_accuracy: 0.2500
# Epoch 242/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6905 - accuracy: 0.6667 - val_loss: 0.7006 - val_accuracy: 0.2500
# Epoch 243/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6877 - accuracy: 0.6667 - val_loss: 0.7006 - val_accuracy: 0.2500
# Epoch 244/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6926 - accuracy: 0.5000 - val_loss: 0.7005 - val_accuracy: 0.2500
# Epoch 245/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7057 - accuracy: 0.1667 - val_loss: 0.7004 - val_accuracy: 0.2500
# Epoch 246/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6912 - accuracy: 0.5833 - val_loss: 0.7004 - val_accuracy: 0.2500
# Epoch 247/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6896 - accuracy: 0.4167 - val_loss: 0.7003 - val_accuracy: 0.2500
# Epoch 248/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6888 - accuracy: 0.7500 - val_loss: 0.7003 - val_accuracy: 0.2500
# Epoch 249/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6938 - accuracy: 0.4167 - val_loss: 0.7002 - val_accuracy: 0.2500
# Epoch 250/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6967 - accuracy: 0.3333 - val_loss: 0.7002 - val_accuracy: 0.2500
# Epoch 251/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6983 - accuracy: 0.2500 - val_loss: 0.7001 - val_accuracy: 0.2500
# Epoch 252/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6925 - accuracy: 0.5833 - val_loss: 0.7001 - val_accuracy: 0.2500
# Epoch 253/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6957 - accuracy: 0.4167 - val_loss: 0.7000 - val_accuracy: 0.2500
# Epoch 254/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6968 - accuracy: 0.5000 - val_loss: 0.7000 - val_accuracy: 0.2500
# Epoch 255/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6952 - accuracy: 0.4167 - val_loss: 0.6999 - val_accuracy: 0.2500
# Epoch 256/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6926 - accuracy: 0.4167 - val_loss: 0.6998 - val_accuracy: 0.2500
# Epoch 257/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6888 - accuracy: 0.6667 - val_loss: 0.6998 - val_accuracy: 0.2500
# Epoch 258/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6925 - accuracy: 0.6667 - val_loss: 0.6998 - val_accuracy: 0.2500
# Epoch 259/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6954 - accuracy: 0.2500 - val_loss: 0.6997 - val_accuracy: 0.2500
# Epoch 260/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6917 - accuracy: 0.5833 - val_loss: 0.6997 - val_accuracy: 0.2500
# Epoch 261/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6975 - accuracy: 0.3333 - val_loss: 0.6996 - val_accuracy: 0.2500
# Epoch 262/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6930 - accuracy: 0.5833 - val_loss: 0.6995 - val_accuracy: 0.2500
# Epoch 263/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6848 - accuracy: 0.6667 - val_loss: 0.6995 - val_accuracy: 0.2500
# Epoch 264/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6817 - accuracy: 0.8333 - val_loss: 0.6994 - val_accuracy: 0.2500
# Epoch 265/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6844 - accuracy: 0.6667 - val_loss: 0.6994 - val_accuracy: 0.2500
# Epoch 266/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6883 - accuracy: 0.5833 - val_loss: 0.6993 - val_accuracy: 0.2500
# Epoch 267/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6918 - accuracy: 0.6667 - val_loss: 0.6993 - val_accuracy: 0.2500
# Epoch 268/500
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6834 - accuracy: 0.7500 - val_loss: 0.6992 - val_accuracy: 0.2500
# Epoch 269/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6942 - accuracy: 0.5000 - val_loss: 0.6992 - val_accuracy: 0.2500
# Epoch 270/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6897 - accuracy: 0.6667 - val_loss: 0.6991 - val_accuracy: 0.2500
# Epoch 271/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6906 - accuracy: 0.6667 - val_loss: 0.6991 - val_accuracy: 0.2500
# Epoch 272/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6918 - accuracy: 0.5000 - val_loss: 0.6990 - val_accuracy: 0.2500
# Epoch 273/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6888 - accuracy: 0.5000 - val_loss: 0.6990 - val_accuracy: 0.2500
# Epoch 274/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6925 - accuracy: 0.6667 - val_loss: 0.6989 - val_accuracy: 0.2500
# Epoch 275/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6955 - accuracy: 0.4167 - val_loss: 0.6988 - val_accuracy: 0.2500
# Epoch 276/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6861 - accuracy: 0.6667 - val_loss: 0.6988 - val_accuracy: 0.2500
# Epoch 277/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6864 - accuracy: 0.6667 - val_loss: 0.6987 - val_accuracy: 0.2500
# Epoch 278/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6847 - accuracy: 0.7500 - val_loss: 0.6987 - val_accuracy: 0.2500
# Epoch 279/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6879 - accuracy: 0.5000 - val_loss: 0.6986 - val_accuracy: 0.2500
# Epoch 280/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6957 - accuracy: 0.4167 - val_loss: 0.6986 - val_accuracy: 0.2500
# Epoch 281/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6964 - accuracy: 0.4167 - val_loss: 0.6985 - val_accuracy: 0.2500
# Epoch 282/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6920 - accuracy: 0.5000 - val_loss: 0.6985 - val_accuracy: 0.2500
# Epoch 283/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.6984 - val_accuracy: 0.2500
# Epoch 284/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6891 - accuracy: 0.6667 - val_loss: 0.6983 - val_accuracy: 0.2500
# Epoch 285/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6920 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.2500
# Epoch 286/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6969 - accuracy: 0.5000 - val_loss: 0.6982 - val_accuracy: 0.2500
# Epoch 287/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6858 - accuracy: 0.9167 - val_loss: 0.6982 - val_accuracy: 0.2500
# Epoch 288/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6914 - accuracy: 0.6667 - val_loss: 0.6981 - val_accuracy: 0.2500
# Epoch 289/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7002 - accuracy: 0.3333 - val_loss: 0.6980 - val_accuracy: 0.2500
# Epoch 290/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6914 - accuracy: 0.4167 - val_loss: 0.6980 - val_accuracy: 0.2500
# Epoch 291/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6890 - accuracy: 0.5000 - val_loss: 0.6979 - val_accuracy: 0.2500
# Epoch 292/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6956 - accuracy: 0.5000 - val_loss: 0.6979 - val_accuracy: 0.2500
# Epoch 293/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6896 - accuracy: 0.5833 - val_loss: 0.6978 - val_accuracy: 0.2500
# Epoch 294/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6878 - accuracy: 0.6667 - val_loss: 0.6978 - val_accuracy: 0.2500
# Epoch 295/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6868 - accuracy: 0.6667 - val_loss: 0.6977 - val_accuracy: 0.2500
# Epoch 296/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6968 - accuracy: 0.4167 - val_loss: 0.6977 - val_accuracy: 0.2500
# Epoch 297/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6976 - val_accuracy: 0.2500
# Epoch 298/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6850 - accuracy: 0.7500 - val_loss: 0.6976 - val_accuracy: 0.2500
# Epoch 299/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6896 - accuracy: 0.6667 - val_loss: 0.6975 - val_accuracy: 0.2500
# Epoch 300/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6876 - accuracy: 0.6667 - val_loss: 0.6975 - val_accuracy: 0.2500
# Epoch 301/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6846 - accuracy: 0.7500 - val_loss: 0.6974 - val_accuracy: 0.2500
# Epoch 302/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6904 - accuracy: 0.5833 - val_loss: 0.6974 - val_accuracy: 0.2500
# Epoch 303/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6953 - accuracy: 0.5000 - val_loss: 0.6973 - val_accuracy: 0.2500
# Epoch 304/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6973 - val_accuracy: 0.2500
# Epoch 305/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6807 - accuracy: 0.8333 - val_loss: 0.6972 - val_accuracy: 0.2500
# Epoch 306/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6853 - accuracy: 0.7500 - val_loss: 0.6972 - val_accuracy: 0.2500
# Epoch 307/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6889 - accuracy: 0.5833 - val_loss: 0.6971 - val_accuracy: 0.2500
# Epoch 308/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6862 - accuracy: 0.8333 - val_loss: 0.6970 - val_accuracy: 0.2500
# Epoch 309/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6849 - accuracy: 0.7500 - val_loss: 0.6970 - val_accuracy: 0.2500
# Epoch 310/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6916 - accuracy: 0.6667 - val_loss: 0.6969 - val_accuracy: 0.2500
# Epoch 311/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6887 - accuracy: 0.6667 - val_loss: 0.6969 - val_accuracy: 0.2500
# Epoch 312/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6880 - accuracy: 0.6667 - val_loss: 0.6968 - val_accuracy: 0.2500
# Epoch 313/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6880 - accuracy: 0.5833 - val_loss: 0.6968 - val_accuracy: 0.2500
# Epoch 314/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6896 - accuracy: 0.5833 - val_loss: 0.6967 - val_accuracy: 0.2500
# Epoch 315/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6905 - accuracy: 0.5833 - val_loss: 0.6966 - val_accuracy: 0.2500
# Epoch 316/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6913 - accuracy: 0.5833 - val_loss: 0.6966 - val_accuracy: 0.2500
# Epoch 317/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6966 - accuracy: 0.2500 - val_loss: 0.6965 - val_accuracy: 0.2500
# Epoch 318/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6891 - accuracy: 0.5833 - val_loss: 0.6965 - val_accuracy: 0.2500
# Epoch 319/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6926 - accuracy: 0.4167 - val_loss: 0.6964 - val_accuracy: 0.2500
# Epoch 320/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6891 - accuracy: 0.5000 - val_loss: 0.6964 - val_accuracy: 0.2500
# Epoch 321/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6920 - accuracy: 0.5000 - val_loss: 0.6963 - val_accuracy: 0.2500
# Epoch 322/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6914 - accuracy: 0.5833 - val_loss: 0.6963 - val_accuracy: 0.2500
# Epoch 323/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6895 - accuracy: 0.5000 - val_loss: 0.6962 - val_accuracy: 0.2500
# Epoch 324/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6981 - accuracy: 0.4167 - val_loss: 0.6962 - val_accuracy: 0.2500
# Epoch 325/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6907 - accuracy: 0.5000 - val_loss: 0.6961 - val_accuracy: 0.2500
# Epoch 326/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7003 - accuracy: 0.3333 - val_loss: 0.6961 - val_accuracy: 0.2500
# Epoch 327/500
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6874 - accuracy: 0.6667 - val_loss: 0.6960 - val_accuracy: 0.2500
# Epoch 328/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6909 - accuracy: 0.5833 - val_loss: 0.6960 - val_accuracy: 0.2500
# Epoch 329/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6871 - accuracy: 0.5833 - val_loss: 0.6959 - val_accuracy: 0.2500
# Epoch 330/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6887 - accuracy: 0.5000 - val_loss: 0.6958 - val_accuracy: 0.2500
# Epoch 331/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6920 - accuracy: 0.5833 - val_loss: 0.6958 - val_accuracy: 0.2500
# Epoch 332/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7043 - accuracy: 0.0833 - val_loss: 0.6957 - val_accuracy: 0.2500
# Epoch 333/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6869 - accuracy: 0.7500 - val_loss: 0.6956 - val_accuracy: 0.2500
# Epoch 334/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6926 - accuracy: 0.6667 - val_loss: 0.6956 - val_accuracy: 0.2500
# Epoch 335/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6936 - accuracy: 0.4167 - val_loss: 0.6955 - val_accuracy: 0.2500
# Epoch 336/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6831 - accuracy: 0.7500 - val_loss: 0.6955 - val_accuracy: 0.2500
# Epoch 337/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6863 - accuracy: 0.5000 - val_loss: 0.6954 - val_accuracy: 0.2500
# Epoch 338/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6882 - accuracy: 0.6667 - val_loss: 0.6954 - val_accuracy: 0.2500
# Epoch 339/500
# ...
# Epoch 389/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6852 - accuracy: 0.7500 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 390/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6836 - accuracy: 0.6667 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 391/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 392/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6927 - accuracy: 0.5833 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 393/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6818 - accuracy: 0.8333 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 394/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6839 - accuracy: 0.7500 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 395/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6927 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 396/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6876 - accuracy: 0.5000 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 397/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6853 - accuracy: 0.6667 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 398/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6862 - accuracy: 0.6667 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 399/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6898 - accuracy: 0.5000 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 400/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6811 - accuracy: 0.8333 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 401/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6851 - accuracy: 0.8333 - val_loss: 0.6920 - val_accuracy: 0.5000
# Epoch 402/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6876 - accuracy: 0.5833 - val_loss: 0.6920 - val_accuracy: 0.5000
# Epoch 403/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6827 - accuracy: 0.7500 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 404/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6908 - accuracy: 0.5833 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 405/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6922 - accuracy: 0.5000 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 406/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6888 - accuracy: 0.5000 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 407/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6875 - accuracy: 0.5833 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 408/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6866 - accuracy: 0.5000 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 409/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6819 - accuracy: 0.7500 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 410/500
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6913 - accuracy: 0.3333 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 411/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6864 - accuracy: 0.5833 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 412/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6958 - accuracy: 0.5000 - val_loss: 0.6914 - val_accuracy: 0.5000
# Epoch 413/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6810 - accuracy: 0.6667 - val_loss: 0.6914 - val_accuracy: 0.5000
# Epoch 414/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6903 - accuracy: 0.6667 - val_loss: 0.6913 - val_accuracy: 0.5000
# Epoch 415/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6852 - accuracy: 0.7500 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 416/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6831 - accuracy: 0.7500 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 417/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6928 - accuracy: 0.3333 - val_loss: 0.6911 - val_accuracy: 0.5000
# Epoch 418/500
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6860 - accuracy: 0.5833 - val_loss: 0.6911 - val_accuracy: 0.5000
# Epoch 419/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6886 - accuracy: 0.5833 - val_loss: 0.6910 - val_accuracy: 0.5000
# Epoch 420/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6813 - accuracy: 0.7500 - val_loss: 0.6910 - val_accuracy: 0.5000
# Epoch 421/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6902 - accuracy: 0.5833 - val_loss: 0.6909 - val_accuracy: 0.5000
# Epoch 422/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6870 - accuracy: 0.5833 - val_loss: 0.6909 - val_accuracy: 0.5000
# Epoch 423/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6935 - accuracy: 0.7500 - val_loss: 0.6908 - val_accuracy: 0.5000
# Epoch 424/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6821 - accuracy: 0.6667 - val_loss: 0.6908 - val_accuracy: 0.5000
# Epoch 425/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6863 - accuracy: 0.6667 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 426/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6881 - accuracy: 0.5833 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 427/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6844 - accuracy: 0.6667 - val_loss: 0.6906 - val_accuracy: 0.5000
# Epoch 428/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6873 - accuracy: 0.5000 - val_loss: 0.6906 - val_accuracy: 0.5000
# Epoch 429/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6946 - accuracy: 0.4167 - val_loss: 0.6905 - val_accuracy: 0.5000
# Epoch 430/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6830 - accuracy: 0.7500 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 431/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6857 - accuracy: 0.5833 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 432/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6890 - accuracy: 0.6667 - val_loss: 0.6903 - val_accuracy: 0.5000
# Epoch 433/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6877 - accuracy: 0.5833 - val_loss: 0.6903 - val_accuracy: 0.5000
# Epoch 434/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6870 - accuracy: 0.7500 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 435/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6878 - accuracy: 0.5833 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 436/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6927 - accuracy: 0.3333 - val_loss: 0.6901 - val_accuracy: 0.5000
# Epoch 437/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6939 - accuracy: 0.5833 - val_loss: 0.6901 - val_accuracy: 0.5000
# Epoch 438/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6842 - accuracy: 0.6667 - val_loss: 0.6900 - val_accuracy: 0.5000
# Epoch 439/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6864 - accuracy: 0.8333 - val_loss: 0.6900 - val_accuracy: 0.5000
# Epoch 440/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6854 - accuracy: 0.8333 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 441/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6857 - accuracy: 0.5833 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 442/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6888 - accuracy: 0.5833 - val_loss: 0.6898 - val_accuracy: 0.5000
# Epoch 443/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6803 - accuracy: 0.9167 - val_loss: 0.6898 - val_accuracy: 0.5000
# Epoch 444/500
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6880 - accuracy: 0.5000 - val_loss: 0.6897 - val_accuracy: 0.5000
# Epoch 445/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6899 - accuracy: 0.5000 - val_loss: 0.6897 - val_accuracy: 0.5000
# Epoch 446/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6831 - accuracy: 0.7500 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 447/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6857 - accuracy: 0.5000 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 448/500
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6922 - accuracy: 0.4167 - val_loss: 0.6895 - val_accuracy: 0.5000
# Epoch 449/500
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6894 - val_accuracy: 0.5000
# Epoch 450/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6823 - accuracy: 0.5833 - val_loss: 0.6894 - val_accuracy: 0.7500
# Epoch 451/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6926 - accuracy: 0.5000 - val_loss: 0.6893 - val_accuracy: 0.7500
# Epoch 452/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6893 - val_accuracy: 0.7500
# Epoch 453/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6845 - accuracy: 0.8333 - val_loss: 0.6893 - val_accuracy: 0.7500
# Epoch 454/500
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6876 - accuracy: 0.6667 - val_loss: 0.6892 - val_accuracy: 0.7500
# Epoch 455/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6851 - accuracy: 0.6667 - val_loss: 0.6892 - val_accuracy: 0.7500
# Epoch 456/500
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6902 - accuracy: 0.5000 - val_loss: 0.6891 - val_accuracy: 0.7500
# Epoch 457/500
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6890 - val_accuracy: 0.7500
# Epoch 458/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6884 - accuracy: 0.6667 - val_loss: 0.6890 - val_accuracy: 0.7500
# Epoch 459/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6843 - accuracy: 0.6667 - val_loss: 0.6889 - val_accuracy: 0.7500
# Epoch 460/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6854 - accuracy: 0.7500 - val_loss: 0.6889 - val_accuracy: 0.7500
# Epoch 461/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6915 - accuracy: 0.5000 - val_loss: 0.6888 - val_accuracy: 0.7500
# Epoch 462/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6835 - accuracy: 0.8333 - val_loss: 0.6888 - val_accuracy: 0.7500
# Epoch 463/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6832 - accuracy: 0.5833 - val_loss: 0.6887 - val_accuracy: 0.7500
# Epoch 464/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6879 - accuracy: 0.6667 - val_loss: 0.6887 - val_accuracy: 0.7500
# Epoch 465/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6803 - accuracy: 0.7500 - val_loss: 0.6887 - val_accuracy: 0.7500
# Epoch 466/500
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6923 - accuracy: 0.5000 - val_loss: 0.6886 - val_accuracy: 0.7500
# Epoch 467/500
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6795 - accuracy: 0.7500 - val_loss: 0.6885 - val_accuracy: 0.7500
# Epoch 468/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6864 - accuracy: 0.4167 - val_loss: 0.6885 - val_accuracy: 0.7500
# Epoch 469/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6900 - accuracy: 0.5833 - val_loss: 0.6885 - val_accuracy: 0.7500
# Epoch 470/500
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6847 - accuracy: 0.6667 - val_loss: 0.6884 - val_accuracy: 0.7500
# Epoch 471/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6842 - accuracy: 0.5833 - val_loss: 0.6883 - val_accuracy: 0.7500
# Epoch 472/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6867 - accuracy: 0.7500 - val_loss: 0.6883 - val_accuracy: 0.7500
# Epoch 473/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6850 - accuracy: 0.5833 - val_loss: 0.6882 - val_accuracy: 0.7500
# Epoch 474/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6793 - accuracy: 0.6667 - val_loss: 0.6882 - val_accuracy: 0.7500
# Epoch 475/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6891 - accuracy: 0.6667 - val_loss: 0.6881 - val_accuracy: 0.7500
# Epoch 476/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6822 - accuracy: 0.6667 - val_loss: 0.6881 - val_accuracy: 0.7500
# Epoch 477/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6762 - accuracy: 0.8333 - val_loss: 0.6880 - val_accuracy: 0.7500
# Epoch 478/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6839 - accuracy: 0.6667 - val_loss: 0.6880 - val_accuracy: 0.7500
# Epoch 479/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6879 - accuracy: 0.5000 - val_loss: 0.6879 - val_accuracy: 0.7500
# Epoch 480/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6884 - accuracy: 0.5000 - val_loss: 0.6878 - val_accuracy: 0.7500
# Epoch 481/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6787 - accuracy: 0.8333 - val_loss: 0.6878 - val_accuracy: 0.7500
# Epoch 482/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6874 - accuracy: 0.6667 - val_loss: 0.6878 - val_accuracy: 0.7500
# Epoch 483/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6967 - accuracy: 0.3333 - val_loss: 0.6877 - val_accuracy: 0.7500
# Epoch 484/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6809 - accuracy: 0.6667 - val_loss: 0.6876 - val_accuracy: 0.7500
# Epoch 485/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6811 - accuracy: 0.7500 - val_loss: 0.6876 - val_accuracy: 0.7500
# Epoch 486/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6884 - accuracy: 0.7500 - val_loss: 0.6875 - val_accuracy: 0.7500
# Epoch 487/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6849 - accuracy: 0.7500 - val_loss: 0.6875 - val_accuracy: 0.7500
# Epoch 488/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6806 - accuracy: 0.7500 - val_loss: 0.6874 - val_accuracy: 0.7500
# Epoch 489/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6873 - accuracy: 0.5000 - val_loss: 0.6874 - val_accuracy: 0.7500
# Epoch 490/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6870 - accuracy: 0.7500 - val_loss: 0.6873 - val_accuracy: 0.7500
# Epoch 491/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6854 - accuracy: 0.7500 - val_loss: 0.6872 - val_accuracy: 0.7500
# Epoch 492/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6796 - accuracy: 0.9167 - val_loss: 0.6872 - val_accuracy: 0.7500
# Epoch 493/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6925 - accuracy: 0.4167 - val_loss: 0.6871 - val_accuracy: 0.7500
# Epoch 494/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6909 - accuracy: 0.5000 - val_loss: 0.6871 - val_accuracy: 0.7500
# Epoch 495/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6883 - accuracy: 0.6667 - val_loss: 0.6871 - val_accuracy: 0.7500
# Epoch 496/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6848 - accuracy: 0.7500 - val_loss: 0.6870 - val_accuracy: 0.7500
# Epoch 497/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6931 - accuracy: 0.5833 - val_loss: 0.6870 - val_accuracy: 0.7500
# Epoch 498/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6854 - accuracy: 0.6667 - val_loss: 0.6869 - val_accuracy: 0.7500
# Epoch 499/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6834 - accuracy: 0.7500 - val_loss: 0.6868 - val_accuracy: 0.7500
# Epoch 500/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6821 - accuracy: 0.5833 - val_loss: 0.6868 - val_accuracy: 0.7500
