# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import joblib
import os
import random

# %% [markdown]
# ====================================================================================================
#
# **Goal : gather similar companies according to their features and number of trading days**
#
# **Use : provide coherent and meaningful data to model**
#
#
# **(_Ideal_ : develop tailored model to each type of groups)**
#
#
#
# **_See Notebook `Table of content` for good understanding about what this notebook is doing when ran_**
#
# ====================================================================================================

# %% [markdown]
# # Anaysis of Companies Age from `nasdaq_us_stats.xls`

# %%
#!!!Path might not be the same!!!

meta_df = pd.read_csv('../../../raw_data/metadata/nasdaq_us_stats.xls')

# %%
meta_df.head()
# Out:
#    Unnamed: 0     stock  days  min_close  max_close  start_date    end_date
# 0           0   AACG.US  3165    0.21703      3.850  2008-01-28  2021-01-25
# 1           1   AACQ.US    96    9.62000     11.070  2020-09-08  2021-01-25
# 2           2  AACQU.US   134   10.00000     11.900  2020-07-15  2021-01-25
# 3           3  AACQW.US    95    1.07500      2.580  2020-09-09  2021-01-25
# 4           4    AAL.US  1793    9.04000     56.989  2013-12-10  2021-01-25

# %%
meta_df.describe()
# Out:
#         Unnamed: 0          days    min_close     max_close
# count  3921.000000   3921.000000  3921.000000  3.921000e+03
# mean   1960.000000   1876.186942     8.257047  6.181576e+06
# std    1132.039531   1795.084440    16.268917  3.863434e+08
# min       0.000000      1.000000     0.001000  2.400000e-01
# 25%     980.000000    312.000000     1.490000  1.438700e+01
# 50%    1960.000000   1286.000000     5.010000  2.880000e+01
# 75%    2940.000000   3775.000000    10.384000  6.533000e+01
# max    3920.000000  12879.000000   647.290000  2.419200e+10

# %%
meta_df = meta_df[['stock', 'days', 'min_close', 'max_close']]

# %% [markdown]
# ## Company age classification

# %%
meta_df['range_price'] = meta_df['max_close'] - meta_df['min_close']
meta_df['years'] = meta_df['days']/365

# %%
clean_meta_df = meta_df[['stock', 'years', 'range_price']]

# %%
sns.histplot(clean_meta_df['years'], binwidth=1)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %% [markdown]
# 👆👆**Anomaly at less than 1 year and 10 year old companies**👆👆

# %%
bins = [0, 1, 5, 10, 15, 20, 25, 30, 40]

clean_meta_df['company_vintage'] = pd.cut(meta_df['years'].copy(), 
                                          bins)                            # A company aged of 1Y and one day is
                                          #labels=['(0, 1]','(1, 5]',       # part of the '(1, 5]' class
                                          #        '(5, 10]', '(10, 15]',
                                          #        '(15, 20]', '(20, 25]',
                                          #        '(25, 30]', '(30, 40]'])
print(clean_meta_df['company_vintage'])
# Out:
# 0        (5, 10]
# 1         (0, 1]
# 2         (0, 1]
# 3         (0, 1]
# 4         (1, 5]
# 5        (5, 10]
# 6        (5, 10]
# 7       (10, 15]
# 8       (25, 30]
# 9       (10, 15]
# 10      (10, 15]
# 11      (10, 15]
# 12        (0, 1]
# 13        (0, 1]
# 14        (1, 5]
# 15      (10, 15]
# 16      (10, 15]
# 17        (0, 1]
# 18        (0, 1]
# 19        (1, 5]
# 20       (5, 10]
# 21        (0, 1]
# 22        (0, 1]
# 23        (0, 1]
# 24      (10, 15]
# 25        (0, 1]
# 26        (0, 1]
# 27        (0, 1]
# 28        (1, 5]
# 29        (0, 1]
#           ...
# 3891     (5, 10]
# 3892     (5, 10]
# 3893      (0, 1]
# 3894      (0, 1]
# 3895      (0, 1]
# 3896      (0, 1]
# 3897      (0, 1]
# 3898      (1, 5]
# 3899    (20, 25]
# 3900      (1, 5]
# 3901      (0, 1]
# 3902      (0, 1]
# 3903      (0, 1]
# 3904    (10, 15]
# 3905    (10, 15]
# 3906      (1, 5]
# 3907      (1, 5]
# 3908      (1, 5]
# 3909     (5, 10]
# 3910      (0, 1]
# 3911      (0, 1]
# 3912      (0, 1]
# 3913      (0, 1]
# 3914      (1, 5]
# 3915      (1, 5]
# 3916    (10, 15]
# 3917     (5, 10]
# 3918      (1, 5]
# 3919      (1, 5]
# 3920      (1, 5]
# Name: company_vintage, Length: 3921, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 5] < (5, 10] < (10, 15] < (15, 20] < (20, 25] < (25, 30] < (30, 40]]
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
clean_meta_df['company_vintage'].apply(str)
print(clean_meta_df.info())
clean_meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
# stock              3921 non-null object
# years              3921 non-null float64
# range_price        3921 non-null float64
# company_vintage    3921 non-null category
# dtypes: category(1), float64(2), object(1)
# memory usage: 95.9+ KB
# None
#       stock     years  range_price company_vintage
# 0   AACG.US  8.671233      3.63297         (5, 10]
# 1   AACQ.US  0.263014      1.45000          (0, 1]
# 2  AACQU.US  0.367123      1.90000          (0, 1]
# 3  AACQW.US  0.260274      1.50500          (0, 1]
# 4    AAL.US  4.912329     47.94900          (1, 5]

# %% [markdown]
# ## Classification Results

# %%
sns.histplot(data=clean_meta_df, x='years', binwidth=1, hue='company_vintage')
#plt.savefig('companies_age_classification.pdf', dpi=1200)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %%
clean_meta_df.groupby('company_vintage')['stock'].count()
# Out:
# company_vintage
# (0, 1]      1069
# (1, 5]      1252
# (5, 10]      564
# (10, 15]     950
# (15, 20]      32
# (20, 25]      37
# (25, 30]      13
# (30, 40]       4
# Name: stock, dtype: int64

# %% [markdown]
# ### Saving List of Companies Name via `joblib`

# %%
stocks_bin_1 = []
stocks_bin_2 = []
stocks_bin_3 = []
stocks_bin_4 = []
stocks_bin_5 = []
stocks_bin_6 = []
stocks_bin_7 = []
stocks_bin_8 = []

for idx, row in clean_meta_df.iterrows():
    x = row['years']                                            # <=> ['days']/365
    st = row['stock'].replace('.US', '')
    
    #print(idx, x, row['stock'])
    if x <= 1 : stocks_bin_1.append(st)
    elif x > 1 and x <= 5: stocks_bin_2.append(st)
    elif x > 5 and x <= 10: stocks_bin_3.append(st)
    elif x > 10 and x <= 15: stocks_bin_4.append(st)        
    elif x > 15 and x <= 20: stocks_bin_5.append(st)        
    elif x > 20 and x <= 25: stocks_bin_6.append(st)        
    elif x > 25 and x <= 30: stocks_bin_7.append(st)        
    elif x > 30: stocks_bin_8.append(st)
    
print(f"Number of companies with less than a year of history: {len(stocks_bin_1)}")
print(f"Number of companies with between a year and 5 years of history: {len(stocks_bin_2)}")    
print(f"Number of companies with between 5 years and 10 years of history: {len(stocks_bin_3)}")
print(f"Number of companies with between 10 years and 15 years of history: {len(stocks_bin_4)}")
print(f"Number of companies with between 15 years and 20 years of history: {len(stocks_bin_5)}")
print(f"Number of companies with between 20 years and 25 years of history: {len(stocks_bin_6)}")
print(f"Number of companies with between 25 years and 30 years of history: {len(stocks_bin_7)}")
print(f"Number of companies with more than 30 years of history: {len(stocks_bin_8)}")

stock_bins = [stocks_bin_1, stocks_bin_2, stocks_bin_3,
              stocks_bin_4, stocks_bin_5, stocks_bin_6,
              stocks_bin_7, stocks_bin_8]
# Out:
# Number of companies with less than a year of history: 1069
# Number of companies with between a year and 5 years of history: 1252
# Number of companies with between 5 years and 10 years of history: 564
# Number of companies with between 10 years and 15 years of history: 950
# Number of companies with between 15 years and 20 years of history: 32
# Number of companies with between 20 years and 25 years of history: 37
# Number of companies with between 25 years and 30 years of history: 13
# Number of companies with more than 30 years of history: 4

# %%
stock_bins
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# ❗❗❗**You should check the path you want to save the `stock_bins` list**❗❗❗
#
# (The `metadata` directory is where I saved the `nasdaq_us_stats.xls` csv file of Ian)

# %%
joblib.dump(stock_bins, '../../../raw_data/metadata/tickers_per_history_lenght__list')
# Out:
# ['../../../raw_data/metadata/tickers_per_history_lenght__list']

# %%
stocks_tickers = joblib.load('../../../raw_data/metadata/tickers_per_history_lenght__list')
stocks_tickers
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# # Modeling Companies per Vintage - (0, 1] - The youngest ones

# %% [markdown]
# ## Functions definitions & Imports

# %% [markdown]
# ### `precise_stocks_selector_local()`

# %%
from termcolor import colored

def precise_stocks_selector_local(tickers_list=[], path_files='../../../raw_data/processed/',
                                  random_sample=False, num_samp = 2, verbose=1):
    """
    Returns a concatened DataFrame of the stocks data which tickers' list were passed
    
    If random_sample = True, return a DataFrame with random sample of stocks from the tickers' list passed
    
    Example:
    INPUT: ['AEP', 'GT', 'INTC', 'PEP']
    OUTPUT: df.tickers.unique() ==> ['GT', 'INTC']
   
    """
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        
    t = []
    for ticker in tickers_list:
        ticker = f"{ticker}.csv".lower()
        t.append(ticker)
    tickers_list = t
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        print()
        print()
    
    if verbose >= 1:
        print(colored(f"****** Starting browsing the '{path_files}' directory ******", 'magenta'))
        
    filenames = []
    missing_stock_csv = []

    
    if random_sample:
        for file in os.listdir(path_files):
            if file.endswith('.csv'):
                if file in tickers_list:
                    filenames.append(file)
        
        for ticker in tickers_list:
            #print(ticker)
            #print(missing_stock_csv)
            if ticker not in filenames:
                missing_stock_csv.append(ticker)
                print(colored(f"{ticker} missing", 'red'))
            else:
                pass
        
        #print(missing_stock_csv)
        
        for missed in missing_stock_csv:
            if missed not in tickers_list:
                missing_stock_csv.remove(missed)
        #print(missing_stock_csv)
        
        if len(filenames) < num_samp:
            print(colored('\nSample size bigger that nuber of companies available\n','red'))
        else:
            sample = random.sample(filenames, num_samp)
            
        if verbose >= 1:
            print(colored("\n   *** Complete sampling ***", 'green'))
            
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting stocks DataFrame creation the sample ******", 'magenta'))
        
        dfs = []

        for ticker in sample:
            ticker_df = pd.read_csv('../../../raw_data/processed/'+ticker)
            dfs.append(ticker_df)
            if verbose == 2:
                print(colored(f"{ticker} DataFrame created", 'yellow'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
            
            
    else: 
        for file in os.listdir(path_files):
            if (file.endswith('.csv')):
                filenames.append(file)
                #print(f"{file}")
        
        if verbose >= 1:
            print(colored("\n   *** Complete file selection ***", 'green'))
        
        dfs = []
        
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"****** Starting stocks DataFrame creation the sample ******", 'magenta'))
      
        for ticker in tickers_list:
            if ticker in filenames:
                #print(f"{ticker}")
                ticker_df = pd.read_csv('../../../raw_data/processed/'+ticker)
                dfs.append(ticker_df)
                if verbose == 2:
                    print(colored(f"{ticker} DataFrame created", 'yellow'))
            else:
                missing_stock_csv.append(ticker)
                print(colored(f"\n{ticker} missing", 'red'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
    
    
    if len(missing_stock_csv) !=0:
        
        print(colored("""\n\n##### Problematic Issue: following stocks not in local database! #####""", "red"))
        print(colored(f"Number of missed stocks: {len(missing_stock_csv)}", "red"))
        print(colored(f"""\n{missing_stock_csv}""", "red"))
    
    return pd.concat(dfs)

# %% [markdown]
# ### Preprocessing Functions

# %%
from sklearn.preprocessing import StandardScaler

def std_scaler(train_set, test_set=0, fit=True, transform=True):
    """
    Scale the data with SKlearn StandardScaler
    
    Fit (if fit) the scaler on train and transform it (if transform) train_set
        and test_set (if test_set and (fit and transform))
    """
    
    scaler = StandardScaler()
    
    if len(test_set)!=0 and len(train_set)!=0:
        col_to_scale_df = test_set.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
        col_to_scale = list(col_to_scale_df)
        
        scaled_test_df = test_set
        
        scaled_train_df = train_set
        
        for col in col_to_scale:
            if fit and transform:
                scaled_train_df[col] = scaler.fit_transform(scaled_train_df[[col]])

            elif fit:
                scaled_train_df[col] = scaler.fit(scaled_train_df[[col]])

        for col in col_to_scale:
            if fit and transform:
                scaler.fit(train_set[[col]])
                scaled_test_df[col] = scaler.transform(scaled_test_df[[col]])
        
        return scaled_train_df, scaled_test_df
    
    
    elif len(train_set)!=0:
        col_to_scale_df = train_set.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
        col_to_scale = list(col_to_scale_df)
        
        scaled_train_df = train_set
        
        for col in col_to_scale:
            if fit and transform:
                scaled_train_df[col] = scaler.fit_transform(scaled_train_df[[col]])

            elif fit:
                scaled_train_df[col] = scaler.fit(scaled_train_df[[col]])

                if transform:
                    scaled_train_df[col] = scaler.transform(scaled_train_df[[col]])
        return scaled_train_df

# %%
#Marcin's Function

def build_input_arrays(df, time_window=5, stride=3, input_cols=['RSI', 'Stochastic', 'Stochastic_signal', 'ADI',
       'OBV', 'ATR', 'ADX', 'ADX_pos', 'ADX_neg', 'MACD', 'MACD_diff',
       'MACD_signal'] , target_col='5TD_return'):
    output_array = []
    target_array = []
    df_sorted = df.sort_values('date', ascending=False)
    df_sorted.reset_index(drop=True, inplace=True)
    for row in range(0, len(df), stride):
        df_slice = df_sorted.iloc[row: row + time_window]
        if df_slice.shape[0]==time_window:
            output_array.append(np.array(df_slice[input_cols].values))
            target_array.append(df_slice[target_col].iloc[0])
    return np.array(output_array), np.array(target_array)

# %%
#Ian's Function

def train_test_split(df, test_set_size='3Y'):
    """
    Split the preprocessed stock data file into a train and test dataset
    INPUT: the dataframe to be split, and size of the test set in months or years ('3M' or '2Y')
    OUTPUT: returns a train_set and test_set dataframe, index is set to the date
    
    EXAMPLE: train_set, test_set = train_test_split(input_df, '3Y')
    """
    if not np.issubdtype(df['date'].dtype, np.datetime64):
        df['date'] = pd.to_datetime(df['date'], format=('%Y-%m-%d'))
    test_set = df.sort_values(by="date",ascending=True).set_index("date").last(test_set_size)
    train_set = df.drop(df.tail(len(test_set)).index).set_index("date")
    test_set.reset_index(inplace=True)
    train_set.reset_index(inplace=True)
    return train_set, test_set

# %%
def thresholds_encoding(df, r5d=0.0006, same_thresholds=True, r10d=0.0012, r20d=0.0024):
    """
    Binary encode the 5, 10 and 20 days return columns according to the thresholds
    
    INPUT: dataframe with '5TD_return', '10TD_return' and '20TD_return' columns
    OUTPUT: dataframe with binary encoded aforementionned columns
    
    If the thresolds returns are the same on a yearly basis for the different period use:
                r10d = r5d * 2 
            and
                r20d = r10d * 2
            keep same_thresholds=True
        Otherwise, define manually r10d and r20d
    """
    wk_df = df.copy()
    
    if same_thresholds:
        r10d = r5d * 2
        r20d = r10d * 2
    
    wk_df['5TD_return'] = wk_df['5TD_return'].apply(lambda x: 1 if x > r5d else 0)
    wk_df['10TD_return'] = wk_df['10TD_return'].apply(lambda x: 1 if x > r10d else 0)
    wk_df['20TD_return'] = wk_df['20TD_return'].apply(lambda x: 1 if x > r20d else 0)
    
    return wk_df

# %% [markdown]
# ### Visualisation Functions

# %%
def plot_loss_accuracy(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()

# %% [markdown]
# ### Model Saving Functions

# %%
def runs_history_loading(name='charles', vintage='0_1', path_files='../models_histories'):
    
    filenames = []
    
    run_history = f"{name}_companies_{vintage}_model_history"
    
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if run_history in filenames:
        print("Previous models scores:\n",joblib.load(path_files+'/'+run_history))
        return joblib.load(path_files+'/'+run_history)
    
    else:
        print("No previous models scores found\nReturning uncomplete list: [('tickers', ['loss', 'precision', 'accuracy'])]")
        return [('tickers', ['loss', 'precision', 'accuracy'])]

# %%
def runs_history_saving(score_file, vintage='0_1', author='charles', path_files='../models_histories'):
    filenames = []
    
    run_history = f"{author}_companies_{vintage}_model_history"
    
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if f"{author}_old_cie_model_history" in filenames:
        print("Previous models scores found:\n", joblib.load(path_files+'/'+run_history))
        confirmation = input(prompt="""You are about to save over the previous history, which will replace it by your new history.
        Are you sure you want to do that? (Y/n)""")
        
        if confirmation =='Y':
            joblib.dump(path_files+'/'+run_history)
            print("History Saving Complete!")
            print(f"File saved as: {author}_companies_{vintage}_model_history")
            print(f"File location:{path_files}")            
            
        else:
            print("History Saving Aborted!")
    
    else:
        joblib.dump(score_file, path_files+'/'+run_history)
        print("History Saving Complete!")
        print(f"File saved as: {author}_companies_{vintage}_model_history")
        print(f"File location:{path_files}")

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Importing the (0,1] Companies Sample

# %%
companies_0_1 = stocks_tickers[0]
companies_0_1
# Out:
# ['AACQ',
#  'AACQU',
#  'AACQW',
#  'ABCL',
#  'ABCM',
#  'ABNB',
#  'ABST',
#  'ACAC',
#  'ACACU',
#  'ACACW',
#  'ACAM',
#  'ACAMU',
#  'ACAMW',
#  'ACCD',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACKIU',
#  'ACTC',
#  'ACTCU',
#  'ACTCW',
#  'ADERU',
#  'ADILW',
#  'ADOC',
#  'ADOCR',
#  'ADOCU',
#  'ADOCW',
#  'ADTX',
#  'ADV',
#  'ADVWW',
#  'ADXN',
#  'AEACU',
#  'AEPPZ',
#  'AFBI',
#  'AFIB',
#  'AFINO',
#  'AFRM',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGC',
#  'AGCUU',
#  'AGCWW',
#  'AGNCO',
#  'AGNCP',
#  'AHAC',
#  'AHACU',
#  'AHACW',
#  'AIH',
#  'AIRTP',
#  'AIRTW',
#  'AKICU',
#  'AKU',
#  'AKUS',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALGM',
#  'ALGS',
#  'ALRS',
#  'ALTUU',
#  'ALVR',
#  'ALXO',
#  'AMCIU',
#  'AMCIW',
#  'AMHC',
#  'AMHCU',
#  'AMHCW',
#  'AMST',
#  'AMTI',
#  'AMYT',
#  'ANDA',
#  'ANDAR',
#  'ANDAU',
#  'ANDAW',
#  'ANNX',
#  'ANPC',
#  'AOUT',
#  'API',
#  'APRE',
#  'APXT',
#  'APXTU',
#  'APXTW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARKO',
#  'ARKOW',
#  'ARQT',
#  'ARRY',
#  'ARTLW',
#  'ARYA',
#  'ASLE',
#  'ASLEW',
#  'ASO',
#  'ATCXW',
#  'ATHA',
#  'ATNF',
#  'AUBAP',
#  'AUVI',
#  'AVCTW',
#  'AVGOP',
#  'AVIR',
#  'AVO',
#  'AYLA',
#  'AZYO',
#  'BCAB',
#  'BCDA',
#  'BCDAW',
#  'BCTG',
#  'BCYPU',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEEMW',
#  'BENEU',
#  'BFRA',
#  'BHFAN',
#  'BHFAO',
#  'BHSE',
#  'BHSEU',
#  'BHSEW',
#  'BIGC',
#  'BIVI',
#  'BLCT',
#  'BLI',
#  'BLSA',
#  'BLTSU',
#  'BLU',
#  'BLUWU',
#  'BNR',
#  'BNTX',
#  'BOWX',
#  'BOWXU',
#  'BOWXW',
#  'BPYPN',
#  'BPYPO',
#  'BREZ',
#  'BREZR',
#  'BREZU',
#  'BREZW',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRP',
#  'BRPA',
#  'BRPAR',
#  'BRPAU',
#  'BRPAW',
#  'BRQS',
#  'BSBK',
#  'BSCU',
#  'BSJS',
#  'BSML',
#  'BSMM',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSY',
#  'BTAQ',
#  'BTAQU',
#  'BTAQW',
#  'BTBT',
#  'BTRS',
#  'BTRSW',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BUG',
#  'BWAC',
#  'BWACU',
#  'BWACW',
#  'BWMX',
#  'BXRX',
#  'CABA',
#  'CALB',
#  'CALT',
#  'CAN',
#  'CAPA',
#  'CAPAU',
#  'CAPAW',
#  'CCCC',
#  'CCNEP',
#  'CD',
#  'CDAK',
#  'CEFA',
#  'CERE',
#  'CEREW',
#  'CERT',
#  'CFAC',
#  'CFACU',
#  'CFACW',
#  'CFB',
#  'CFFAU',
#  'CFII',
#  'CFIIU',
#  'CFIIW',
#  'CFIVU',
#  'CGEM',
#  'CGRO',
#  'CGROU',
#  'CGROW',
#  'CHB',
#  'CHPM',
#  'CHPMU',
#  'CHPMW',
#  'CIIC',
#  'CIICU',
#  'CIICW',
#  'CLDB',
#  'CLEU',
#  'CLNN',
#  'CLNNW',
#  'CLOV',
#  'CLOVW',
#  'CLSK',
#  'CLVR',
#  'CLVRW',
#  'CMCTP',
#  'CMLF',
#  'CMLFU',
#  'CMLFW',
#  'CMPI',
#  'CMPS',
#  'CNNB',
#  'CNSP',
#  'CNTG',
#  'CNXC',
#  'COFS',
#  'COMS',
#  'COMSW',
#  'CONX',
#  'CONXU',
#  'CONXW',
#  'COOLU',
#  'CPZ',
#  'CREXW',
#  'CRNC',
#  'CRSA',
#  'CRSAU',
#  'CRSAW',
#  'CRSR',
#  'CRTD',
#  'CRTDW',
#  'CSSEN',
#  'CTAQU',
#  'CTEC',
#  'CURI',
#  'CURIW',
#  'CVAC',
#  'CVLB',
#  'CXDO',
#  'CYTH',
#  'CYTHW',
#  'DADA',
#  'DBDR',
#  'DBDRU',
#  'DBDRW',
#  'DCBO',
#  'DCOMP',
#  'DCRB',
#  'DCRBU',
#  'DCRBW',
#  'DCT',
#  'DCTH',
#  'DDMXU',
#  'DDOG',
#  'DEMZ',
#  'DFH',
#  'DFHT',
#  'DFHTU',
#  'DFHTW',
#  'DFPH',
#  'DFPHU',
#  'DFPHW',
#  'DGNS',
#  'DKNG',
#  'DLCAU',
#  'DLPNW',
#  'DMXF',
#  'DPHCU',
#  'DRTT',
#  'DRVN',
#  'DSAC',
#  'DSACU',
#  'DSACW',
#  'DUNEU',
#  'DUO',
#  'DUOT',
#  'DWAW',
#  'DWCR',
#  'DWEQ',
#  'DWUS',
#  'DYN',
#  'EACPU',
#  'EAR',
#  'EBC',
#  'EBON',
#  'ECOLW',
#  'ECOW',
#  'EDOC',
#  'EDTK',
#  'EDTXU',
#  'EDUT',
#  'EH',
#  'ELDN',
#  'EMXF',
#  'ENFAU',
#  'ENTXW',
#  'ENVIU',
#  'EOSE',
#  'EOSEW',
#  'EPHYU',
#  'EQOS',
#  'EQOSW',
#  'ERES',
#  'ERESU',
#  'ERESW',
#  'ESSC',
#  'ESSCR',
#  'ESSCU',
#  'ESSCW',
#  'ETAC',
#  'ETACU',
#  'ETACW',
#  'ETNB',
#  'EUCR',
#  'EUCRU',
#  'EUCRW',
#  'EUSGU',
#  'EWEB',
#  'EWJE',
#  'EWJV',
#  'EXPC',
#  'EXPCU',
#  'EXPCW',
#  'FATBP',
#  'FATBW',
#  'FCAC',
#  'FCACU',
#  'FCACW',
#  'FCNCP',
#  'FDMT',
#  'FDUSG',
#  'FHTX',
#  'FICS',
#  'FIII',
#  'FIIIU',
#  'FIIIW',
#  'FINMU',
#  'FITBO',
#  'FITBP',
#  'FLACU',
#  'FLUX',
#  'FMBIO',
#  'FMBIP',
#  'FMTX',
#  'FOXWU',
#  'FPXE',
#  'FREE',
#  'FREEW',
#  'FREQ',
#  'FRG',
#  'FRGAP',
#  'FRHC',
#  'FRLN',
#  'FROG',
#  'FSDC',
#  'FSEA',
#  'FSRV',
#  'FSRVU',
#  'FSRVW',
#  'FTCVU',
#  'FTHM',
#  'FTIV',
#  'FTIVU',
#  'FTIVW',
#  'FTOC',
#  'FTOCU',
#  'FTOCW',
#  'FULTP',
#  'FUSN',
#  'FVAM',
#  'FXNC',
#  'GAN',
#  'GBIO',
#  'GBNY',
#  'GBS',
#  'GCMG',
#  'GDRX',
#  'GDYNW',
#  'GFNSZ',
#  'GHIV',
#  'GHIVU',
#  'GHIVW',
#  'GHVIU',
#  'GLADL',
#  'GLAQU',
#  'GLSI',
#  'GLTO',
#  'GMBL',
#  'GMBLW',
#  'GMBTU',
#  'GMHIU',
#  'GMIIU',
#  'GNACU',
#  'GNOG',
#  'GNOGW',
#  'GNRS',
#  'GNRSU',
#  'GNRSW',
#  'GOCO',
#  'GOODN',
#  'GOVX',
#  'GOVXW',
#  'GP',
#  'GPACU',
#  'GRAY',
#  'GRCL',
#  'GRCY',
#  'GRCYU',
#  'GRCYW',
#  'GRIL',
#  'GRNV',
#  'GRNVR',
#  'GRNVU',
#  'GRNVW',
#  'GRSV',
#  'GRSVU',
#  'GRSVW',
#  'GRTX',
#  'GRWG',
#  'GSAQU',
#  'GTH',
#  'GWAC',
#  'GWACU',
#  'GWACW',
#  'GXGX',
#  'GXGXU',
#  'GXGXW',
#  'GXTG',
#  'HAAC',
#  'HAACU',
#  'HAACW',
#  'HAPP',
#  'HBT',
#  'HCACU',
#  'HCAR',
#  'HCARU',
#  'HCARW',
#  'HCCCU',
#  'HCCH',
#  'HCCHR',
#  'HCCHU',
#  'HCCHW',
#  'HCCOU',
#  'HCDI',
#  'HCICU',
#  'HEC',
#  'HECCU',
#  'HECCW',
#  'HERD',
#  'HERO',
#  'HFEN',
#  'HGBL',
#  'HLAHU',
#  'HLXA',
#  'HMCOU',
#  'HOL',
#  'HOLUU',
#  'HOLUW',
#  'HRMY',
#  'HSAQ',
#  'HTIA',
#  'HTLFP',
#  'HTOO',
#  'HTOOW',
#  'HUDI',
#  'HUGE',
#  'HUIZ',
#  'HWCPZ',
#  'HYAC',
#  'HYACU',
#  'HYACW',
#  'HYFM',
#  'HYMCZ',
#  'IBBJ',
#  'IBEX',
#  'IBKR',
#  'IBTA',
#  'IBTB',
#  'IBTD',
#  'IBTE',
#  'IBTF',
#  'IBTG',
#  'IBTH',
#  'IBTI',
#  'IBTJ',
#  'IBTK',
#  'IGAC',
#  'IGACU',
#  'IGACW',
#  'IGMS',
#  'IHYF',
#  'IIIIU',
#  'IIVIP',
#  'IKT',
#  'IMAB',
#  'IMACW',
#  'IMNM',
#  'IMRA',
#  'IMTXW',
#  'IMVT',
#  'INAQ',
#  'INAQU',
#  'INAQW',
#  'INBKZ',
#  'INBX',
#  'INKAU',
#  'INM',
#  'INTZ',
#  'INVO',
#  'INZY',
#  'IPA',
#  'IPDN',
#  'IPHA',
#  'ISUN',
#  'ITAC',
#  'ITACU',
#  'ITACW',
#  'ITOS',
#  'IVA',
#  'JAMF',
#  'JCICU',
#  'JFU',
#  'JMPNZ',
#  'JOET',
#  'JUPW',
#  'JUPWW',
#  'JYAC',
#  'KAIRU',
#  'KBLMU',
#  'KBNT',
#  'KBNTW',
#  'KC',
#  'KELYB',
#  'KINZU',
#  'KLAQU',
#  'KMPH',
#  'KNTE',
#  'KOR',
#  'KRBP',
#  'KRKR',
#  'KRMD',
#  'KRON',
#  'KROS',
#  'KSMT',
#  'KSMTU',
#  'KSMTW',
#  'KYMR',
#  'LACQU',
#  'LANDO',
#  'LATN',
#  'LATNU',
#  'LATNW',
#  'LAZR',
#  'LAZRW',
#  'LBRDP',
#  'LBTYB',
#  'LCAHU',
#  'LCAP',
#  'LCAPU',
#  'LCAPW',
#  'LCY',
#  'LCYAU',
#  'LCYAW',
#  'LDEM',
#  'LEGN',
#  'LEGOU',
#  'LESL',
#  'LEVLP',
#  'LEXX',
#  'LEXXW',
#  'LFACU',
#  'LFACW',
#  'LFTR',
#  'LFTRU',
#  'LFTRW',
#  'LGHL',
#  'LGHLW',
#  'LI',
#  'LIVK',
#  'LIVKU',
#  'LIVKW',
#  'LIXT',
#  'LIXTW',
#  'LIZI',
#  'LJAQU',
#  'LMACU',
#  'LMFAW',
#  'LMNL',
#  'LMPX',
#  'LNSR',
#  'LOAC',
#  'LOACR',
#  'LOACU',
#  'LOACW',
#  'LOTZ',
#  'LOTZW',
#  'LPRO',
#  'LSAQ',
#  'LSEA',
#  'LSEAW',
#  'LSXMB',
#  'LTRN',
#  'LTRPB',
#  'LUNG',
#  'LUXA',
#  'LUXAU',
#  'LUXAW',
#  'LVGO',
#  'LWACU',
#  'LXEH',
#  'LYRA',
#  'MAAC',
#  'MAACU',
#  'MAACW',
#  'MACU',
#  'MACUU',
#  'MACUW',
#  'MASS',
#  'MAXN',
#  'MAYS',
#  'MBINO',
#  'MBNKP',
#  'MCAC',
#  'MCACR',
#  'MCACU',
#  'MCADU',
#  'MCBS',
#  'MCFE',
#  'MCMJ',
#  'MCMJW',
#  'MDGSW',
#  'MDIA',
#  'MDNA',
#  'MDRRP',
#  'MDWT',
#  'MDXG',
#  'METXW',
#  'MKD',
#  'MLAC',
#  'MLACU',
#  'MLACW',
#  'MNCLU',
#  'MNPR',
#  'MNSBP',
#  'MNTK',
#  'MODV',
#  'MOHO',
#  'MONCU',
#  'MOTN',
#  'MOTNU',
#  'MOTNW',
#  'MRACU',
#  'MRM',
#  'MRVI',
#  'MSGM',
#  'MTACU',
#  'MTCR',
#  'MUDSU',
#  'NAACU',
#  'NARI',
#  'NBAC',
#  'NBACR',
#  'NBACU',
#  'NBACW',
#  'NBTX',
#  'NCNO',
#  'NEBCU',
#  'NEPH',
#  'NFIN',
#  'NFINU',
#  'NFINW',
#  'NGAC',
#  'NGACU',
#  'NGACW',
#  'NGMS',
#  'NHIC',
#  'NHICU',
#  'NHICW',
#  'NKTX',
#  'NMMC',
#  'NMMCU',
#  'NMMCW',
#  'NMTR',
#  'NNOX',
#  'NOACU',
#  'NOVS',
#  'NOVSU',
#  'NOVSW',
#  'NPA',
#  'NPAUU',
#  'NPAWW',
#  'NRIX',
#  'NTRSO',
#  'NUZE',
#  'NYMTM',
#  'OAS',
#  'OCAXU',
#  'OCFCP',
#  'OCG',
#  'OEPWU',
#  'OFSSG',
#  'OFSSI',
#  'OLB',
#  'OLMA',
#  'OM',
#  'OMEG',
#  'ONCR',
#  'ONDS',
#  'ONEM',
#  'ONEW',
#  'OPEN',
#  'OPENW',
#  'OPESU',
#  'OPINL',
#  'OPRT',
#  'OPT',
#  'ORIC',
#  'ORPH',
#  'ORSNR',
#  'ORSNU',
#  'OSTRU',
#  'OTRA',
#  'OTRAU',
#  'OTRAW',
#  'OTRKP',
#  'OXLCP',
#  'OYST',
#  'OZON',
#  'PACXU',
#  'PAEWW',
#  'PAIC',
#  'PAICU',
#  'PAICW',
#  'PAND',
#  'PAQCU',
#  'PASG',
#  'PAX',
#  'PAYA',
#  'PAYAW',
#  'PBLA',
#  'PCSA',
#  'PCVX',
#  'PDEV',
#  'PFHD',
#  'PGNY',
#  'PHAR',
#  'PHAT',
#  'PHIC',
#  'PHICU',
#  'PHICW',
#  'PLC',
#  'PLIN',
#  'PLRX',
#  'PLTK',
#  'PMVP',
#  'PNFPP',
#  'PNNTG',
#  'PNTG',
#  'POSH',
#  'POTX',
#  'POWRU',
#  'POWW',
#  'PPD',
#  'PPGHU',
#  'PRAX',
#  'PRCH',
#  'PRCHW',
#  'PRFX',
#  'PRLD',
#  'PROG',
#  'PRPLW',
#  'PRSRU',
#  'PRTC',
#  'PSAC',
#  'PSACU',
#  'PSACW',
#  'PSM',
#  'PSTX',
#  'PTACU',
#  'PTICU',
#  'PTON',
#  'PTPI',
#  'PTRS',
#  'PTVE',
#  'PUBM',
#  'PXSAP',
#  'PXSAW',
#  'PYPD',
#  'QELL',
#  'QELLU',
#  'QELLW',
#  'QH',
#  'QK',
#  'QLI',
#  'QMCO',
#  'QQC',
#  'QQD',
#  'QQQJ',
#  'QQQM',
#  'QQQN',
#  'QRTEP',
#  'QYLG',
#  'RAACU',
#  'RACA',
#  'RADI',
#  'RAPT',
#  'RCEL',
#  'RCHG',
#  'RCHGU',
#  'RCHGW',
#  'RDIB',
#  'REYN',
#  'RIDE',
#  'RIDEW',
#  'RILYL',
#  'RILYM',
#  'RILYN',
#  'RILYP',
#  'RLAY',
#  'RMGBU',
#  'RNA',
#  'RNLX',
#  'ROCC',
#  'ROCCU',
#  'ROCCW',
#  'ROCH',
#  'ROCHU',
#  'ROCHW',
#  'ROOT',
#  'RPRX',
#  'RPTX',
#  'RSSS',
#  'RSVA',
#  'RSVAU',
#  'RSVAW',
#  'RVMD',
#  'RVPH',
#  'RVPHW',
#  'RXT',
#  'RZLT',
#  'SABRP',
#  'SAII',
#  'SAIIU',
#  'SAIIW',
#  'SAMA',
#  'SAMAU',
#  'SAMAW',
#  'SBNYP',
#  'SBTX',
#  'SCOAU',
#  'SCPS',
#  'SDC',
#  'SDGR',
#  'SEER',
#  'SFT',
#  'SFTTW',
#  'SGAM',
#  'SGAMU',
#  'SGAMW',
#  'SGLBW',
#  'SGTX',
#  'SHACU',
#  'SHC',
#  'SHIPZ',
#  'SHLD',
#  'SIGIP',
#  'SITM',
#  'SIVBP',
#  'SJ',
#  'SKYU',
#  'SLCRU',
#  'SLN',
#  'SMCI',
#  'SMID',
#  'SMMC',
#  'SMMCU',
#  'SMMCW',
#  'SMTI',
#  'SNGXW',
#  'SNRHU',
#  'SNUG',
#  'SPQQ',
#  'SPRB',
#  'SPT',
#  'SQFT',
#  'SRAC',
#  'SRACU',
#  'SRACW',
#  'SRSA',
#  'SRSAU',
#  'SRSAW',
#  'SSPK',
#  'SSPKU',
#  'SSPKW',
#  'STEP',
#  'STRRP',
#  'STSA',
#  'STTK',
#  'STWO',
#  'STWOU',
#  'STWOW',
#  'SUMO',
#  'SV',
#  'SVAC',
#  'SVACU',
#  'SVACW',
#  'SVFAU',
#  'SVOKU',
#  'SVSVU',
#  'SVSVW',
#  'SWETU',
#  'SWKH',
#  'SWTX',
#  'SYTA',
#  'SYTAW',
#  'TARS',
#  'TBKCP',
#  'TDACU',
#  'TECTP',
#  'TEKK',
#  'TEKKU',
#  'TEKKW',
#  'TELA',
#  'TFFP',
#  'THBR',
#  'THBRU',
#  'THBRW',
#  'THCA',
#  'THCAU',
#  'THCAW',
#  'THCBU',
#  'THRY',
#  'THTX',
#  'TIG',
#  'TLMD',
#  'TLMDW',
#  'TLS',
#  'TMKRU',
#  'TMPM',
#  'TMPMU',
#  'TMPMW',
#  'TMTS',
#  'TMTSU',
#  'TMTSW',
#  'TOMZ',
#  'TOTA',
#  'TOTAR',
#  'TOTAW',
#  'TRIT',
#  'TRITW',
#  'TSHA',
#  'TSIA',
#  'TSIAU',
#  'TSIAW',
#  'TVACU',
#  'TWCT',
#  'TWCTU',
#  'TWCTW',
#  'TXG',
#  'TZACU',
#  'TZPSU',
#  'UCBIO',
#  'UCL',
#  'UCYB',
#  'UK',
#  'UKOMW',
#  'UPST',
#  'USAT',
#  'USXF',
#  'VACQ',
#  'VACQU',
#  'VACQW',
#  'VCKAU',
#  'VCVC',
#  'VCVCU',
#  'VCVCW',
#  'VERX',
#  'VERY',
#  'VETS',
#  'VIACA',
#  ...]

# %% [markdown]
# ### (Security autobreak)

# %%
#breaking_auto_run = #Bug on purpose: you might want to look at the companies (randomly) selected below

# %%
stocks_0_1_df = precise_stocks_selector_local(tickers_list=companies_0_1, random_sample=True, num_samp = 1, verbose=1)
# Out:
# ****** Starting browsing the '../../../raw_data/processed/' directory ******
# aacqu.csv missing
# abcl.csv missing
# abnb.csv missing
# abst.csv missing
# acacu.csv missing
# acacw.csv missing
# acamu.csv missing
# acevu.csv missing
# ackiu.csv missing
# actcu.csv missing
# actcw.csv missing
# aderu.csv missing
# adoc.csv missing
# adocr.csv missing
# adocu.csv missing
# adocw.csv missing
# adtx.csv missing
# aeacu.csv missing
# afbi.csv missing
# afino.csv missing
# afrm.csv missing
# agbau.csv missing
# agcuu.csv missing
# agcww.csv missing
# ahacu.csv missing
# ahacw.csv missing
# akicu.csv missing
# aku.csv missing
# akus.csv missing
# alacu.csv missing
# algs.csv missing
# alrs.csv missing
# altuu.csv missing
# amciu.csv missing
# amhcu.csv missing
# amst.csv missing
# amyt.csv missing
# andau.csv missing
# annx.csv missing
# aout.csv missing
# apxt.csv missing
# apxtu.csv missing
# arbg.csv missing
# arbgu.csv missing
# arbgw.csv missing
# arko.csv missing
# arkow.csv missing
# arqt.csv missing
# avir.csv missing
# bcab.csv missing
# bcypu.csv missing
# bdsx.csv missing
# bdtx.csv missing
# beneu.csv missing
# bhfan.csv missing
# bhse.csv missing
# bhseu.csv missing
# bhsew.csv missing
# blct.csv missing
# bltsu.csv missing
# blu.csv missing
# bluwu.csv missing
# bntx.csv missing
# bowx.csv missing
# bowxu.csv missing
# brez.csv missing
# brezr.csv missing
# brezu.csv missing
# brezw.csv missing
# brliu.csv missing
# brpau.csv missing
# brqs.csv missing
# bscu.csv missing
# bsjs.csv missing
# bsms.csv missing
# bsmt.csv missing
# bsmu.csv missing
# btaqu.csv missing
# btbt.csv missing
# btrs.csv missing
# btrsw.csv missing
# btwnu.csv missing
# btwnw.csv missing
# bwac.csv missing
# bwacu.csv missing
# bwacw.csv missing
# bwmx.csv missing
# bxrx.csv missing
# calt.csv missing
# capau.csv missing
# capaw.csv missing
# cert.csv missing
# cfac.csv missing
# cfacu.csv missing
# cfacw.csv missing
# cffau.csv missing
# cfiiu.csv missing
# cfiiw.csv missing
# cfivu.csv missing
# cgem.csv missing
# cgrou.csv missing
# chpmu.csv missing
# ciicu.csv missing
# cleu.csv missing
# clnn.csv missing
# clnnw.csv missing
# clov.csv missing
# clovw.csv missing
# clvr.csv missing
# clvrw.csv missing
# cmctp.csv missing
# cmlfu.csv missing
# cmlfw.csv missing
# cmps.csv missing
# cnxc.csv missing
# cofs.csv missing
# coms.csv missing
# comsw.csv missing
# conx.csv missing
# conxu.csv missing
# conxw.csv missing
# coolu.csv missing
# crsau.csv missing
# ctaqu.csv missing
# ctec.csv missing
# cvlb.csv missing
# cyth.csv missing
# cythw.csv missing
# dbdr.csv missing
# dbdru.csv missing
# dbdrw.csv missing
# dcbo.csv missing
# dcrbu.csv missing
# dcrbw.csv missing
# dct.csv missing
# ddmxu.csv missing
# demz.csv missing
# dfht.csv missing
# dfhtu.csv missing
# dfphu.csv missing
# dgns.csv missing
# dlcau.csv missing
# dphcu.csv missing
# drtt.csv missing
# drvn.csv missing
# dsac.csv missing
# dsacu.csv missing
# dsacw.csv missing
# duneu.csv missing
# duot.csv missing
# dwcr.csv missing
# dwus.csv missing
# eacpu.csv missing
# edtxu.csv missing
# edut.csv missing
# eldn.csv missing
# emxf.csv missing
# enfau.csv missing
# enviu.csv missing
# eosew.csv missing
# ephyu.csv missing
# eqos.csv missing
# eres.csv missing
# eresu.csv missing
# esscu.csv missing
# etacu.csv missing
# eucr.csv missing
# eucru.csv missing
# eucrw.csv missing
# eusgu.csv missing
# eweb.csv missing
# expcu.csv missing
# fcacu.csv missing
# fcacw.csv missing
# fdmt.csv missing
# fhtx.csv missing
# fics.csv missing
# fiiiu.csv missing
# finmu.csv missing
# flacu.csv missing
# flux.csv missing
# fmtx.csv missing
# foxwu.csv missing
# fsrvu.csv missing
# ftcvu.csv missing
# ftivu.csv missing
# ftivw.csv missing
# ftocu.csv missing
# fultp.csv missing
# gbny.csv missing
# gbs.csv missing
# gdrx.csv missing
# gfnsz.csv missing
# ghivu.csv missing
# ghviu.csv missing
# glaqu.csv missing
# gmbtu.csv missing
# gmhiu.csv missing
# gmiiu.csv missing
# gnacu.csv missing
# gnrs.csv missing
# gnrsu.csv missing
# govx.csv missing
# gpacu.csv missing
# grcl.csv missing
# grcyu.csv missing
# grnvu.csv missing
# grsvu.csv missing
# grtx.csv missing
# gsaqu.csv missing
# gwac.csv missing
# gwacu.csv missing
# gwacw.csv missing
# gxgx.csv missing
# gxgxu.csv missing
# haac.csv missing
# haacu.csv missing
# haacw.csv missing
# hbt.csv missing
# hcacu.csv missing
# hcar.csv missing
# hcaru.csv missing
# hcarw.csv missing
# hcccu.csv missing
# hcchu.csv missing
# hccou.csv missing
# hcicu.csv missing
# heccu.csv missing
# hfen.csv missing
# hlahu.csv missing
# hmcou.csv missing
# holuu.csv missing
# holuw.csv missing
# htoo.csv missing
# htoow.csv missing
# hudi.csv missing
# hyacu.csv missing
# hyfm.csv missing
# ibex.csv missing
# ibtk.csv missing
# igacu.csv missing
# igacw.csv missing
# igms.csv missing
# ihyf.csv missing
# iiiiu.csv missing
# ikt.csv missing
# imvt.csv missing
# inaqu.csv missing
# inaqw.csv missing
# inbx.csv missing
# inkau.csv missing
# inm.csv missing
# invo.csv missing
# ipa.csv missing
# isun.csv missing
# itacu.csv missing
# itacw.csv missing
# itos.csv missing
# jcicu.csv missing
# jfu.csv missing
# joet.csv missing
# jupw.csv missing
# jupww.csv missing
# jyac.csv missing
# kairu.csv missing
# kblmu.csv missing
# kbnt.csv missing
# kinzu.csv missing
# klaqu.csv missing
# kmph.csv missing
# knte.csv missing
# kros.csv missing
# ksmt.csv missing
# ksmtu.csv missing
# lacqu.csv missing
# latnu.csv missing
# lbrdp.csv missing
# lcahu.csv missing
# lcapu.csv missing
# lcapw.csv missing
# lcy.csv missing
# lcyau.csv missing
# lcyaw.csv missing
# legou.csv missing
# lexx.csv missing
# lexxw.csv missing
# lfacu.csv missing
# lftru.csv missing
# lftrw.csv missing
# livku.csv missing
# lixt.csv missing
# lixtw.csv missing
# ljaqu.csv missing
# lmacu.csv missing
# lmpx.csv missing
# loacu.csv missing
# lotz.csv missing
# lotzw.csv missing
# lsaq.csv missing
# lsea.csv missing
# lseaw.csv missing
# luxau.csv missing
# luxaw.csv missing
# lwacu.csv missing
# maacu.csv missing
# maacw.csv missing
# macu.csv missing
# macuu.csv missing
# macuw.csv missing
# mass.csv missing
# mays.csv missing
# mcacu.csv missing
# mcadu.csv missing
# mcbs.csv missing
# mdwt.csv missing
# mdxg.csv missing
# mlacu.csv missing
# mnclu.csv missing
# mntk.csv missing
# modv.csv missing
# moncu.csv missing
# motnu.csv missing
# motnw.csv missing
# mracu.csv missing
# mrm.csv missing
# mrvi.csv missing
# msgm.csv missing
# mtacu.csv missing
# mudsu.csv missing
# naacu.csv missing
# nbacu.csv missing
# nbtx.csv missing
# nebcu.csv missing
# nfinu.csv missing
# ngacu.csv missing
# ngacw.csv missing
# ngms.csv missing
# nhicu.csv missing
# nktx.csv missing
# nmmcu.csv missing
# nmmcw.csv missing
# nnox.csv missing
# noacu.csv missing
# novs.csv missing
# novsu.csv missing
# npauu.csv missing
# nrix.csv missing
# oas.csv missing
# ocaxu.csv missing
# ocg.csv missing
# oepwu.csv missing
# olma.csv missing
# omeg.csv missing
# onds.csv missing
# openw.csv missing
# opesu.csv missing
# oprt.csv missing
# opt.csv missing
# orsnu.csv missing
# ostru.csv missing
# otra.csv missing
# otrau.csv missing
# otraw.csv missing
# oyst.csv missing
# ozon.csv missing
# pacxu.csv missing
# paic.csv missing
# paicu.csv missing
# paicw.csv missing
# paqcu.csv missing
# pax.csv missing
# pcvx.csv missing
# pdev.csv missing
# phar.csv missing
# phat.csv missing
# phic.csv missing
# phicu.csv missing
# phicw.csv missing
# plrx.csv missing
# pltk.csv missing
# posh.csv missing
# potx.csv missing
# powru.csv missing
# poww.csv missing
# ppghu.csv missing
# prax.csv missing
# prfx.csv missing
# prsru.csv missing
# prtc.csv missing
# psacu.csv missing
# pstx.csv missing
# ptacu.csv missing
# pticu.csv missing
# ptpi.csv missing
# ptrs.csv missing
# pubm.csv missing
# pxsap.csv missing
# pxsaw.csv missing
# qellu.csv missing
# qellw.csv missing
# qli.csv missing
# qqc.csv missing
# qqd.csv missing
# raacu.csv missing
# rapt.csv missing
# rchgu.csv missing
# rchgw.csv missing
# rmgbu.csv missing
# rnlx.csv missing
# rocc.csv missing
# roccu.csv missing
# roccw.csv missing
# rochu.csv missing
# root.csv missing
# rprx.csv missing
# rptx.csv missing
# rsss.csv missing
# rsva.csv missing
# rsvau.csv missing
# rsvaw.csv missing
# rxt.csv missing
# rzlt.csv missing
# saiiu.csv missing
# samau.csv missing
# sbnyp.csv missing
# sbtx.csv missing
# scoau.csv missing
# scps.csv missing
# seer.csv missing
# sft.csv missing
# sgam.csv missing
# sgamu.csv missing
# sgamw.csv missing
# sgtx.csv missing
# shacu.csv missing
# shc.csv missing
# shld.csv missing
# sigip.csv missing
# skyu.csv missing
# slcru.csv missing
# sln.csv missing
# smid.csv missing
# smmcu.csv missing
# smti.csv missing
# snrhu.csv missing
# spt.csv missing
# sqft.csv missing
# sracu.csv missing
# srsau.csv missing
# srsaw.csv missing
# sspku.csv missing
# stwou.csv missing
# stwow.csv missing
# sv.csv missing
# svacu.csv missing
# svacw.csv missing
# svfau.csv missing
# svoku.csv missing
# svsvu.csv missing
# svsvw.csv missing
# swetu.csv missing
# swtx.csv missing
# tars.csv missing
# tdacu.csv missing
# tekku.csv missing
# tekkw.csv missing
# thbru.csv missing
# thcau.csv missing
# thcbu.csv missing
# thtx.csv missing
# tls.csv missing
# tmkru.csv missing
# tmpm.csv missing
# tmpmu.csv missing
# tmpmw.csv missing
# tmts.csv missing
# tmtsu.csv missing
# tmtsw.csv missing
# trit.csv missing
# tritw.csv missing
# tsia.csv missing
# tsiau.csv missing
# tsiaw.csv missing
# tvacu.csv missing
# twct.csv missing
# twctu.csv missing
# twctw.csv missing
# tzacu.csv missing
# tzpsu.csv missing
# ucyb.csv missing
# upst.csv missing
# usat.csv missing
# vacqu.csv missing
# vacqw.csv missing
# vckau.csv missing
# vcvc.csv missing
# vcvcu.csv missing
# vcvcw.csv missing
# verx.csv missing
# vets.csv missing
# vih.csv missing
# vihau.csv missing
# vihaw.csv missing
# viiau.csv missing
# vincu.csv missing
# viri.csv missing
# vldrw.csv missing
# vmacu.csv missing
# vmar.csv missing
# vosou.csv missing
# vpn.csv missing
# vrdn.csv missing
# vs.csv missing
# vspru.csv missing
# vsprw.csv missing
# vssyw.csv missing
# vtaqu.csv missing
# vtiqu.csv missing
# vtrn.csv missing
# vtrs.csv missing
# vtru.csv missing
# vvos.csv missing
# wint.csv missing
# wish.csv missing
# wnw.csv missing
# woof.csv missing
# xog.csv missing
# xomap.csv missing
# yq.csv missing
# ysacu.csv missing
# ysacw.csv missing
# zgyhu.csv missing
# znte.csv missing
# znteu.csv missing
# zntew.csv missing
#
#    *** Complete sampling ***
#
#
# ****** Starting stocks DataFrame creation the sample ******
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 535
#
# ['aacqu.csv', 'abcl.csv', 'abnb.csv', 'abst.csv', 'acacu.csv', 'acacw.csv', 'acamu.csv', 'acevu.csv', 'ackiu.csv', 'actcu.csv', 'actcw.csv', 'aderu.csv', 'adoc.csv', 'adocr.csv', 'adocu.csv', 'adocw.csv', 'adtx.csv', 'aeacu.csv', 'afbi.csv', 'afino.csv', 'afrm.csv', 'agbau.csv', 'agcuu.csv', 'agcww.csv', 'ahacu.csv', 'ahacw.csv', 'akicu.csv', 'aku.csv', 'akus.csv', 'alacu.csv', 'algs.csv', 'alrs.csv', 'altuu.csv', 'amciu.csv', 'amhcu.csv', 'amst.csv', 'amyt.csv', 'andau.csv', 'annx.csv', 'aout.csv', 'apxt.csv', 'apxtu.csv', 'arbg.csv', 'arbgu.csv', 'arbgw.csv', 'arko.csv', 'arkow.csv', 'arqt.csv', 'avir.csv', 'bcab.csv', 'bcypu.csv', 'bdsx.csv', 'bdtx.csv', 'beneu.csv', 'bhfan.csv', 'bhse.csv', 'bhseu.csv', 'bhsew.csv', 'blct.csv', 'bltsu.csv', 'blu.csv', 'bluwu.csv', 'bntx.csv', 'bowx.csv', 'bowxu.csv', 'brez.csv', 'brezr.csv', 'brezu.csv', 'brezw.csv', 'brliu.csv', 'brpau.csv', 'brqs.csv', 'bscu.csv', 'bsjs.csv', 'bsms.csv', 'bsmt.csv', 'bsmu.csv', 'btaqu.csv', 'btbt.csv', 'btrs.csv', 'btrsw.csv', 'btwnu.csv', 'btwnw.csv', 'bwac.csv', 'bwacu.csv', 'bwacw.csv', 'bwmx.csv', 'bxrx.csv', 'calt.csv', 'capau.csv', 'capaw.csv', 'cert.csv', 'cfac.csv', 'cfacu.csv', 'cfacw.csv', 'cffau.csv', 'cfiiu.csv', 'cfiiw.csv', 'cfivu.csv', 'cgem.csv', 'cgrou.csv', 'chpmu.csv', 'ciicu.csv', 'cleu.csv', 'clnn.csv', 'clnnw.csv', 'clov.csv', 'clovw.csv', 'clvr.csv', 'clvrw.csv', 'cmctp.csv', 'cmlfu.csv', 'cmlfw.csv', 'cmps.csv', 'cnxc.csv', 'cofs.csv', 'coms.csv', 'comsw.csv', 'conx.csv', 'conxu.csv', 'conxw.csv', 'coolu.csv', 'crsau.csv', 'ctaqu.csv', 'ctec.csv', 'cvlb.csv', 'cyth.csv', 'cythw.csv', 'dbdr.csv', 'dbdru.csv', 'dbdrw.csv', 'dcbo.csv', 'dcrbu.csv', 'dcrbw.csv', 'dct.csv', 'ddmxu.csv', 'demz.csv', 'dfht.csv', 'dfhtu.csv', 'dfphu.csv', 'dgns.csv', 'dlcau.csv', 'dphcu.csv', 'drtt.csv', 'drvn.csv', 'dsac.csv', 'dsacu.csv', 'dsacw.csv', 'duneu.csv', 'duot.csv', 'dwcr.csv', 'dwus.csv', 'eacpu.csv', 'edtxu.csv', 'edut.csv', 'eldn.csv', 'emxf.csv', 'enfau.csv', 'enviu.csv', 'eosew.csv', 'ephyu.csv', 'eqos.csv', 'eres.csv', 'eresu.csv', 'esscu.csv', 'etacu.csv', 'eucr.csv', 'eucru.csv', 'eucrw.csv', 'eusgu.csv', 'eweb.csv', 'expcu.csv', 'fcacu.csv', 'fcacw.csv', 'fdmt.csv', 'fhtx.csv', 'fics.csv', 'fiiiu.csv', 'finmu.csv', 'flacu.csv', 'flux.csv', 'fmtx.csv', 'foxwu.csv', 'fsrvu.csv', 'ftcvu.csv', 'ftivu.csv', 'ftivw.csv', 'ftocu.csv', 'fultp.csv', 'gbny.csv', 'gbs.csv', 'gdrx.csv', 'gfnsz.csv', 'ghivu.csv', 'ghviu.csv', 'glaqu.csv', 'gmbtu.csv', 'gmhiu.csv', 'gmiiu.csv', 'gnacu.csv', 'gnrs.csv', 'gnrsu.csv', 'govx.csv', 'gpacu.csv', 'grcl.csv', 'grcyu.csv', 'grnvu.csv', 'grsvu.csv', 'grtx.csv', 'gsaqu.csv', 'gwac.csv', 'gwacu.csv', 'gwacw.csv', 'gxgx.csv', 'gxgxu.csv', 'haac.csv', 'haacu.csv', 'haacw.csv', 'hbt.csv', 'hcacu.csv', 'hcar.csv', 'hcaru.csv', 'hcarw.csv', 'hcccu.csv', 'hcchu.csv', 'hccou.csv', 'hcicu.csv', 'heccu.csv', 'hfen.csv', 'hlahu.csv', 'hmcou.csv', 'holuu.csv', 'holuw.csv', 'htoo.csv', 'htoow.csv', 'hudi.csv', 'hyacu.csv', 'hyfm.csv', 'ibex.csv', 'ibtk.csv', 'igacu.csv', 'igacw.csv', 'igms.csv', 'ihyf.csv', 'iiiiu.csv', 'ikt.csv', 'imvt.csv', 'inaqu.csv', 'inaqw.csv', 'inbx.csv', 'inkau.csv', 'inm.csv', 'invo.csv', 'ipa.csv', 'isun.csv', 'itacu.csv', 'itacw.csv', 'itos.csv', 'jcicu.csv', 'jfu.csv', 'joet.csv', 'jupw.csv', 'jupww.csv', 'jyac.csv', 'kairu.csv', 'kblmu.csv', 'kbnt.csv', 'kinzu.csv', 'klaqu.csv', 'kmph.csv', 'knte.csv', 'kros.csv', 'ksmt.csv', 'ksmtu.csv', 'lacqu.csv', 'latnu.csv', 'lbrdp.csv', 'lcahu.csv', 'lcapu.csv', 'lcapw.csv', 'lcy.csv', 'lcyau.csv', 'lcyaw.csv', 'legou.csv', 'lexx.csv', 'lexxw.csv', 'lfacu.csv', 'lftru.csv', 'lftrw.csv', 'livku.csv', 'lixt.csv', 'lixtw.csv', 'ljaqu.csv', 'lmacu.csv', 'lmpx.csv', 'loacu.csv', 'lotz.csv', 'lotzw.csv', 'lsaq.csv', 'lsea.csv', 'lseaw.csv', 'luxau.csv', 'luxaw.csv', 'lwacu.csv', 'maacu.csv', 'maacw.csv', 'macu.csv', 'macuu.csv', 'macuw.csv', 'mass.csv', 'mays.csv', 'mcacu.csv', 'mcadu.csv', 'mcbs.csv', 'mdwt.csv', 'mdxg.csv', 'mlacu.csv', 'mnclu.csv', 'mntk ...

# %% [markdown]
# ### Companies (randomly) selected

# %%
stocks_0_1_df.ticker.unique()
# Out:
# array(['GOCO'], dtype=object)

# %% [markdown]
# ### Setting date to `datetime` type

# %%
stocks_0_1_df['date'] = pd.to_datetime(stocks_0_1_df['date'])

# %% [markdown]
# ### Encoding the Returns

# %%
clean_stocks_0_1_df = thresholds_encoding(stocks_0_1_df)
clean_stocks_0_1_df
# Out:
#    ticker       date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0    GOCO 2020-08-31  33.679139   15.174507          11.178553 -3.302268e+07
# 1    GOCO 2020-09-01  32.726527   11.532625          11.532625 -3.277963e+07
# 2    GOCO 2020-09-02  37.707400   21.092564          15.933232 -3.149435e+07
# 3    GOCO 2020-09-03  35.696934   14.339909          15.655033 -3.165896e+07
# 4    GOCO 2020-09-04  33.676369    7.283763          14.238746 -3.219222e+07
# 5    GOCO 2020-09-08  32.320547    4.790419           8.804697 -3.220936e+07
# 6    GOCO 2020-09-09  31.803456    3.643054           5.239079 -3.263899e+07
# 7    GOCO 2020-09-10  36.794696   15.432099           7.955191 -3.253726e+07
# 8    GOCO 2020-09-11  33.309995    0.595788           6.556980 -3.322944e+07
# 9    GOCO 2020-09-14  33.955908    3.249097           6.425661 -3.421527e+07
# 10   GOCO 2020-09-15  32.456686    9.292035           4.378974 -3.462113e+07
# 11   GOCO 2020-09-16  32.456686    9.722222           7.421118 -3.499905e+07
# 12   GOCO 2020-09-17  42.154882   58.628319          25.880859 -3.394783e+07
# 13   GOCO 2020-09-18  44.963686   73.451327          47.267289 -3.090727e+07
# 14   GOCO 2020-09-21  41.349176   48.672566          60.250737 -3.108708e+07
# 15   GOCO 2020-09-22  46.554370   76.548673          66.224189 -3.043669e+07
# 16   GOCO 2020-09-23  47.588037   76.859504          67.360248 -3.074593e+07
# 17   GOCO 2020-09-24  43.099588   50.000000          67.802726 -3.090703e+07
# 18   GOCO 2020-09-25  46.130116   64.876033          63.911846 -3.079696e+07
# 19   GOCO 2020-09-28  43.958945   52.066116          55.647383 -3.102019e+07
# 20   GOCO 2020-09-29  42.634460   44.214876          53.719008 -3.125036e+07
# 21   GOCO 2020-09-30  40.788532   33.264463          43.181818 -3.154842e+07
# 22   GOCO 2020-10-01  47.240315   61.983471          46.487603 -3.101250e+07
# 23   GOCO 2020-10-02  54.333756   87.364621          60.870852 -3.042869e+07
# 24   GOCO 2020-10-05  56.846615   90.584416          79.977503 -3.057878e+07
# 25   GOCO 2020-10-06  48.931366   57.792208          78.580415 -3.166221e+07
# 26   GOCO 2020-10-07  49.382263   48.647865          65.674830 -3.154234e+07
# 27   GOCO 2020-10-08  45.959113   29.183750          45.207941 -3.195395e+07
# 28   GOCO 2020-10-09  44.203852   18.830497          32.220704 -3.220046e+07
# 29   GOCO 2020-10-12  41.927557    5.164203          17.726150 -3.272719e+07
# ..    ...        ...        ...         ...                ...           ...
# 51   GOCO 2020-11-11  61.517826   90.684932          93.239063 -3.443605e+07
# 52   GOCO 2020-11-12  41.581590   29.863014          72.763294 -3.659267e+07
# 53   GOCO 2020-11-13  44.792818   40.000000          53.515982 -3.503213e+07
# 54   GOCO 2020-11-16  42.098604   29.041096          32.968037 -3.578293e+07
# 55   GOCO 2020-11-17  44.524186   36.438356          35.159817 -3.528239e+07
# 56   GOCO 2020-11-18  48.242847   48.219178          37.899543 -3.445052e+07
# 57   GOCO 2020-11-19  50.247438   53.389831          46.015788 -3.416492e+07
# 58   GOCO 2020-11-20  47.057912   35.238095          45.615701 -3.455040e+07
# 59   GOCO 2020-11-23  42.512448    8.304498          32.310808 -3.581038e+07
# 60   GOCO 2020-11-24  42.010959    5.882353          16.474982 -3.687531e+07
# 61   GOCO 2020-11-25  42.840824    8.650519           7.612457 -3.701821e+07
# 62   GOCO 2020-11-27  43.921152   12.110727           8.881200 -3.714588e+07
# 63   GOCO 2020-11-30  39.212170    0.949367           7.236871 -3.869320e+07
# 64   GOCO 2020-12-01  35.781055    0.000000           4.353365 -4.059760e+07
# 65   GOCO 2020-12-02  43.400349   34.418605          11.789324 -3.871145e+07
# 66   GOCO 2020-12-03  47.341226   53.488372          29.302326 -3.755498e+07
# 67   GOCO 2020-12-04  53.393082   86.511628          58.139535 -3.626081e+07
# 68   GOCO 2020-12-07  54.734489   84.232365          74.744122 -3.624917e+07
# 69   GOCO 2020-12-08  58.237118   94.676806          88.473600 -3.570709e+07
# 70   GOCO 2020-12-09  55.713887   76.190476          85.033216 -3.609032e+07
# 71   GOCO 2020-12-10  65.248323   97.760211          89.542498 -3.493786e+07
# 72   GOCO 2020-12-11  61.104185   83.460560          85.803749 -3.536277e+07
# 73   GOCO 2020-12-14  65.495071   79.223301          86.814691 -3.694947e+07
# 74   GOCO 2020-12-15  62.639371   73.398058          78.693973 -3.787915e+07
# 75   GOCO 2020-12-16  61.109014   70.291262          74.304207 -3.826111e+07
# 76   GOCO 2020-12-17  64.654487   82.135922          75.275081 -3.782787e+07
# 77   GOCO 2020-12-18  66.178642   87.572816          80.000000 -3.708809e+07
# 78   GOCO 2020-12-21  61.677710   79.029126          82.912621 -3.693190e+07
# 79   GOCO 2020-12-22  55.489024   61.453744          76.018562 -3.778519e+07
# 80   GOCO 2020-12-23  58.871920   68.607595          69.696822 -3.744914e+07
#
#          OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0   19727779  1.345678  36.962293  15.600204  36.268790 -1.273478  -0.360273
# 1   18398149  1.315986  37.302140  14.753332  35.875948 -1.306275  -0.314456
# 2   19891855  1.283416  37.242524  15.845431  34.035917 -1.266827  -0.220007
# 3   18341764  1.272458  37.273151  14.773263  32.631102 -1.256983  -0.168130
# 4   17442836  1.223711  37.349518  14.231791  31.932080 -1.272040  -0.146550
# 5   16328860  1.182731  37.729062  13.638703  33.935236 -1.294868  -0.135502
# 6   15871514  1.133608  38.037321  13.388264  32.813755 -1.307569  -0.118562
# 7   16665003  1.104064  37.958266  14.369942  31.198692 -1.258744  -0.055790
# 8   15972825  1.090203  38.227780  13.467705  32.758637 -1.264380  -0.049141
# 9   17044382  1.043045  38.478044  13.050728  31.744388 -1.248803  -0.026851
# 10  16267960  1.031399  39.045016  12.217076  33.382342 -1.247096  -0.020116
# 11  17539171  0.984156  39.571490  11.873646  32.443943 -1.231547  -0.003653
# 12  19653562  1.040288  38.137810  19.090828  28.339790 -1.124362   0.082826
# 13  24342271  1.024910  36.758332  18.204288  26.647732 -1.000848   0.165072
# 14  23821525  1.018602  35.659490  16.965836  26.190252 -0.937344   0.182861
# 15  24654201  1.017631  34.469659  16.527030  24.281386 -0.826652   0.234842
# 16  25539270  1.004229  32.515551  19.774981  22.803203 -0.720137   0.273086
# 17  24948575  1.001784  31.463590  18.367679  26.316071 -0.680330   0.250314
# 18  25306443  0.968799  30.486770  17.616078  25.239224 -0.612671   0.254379
# 19  24990204  0.948171  29.437962  17.385759  23.912276 -0.577409   0.231712
# 20  24073317  0.914701  28.774112  16.718152  25.152632 -0.558359   0.200610
# 21  23526906  0.893273  28.410376  15.876650  25.729812 -0.558210   0.160607
# 22  24699210  0.892682  27.366304  18.081086  23.867158 -0.496290   0.178021
# 23  25884020  0.927490  25.928990  24.603996  21.280188 -0.368732   0.244464
# 24  27184830  0.908384  24.952498  25.786575  20.155005 -0.235075   0.302496
# 25  25922041  0.934021  23.420678  23.245029  24.934700 -0.208249   0.263458
# 26  26466058  0.909448  22.241024  22.150457  25.436593 -0.180072   0.233308
# 27  25895558  0.900909  21.399760  20.742225  25.590131 -0.193437   0.175955
# 28  25416703  0.898387  21.011609  19.294596  26.626132 -0.221646   0.118196
# 29  24731954  0.889930  20.880425  18.070715  26.644967 -0.267547   0.057836
# ..       ...       ...        ...        ...        ...       ...        ...
# 51  25169648  0.725090  25.973083  31.945662  17.497940 -0.102843   0.347567
# 52  20612724  0.855441  25.060181  25.126900  32.764151 -0.176924   0.218788
# 53  22762159  0.846481  24.212486  23.575506  30.741215 -0.203433   0.153824
# 54  21619632  0.861018  22.952996  24.593539  28.057800 -0.253793   0.082771
# 55  22556536  0.851659  21.905991  23.084810  27.260951 -0.268818   0.054197
# 56  23436634  0.842969  20.563090  24.031197  25.571552 -0.243224   0.063832
# 57  23901744  0.823472  19.294737  25.708450  24.304999 -0.201255   0.084641
# 58  23435956  0.806081  18.155732  24.651227  23.053745 -0.197191   0.070964
# 59  22138373  0.797789  17.376408  23.125928  26.738718 -0.240420   0.022188
# 60  20849247  0.773661  16.778624  22.142296  26.526067 -0.277134  -0.011620
# 61  21407889  0.733757  16.223539  21.678186  25.970071 -0.296358  -0.024676
# 62  21790890  0.699917  15.499396  22.379650  25.279997 -0.300065  -0.022706
# 63  20093976  0.698537  15.570756  20.820069  29.047423 -0.346616  -0.055405
# 64  18189575  0.697213  16.187680  19.367833  31.739814 -0.418225  -0.101612
# 65  20180515  0.701698  16.806942  17.867754  29.689141 -0.413723  -0.077688
# 66  21681461  0.695148  16.526082  21.478332  27.826244 -0.372774  -0.029391
# 67  23056513  0.697638  15.467182  26.635623  25.744385 -0.279805   0.050862
# 68  23952900  0.702806  15.189275  29.940777  23.727841 -0.190217   0.112361
# 69  24824940  0.705463  15.202664  29.924951  21.948514 -0.081163   0.177131
# 70  23144624  0.736501  15.585172  29.622673  19.520026 -0.014741   0.194843
# 71  24406234  0.824251  16.813486  31.989195  16.193990  0.154733   0.291453
# 72  23377506  0.831091  18.076483  30.619288  14.912794  0.251446   0.310533
# 73  25739100  0.905298  20.179475  35.729974  12.711418  0.388170   0.357806
# 74  24754734  0.917777  21.914927  32.725374  12.576845  0.466935   0.349257
# 75  23925582  0.915793  22.864971  30.452732  14.590511  0.510561   0.314306
# 76  24647651  0.903951  23.831902  29.437774  13.725483  0.587584   0.313063
# 77  25608873  0.876590  24.902156  29.818113  13.142681  0.663569   0.311238
# 78  24895850  0.868262  25.324861  27.953158  14.782131  0.680440   0.262487
# 79  23967551  0.876958  25.018165  25.698396  16.767372  0.632456   0.171603
# 80  24508304  0.859603  24.733376  24.344134  15.883759  0.628338   0.133988
#
#     MACD_signal  5TD_return  10TD_return  20TD_return
# 0     -0.913205           0            0            0
# 1     -0.991819           0            0            0
# 2     -1.046820           0            0            0
# 3     -1.088853           0            1            1
# 4     -1.125490           0            0            1
# 5     -1.159366           0            1            1
# 6     -1.189006           0            1            1
# 7     -1.202954           1            0            1
# 8     -1.215239           1            1            1
# 9     -1.221952           1            1            1
# 10    -1.226981           1            1            1
# 11    -1.227894           1            1            0
# 12    -1.207188           0            1            0
# 13    -1.165920           0            1            0
# 14    -1.120204           1            1            0
# 15    -1.061494           0            1            0
# 16    -0.993222           0            0            0
# 17    -0.930644           1            1            0
# 18    -0.867049           1            0            0
# 19    -0.809121           1            0            0
# 20    -0.758969           1            0            0
# 21    -0.718817           1            0            0
# 22    -0.674312           0            0            0
# 23    -0.613196           0            0            0
# 24    -0.537572           0            0            0
# 25    -0.471707           0            0            0
# 26    -0.413380           0            0            0
# 27    -0.369391           0            0            0
# 28    -0.339842           0            0            0
# 29    -0.325383           0            0            0
# ..          ...         ...          ...          ...
# 51    -0.450410           0            0            1
# 52    -0.395713           1            1            1
# 53    -0.357257           1            0            1
# 54    -0.336564           0            0            1
# 55    -0.323015           0            0            1
# 56    -0.307057           0            0            1
# 57    -0.285896           0            0            1
# 58    -0.268155           0            1            1
# 59    -0.262608           0            1            1
# 60    -0.265513           0            1            1
# 61    -0.271682           1            1            1
# 62    -0.277359           1            1            1
# 63    -0.291210           1            1            1
# 64    -0.316613           1            1            1
# 65    -0.336035           1            1            1
# 66    -0.343383           1            1            1
# 67    -0.330667           1            1            1
# 68    -0.302577           1            1            1
# 69    -0.258294           1            1            1
# 70    -0.209584           1            1            1
# 71    -0.136720           1            1            1
# 72    -0.059087           1            1            1
# 73     0.030364           0            0            1
# 74     0.117679           0            0            1
# 75     0.196255           1            1            1
# 76     0.274521           0            1            1
# 77     0.352330           0            1            1
# 78     0.417952           0            1            1
# 79     0.460853           1            1            1
# 80     0.494350           0            1            1
#
# [81 rows x 17 columns]

# %% [markdown]
# ### Getting `X_train`, `y_train`, `X_test`, `y_test`

# %%
train, test = train_test_split(clean_stocks_0_1_df, '1M')

# %%
train.shape
# Out:
# (64, 17)

# %%
test.shape
# Out:
# (17, 17)

# %% [markdown]
# ### Scaling train and transforming test

# %%
train, test = std_scaler(train, test)
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:31: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
X_train, y_train = build_input_arrays(train)
X_test, y_test = build_input_arrays(test)

# %%
X_train.shape
# Out:
# (20, 5, 12)

# %%
X_test.shape
# Out:
# (5, 5, 12)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Initialisation

# %%
X_train.shape[1:]
# Out:
# (5, 12)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers, models 
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import Precision

precision = Precision()


optim = RMSprop(learning_rate=0.0001)

def init_model(X_train):
    model = Sequential()
    reg_l1 = regularizers.l1(0.001)
    reg_l2 = regularizers.l2(0.001)
    reg_l1_l2 = regularizers.l1_l2(l1=0.001, l2=0.0001)
    
    model.add(layers.LSTM(200, return_sequences=True, input_shape=X_train.shape[1:], activation='tanh'))
    model.add(layers.LSTM(200, activation='tanh'))
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(200, activation='tanh', kernel_regularizer=reg_l1))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(100, activation='tanh', bias_regularizer=reg_l2))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(50, activation='relu', activity_regularizer=reg_l1_l2))
    model.add(layers.Dropout(0.3))
    #model.add(layers.Dense(25, activation='relu'))
    #model.add(layers.BatchNormalization())
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=[precision, 'accuracy'])
    
    return model

# %%
model = init_model(X_train)

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=10, restore_best_weights=True)

model.fit(X_train, y_train, 
          epochs=500, 
          batch_size=8,
          validation_split=0.25,
          callbacks=[es]
         )
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 567ms/step - loss: 3.2058 - precision: 0.5000 - accuracy: 0.7333 - val_loss: 3.1481 - val_precision: 0.4000 - val_accuracy: 0.4000
# Epoch 2/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.2323 - precision: 0.3000 - accuracy: 0.4667 - val_loss: 3.1512 - val_precision: 0.4000 - val_accuracy: 0.4000
# Epoch 3/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1203 - precision: 0.5000 - accuracy: 0.7333 - val_loss: 3.1538 - val_precision: 0.4000 - val_accuracy: 0.4000
# Epoch 4/500
# 2/2 [==============================] - 0s 38ms/step - loss: 3.1431 - precision: 0.3750 - accuracy: 0.6000 - val_loss: 3.1557 - val_precision: 0.4000 - val_accuracy: 0.4000
# Epoch 5/500
# 2/2 [==============================] - 0s 32ms/step - loss: 3.0688 - precision: 0.5000 - accuracy: 0.7333 - val_loss: 3.1552 - val_precision: 0.4000 - val_accuracy: 0.4000
# Epoch 6/500
# 2/2 [==============================] - 0s 30ms/step - loss: 3.1879 - precision: 0.2000 - accuracy: 0.3333 - val_loss: 3.1564 - val_precision: 0.2500 - val_accuracy: 0.2000
# Epoch 7/500
# 2/2 [==============================] - 0s 32ms/step - loss: 3.1929 - precision: 0.3000 - accuracy: 0.4667 - val_loss: 3.1566 - val_precision: 0.2500 - val_accuracy: 0.2000
# Epoch 8/500
# 2/2 [==============================] - 0s 32ms/step - loss: 2.9682 - precision: 0.5000 - accuracy: 0.7333 - val_loss: 3.1572 - val_precision: 0.2500 - val_accuracy: 0.2000
# Epoch 9/500
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0520 - precision: 0.5000 - accuracy: 0.7333 - val_loss: 3.1564 - val_precision: 0.2500 - val_accuracy: 0.2000
# Epoch 10/500
# 2/2 [==============================] - 0s 27ms/step - loss: 3.1800 - precision: 0.3333 - accuracy: 0.5333 - val_loss: 3.1578 - val_precision: 0.2500 - val_accuracy: 0.2000
# Epoch 11/500
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0543 - precision: 0.4444 - accuracy: 0.6667 - val_loss: 3.1578 - val_precision: 0.2500 - val_accuracy: 0.2000

# %% [markdown]
# ### Model Evalutation

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (5, 1)

# %%
y_test.sum()/len(y_test)
# Out:
# 0.4

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1555 - precision: 0.4000 - accuracy: 0.4000
# [3.1555283069610596, 0.4000000059604645, 0.4000000059604645]

# %% [markdown]
# ### Model Score Saving

# %%
model_runs_history = runs_history_loading()
# Out:
# Previous models scores:
#  [('tickers', ['loss', 'precision', 'accuracy']), (['LEGN'], [3.175008773803711, 0.4000000059604645, 0.4000000059604645]), (['LMFAW'], [3.1875081062316895, 0.0, 0.0]), (['KBNTW'], [5.809561729431152, 0.4000000059604645, 0.4000000059604645]), (['KYMR'], [3.1488096714019775, 0.75, 0.6000000238418579])]

# %%
model_runs_history
# Out:
# [('tickers', ['loss', 'precision', 'accuracy']),
#  (['LEGN'], [3.175008773803711, 0.4000000059604645, 0.4000000059604645]),
#  (['LMFAW'], [3.1875081062316895, 0.0, 0.0]),
#  (['KBNTW'], [5.809561729431152, 0.4000000059604645, 0.4000000059604645]),
#  (['KYMR'], [3.1488096714019775, 0.75, 0.6000000238418579])]

# %%
model_runs_history.append((list(stocks_0_1_df.ticker.unique()),model.evaluate(X_test, y_test)))
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1555 - precision: 0.4000 - accuracy: 0.4000

# %%
runs_history_saving(model_runs_history)
# Out:
# History Saving Complete!
# File saved as: charles_companies_0_1_model_history
# File location:../models_histories
