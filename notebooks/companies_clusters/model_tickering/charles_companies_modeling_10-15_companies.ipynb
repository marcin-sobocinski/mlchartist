# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import joblib
import os
import random

# %% [markdown]
# ====================================================================================================
#
# **Goal : gather similar companies according to their features and number of trading days**
#
# **Use : provide coherent and meaningful data to model**
#
#
# **(_Ideal_ : develop tailored model to each type of groups)**
#
#
#
# **_See Notebook `Table of content` for good understanding about what this notebook is doing when ran_**
#
# ====================================================================================================

# %% [markdown]
# # Anaysis of Companies Age from `nasdaq_us_stats.xls`

# %%
#!!!Path might not be the same!!!

meta_df = pd.read_csv('../../../raw_data/metadata/nasdaq_us_stats.xls')

# %%
meta_df.head()
# Out:
#    Unnamed: 0     stock  days  min_close  max_close  start_date    end_date
# 0           0   AACG.US  3165    0.21703      3.850  2008-01-28  2021-01-25
# 1           1   AACQ.US    96    9.62000     11.070  2020-09-08  2021-01-25
# 2           2  AACQU.US   134   10.00000     11.900  2020-07-15  2021-01-25
# 3           3  AACQW.US    95    1.07500      2.580  2020-09-09  2021-01-25
# 4           4    AAL.US  1793    9.04000     56.989  2013-12-10  2021-01-25

# %%
meta_df.describe()
# Out:
#         Unnamed: 0          days    min_close     max_close
# count  3921.000000   3921.000000  3921.000000  3.921000e+03
# mean   1960.000000   1876.186942     8.257047  6.181576e+06
# std    1132.039531   1795.084440    16.268917  3.863434e+08
# min       0.000000      1.000000     0.001000  2.400000e-01
# 25%     980.000000    312.000000     1.490000  1.438700e+01
# 50%    1960.000000   1286.000000     5.010000  2.880000e+01
# 75%    2940.000000   3775.000000    10.384000  6.533000e+01
# max    3920.000000  12879.000000   647.290000  2.419200e+10

# %%
meta_df = meta_df[['stock', 'days', 'min_close', 'max_close']]

# %% [markdown]
# ## Company age classification

# %%
meta_df['range_price'] = meta_df['max_close'] - meta_df['min_close']
meta_df['years'] = meta_df['days']/365

# %%
clean_meta_df = meta_df[['stock', 'years', 'range_price']]

# %%
sns.histplot(clean_meta_df['years'], binwidth=1)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %% [markdown]
# 👆👆**Anomaly at less than 1 year and 10 year old companies**👆👆

# %%
bins = [0, 1, 5, 10, 15, 20, 25, 30, 40]

clean_meta_df['company_vintage'] = pd.cut(meta_df['years'].copy(), 
                                          bins)                            # A company aged of 1Y and one day is
                                          #labels=['(0, 1]','(1, 5]',       # part of the '(1, 5]' class
                                          #        '(5, 10]', '(10, 15]',
                                          #        '(15, 20]', '(20, 25]',
                                          #        '(25, 30]', '(30, 40]'])
print(clean_meta_df['company_vintage'])
# Out:
# 0        (5, 10]
# 1         (0, 1]
# 2         (0, 1]
# 3         (0, 1]
# 4         (1, 5]
# 5        (5, 10]
# 6        (5, 10]
# 7       (10, 15]
# 8       (25, 30]
# 9       (10, 15]
# 10      (10, 15]
# 11      (10, 15]
# 12        (0, 1]
# 13        (0, 1]
# 14        (1, 5]
# 15      (10, 15]
# 16      (10, 15]
# 17        (0, 1]
# 18        (0, 1]
# 19        (1, 5]
# 20       (5, 10]
# 21        (0, 1]
# 22        (0, 1]
# 23        (0, 1]
# 24      (10, 15]
# 25        (0, 1]
# 26        (0, 1]
# 27        (0, 1]
# 28        (1, 5]
# 29        (0, 1]
#           ...
# 3891     (5, 10]
# 3892     (5, 10]
# 3893      (0, 1]
# 3894      (0, 1]
# 3895      (0, 1]
# 3896      (0, 1]
# 3897      (0, 1]
# 3898      (1, 5]
# 3899    (20, 25]
# 3900      (1, 5]
# 3901      (0, 1]
# 3902      (0, 1]
# 3903      (0, 1]
# 3904    (10, 15]
# 3905    (10, 15]
# 3906      (1, 5]
# 3907      (1, 5]
# 3908      (1, 5]
# 3909     (5, 10]
# 3910      (0, 1]
# 3911      (0, 1]
# 3912      (0, 1]
# 3913      (0, 1]
# 3914      (1, 5]
# 3915      (1, 5]
# 3916    (10, 15]
# 3917     (5, 10]
# 3918      (1, 5]
# 3919      (1, 5]
# 3920      (1, 5]
# Name: company_vintage, Length: 3921, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 5] < (5, 10] < (10, 15] < (15, 20] < (20, 25] < (25, 30] < (30, 40]]
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
clean_meta_df['company_vintage'].apply(str)
print(clean_meta_df.info())
clean_meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
# stock              3921 non-null object
# years              3921 non-null float64
# range_price        3921 non-null float64
# company_vintage    3921 non-null category
# dtypes: category(1), float64(2), object(1)
# memory usage: 95.9+ KB
# None
#       stock     years  range_price company_vintage
# 0   AACG.US  8.671233      3.63297         (5, 10]
# 1   AACQ.US  0.263014      1.45000          (0, 1]
# 2  AACQU.US  0.367123      1.90000          (0, 1]
# 3  AACQW.US  0.260274      1.50500          (0, 1]
# 4    AAL.US  4.912329     47.94900          (1, 5]

# %% [markdown]
# ## Classification Results

# %%
sns.histplot(data=clean_meta_df, x='years', binwidth=1, hue='company_vintage')
#plt.savefig('companies_age_classification.pdf', dpi=1200)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %%
clean_meta_df.groupby('company_vintage')['stock'].count()
# Out:
# company_vintage
# (0, 1]      1069
# (1, 5]      1252
# (5, 10]      564
# (10, 15]     950
# (15, 20]      32
# (20, 25]      37
# (25, 30]      13
# (30, 40]       4
# Name: stock, dtype: int64

# %% [markdown]
# ### Saving List of Companies Name via `joblib`

# %%
stocks_bin_1 = []
stocks_bin_2 = []
stocks_bin_3 = []
stocks_bin_4 = []
stocks_bin_5 = []
stocks_bin_6 = []
stocks_bin_7 = []
stocks_bin_8 = []

for idx, row in clean_meta_df.iterrows():
    x = row['years']                                            # <=> ['days']/365
    st = row['stock'].replace('.US', '')
    
    #print(idx, x, row['stock'])
    if x <= 1 : stocks_bin_1.append(st)
    elif x > 1 and x <= 5: stocks_bin_2.append(st)
    elif x > 5 and x <= 10: stocks_bin_3.append(st)
    elif x > 10 and x <= 15: stocks_bin_4.append(st)        
    elif x > 15 and x <= 20: stocks_bin_5.append(st)        
    elif x > 20 and x <= 25: stocks_bin_6.append(st)        
    elif x > 25 and x <= 30: stocks_bin_7.append(st)        
    elif x > 30: stocks_bin_8.append(st)
    
print(f"Number of companies with less than a year of history: {len(stocks_bin_1)}")
print(f"Number of companies with between a year and 5 years of history: {len(stocks_bin_2)}")    
print(f"Number of companies with between 5 years and 10 years of history: {len(stocks_bin_3)}")
print(f"Number of companies with between 10 years and 15 years of history: {len(stocks_bin_4)}")
print(f"Number of companies with between 15 years and 20 years of history: {len(stocks_bin_5)}")
print(f"Number of companies with between 20 years and 25 years of history: {len(stocks_bin_6)}")
print(f"Number of companies with between 25 years and 30 years of history: {len(stocks_bin_7)}")
print(f"Number of companies with more than 30 years of history: {len(stocks_bin_8)}")

stock_bins = [stocks_bin_1, stocks_bin_2, stocks_bin_3,
              stocks_bin_4, stocks_bin_5, stocks_bin_6,
              stocks_bin_7, stocks_bin_8]
# Out:
# Number of companies with less than a year of history: 1069
# Number of companies with between a year and 5 years of history: 1252
# Number of companies with between 5 years and 10 years of history: 564
# Number of companies with between 10 years and 15 years of history: 950
# Number of companies with between 15 years and 20 years of history: 32
# Number of companies with between 20 years and 25 years of history: 37
# Number of companies with between 25 years and 30 years of history: 13
# Number of companies with more than 30 years of history: 4

# %%
stock_bins
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# ❗❗❗**You should check the path you want to save the `stock_bins` list**❗❗❗
#
# (The `metadata` directory is where I saved the `nasdaq_us_stats.xls` csv file of Ian)

# %%
joblib.dump(stock_bins, '../../../raw_data/metadata/tickers_per_history_lenght__list')
# Out:
# ['../../../raw_data/metadata/tickers_per_history_lenght__list']

# %%
stocks_tickers = joblib.load('../../../raw_data/metadata/tickers_per_history_lenght__list')
stocks_tickers
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# # Modeling Companies per Vintage - (10, 15]

# %% [markdown]
# ## Functions definitions & Imports

# %% [markdown]
# ### `precise_stocks_selector_local()`

# %%
from termcolor import colored

def precise_stocks_selector_local(tickers_list=[], path_files='../../../raw_data/processed/',
                                  random_sample=False, num_samp = 2, verbose=1):
    """
    Returns a concatened DataFrame of the stocks data which tickers' list were passed
    
    If random_sample = True, return a DataFrame with random sample of stocks from the tickers' list passed
    
    Example:
    INPUT: ['AEP', 'GT', 'INTC', 'PEP']
    OUTPUT: df.tickers.unique() ==> ['GT', 'INTC']
   
    """
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        
    t = []
    for ticker in tickers_list:
        ticker = f"{ticker}.csv".lower()
        t.append(ticker)
    tickers_list = t
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        print()
        print()
    
    if verbose >= 1:
        print(colored(f"****** Starting browsing the '{path_files}' directory ******", 'magenta'))
        
    filenames = []
    missing_stock_csv = []

    
    if random_sample:
        for file in os.listdir(path_files):
            if file.endswith('.csv'):
                if file in tickers_list:
                    filenames.append(file)
        
        for ticker in tickers_list:
            #print(ticker)
            #print(missing_stock_csv)
            if ticker not in filenames:
                missing_stock_csv.append(ticker)
                print(colored(f"{ticker} missing", 'red'))
            else:
                pass
        
        #print(missing_stock_csv)
        
        for missed in missing_stock_csv:
            if missed not in tickers_list:
                missing_stock_csv.remove(missed)
        #print(missing_stock_csv)
        
        if len(filenames) < num_samp:
            print(colored('\nSample size bigger that nuber of companies available\n','red'))
        else:
            sample = random.sample(filenames, num_samp)
            
        if verbose >= 1:
            print(colored("\n   *** Complete sampling ***", 'green'))
            
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting stocks DataFrame creation the sample ******", 'magenta'))
        
        dfs = []

        for ticker in sample:
            ticker_df = pd.read_csv('../../../raw_data/processed/'+ticker)
            dfs.append(ticker_df)
            if verbose == 2:
                print(colored(f"{ticker} DataFrame created", 'yellow'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
            
            
    else: 
        for file in os.listdir(path_files):
            if (file.endswith('.csv')):
                filenames.append(file)
                #print(f"{file}")
        
        if verbose >= 1:
            print(colored("\n   *** Complete file selection ***", 'green'))
        
        dfs = []
        
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"****** Starting stocks DataFrame creation the sample ******", 'magenta'))
      
        for ticker in tickers_list:
            if ticker in filenames:
                #print(f"{ticker}")
                ticker_df = pd.read_csv('../../../raw_data/processed/'+ticker)
                dfs.append(ticker_df)
                if verbose == 2:
                    print(colored(f"{ticker} DataFrame created", 'yellow'))
            else:
                missing_stock_csv.append(ticker)
                print(colored(f"\n{ticker} missing", 'red'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
    
    
    if len(missing_stock_csv) !=0:
        
        print(colored("""\n\n##### Problematic Issue: following stocks not in local database! #####""", "red"))
        print(colored(f"Number of missed stocks: {len(missing_stock_csv)}", "red"))
        print(colored(f"""\n{missing_stock_csv}""", "red"))
    
    return pd.concat(dfs)

# %% [markdown]
# ### Preprocessing Functions

# %%
from sklearn.preprocessing import StandardScaler

def std_scaler(train_set, test_set=0, fit=True, transform=True):
    """
    Scale the data with SKlearn StandardScaler
    
    Fit (if fit) the scaler on train and transform it (if transform) train_set
        and test_set (if test_set and (fit and transform))
    """
    
    scaler = StandardScaler()
    
    if len(test_set)!=0 and len(train_set)!=0:
        col_to_scale_df = test_set.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
        col_to_scale = list(col_to_scale_df)
        
        scaled_test_df = test_set
        
        scaled_train_df = train_set
        
        for col in col_to_scale:
            if fit and transform:
                scaled_train_df[col] = scaler.fit_transform(scaled_train_df[[col]])

            elif fit:
                scaled_train_df[col] = scaler.fit(scaled_train_df[[col]])

        for col in col_to_scale:
            if fit and transform:
                scaler.fit(train_set[[col]])
                scaled_test_df[col] = scaler.transform(scaled_test_df[[col]])
        
        return scaled_train_df, scaled_test_df
    
    
    elif len(train_set)!=0:
        col_to_scale_df = train_set.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
        col_to_scale = list(col_to_scale_df)
        
        scaled_train_df = train_set
        
        for col in col_to_scale:
            if fit and transform:
                scaled_train_df[col] = scaler.fit_transform(scaled_train_df[[col]])

            elif fit:
                scaled_train_df[col] = scaler.fit(scaled_train_df[[col]])

                if transform:
                    scaled_train_df[col] = scaler.transform(scaled_train_df[[col]])
        return scaled_train_df

# %%
#Marcin's Function

def build_input_arrays(df, time_window=5, stride=3, input_cols=['RSI', 'Stochastic', 'Stochastic_signal', 'ADI',
       'OBV', 'ATR', 'ADX', 'ADX_pos', 'ADX_neg', 'MACD', 'MACD_diff',
       'MACD_signal'] , target_col='5TD_return'):
    output_array = []
    target_array = []
    df_sorted = df.sort_values('date', ascending=False)
    df_sorted.reset_index(drop=True, inplace=True)
    for row in range(0, len(df), stride):
        df_slice = df_sorted.iloc[row: row + time_window]
        if df_slice.shape[0]==time_window:
            output_array.append(np.array(df_slice[input_cols].values))
            target_array.append(df_slice[target_col].iloc[0])
    return np.array(output_array), np.array(target_array)

# %%
#Ian's Function

def train_test_split(df, test_set_size='3Y'):
    """
    Split the preprocessed stock data file into a train and test dataset
    INPUT: the dataframe to be split, and size of the test set in months or years ('3M' or '2Y')
    OUTPUT: returns a train_set and test_set dataframe, index is set to the date
    
    EXAMPLE: train_set, test_set = train_test_split(input_df, '3Y')
    """
    if not np.issubdtype(df['date'].dtype, np.datetime64):
        df['date'] = pd.to_datetime(df['date'], format=('%Y-%m-%d'))
    test_set = df.sort_values(by="date",ascending=True).set_index("date").last(test_set_size)
    train_set = df.drop(df.tail(len(test_set)).index).set_index("date")
    test_set.reset_index(inplace=True)
    train_set.reset_index(inplace=True)
    return train_set, test_set

# %%
def thresholds_encoding(df, r5d=0.0006, same_thresholds=True, r10d=0.0012, r20d=0.0024):
    """
    Binary encode the 5, 10 and 20 days return columns according to the thresholds
    
    INPUT: dataframe with '5TD_return', '10TD_return' and '20TD_return' columns
    OUTPUT: dataframe with binary encoded aforementionned columns
    
    If the thresolds returns are the same on a yearly basis for the different period use:
                r10d = r5d * 2 
            and
                r20d = r10d * 2
            keep same_thresholds=True
        Otherwise, define manually r10d and r20d
    """
    wk_df = df.copy()
    
    if same_thresholds:
        r10d = r5d * 2
        r20d = r10d * 2
    
    wk_df['5TD_return'] = wk_df['5TD_return'].apply(lambda x: 1 if x > r5d else 0)
    wk_df['10TD_return'] = wk_df['10TD_return'].apply(lambda x: 1 if x > r10d else 0)
    wk_df['20TD_return'] = wk_df['20TD_return'].apply(lambda x: 1 if x > r20d else 0)
    
    return wk_df

# %% [markdown]
# ### Visualisation Functions

# %%
def plot_loss_accuracy(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()

# %% [markdown]
# ### Model Saving Functions

# %%
def runs_history_loading(name='charles', vintage='10-15', path_files='../models_histories'):
    
    filenames = []
    
    run_history = f"{name}_companies_{vintage}_model_history"
    
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if run_history in filenames:
        print("Previous models scores:\n",joblib.load(path_files+'/'+run_history))
        return joblib.load(path_files+'/'+run_history)
    
    else:
        print("No previous models scores found\nReturning uncomplete list: [('tickers', ['loss', 'precision', 'accuracy'])]")
        return [('tickers', ['loss', 'precision', 'accuracy'])]

# %%
def runs_history_saving(score_file, vintage='10-15', author='charles', path_files='../models_histories'):
    filenames = []
    
    run_history = f"{author}_companies_{vintage}_model_history"
        
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if f"{author}_old_cie_model_history" in filenames:
        print("Previous models scores found:\n", joblib.load(path_files+'/'+run_history))
        confirmation = input(prompt="""You are about to save over the previous history, which will replace it by your new history.
        Are you sure you want to do that? (Y/n)""")
        
        if confirmation =='Y':
            joblib.dump(path_files+'/'+run_history)
            print("History Saving Complete!")
            print(f"File saved as: {author}_companies_{vintage}_model_history")
            print(f"File location:{path_files}")            
            
        else:
            print("History Saving Aborted!")
    
    else:
        joblib.dump(score_file, path_files+'/'+run_history)
        print("History Saving Complete!")
        print(f"File saved as: {author}_companies_{vintage}_model_history")
        print(f"File location:{path_files}")

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Importing the (10, 15] Companies Sample

# %%
companies_10_15 = stocks_tickers[3] ### Change the stocks_tickers[i] to get
companies_10_15                     ###    the appropriate subset of companies!!
# Out:
# ['AAON',
#  'AAWW',
#  'AAXN',
#  'ABCB',
#  'ABIO',
#  'ABMD',
#  'ACAD',
#  'ACER',
#  'ACGL',
#  'ACHV',
#  'ACIW',
#  'ACLS',
#  'ACOR',
#  'ACTG',
#  'ADTN',
#  'ADXS',
#  'AEHR',
#  'AEIS',
#  'AEY',
#  'AEZS',
#  'AGEN',
#  'AGYS',
#  'AINV',
#  'AIRT',
#  'AKAM',
#  'ALCO',
#  'ALGN',
#  'ALKS',
#  'ALNY',
#  'ALOT',
#  'ALSK',
#  'ALT',
#  'ALXN',
#  'AMAG',
#  'AMED',
#  'AMKR',
#  'AMNB',
#  'AMOT',
#  'AMRB',
#  'AMRN',
#  'AMSC',
#  'AMSF',
#  'AMSWA',
#  'AMWD',
#  'ANAT',
#  'ANDE',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANSS',
#  'APDN',
#  'APEX',
#  'APOG',
#  'APYX',
#  'ARCB',
#  'ARCC',
#  'ARKR',
#  'ARLP',
#  'ARNA',
#  'AROW',
#  'ARTNA',
#  'ARTW',
#  'ASML',
#  'ASRT',
#  'ASRV',
#  'ASTC',
#  'ASTE',
#  'ASUR',
#  'ASYS',
#  'ATAX',
#  'ATEC',
#  'ATHE',
#  'ATLC',
#  'ATLO',
#  'ATNI',
#  'ATRC',
#  'ATRI',
#  'ATRS',
#  'ATSG',
#  'ATVI',
#  'AUB',
#  'AUDC',
#  'AUTO',
#  'AVDL',
#  'AVID',
#  'AVT',
#  'AWRE',
#  'AXAS',
#  'AXDX',
#  'AXTI',
#  'AYRO',
#  'AZN',
#  'AZPN',
#  'BANF',
#  'BASI',
#  'BBGI',
#  'BBI',
#  'BBQ',
#  'BBSI',
#  'BCOR',
#  'BCPC',
#  'BCRX',
#  'BDGE',
#  'BDSI',
#  'BECN',
#  'BELFB',
#  'BFIN',
#  'BGCP',
#  'BGFV',
#  'BIDU',
#  'BIOL',
#  'BJRI',
#  'BKNG',
#  'BLDP',
#  'BLDR',
#  'BLKB',
#  'BMRC',
#  'BMRN',
#  'BMTC',
#  'BOCH',
#  'BOKF',
#  'BOOM',
#  'BPFH',
#  'BPOP',
#  'BRKL',
#  'BRKR',
#  'BRKS',
#  'BSET',
#  'BSQR',
#  'BSRR',
#  'BSTC',
#  'BUSE',
#  'BWEN',
#  'CAAS',
#  'CAC',
#  'CACC',
#  'CAKE',
#  'CALM',
#  'CAMP',
#  'CAMT',
#  'CAR',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATY',
#  'CBAT',
#  'CBIO',
#  'CBRL',
#  'CBSH',
#  'CCBG',
#  'CCMP',
#  'CCNE',
#  'CCOI',
#  'CCRN',
#  'CDMO',
#  'CDNS',
#  'CDZI',
#  'CECE',
#  'CENT',
#  'CENX',
#  'CERN',
#  'CERS',
#  'CEVA',
#  'CFFN',
#  'CGEN',
#  'CGNX',
#  'CGO',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHI',
#  'CHNR',
#  'CHY',
#  'CIDM',
#  'CIVB',
#  'CLAR',
#  'CLBS',
#  'CLCT',
#  'CLDX',
#  'CLFD',
#  'CLMT',
#  'CLRO',
#  'CLSN',
#  'CLWT',
#  'CMCO',
#  'CMCT',
#  'CME',
#  'CMPR',
#  'CMTL',
#  'CNBKA',
#  'CNOB',
#  'CNSL',
#  'CNTY',
#  'CNXN',
#  'COHR',
#  'COHU',
#  'COKE',
#  'COLB',
#  'COLM',
#  'CONN',
#  'CORE',
#  'CORT',
#  'COWN',
#  'CPRT',
#  'CPSI',
#  'CPSS',
#  'CPST',
#  'CRAI',
#  'CREE',
#  'CREG',
#  'CRESY',
#  'CRIS',
#  'CRMT',
#  'CRNT',
#  'CROX',
#  'CRUS',
#  'CRVL',
#  'CRWS',
#  'CSGP',
#  'CSGS',
#  'CSII',
#  'CSPI',
#  'CSQ',
#  'CSWC',
#  'CTBI',
#  'CTG',
#  'CTHR',
#  'CTRN',
#  'CTSH',
#  'CUBA',
#  'CUTR',
#  'CVBF',
#  'CVCO',
#  'CVGI',
#  'CVGW',
#  'CVLG',
#  'CVV',
#  'CWCO',
#  'CWST',
#  'CYAN',
#  'CYBE',
#  'CYCC',
#  'CYRN',
#  'CYTK',
#  'CZNC',
#  'DAIO',
#  'DAKT',
#  'DCOM',
#  'DENN',
#  'DGICA',
#  'DGII',
#  'DGLY',
#  'DHC',
#  'DHIL',
#  'DIOD',
#  'DISCA',
#  'DLHC',
#  'DMLP',
#  'DORM',
#  'DOX',
#  'DRRX',
#  'DSGX',
#  'DSPG',
#  'DSWL',
#  'DVAX',
#  'DWSN',
#  'DXCM',
#  'DXLG',
#  'DXPE',
#  'DXYN',
#  'DYNT',
#  'DZSI',
#  'EBIX',
#  'EBTC',
#  'ECOL',
#  'ECPG',
#  'EDAP',
#  'EDUC',
#  'EEFT',
#  'EFSC',
#  'EGBN',
#  'EGLE',
#  'EGOV',
#  'ELTK',
#  'EMKR',
#  'EML',
#  'ENDP',
#  'ENG',
#  'ENTG',
#  'EPAY',
#  'EQIX',
#  'ERIC',
#  'ERIE',
#  'ESCA',
#  'ESLT',
#  'EVOL',
#  'EWBC',
#  'EXAS',
#  'EXEL',
#  'EXFO',
#  'EXPE',
#  'EXPO',
#  'EXTR',
#  'EYPT',
#  'EZPW',
#  'FARM',
#  'FARO',
#  'FBNC',
#  'FCBC',
#  'FCEL',
#  'FCFS',
#  'FCNCA',
#  'FEIM',
#  'FELE',
#  'FFBC',
#  'FFIC',
#  'FFIN',
#  'FFIV',
#  'FISI',
#  'FIZZ',
#  'FLIC',
#  'FLIR',
#  'FLL',
#  'FLWS',
#  'FLXS',
#  'FMBI',
#  'FNHC',
#  'FNLC',
#  'FONR',
#  'FORD',
#  'FORM',
#  'FORR',
#  'FOSL',
#  'FRBK',
#  'FRME',
#  'FRPH',
#  'FSTR',
#  'FTEK',
#  'FULT',
#  'FUNC',
#  'FUND',
#  'FVE',
#  'FWONA',
#  'FWRD',
#  'GABC',
#  'GAIA',
#  'GAIN',
#  'GASS',
#  'GBCI',
#  'GBLI',
#  'GDEN',
#  'GEG',
#  'GENC',
#  'GEOS',
#  'GERN',
#  'GGAL',
#  'GIFI',
#  'GIGM',
#  'GIII',
#  'GILT',
#  'GLAD',
#  'GLDD',
#  'GLNG',
#  'GNSS',
#  'GOGL',
#  'GOOD',
#  'GOOGL',
#  'GPORQ',
#  'GPRE',
#  'GRMN',
#  'GROW',
#  'GRVY',
#  'GSBC',
#  'GVP',
#  'HA',
#  'HAIN',
#  'HALL',
#  'HALO',
#  'HAYN',
#  'HBIO',
#  'HBNC',
#  'HCKT',
#  'HCSG',
#  'HDSN',
#  'HEES',
#  'HELE',
#  'HFWA',
#  'HIBB',
#  'HIHO',
#  'HIMX',
#  'HLIO',
#  'HLIT',
#  'HMSY',
#  'HOFT',
#  'HOLI',
#  'HOLX',
#  'HOMB',
#  'HSII',
#  'HSKA',
#  'HSON',
#  'HST',
#  'HSTM',
#  'HTBK',
#  'HTLD',
#  'HTLF',
#  'HUBG',
#  'HURC',
#  'HURN',
#  'HWC',
#  'HWCC',
#  'HWKN',
#  'IART',
#  'IBCP',
#  'IBOC',
#  'ICAD',
#  'ICLR',
#  'ICON',
#  'ICUI',
#  'IDCC',
#  'IDN',
#  'IDRA',
#  'IDXG',
#  'IDXX',
#  'IEC',
#  'IEP',
#  'IIIN',
#  'IIN',
#  'IIVI',
#  'ILMN',
#  'IMBI',
#  'IMGN',
#  'IMKTA',
#  'IMMR',
#  'INCY',
#  'INDB',
#  'INFI',
#  'INO',
#  'INOD',
#  'INSG',
#  'INVA',
#  'INVE',
#  'IONS',
#  'IOSP',
#  'IPAR',
#  'IRBT',
#  'IRIX',
#  'ISBC',
#  'ISIG',
#  'ISNS',
#  'ISRG',
#  'ISSC',
#  'ITI',
#  'ITRI',
#  'ITRN',
#  'IVAC',
#  'JACK',
#  'JAKK',
#  'JAN',
#  'JBHT',
#  'JBLU',
#  'JBSS',
#  'JCOM',
#  'JCS',
#  'JJSF',
#  'JKHY',
#  'JOBS',
#  'JOUT',
#  'JRJC',
#  'JVA',
#  'KALU',
#  'KELYA',
#  'KFRC',
#  'KIRK',
#  'KLIC',
#  'KOPN',
#  'KRNY',
#  'KSPN',
#  'KTCC',
#  'KTOS',
#  'KVHI',
#  'LAKE',
#  'LANC',
#  'LAWS',
#  'LBAI',
#  'LBTYA',
#  'LBTYK',
#  'LCUT',
#  'LECO',
#  'LFUS',
#  'LGND',
#  'LHCG',
#  'LINC',
#  'LIVE',
#  'LKFN',
#  'LKQ',
#  'LMNX',
#  'LNDC',
#  'LNT',
#  'LORL',
#  'LPSN',
#  'LPTH',
#  'LQDT',
#  'LSCC',
#  'LSTR',
#  'LTBR',
#  'LTRX',
#  'LUNA',
#  'LWAY',
#  'LXRX',
#  'LYTS',
#  'MAGS',
#  'MANH',
#  'MANT',
#  'MARK',
#  'MARPS',
#  'MATW',
#  'MBWM',
#  'MCBC',
#  'MCHX',
#  'MCRI',
#  'MDCA',
#  'MDRX',
#  'MEIP',
#  'MEOH',
#  'MERC',
#  'MFIN',
#  'MGEE',
#  'MGI',
#  'MGIC',
#  'MGLN',
#  'MGPI',
#  'MGRC',
#  'MIDD',
#  'MIND',
#  'MKSI',
#  'MKTX',
#  'MLAB',
#  'MLHR',
#  'MMLP',
#  'MMSI',
#  'MNDO',
#  'MNKD',
#  'MNRO',
#  'MNTX',
#  'MORN',
#  'MOSY',
#  'MPAA',
#  'MPWR',
#  'MRCY',
#  'MRLN',
#  'MRTN',
#  'MRVL',
#  'MSEX',
#  'MSON',
#  'MSTR',
#  'MTEM',
#  'MTEX',
#  'MTRX',
#  'MTSC',
#  'MVIS',
#  'MYGN',
#  'MYL',
#  'NAII',
#  'NATH',
#  'NATI',
#  'NATR',
#  'NBIX',
#  'NBTB',
#  'NCTY',
#  'NDAQ',
#  'NDSN',
#  'NEOG',
#  'NEWT',
#  'NFLX',
#  'NICE',
#  'NICK',
#  'NKSH',
#  'NKTR',
#  'NOVT',
#  'NRIM',
#  'NSIT',
#  'NSSC',
#  'NTCT',
#  'NTES',
#  'NTGR',
#  'NTIC',
#  'NTUS',
#  'NTWK',
#  'NUAN',
#  'NUVA',
#  'NVAX',
#  'NVEC',
#  'NVMI',
#  'NWBI',
#  'NWE',
#  'NWLI',
#  'NWPX',
#  'NXGN',
#  'NXST',
#  'NYMT',
#  'NYMX',
#  'OBCI',
#  'OCFC',
#  'ODFL',
#  'OEG',
#  'OFIX',
#  'OFLX',
#  'OIIM',
#  'OLED',
#  'OMCL',
#  'OMEX',
#  'ON',
#  'ONB',
#  'ONCT',
#  'OPCH',
#  'OPK',
#  'ORLY',
#  'ORRF',
#  'OSBC',
#  'OSIS',
#  'OSPN',
#  'OSTK',
#  'OSUR',
#  'OTEX',
#  'OTTR',
#  'OXSQ',
#  'OZK',
#  'PAA',
#  'PAAS',
#  'PACW',
#  'PATK',
#  'PBCT',
#  'PCH',
#  'PCOM',
#  'PCTI',
#  'PCYG',
#  'PCYO',
#  'PDEX',
#  'PDFS',
#  'PDLI',
#  'PEBO',
#  'PEGA',
#  'PENN',
#  'PESI',
#  'PETS',
#  'PEY',
#  'PFBI',
#  'PFC',
#  'PFG',
#  'PFM',
#  'PFSW',
#  'PGC',
#  'PGJ',
#  'PHO',
#  'PICO',
#  'PID',
#  'PKBK',
#  'PKOH',
#  'PLAB',
#  'PLCE',
#  'PLPC',
#  'PLUS',
#  'PLXS',
#  'PMBC',
#  'PMD',
#  'PNFP',
#  'POOL',
#  'POWI',
#  'POWL',
#  'PPBI',
#  'PPC',
#  'PPIH',
#  'PRAA',
#  'PRCP',
#  'PRFT',
#  'PRGS',
#  'PRGX',
#  'PROV',
#  'PRPH',
#  'PRSC',
#  'PRTK',
#  'PSEC',
#  'PSMT',
#  'PSTI',
#  'PSTV',
#  'PTE',
#  'PTNR',
#  'PTSI',
#  'PTVCB',
#  'PUI',
#  'PWFL',
#  'PWOD',
#  'PXLW',
#  'PZZA',
#  'QCRH',
#  'QDEL',
#  'QRTEA',
#  'QUIK',
#  'QUMU',
#  'RADA',
#  'RAIL',
#  'RAVN',
#  'RBBN',
#  'RBCAA',
#  'RCII',
#  'RCKY',
#  'RCMT',
#  'RDCM',
#  'RDI',
#  'RDNT',
#  'RDWR',
#  'REFR',
#  'REG',
#  'REGN',
#  'RELL',
#  'RELV',
#  'RFIL',
#  'RGEN',
#  'RGLD',
#  'RGP',
#  'RICK',
#  'RIGL',
#  'RMBS',
#  'RMCF',
#  'RMRM',
#  'RMTI',
#  'RNST',
#  'ROCK',
#  'ROLL',
#  'RRGB',
#  'RTH',
#  'RUSHA',
#  'RUSHB',
#  'RUTH',
#  'RVSB',
#  'SAFM',
#  'SAFT',
#  'SAIA',
#  'SALM',
#  'SASR',
#  'SAVA',
#  'SBAC',
#  'SBCF',
#  'SBFG',
#  'SBGI',
#  'SBLK',
#  'SBNY',
#  'SBRA',
#  'SBSI',
#  'SCHL',
#  'SCHN',
#  'SCSC',
#  'SCVL',
#  'SEAC',
#  'SEED',
#  'SEEL',
#  'SEIC',
#  'SENEA',
#  'SFNC',
#  'SGA',
#  'SGC',
#  'SGEN',
#  'SGMA',
#  'SGMO',
#  'SGMS',
#  'SHBI',
#  'SHEN',
#  'SHOO',
#  'SHYF',
#  'SIFY',
#  'SIGI',
#  'SILC',
#  'SIMO',
#  'SINA',
#  'SIRI',
#  'SIVB',
#  'SKYW',
#  'SLAB',
#  'SLGN',
#  'SLP',
#  'SMED',
#  'SMMF',
#  'SMSI',
#  'SMTC',
#  'SMTX',
#  'SNBR',
#  'SNEX',
#  'SNFCA',
#  'SNY',
#  'SOHO',
#  'SOHU',
#  'SP',
#  'SPNS',
#  'SPOK',
#  'SPPI',
#  'SPRT',
#  'SPTN',
#  'SRCE',
#  'SRCL',
#  'SRDX',
#  'SRGA',
#  'SRPT',
#  'SSB',
#  'SSKN',
#  'SSP',
#  'SSRM',
#  'SSYS',
#  'STAA',
#  'STBA',
#  'STCN',
#  'STFC',
#  'STKL',
#  'STLD',
#  'STMP',
#  'STRA',
#  'STRL',
#  'STRM',
#  'STRR',
#  'STRT',
#  'STX',
#  'SUMR',
#  'SVBI',
#  'SVC',
#  'SVRA',
#  'SWBI',
#  'SWIR',
#  'SWKS',
#  'SYBT',
#  'SYKE',
#  'SYNA',
#  'SYNL',
#  'SYPR',
#  'TACT',
#  'TAYD',
#  'TBBK',
#  'TCBI',
#  'TCBK',
#  'TCF',
#  'TCFCP',
#  'TCOM',
#  'TCX',
#  'TECH',
#  'TELL',
#  'TENX',
#  'TESS',
#  'TGA',
#  'THFF',
#  'THMO',
#  'THRM',
#  'TILE',
#  'TLGT',
#  'TOWN',
#  'TRIB',
#  'TRMB',
#  'TRMK',
#  'TRST',
#  'TSBK',
#  'TSCO',
#  'TSEM',
#  'TTEC',
#  'TTEK',
#  'TTMI',
#  'TTWO',
#  'TURN',
#  'TVTY',
#  'TWIN',
#  'TXRH',
#  'TZOO',
#  'UAL',
#  'UBCP',
#  'UBFO',
#  'UBSI',
#  'UCTT',
#  'UEIC',
#  'UEPS',
#  'UFCS',
#  'UFPI',
#  'UFPT',
#  'UG',
#  'UHAL',
#  'ULBI',
#  'ULH',
#  'UMBF',
#  'UMPQ',
#  'UONEK',
#  'URBN',
#  'USAK',
#  'USAP',
#  'USAU',
#  'USEG',
#  'USLM',
#  'UTHR',
#  'UTMD',
#  'UTSI',
#  'UVSP',
#  'VALU',
#  'VCEL',
#  'VECO',
#  'VERU',
#  'VG',
#  'VIAC',
#  'VICR',
#  'VIRC',
#  'VIVO',
#  'VLGEA',
#  'VLY',
#  'VNDA',
#  'VOD',
#  'VOXX',
#  'VRNT',
#  'VRTX',
#  'VSAT',
#  'VSEC',
#  'WABC',
#  'WAFD',
#  'WASH',
#  'WDC',
#  'WDFC',
#  'WERN',
#  'WEYS',
#  'WILC',
#  'WINA',
#  'WIRE',
#  'WLFC',
#  'WLTW',
#  'WNEB',
#  'WPRT',
#  'WRLD',
#  'WSBC',
#  'WSBF',
#  'WSFS',
#  'WSTG',
#  'WTBA',
#  'WTFC',
#  'WVVI',
#  'WW',
#  'WWD',
#  'WWR',
#  'WYNN',
#  'XEL',
#  'XOMA',
#  'XPER',
#  'YORW',
#  'YVR',
#  'ZBRA',
#  'ZEUS',
#  'ZIOP',
#  'ZIXI',
#  'ZUMZ']

# %%
stocks_10_15_df = precise_stocks_selector_local(tickers_list=companies_10_15, random_sample=True, num_samp = 1, verbose=1)
# Out:
# ****** Starting browsing the '../../../raw_data/processed/' directory ******
# acls.csv missing
# adxs.csv missing
# aeis.csv missing
# aezs.csv missing
# agys.csv missing
# airt.csv missing
# alks.csv missing
# alot.csv missing
# alt.csv missing
# amot.csv missing
# anat.csv missing
# anss.csv missing
# apex.csv missing
# apyx.csv missing
# asrt.csv missing
# asys.csv missing
# atax.csv missing
# atrs.csv missing
# avt.csv missing
# axas.csv missing
# axdx.csv missing
# bcrx.csv missing
# bidu.csv missing
# brks.csv missing
# bset.csv missing
# caas.csv missing
# camt.csv missing
# cass.csv missing
# cbat.csv missing
# cdns.csv missing
# cent.csv missing
# cenx.csv missing
# cers.csv missing
# cgnx.csv missing
# clbs.csv missing
# clct.csv missing
# cldx.csv missing
# clmt.csv missing
# clwt.csv missing
# cmct.csv missing
# cohu.csv missing
# cort.csv missing
# cprt.csv missing
# cpss.csv missing
# cpst.csv missing
# cris.csv missing
# crmt.csv missing
# crnt.csv missing
# crox.csv missing
# crus.csv missing
# crws.csv missing
# csgs.csv missing
# cwst.csv missing
# dakt.csv missing
# dox.csv missing
# drrx.csv missing
# dsgx.csv missing
# dvax.csv missing
# dynt.csv missing
# ebix.csv missing
# eeft.csv missing
# eqix.csv missing
# eslt.csv missing
# exas.csv missing
# eypt.csv missing
# fcfs.csv missing
# flws.csv missing
# flxs.csv missing
# fult.csv missing
# gass.csv missing
# geos.csv missing
# gilt.csv missing
# gnss.csv missing
# hckt.csv missing
# hees.csv missing
# himx.csv missing
# hlit.csv missing
# hoft.csv missing
# holx.csv missing
# hst.csv missing
# iart.csv missing
# idxx.csv missing
# ions.csv missing
# irbt.csv missing
# irix.csv missing
# isns.csv missing
# jbht.csv missing
# jblu.csv missing
# jbss.csv missing
# jcs.csv missing
# jobs.csv missing
# jout.csv missing
# kalu.csv missing
# ktos.csv missing
# laws.csv missing
# lcut.csv missing
# lfus.csv missing
# lmnx.csv missing
# lnt.csv missing
# lqdt.csv missing
# ltrx.csv missing
# lxrx.csv missing
# lyts.csv missing
# mags.csv missing
# mant.csv missing
# marps.csv missing
# mchx.csv missing
# mdrx.csv missing
# mktx.csv missing
# mntx.csv missing
# msex.csv missing
# mtex.csv missing
# mtrx.csv missing
# mvis.csv missing
# nbix.csv missing
# newt.csv missing
# nflx.csv missing
# novt.csv missing
# nsit.csv missing
# ntct.csv missing
# ntes.csv missing
# ntus.csv missing
# nvax.csv missing
# nwpx.csv missing
# nxst.csv missing
# nymt.csv missing
# nymx.csv missing
# ofix.csv missing
# oflx.csv missing
# omex.csv missing
# onct.csv missing
# osis.csv missing
# otex.csv missing
# paas.csv missing
# pbct.csv missing
# pdex.csv missing
# pdfs.csv missing
# pets.csv missing
# plus.csv missing
# plxs.csv missing
# prft.csv missing
# prgs.csv missing
# prgx.csv missing
# psmt.csv missing
# qumu.csv missing
# rcmt.csv missing
# rdnt.csv missing
# rmbs.csv missing
# rnst.csv missing
# saft.csv missing
# sgms.csv missing
# smtx.csv missing
# snex.csv missing
# sohu.csv missing
# spns.csv missing
# sprt.csv missing
# srdx.csv missing
# srpt.csv missing
# ssys.csv missing
# strt.csv missing
# stx.csv missing
# swks.csv missing
# sybt.csv missing
# tact.csv missing
# tcx.csv missing
# tenx.csv missing
# tess.csv missing
# tlgt.csv missing
# trst.csv missing
# uctt.csv missing
# ueps.csv missing
# ufcs.csv missing
# ufpt.csv missing
# usau.csv missing
# valu.csv missing
# veru.csv missing
# voxx.csv missing
# vrnt.csv missing
# vrtx.csv missing
# vsat.csv missing
# weys.csv missing
# wprt.csv missing
# wsfs.csv missing
# zeus.csv missing
#
#    *** Complete sampling ***
#
#
# ****** Starting stocks DataFrame creation the sample ******
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 184
#
# ['acls.csv', 'adxs.csv', 'aeis.csv', 'aezs.csv', 'agys.csv', 'airt.csv', 'alks.csv', 'alot.csv', 'alt.csv', 'amot.csv', 'anat.csv', 'anss.csv', 'apex.csv', 'apyx.csv', 'asrt.csv', 'asys.csv', 'atax.csv', 'atrs.csv', 'avt.csv', 'axas.csv', 'axdx.csv', 'bcrx.csv', 'bidu.csv', 'brks.csv', 'bset.csv', 'caas.csv', 'camt.csv', 'cass.csv', 'cbat.csv', 'cdns.csv', 'cent.csv', 'cenx.csv', 'cers.csv', 'cgnx.csv', 'clbs.csv', 'clct.csv', 'cldx.csv', 'clmt.csv', 'clwt.csv', 'cmct.csv', 'cohu.csv', 'cort.csv', 'cprt.csv', 'cpss.csv', 'cpst.csv', 'cris.csv', 'crmt.csv', 'crnt.csv', 'crox.csv', 'crus.csv', 'crws.csv', 'csgs.csv', 'cwst.csv', 'dakt.csv', 'dox.csv', 'drrx.csv', 'dsgx.csv', 'dvax.csv', 'dynt.csv', 'ebix.csv', 'eeft.csv', 'eqix.csv', 'eslt.csv', 'exas.csv', 'eypt.csv', 'fcfs.csv', 'flws.csv', 'flxs.csv', 'fult.csv', 'gass.csv', 'geos.csv', 'gilt.csv', 'gnss.csv', 'hckt.csv', 'hees.csv', 'himx.csv', 'hlit.csv', 'hoft.csv', 'holx.csv', 'hst.csv', 'iart.csv', 'idxx.csv', 'ions.csv', 'irbt.csv', 'irix.csv', 'isns.csv', 'jbht.csv', 'jblu.csv', 'jbss.csv', 'jcs.csv', 'jobs.csv', 'jout.csv', 'kalu.csv', 'ktos.csv', 'laws.csv', 'lcut.csv', 'lfus.csv', 'lmnx.csv', 'lnt.csv', 'lqdt.csv', 'ltrx.csv', 'lxrx.csv', 'lyts.csv', 'mags.csv', 'mant.csv', 'marps.csv', 'mchx.csv', 'mdrx.csv', 'mktx.csv', 'mntx.csv', 'msex.csv', 'mtex.csv', 'mtrx.csv', 'mvis.csv', 'nbix.csv', 'newt.csv', 'nflx.csv', 'novt.csv', 'nsit.csv', 'ntct.csv', 'ntes.csv', 'ntus.csv', 'nvax.csv', 'nwpx.csv', 'nxst.csv', 'nymt.csv', 'nymx.csv', 'ofix.csv', 'oflx.csv', 'omex.csv', 'onct.csv', 'osis.csv', 'otex.csv', 'paas.csv', 'pbct.csv', 'pdex.csv', 'pdfs.csv', 'pets.csv', 'plus.csv', 'plxs.csv', 'prft.csv', 'prgs.csv', 'prgx.csv', 'psmt.csv', 'qumu.csv', 'rcmt.csv', 'rdnt.csv', 'rmbs.csv', 'rnst.csv', 'saft.csv', 'sgms.csv', 'smtx.csv', 'snex.csv', 'sohu.csv', 'spns.csv', 'sprt.csv', 'srdx.csv', 'srpt.csv', 'ssys.csv', 'strt.csv', 'stx.csv', 'swks.csv', 'sybt.csv', 'tact.csv', 'tcx.csv', 'tenx.csv', 'tess.csv', 'tlgt.csv', 'trst.csv', 'uctt.csv', 'ueps.csv', 'ufcs.csv', 'ufpt.csv', 'usau.csv', 'valu.csv', 'veru.csv', 'voxx.csv', 'vrnt.csv', 'vrtx.csv', 'vsat.csv', 'weys.csv', 'wprt.csv', 'wsfs.csv', 'zeus.csv']

# %% [markdown]
# ### Companies (randomly) selected

# %%
stocks_10_15_df.ticker.unique()
# Out:
# array(['TTEC'], dtype=object)

# %% [markdown]
# ### Setting date to `datetime` type

# %%
stocks_10_15_df['date'] = pd.to_datetime(stocks_10_15_df['date'])

# %% [markdown]
# ### Encoding the Returns

# %%
clean_stocks_10_15_df = thresholds_encoding(stocks_10_15_df)

# %% [markdown]
# ### Getting `X_train`, `y_train`, `X_test`, `y_test`

# %%
train, test = train_test_split(clean_stocks_10_15_df)

# %%
train.shape
# Out:
# (3201, 17)

# %%
test.shape
# Out:
# (751, 17)

# %% [markdown]
# ### Scaling train and transforming test

# %%
train, test = std_scaler(train, test)
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:31: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
X_train, y_train = build_input_arrays(train)
X_test, y_test = build_input_arrays(test)

# %%
X_train.shape
# Out:
# (1066, 5, 12)

# %%
X_test.shape
# Out:
# (249, 5, 12)

# %% [markdown]
# ## Model Initialisation

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers, models 
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import Precision

precision = Precision()


optim = RMSprop(learning_rate=0.0001)

def init_model(X_train):
    model = Sequential()
    reg_l1 = regularizers.l1(0.001)
    reg_l2 = regularizers.l2(0.001)
    reg_l1_l2 = regularizers.l1_l2(l1=0.001, l2=0.0001)
    
    model.add(layers.LSTM(200, return_sequences=True, input_shape=X_train.shape[1:], activation='tanh'))
    model.add(layers.LSTM(200, activation='tanh'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(200, activation='relu', kernel_regularizer=reg_l1))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(100, activation='relu', bias_regularizer=reg_l2))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(50, activation='relu', activity_regularizer=reg_l1_l2))
    #model.add(layers.Dropout(0.3))
    #model.add(layers.Dense(25, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=[precision, 'accuracy'])
    
    return model

# %%
model = init_model(X_train)

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=5, restore_best_weights=True)

model.fit(X_train, y_train, 
          epochs=500, 
          batch_size=32,
          validation_split=0.2,
          callbacks=[es]
         )
# Out:
# Epoch 1/500
# 27/27 [==============================] - 2s 74ms/step - loss: 3.0656 - precision: 0.5231 - accuracy: 0.4859 - val_loss: 3.0068 - val_precision: 0.5094 - val_accuracy: 0.4112
# Epoch 2/500
# 27/27 [==============================] - 1s 25ms/step - loss: 2.9561 - precision: 0.5512 - accuracy: 0.5035 - val_loss: 2.9049 - val_precision: 0.5472 - val_accuracy: 0.4533
# Epoch 3/500
# 27/27 [==============================] - 1s 30ms/step - loss: 2.8565 - precision: 0.5271 - accuracy: 0.5047 - val_loss: 2.8055 - val_precision: 0.6013 - val_accuracy: 0.5561
# Epoch 4/500
# 27/27 [==============================] - 1s 36ms/step - loss: 2.7601 - precision: 0.5339 - accuracy: 0.5246 - val_loss: 2.7078 - val_precision: 0.5934 - val_accuracy: 0.5654
# Epoch 5/500
# 27/27 [==============================] - 1s 29ms/step - loss: 2.6652 - precision: 0.5450 - accuracy: 0.5446 - val_loss: 2.6140 - val_precision: 0.6011 - val_accuracy: 0.5794
# Epoch 6/500
# 27/27 [==============================] - 1s 38ms/step - loss: 2.5723 - precision: 0.5444 - accuracy: 0.5481 - val_loss: 2.5212 - val_precision: 0.6103 - val_accuracy: 0.6075
# Epoch 7/500
# 27/27 [==============================] - 1s 30ms/step - loss: 2.4818 - precision: 0.5398 - accuracy: 0.5434 - val_loss: 2.4320 - val_precision: 0.6032 - val_accuracy: 0.5888
# Epoch 8/500
# 27/27 [==============================] - 1s 33ms/step - loss: 2.3933 - precision: 0.5483 - accuracy: 0.5552 - val_loss: 2.3440 - val_precision: 0.6062 - val_accuracy: 0.5981
# Epoch 9/500
# 27/27 [==============================] - 1s 24ms/step - loss: 2.3079 - precision: 0.5356 - accuracy: 0.5411 - val_loss: 2.2597 - val_precision: 0.6042 - val_accuracy: 0.5935
# Epoch 10/500
# 27/27 [==============================] - 1s 35ms/step - loss: 2.2242 - precision: 0.5472 - accuracy: 0.5540 - val_loss: 2.1772 - val_precision: 0.6073 - val_accuracy: 0.5981
# Epoch 11/500
# 27/27 [==============================] - 1s 29ms/step - loss: 2.1431 - precision: 0.5593 - accuracy: 0.5728 - val_loss: 2.0969 - val_precision: 0.6096 - val_accuracy: 0.5981
# Epoch 12/500
# 27/27 [==============================] - 1s 29ms/step - loss: 2.0644 - precision: 0.5567 - accuracy: 0.5692 - val_loss: 2.0196 - val_precision: 0.6175 - val_accuracy: 0.6075
# Epoch 13/500
# 27/27 [==============================] - 1s 27ms/step - loss: 1.9890 - precision: 0.5502 - accuracy: 0.5575 - val_loss: 1.9459 - val_precision: 0.6133 - val_accuracy: 0.5981
# Epoch 14/500
# 27/27 [==============================] - 1s 36ms/step - loss: 1.9161 - precision: 0.5584 - accuracy: 0.5704 - val_loss: 1.8741 - val_precision: 0.6133 - val_accuracy: 0.5981
# Epoch 15/500
# 27/27 [==============================] - 1s 40ms/step - loss: 1.8447 - precision: 0.5668 - accuracy: 0.5810 - val_loss: 1.8046 - val_precision: 0.6167 - val_accuracy: 0.6028
# Epoch 16/500
# 27/27 [==============================] - 1s 31ms/step - loss: 1.7769 - precision: 0.5624 - accuracy: 0.5716 - val_loss: 1.7379 - val_precision: 0.6167 - val_accuracy: 0.6028
# Epoch 17/500
# 27/27 [==============================] - 1s 32ms/step - loss: 1.7098 - precision: 0.5670 - accuracy: 0.5810 - val_loss: 1.6735 - val_precision: 0.6167 - val_accuracy: 0.6028
# Epoch 18/500
# 27/27 [==============================] - 1s 33ms/step - loss: 1.6470 - precision: 0.5620 - accuracy: 0.5716 - val_loss: 1.6126 - val_precision: 0.6145 - val_accuracy: 0.5981
# Epoch 19/500
# 27/27 [==============================] - 1s 26ms/step - loss: 1.5873 - precision: 0.5619 - accuracy: 0.5704 - val_loss: 1.5537 - val_precision: 0.6158 - val_accuracy: 0.5981
# Epoch 20/500
# 27/27 [==============================] - 1s 24ms/step - loss: 1.5277 - precision: 0.5673 - accuracy: 0.5775 - val_loss: 1.4967 - val_precision: 0.6158 - val_accuracy: 0.5981
# Epoch 21/500
# 27/27 [==============================] - 1s 24ms/step - loss: 1.4707 - precision: 0.5672 - accuracy: 0.5751 - val_loss: 1.4450 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 22/500
# 27/27 [==============================] - 1s 36ms/step - loss: 1.4193 - precision: 0.5719 - accuracy: 0.5822 - val_loss: 1.3937 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 23/500
# 27/27 [==============================] - 1s 33ms/step - loss: 1.3699 - precision: 0.5636 - accuracy: 0.5716 - val_loss: 1.3450 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 24/500
# 27/27 [==============================] - 1s 32ms/step - loss: 1.3217 - precision: 0.5767 - accuracy: 0.5904 - val_loss: 1.2987 - val_precision: 0.6279 - val_accuracy: 0.6121
# Epoch 25/500
# 27/27 [==============================] - 1s 24ms/step - loss: 1.2734 - precision: 0.5674 - accuracy: 0.5751 - val_loss: 1.2535 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 26/500
# 27/27 [==============================] - 1s 32ms/step - loss: 1.2316 - precision: 0.5658 - accuracy: 0.5775 - val_loss: 1.2124 - val_precision: 0.6207 - val_accuracy: 0.6028
# Epoch 27/500
# 27/27 [==============================] - 1s 26ms/step - loss: 1.1896 - precision: 0.5762 - accuracy: 0.5869 - val_loss: 1.1720 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 28/500
# 27/27 [==============================] - 1s 23ms/step - loss: 1.1511 - precision: 0.5731 - accuracy: 0.5822 - val_loss: 1.1319 - val_precision: 0.6215 - val_accuracy: 0.6075
# Epoch 29/500
# 27/27 [==============================] - 1s 23ms/step - loss: 1.1136 - precision: 0.5597 - accuracy: 0.5692 - val_loss: 1.1001 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 30/500
# 27/27 [==============================] - 1s 28ms/step - loss: 1.0801 - precision: 0.5705 - accuracy: 0.5833 - val_loss: 1.0689 - val_precision: 0.6310 - val_accuracy: 0.6121
# Epoch 31/500
# 27/27 [==============================] - 1s 28ms/step - loss: 1.0476 - precision: 0.5651 - accuracy: 0.5728 - val_loss: 1.0358 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 32/500
# 27/27 [==============================] - 1s 30ms/step - loss: 1.0150 - precision: 0.5670 - accuracy: 0.5798 - val_loss: 1.0110 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 33/500
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9862 - precision: 0.5661 - accuracy: 0.5751 - val_loss: 0.9802 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 34/500
# 27/27 [==============================] - 1s 33ms/step - loss: 0.9601 - precision: 0.5596 - accuracy: 0.5669 - val_loss: 0.9555 - val_precision: 0.6163 - val_accuracy: 0.5935
# Epoch 35/500
# 27/27 [==============================] - 1s 31ms/step - loss: 0.9378 - precision: 0.5600 - accuracy: 0.5704 - val_loss: 0.9317 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 36/500
# 27/27 [==============================] - 1s 38ms/step - loss: 0.9127 - precision: 0.5596 - accuracy: 0.5704 - val_loss: 0.9076 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 37/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8877 - precision: 0.5611 - accuracy: 0.5704 - val_loss: 0.8865 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 38/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8650 - precision: 0.5701 - accuracy: 0.5845 - val_loss: 0.8694 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 39/500
# 27/27 [==============================] - 1s 37ms/step - loss: 0.8500 - precision: 0.5714 - accuracy: 0.5833 - val_loss: 0.8519 - val_precision: 0.6207 - val_accuracy: 0.6028
# Epoch 40/500
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8307 - precision: 0.5671 - accuracy: 0.5786 - val_loss: 0.8335 - val_precision: 0.6171 - val_accuracy: 0.5981
# Epoch 41/500
# 27/27 [==============================] - 1s 33ms/step - loss: 0.8120 - precision: 0.5686 - accuracy: 0.5833 - val_loss: 0.8204 - val_precision: 0.6185 - val_accuracy: 0.5981
# Epoch 42/500
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7994 - precision: 0.5719 - accuracy: 0.5880 - val_loss: 0.8121 - val_precision: 0.6140 - val_accuracy: 0.5888
# Epoch 43/500
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7901 - precision: 0.5710 - accuracy: 0.5798 - val_loss: 0.7938 - val_precision: 0.6136 - val_accuracy: 0.5935
# Epoch 44/500
# 27/27 [==============================] - 1s 29ms/step - loss: 0.7790 - precision: 0.5660 - accuracy: 0.5810 - val_loss: 0.7835 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 45/500
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7665 - precision: 0.5659 - accuracy: 0.5786 - val_loss: 0.7755 - val_precision: 0.6114 - val_accuracy: 0.5888
# Epoch 46/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7570 - precision: 0.5765 - accuracy: 0.5951 - val_loss: 0.7700 - val_precision: 0.6163 - val_accuracy: 0.5935
# Epoch 47/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7520 - precision: 0.5683 - accuracy: 0.5822 - val_loss: 0.7596 - val_precision: 0.6136 - val_accuracy: 0.5935
# Epoch 48/500
# 27/27 [==============================] - 1s 24ms/step - loss: 0.7444 - precision: 0.5681 - accuracy: 0.5810 - val_loss: 0.7543 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 49/500
# 27/27 [==============================] - 1s 24ms/step - loss: 0.7380 - precision: 0.5624 - accuracy: 0.5763 - val_loss: 0.7574 - val_precision: 0.6190 - val_accuracy: 0.5935
# Epoch 50/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.7316 - precision: 0.5775 - accuracy: 0.5904 - val_loss: 0.7509 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 51/500
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7295 - precision: 0.5694 - accuracy: 0.5845 - val_loss: 0.7479 - val_precision: 0.6149 - val_accuracy: 0.5935
# Epoch 52/500
# 27/27 [==============================] - 1s 28ms/step - loss: 0.7275 - precision: 0.5750 - accuracy: 0.5927 - val_loss: 0.7436 - val_precision: 0.6176 - val_accuracy: 0.5935
# Epoch 53/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7182 - precision: 0.5730 - accuracy: 0.5880 - val_loss: 0.7394 - val_precision: 0.6140 - val_accuracy: 0.5888
# Epoch 54/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.7195 - precision: 0.5758 - accuracy: 0.5904 - val_loss: 0.7393 - val_precision: 0.6176 - val_accuracy: 0.5935
# Epoch 55/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7159 - precision: 0.5732 - accuracy: 0.5869 - val_loss: 0.7403 - val_precision: 0.6182 - val_accuracy: 0.5888
# Epoch 56/500
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7134 - precision: 0.5680 - accuracy: 0.5786 - val_loss: 0.7331 - val_precision: 0.6176 - val_accuracy: 0.5935
# Epoch 57/500
# 27/27 [==============================] - 1s 22ms/step - loss: 0.7144 - precision: 0.5737 - accuracy: 0.5892 - val_loss: 0.7359 - val_precision: 0.6182 - val_accuracy: 0.5888
# Epoch 58/500
# 27/27 [==============================] - 1s 38ms/step - loss: 0.7103 - precision: 0.5759 - accuracy: 0.5880 - val_loss: 0.7330 - val_precision: 0.6053 - val_accuracy: 0.5561
# Epoch 59/500
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7102 - precision: 0.5726 - accuracy: 0.5857 - val_loss: 0.7300 - val_precision: 0.6090 - val_accuracy: 0.5654
# Epoch 60/500
# 27/27 [==============================] - 1s 38ms/step - loss: 0.7061 - precision: 0.5818 - accuracy: 0.5974 - val_loss: 0.7315 - val_precision: 0.6169 - val_accuracy: 0.5748
# Epoch 61/500
# 27/27 [==============================] - 1s 37ms/step - loss: 0.7047 - precision: 0.5782 - accuracy: 0.5915 - val_loss: 0.7310 - val_precision: 0.6051 - val_accuracy: 0.5607
# Epoch 62/500
# 27/27 [==============================] - 1s 37ms/step - loss: 0.7031 - precision: 0.5802 - accuracy: 0.5927 - val_loss: 0.7291 - val_precision: 0.6054 - val_accuracy: 0.5514
# Epoch 63/500
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7058 - precision: 0.5765 - accuracy: 0.5904 - val_loss: 0.7293 - val_precision: 0.6000 - val_accuracy: 0.5421
# Epoch 64/500
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7028 - precision: 0.5821 - accuracy: 0.5951 - val_loss: 0.7285 - val_precision: 0.6093 - val_accuracy: 0.5607
# Epoch 65/500
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7010 - precision: 0.5749 - accuracy: 0.5880 - val_loss: 0.7281 - val_precision: 0.6093 - val_accuracy: 0.5607
# Epoch 66/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.7032 - precision: 0.5693 - accuracy: 0.5786 - val_loss: 0.7263 - val_precision: 0.6104 - val_accuracy: 0.5654
# Epoch 67/500
# 27/27 [==============================] - 1s 26ms/step - loss: 0.6993 - precision: 0.5707 - accuracy: 0.5786 - val_loss: 0.7231 - val_precision: 0.6000 - val_accuracy: 0.5467
# Epoch 68/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.6991 - precision: 0.5705 - accuracy: 0.5822 - val_loss: 0.7217 - val_precision: 0.5915 - val_accuracy: 0.5280
# Epoch 69/500
# 27/27 [==============================] - 1s 28ms/step - loss: 0.6985 - precision: 0.5850 - accuracy: 0.5962 - val_loss: 0.7208 - val_precision: 0.6014 - val_accuracy: 0.5467
# Epoch 70/500
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6941 - precision: 0.5875 - accuracy: 0.6009 - val_loss: 0.7232 - val_precision: 0.6000 - val_accuracy: 0.5467
# Epoch 71/500
# 27/27 [==============================] - 1s 24ms/step - loss: 0.6978 - precision: 0.5719 - accuracy: 0.5822 - val_loss: 0.7290 - val_precision: 0.6071 - val_accuracy: 0.5467
# Epoch 72/500
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6963 - precision: 0.5860 - accuracy: 0.5974 - val_loss: 0.7293 - val_precision: 0.6000 - val_accuracy: 0.5327
# Epoch 73/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.6948 - precision: 0.5807 - accuracy: 0.5927 - val_loss: 0.7327 - val_precision: 0.6031 - val_accuracy: 0.5327
# Epoch 74/500
# 27/27 [==============================] - 1s 25ms/step - loss: 0.6936 - precision: 0.5775 - accuracy: 0.5857 - val_loss: 0.7270 - val_precision: 0.6000 - val_accuracy: 0.5280

# %% [markdown]
# ### Model Evalutation

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (249, 1)

# %%
y_test.sum()/len(y_test)
# Out:
# 0.5381526104417671

# %%
model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7361 - precision: 0.5382 - accuracy: 0.5382
# [0.7361053228378296, 0.5381526350975037, 0.5381526350975037]

# %% [markdown]
# ### Model Score Saving

# %%
model_runs_history = runs_history_loading()
# Out:
# No previous models scores found
# Returning uncomplete list: [('tickers', ['loss', 'precision', 'accuracy'])]

# %%
model_runs_history
# Out:
# [('tickers', ['loss', 'precision', 'accuracy'])]

# %%
model_runs_history.append((list(stocks_10_15_df.ticker.unique()),model.evaluate(X_test, y_test)))
# Out:
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7361 - precision: 0.5382 - accuracy: 0.5382

# %%
runs_history_saving(model_runs_history)
# Out:
# History Saving Complete!
# File saved as: charles_companies_10-15_model_history
# File location:../models_histories
