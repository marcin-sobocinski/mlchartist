# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import joblib
import os
import random

# %% [markdown]
# ====================================================================================================
#
# **Goal : gather similar companies according to their features and number of trading days**
#
# **Use : provide coherent and meaningful data to model**
#
#
# **(_Ideal_ : develop tailored model to each type of groups)**
#
#
#
# **_See Notebook `Table of content` for good understanding about what this notebook is doing when ran_**
#
# ====================================================================================================

# %% [markdown]
# # Anaysis of Companies Age from `nasdaq_us_stats.xls`

# %%
#!!!Path might not be the same!!!

meta_df = pd.read_csv('../../raw_data/metadata/nasdaq_us_stats.xls')

# %%
meta_df.head()
# Out:
#    Unnamed: 0     stock  days  min_close  max_close  start_date    end_date
# 0           0   AACG.US  3165    0.21703      3.850  2008-01-28  2021-01-25
# 1           1   AACQ.US    96    9.62000     11.070  2020-09-08  2021-01-25
# 2           2  AACQU.US   134   10.00000     11.900  2020-07-15  2021-01-25
# 3           3  AACQW.US    95    1.07500      2.580  2020-09-09  2021-01-25
# 4           4    AAL.US  1793    9.04000     56.989  2013-12-10  2021-01-25

# %%
meta_df.describe()
# Out:
#         Unnamed: 0          days    min_close     max_close
# count  3921.000000   3921.000000  3921.000000  3.921000e+03
# mean   1960.000000   1876.186942     8.257047  6.181576e+06
# std    1132.039531   1795.084440    16.268917  3.863434e+08
# min       0.000000      1.000000     0.001000  2.400000e-01
# 25%     980.000000    312.000000     1.490000  1.438700e+01
# 50%    1960.000000   1286.000000     5.010000  2.880000e+01
# 75%    2940.000000   3775.000000    10.384000  6.533000e+01
# max    3920.000000  12879.000000   647.290000  2.419200e+10

# %%
meta_df = meta_df[['stock', 'days', 'min_close', 'max_close']]

# %% [markdown]
# ## Company age classification

# %%
meta_df['range_price'] = meta_df['max_close'] - meta_df['min_close']
meta_df['years'] = meta_df['days']/365

# %%
clean_meta_df = meta_df[['stock', 'years', 'range_price']]

# %%
sns.histplot(clean_meta_df['years'], binwidth=1)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %% [markdown]
# 👆👆**Anomaly at less than 1 year and 10 year old companies**👆👆

# %%
bins = [0, 1, 5, 10, 15, 20, 25, 30, 40]

clean_meta_df['company_vintage'] = pd.cut(meta_df['years'].copy(), 
                                          bins)                            # A company aged of 1Y and one day is
                                          #labels=['(0, 1]','(1, 5]',       # part of the '(1, 5]' class
                                          #        '(5, 10]', '(10, 15]',
                                          #        '(15, 20]', '(20, 25]',
                                          #        '(25, 30]', '(30, 40]'])
print(clean_meta_df['company_vintage'])
# Out:
# 0        (5, 10]
# 1         (0, 1]
# 2         (0, 1]
# 3         (0, 1]
# 4         (1, 5]
# 5        (5, 10]
# 6        (5, 10]
# 7       (10, 15]
# 8       (25, 30]
# 9       (10, 15]
# 10      (10, 15]
# 11      (10, 15]
# 12        (0, 1]
# 13        (0, 1]
# 14        (1, 5]
# 15      (10, 15]
# 16      (10, 15]
# 17        (0, 1]
# 18        (0, 1]
# 19        (1, 5]
# 20       (5, 10]
# 21        (0, 1]
# 22        (0, 1]
# 23        (0, 1]
# 24      (10, 15]
# 25        (0, 1]
# 26        (0, 1]
# 27        (0, 1]
# 28        (1, 5]
# 29        (0, 1]
#           ...
# 3891     (5, 10]
# 3892     (5, 10]
# 3893      (0, 1]
# 3894      (0, 1]
# 3895      (0, 1]
# 3896      (0, 1]
# 3897      (0, 1]
# 3898      (1, 5]
# 3899    (20, 25]
# 3900      (1, 5]
# 3901      (0, 1]
# 3902      (0, 1]
# 3903      (0, 1]
# 3904    (10, 15]
# 3905    (10, 15]
# 3906      (1, 5]
# 3907      (1, 5]
# 3908      (1, 5]
# 3909     (5, 10]
# 3910      (0, 1]
# 3911      (0, 1]
# 3912      (0, 1]
# 3913      (0, 1]
# 3914      (1, 5]
# 3915      (1, 5]
# 3916    (10, 15]
# 3917     (5, 10]
# 3918      (1, 5]
# 3919      (1, 5]
# 3920      (1, 5]
# Name: company_vintage, Length: 3921, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 5] < (5, 10] < (10, 15] < (15, 20] < (20, 25] < (25, 30] < (30, 40]]
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
clean_meta_df['company_vintage'].apply(str)
print(clean_meta_df.info())
clean_meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
# stock              3921 non-null object
# years              3921 non-null float64
# range_price        3921 non-null float64
# company_vintage    3921 non-null category
# dtypes: category(1), float64(2), object(1)
# memory usage: 95.9+ KB
# None
#       stock     years  range_price company_vintage
# 0   AACG.US  8.671233      3.63297         (5, 10]
# 1   AACQ.US  0.263014      1.45000          (0, 1]
# 2  AACQU.US  0.367123      1.90000          (0, 1]
# 3  AACQW.US  0.260274      1.50500          (0, 1]
# 4    AAL.US  4.912329     47.94900          (1, 5]

# %% [markdown]
# ## Classification Results

# %%
sns.histplot(data=clean_meta_df, x='years', binwidth=1, hue='company_vintage')
#plt.savefig('companies_age_classification.pdf', dpi=1200)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %%
clean_meta_df.groupby('company_vintage')['stock'].count()
# Out:
# company_vintage
# (0, 1]      1069
# (1, 5]      1252
# (5, 10]      564
# (10, 15]     950
# (15, 20]      32
# (20, 25]      37
# (25, 30]      13
# (30, 40]       4
# Name: stock, dtype: int64

# %% [markdown]
# ### Saving List of Companies Name via `joblib`

# %%
stocks_bin_1 = []
stocks_bin_2 = []
stocks_bin_3 = []
stocks_bin_4 = []
stocks_bin_5 = []
stocks_bin_6 = []
stocks_bin_7 = []
stocks_bin_8 = []

for idx, row in clean_meta_df.iterrows():
    x = row['years']                                            # <=> ['days']/365
    st = row['stock'].replace('.US', '')
    
    #print(idx, x, row['stock'])
    if x <= 1 : stocks_bin_1.append(st)
    elif x > 1 and x <= 5: stocks_bin_2.append(st)
    elif x > 5 and x <= 10: stocks_bin_3.append(st)
    elif x > 10 and x <= 15: stocks_bin_4.append(st)        
    elif x > 15 and x <= 20: stocks_bin_5.append(st)        
    elif x > 20 and x <= 25: stocks_bin_6.append(st)        
    elif x > 25 and x <= 30: stocks_bin_7.append(st)        
    elif x > 30: stocks_bin_8.append(st)
    
print(f"Number of companies with less than a year of history: {len(stocks_bin_1)}")
print(f"Number of companies with between a year and 5 years of history: {len(stocks_bin_2)}")    
print(f"Number of companies with between 5 years and 10 years of history: {len(stocks_bin_3)}")
print(f"Number of companies with between 10 years and 15 years of history: {len(stocks_bin_4)}")
print(f"Number of companies with between 15 years and 20 years of history: {len(stocks_bin_5)}")
print(f"Number of companies with between 20 years and 25 years of history: {len(stocks_bin_6)}")
print(f"Number of companies with between 25 years and 30 years of history: {len(stocks_bin_7)}")
print(f"Number of companies with more than 30 years of history: {len(stocks_bin_8)}")

stock_bins = [stocks_bin_1, stocks_bin_2, stocks_bin_3,
              stocks_bin_4, stocks_bin_5, stocks_bin_6,
              stocks_bin_7, stocks_bin_8]
# Out:
# Number of companies with less than a year of history: 1069
# Number of companies with between a year and 5 years of history: 1252
# Number of companies with between 5 years and 10 years of history: 564
# Number of companies with between 10 years and 15 years of history: 950
# Number of companies with between 15 years and 20 years of history: 32
# Number of companies with between 20 years and 25 years of history: 37
# Number of companies with between 25 years and 30 years of history: 13
# Number of companies with more than 30 years of history: 4

# %%
stock_bins
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# ❗❗❗**You should check the path you want to save the `stock_bins` list**❗❗❗
#
# (The `metadata` directory is where I saved the `nasdaq_us_stats.xls` csv file of Ian)

# %%
joblib.dump(stock_bins, '../../raw_data/metadata/tickers_per_history_lenght__list')
# Out:
# ['../../raw_data/metadata/tickers_per_history_lenght__list']

# %%
stocks_tickers = joblib.load('../../raw_data/metadata/tickers_per_history_lenght__list')
stocks_tickers
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# # Modeling Companies per Vintage - (0, 1] - The youngest ones

# %% [markdown]
# ## Functions definitions & Imports

# %% [markdown]
# ### `precise_stocks_selector_local()`

# %%
from termcolor import colored

def precise_stocks_selector_local(tickers_list=[], path_files='../../raw_data/processed/',
                                  random_sample=False, num_samp = 2, verbose=1):
    """
    Returns a concatened DataFrame of the stocks data which tickers' list were passed
    
    If random_sample = True, return a DataFrame with random sample of stocks from the tickers' list passed
    
    Example:
    INPUT: ['AEP', 'GT', 'INTC', 'PEP']
    OUTPUT: df.tickers.unique() ==> ['GT', 'INTC']
   
    """
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        
    t = []
    for ticker in tickers_list:
        ticker = f"{ticker}.csv".lower()
        t.append(ticker)
    tickers_list = t
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        print()
        print()
    
    if verbose >= 1:
        print(colored(f"****** Starting browsing the '{path_files}' directory ******", 'magenta'))
        
    filenames = []
    missing_stock_csv = []

    
    if random_sample:
        for file in os.listdir(path_files):
            if file.endswith('.csv'):
                if file in tickers_list:
                    filenames.append(file)
        
        for ticker in tickers_list:
            #print(ticker)
            #print(missing_stock_csv)
            if ticker not in filenames:
                missing_stock_csv.append(ticker)
                print(colored(f"{ticker} missing", 'red'))
            else:
                pass
        
        #print(missing_stock_csv)
        
        for missed in missing_stock_csv:
            if missed not in tickers_list:
                missing_stock_csv.remove(missed)
        #print(missing_stock_csv)
        
        if len(filenames) < num_samp:
            print(colored('\nSample size bigger that nuber of companies available\n','red'))
        else:
            sample = random.sample(filenames, num_samp)
            
        if verbose >= 1:
            print(colored("\n   *** Complete sampling ***", 'green'))
            
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting stocks DataFrame creation the sample ******", 'magenta'))
        
        dfs = []

        for ticker in sample:
            ticker_df = pd.read_csv('../../raw_data/processed/'+ticker)
            dfs.append(ticker_df)
            if verbose == 2:
                print(colored(f"{ticker} DataFrame created", 'yellow'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
            
            
    else: 
        for file in os.listdir(path_files):
            if (file.endswith('.csv')):
                filenames.append(file)
                #print(f"{file}")
        
        if verbose >= 1:
            print(colored("\n   *** Complete file selection ***", 'green'))
        
        dfs = []
        
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"****** Starting stocks DataFrame creation the sample ******", 'magenta'))
      
        for ticker in tickers_list:
            if ticker in filenames:
                #print(f"{ticker}")
                ticker_df = pd.read_csv('../../raw_data/processed/'+ticker)
                dfs.append(ticker_df)
                if verbose == 2:
                    print(colored(f"{ticker} DataFrame created", 'yellow'))
            else:
                missing_stock_csv.append(ticker)
                print(colored(f"\n{ticker} missing", 'red'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
    
    
    if len(missing_stock_csv) !=0:
        
        print(colored("""\n\n##### Problematic Issue: following stocks not in local database! #####""", "red"))
        print(colored(f"Number of missed stocks: {len(missing_stock_csv)}", "red"))
        print(colored(f"""\n{missing_stock_csv}""", "red"))
    
    return pd.concat(dfs)

# %% [markdown]
# ### Preprocessing Functions

# %%
from sklearn.preprocessing import StandardScaler

def std_scaler(df):
    """
    Scale the data with SKlearn StandardScaler
    """
    
    scaler = StandardScaler()
    
    col_to_scale_df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    col_to_scale = list(col_to_scale_df)
    
    scaled_df = df
    
    for col in col_to_scale:
        scaled_df[col] = scaler.fit_transform(scaled_df[[col]])
    
    return scaled_df

# %%
#Marcin's Function

def build_input_arrays(df, time_window=5, stride=3, input_cols=['RSI', 'Stochastic', 'Stochastic_signal', 'ADI',
       'OBV', 'ATR', 'ADX', 'ADX_pos', 'ADX_neg', 'MACD', 'MACD_diff',
       'MACD_signal'] , target_col='5TD_return'):
    output_array = []
    target_array = []
    df_sorted = df.sort_values('date', ascending=False)
    df_sorted.reset_index(drop=True, inplace=True)
    for row in range(0, len(df), stride):
        df_slice = df_sorted.iloc[row: row + time_window]
        if df_slice.shape[0]==time_window:
            output_array.append(np.array(df_slice[input_cols].values))
            target_array.append(df_slice[target_col].iloc[0])
    return np.array(output_array), np.array(target_array)

# %%
#Ian's Function

def train_test_split(df, test_set_size='3Y'):
    """
    Split the preprocessed stock data file into a train and test dataset
    INPUT: the dataframe to be split, and size of the test set in months or years ('3M' or '2Y')
    OUTPUT: returns a train_set and test_set dataframe, index is set to the date
    
    EXAMPLE: train_set, test_set = train_test_split(input_df, '3Y')
    """
    if not np.issubdtype(df['date'].dtype, np.datetime64):
        df['date'] = pd.to_datetime(df['date'], format=('%Y-%m-%d'))
    test_set = df.sort_values(by="date",ascending=True).set_index("date").last(test_set_size)
    train_set = df.drop(df.tail(len(test_set)).index).set_index("date")
    test_set.reset_index(inplace=True)
    train_set.reset_index(inplace=True)
    return train_set, test_set

# %%
def thresholds_encoding(df, r5d=0.0006, same_thresholds=True, r10d=0.0012, r20d=0.0024):
    """
    Binary encode the 5, 10 and 20 days return columns according to the thresholds
    
    INPUT: dataframe with '5TD_return', '10TD_return' and '20TD_return' columns
    OUTPUT: dataframe with binary encoded aforementionned columns
    
    If the thresolds returns are the same on a yearly basis for the different period use:
                r10d = r5d * 2 
            and
                r20d = r10d * 2
            keep same_thresholds=True
        Otherwise, define manually r10d and r20d
    """
    wk_df = df.copy()
    
    if same_thresholds:
        r10d = r5d * 2
        r20d = r10d * 2
    
    wk_df['5TD_return'] = wk_df['5TD_return'].apply(lambda x: 1 if x > r5d else 0)
    wk_df['10TD_return'] = wk_df['10TD_return'].apply(lambda x: 1 if x > r10d else 0)
    wk_df['20TD_return'] = wk_df['20TD_return'].apply(lambda x: 1 if x > r20d else 0)
    
    return wk_df

# %% [markdown]
# ### Visualisation Functions

# %%
def plot_loss_accuracy(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.show()

# %% [markdown]
# ### Model Saving Functions

# %%
def runs_history_loading(name='charles', vintage='0_1', path_files='models_histories'):
    
    filenames = []
    
    run_history = f"{name}_companies_{vintage}_model_history"
    
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if run_history in filenames:
        print("Previous models scores:\n",joblib.load(path_files+'/'+run_history))
        return joblib.load(path_files+'/'+run_history)
    
    else:
        print("No previous models scores found\nReturning uncomplete list: [('tickers', ['loss', 'precision', 'accuracy'])]")
        return [('tickers', ['loss', 'precision', 'accuracy'])]

# %%
def runs_history_saving(score_file, vintage='0_1', author='charles', path_files='models_histories'):
    filenames = []
    
    run_history = f"{author}_companies_{vintage}_model_history"
    
    for file in os.listdir(path_files):
        filenames.append(file)
    
    if f"{author}_old_cie_model_history" in filenames:
        print("Previous models scores found:\n", joblib.load(path_files+'/'+run_history))
        confirmation = input(prompt="""You are about to save over the previous history, which will replace it by your new history.
        Are you sure you want to do that? (Y/n)""")
        
        if confirmation =='Y':
            joblib.dump(path_files+'/'+run_history)
            print("History Saving Complete!")
            print(f"File saved as: {author}_companies_{vintage}_model_history")
            print(f"File location:{path_files}")            
            
        else:
            print("History Saving Aborted!")
    
    else:
        joblib.dump(score_file, path_files+'/'+run_history)
        print("History Saving Complete!")
        print(f"File saved as: {author}_companies_{vintage}_model_history")
        print(f"File location:{path_files}")

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Importing the (0,1] Companies Sample

# %%
companies_0_1 = stocks_tickers[0]
companies_0_1
# Out:
# ['AACQ',
#  'AACQU',
#  'AACQW',
#  'ABCL',
#  'ABCM',
#  'ABNB',
#  'ABST',
#  'ACAC',
#  'ACACU',
#  'ACACW',
#  'ACAM',
#  'ACAMU',
#  'ACAMW',
#  'ACCD',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACKIU',
#  'ACTC',
#  'ACTCU',
#  'ACTCW',
#  'ADERU',
#  'ADILW',
#  'ADOC',
#  'ADOCR',
#  'ADOCU',
#  'ADOCW',
#  'ADTX',
#  'ADV',
#  'ADVWW',
#  'ADXN',
#  'AEACU',
#  'AEPPZ',
#  'AFBI',
#  'AFIB',
#  'AFINO',
#  'AFRM',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGC',
#  'AGCUU',
#  'AGCWW',
#  'AGNCO',
#  'AGNCP',
#  'AHAC',
#  'AHACU',
#  'AHACW',
#  'AIH',
#  'AIRTP',
#  'AIRTW',
#  'AKICU',
#  'AKU',
#  'AKUS',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALGM',
#  'ALGS',
#  'ALRS',
#  'ALTUU',
#  'ALVR',
#  'ALXO',
#  'AMCIU',
#  'AMCIW',
#  'AMHC',
#  'AMHCU',
#  'AMHCW',
#  'AMST',
#  'AMTI',
#  'AMYT',
#  'ANDA',
#  'ANDAR',
#  'ANDAU',
#  'ANDAW',
#  'ANNX',
#  'ANPC',
#  'AOUT',
#  'API',
#  'APRE',
#  'APXT',
#  'APXTU',
#  'APXTW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARKO',
#  'ARKOW',
#  'ARQT',
#  'ARRY',
#  'ARTLW',
#  'ARYA',
#  'ASLE',
#  'ASLEW',
#  'ASO',
#  'ATCXW',
#  'ATHA',
#  'ATNF',
#  'AUBAP',
#  'AUVI',
#  'AVCTW',
#  'AVGOP',
#  'AVIR',
#  'AVO',
#  'AYLA',
#  'AZYO',
#  'BCAB',
#  'BCDA',
#  'BCDAW',
#  'BCTG',
#  'BCYPU',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEEMW',
#  'BENEU',
#  'BFRA',
#  'BHFAN',
#  'BHFAO',
#  'BHSE',
#  'BHSEU',
#  'BHSEW',
#  'BIGC',
#  'BIVI',
#  'BLCT',
#  'BLI',
#  'BLSA',
#  'BLTSU',
#  'BLU',
#  'BLUWU',
#  'BNR',
#  'BNTX',
#  'BOWX',
#  'BOWXU',
#  'BOWXW',
#  'BPYPN',
#  'BPYPO',
#  'BREZ',
#  'BREZR',
#  'BREZU',
#  'BREZW',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRP',
#  'BRPA',
#  'BRPAR',
#  'BRPAU',
#  'BRPAW',
#  'BRQS',
#  'BSBK',
#  'BSCU',
#  'BSJS',
#  'BSML',
#  'BSMM',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSY',
#  'BTAQ',
#  'BTAQU',
#  'BTAQW',
#  'BTBT',
#  'BTRS',
#  'BTRSW',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BUG',
#  'BWAC',
#  'BWACU',
#  'BWACW',
#  'BWMX',
#  'BXRX',
#  'CABA',
#  'CALB',
#  'CALT',
#  'CAN',
#  'CAPA',
#  'CAPAU',
#  'CAPAW',
#  'CCCC',
#  'CCNEP',
#  'CD',
#  'CDAK',
#  'CEFA',
#  'CERE',
#  'CEREW',
#  'CERT',
#  'CFAC',
#  'CFACU',
#  'CFACW',
#  'CFB',
#  'CFFAU',
#  'CFII',
#  'CFIIU',
#  'CFIIW',
#  'CFIVU',
#  'CGEM',
#  'CGRO',
#  'CGROU',
#  'CGROW',
#  'CHB',
#  'CHPM',
#  'CHPMU',
#  'CHPMW',
#  'CIIC',
#  'CIICU',
#  'CIICW',
#  'CLDB',
#  'CLEU',
#  'CLNN',
#  'CLNNW',
#  'CLOV',
#  'CLOVW',
#  'CLSK',
#  'CLVR',
#  'CLVRW',
#  'CMCTP',
#  'CMLF',
#  'CMLFU',
#  'CMLFW',
#  'CMPI',
#  'CMPS',
#  'CNNB',
#  'CNSP',
#  'CNTG',
#  'CNXC',
#  'COFS',
#  'COMS',
#  'COMSW',
#  'CONX',
#  'CONXU',
#  'CONXW',
#  'COOLU',
#  'CPZ',
#  'CREXW',
#  'CRNC',
#  'CRSA',
#  'CRSAU',
#  'CRSAW',
#  'CRSR',
#  'CRTD',
#  'CRTDW',
#  'CSSEN',
#  'CTAQU',
#  'CTEC',
#  'CURI',
#  'CURIW',
#  'CVAC',
#  'CVLB',
#  'CXDO',
#  'CYTH',
#  'CYTHW',
#  'DADA',
#  'DBDR',
#  'DBDRU',
#  'DBDRW',
#  'DCBO',
#  'DCOMP',
#  'DCRB',
#  'DCRBU',
#  'DCRBW',
#  'DCT',
#  'DCTH',
#  'DDMXU',
#  'DDOG',
#  'DEMZ',
#  'DFH',
#  'DFHT',
#  'DFHTU',
#  'DFHTW',
#  'DFPH',
#  'DFPHU',
#  'DFPHW',
#  'DGNS',
#  'DKNG',
#  'DLCAU',
#  'DLPNW',
#  'DMXF',
#  'DPHCU',
#  'DRTT',
#  'DRVN',
#  'DSAC',
#  'DSACU',
#  'DSACW',
#  'DUNEU',
#  'DUO',
#  'DUOT',
#  'DWAW',
#  'DWCR',
#  'DWEQ',
#  'DWUS',
#  'DYN',
#  'EACPU',
#  'EAR',
#  'EBC',
#  'EBON',
#  'ECOLW',
#  'ECOW',
#  'EDOC',
#  'EDTK',
#  'EDTXU',
#  'EDUT',
#  'EH',
#  'ELDN',
#  'EMXF',
#  'ENFAU',
#  'ENTXW',
#  'ENVIU',
#  'EOSE',
#  'EOSEW',
#  'EPHYU',
#  'EQOS',
#  'EQOSW',
#  'ERES',
#  'ERESU',
#  'ERESW',
#  'ESSC',
#  'ESSCR',
#  'ESSCU',
#  'ESSCW',
#  'ETAC',
#  'ETACU',
#  'ETACW',
#  'ETNB',
#  'EUCR',
#  'EUCRU',
#  'EUCRW',
#  'EUSGU',
#  'EWEB',
#  'EWJE',
#  'EWJV',
#  'EXPC',
#  'EXPCU',
#  'EXPCW',
#  'FATBP',
#  'FATBW',
#  'FCAC',
#  'FCACU',
#  'FCACW',
#  'FCNCP',
#  'FDMT',
#  'FDUSG',
#  'FHTX',
#  'FICS',
#  'FIII',
#  'FIIIU',
#  'FIIIW',
#  'FINMU',
#  'FITBO',
#  'FITBP',
#  'FLACU',
#  'FLUX',
#  'FMBIO',
#  'FMBIP',
#  'FMTX',
#  'FOXWU',
#  'FPXE',
#  'FREE',
#  'FREEW',
#  'FREQ',
#  'FRG',
#  'FRGAP',
#  'FRHC',
#  'FRLN',
#  'FROG',
#  'FSDC',
#  'FSEA',
#  'FSRV',
#  'FSRVU',
#  'FSRVW',
#  'FTCVU',
#  'FTHM',
#  'FTIV',
#  'FTIVU',
#  'FTIVW',
#  'FTOC',
#  'FTOCU',
#  'FTOCW',
#  'FULTP',
#  'FUSN',
#  'FVAM',
#  'FXNC',
#  'GAN',
#  'GBIO',
#  'GBNY',
#  'GBS',
#  'GCMG',
#  'GDRX',
#  'GDYNW',
#  'GFNSZ',
#  'GHIV',
#  'GHIVU',
#  'GHIVW',
#  'GHVIU',
#  'GLADL',
#  'GLAQU',
#  'GLSI',
#  'GLTO',
#  'GMBL',
#  'GMBLW',
#  'GMBTU',
#  'GMHIU',
#  'GMIIU',
#  'GNACU',
#  'GNOG',
#  'GNOGW',
#  'GNRS',
#  'GNRSU',
#  'GNRSW',
#  'GOCO',
#  'GOODN',
#  'GOVX',
#  'GOVXW',
#  'GP',
#  'GPACU',
#  'GRAY',
#  'GRCL',
#  'GRCY',
#  'GRCYU',
#  'GRCYW',
#  'GRIL',
#  'GRNV',
#  'GRNVR',
#  'GRNVU',
#  'GRNVW',
#  'GRSV',
#  'GRSVU',
#  'GRSVW',
#  'GRTX',
#  'GRWG',
#  'GSAQU',
#  'GTH',
#  'GWAC',
#  'GWACU',
#  'GWACW',
#  'GXGX',
#  'GXGXU',
#  'GXGXW',
#  'GXTG',
#  'HAAC',
#  'HAACU',
#  'HAACW',
#  'HAPP',
#  'HBT',
#  'HCACU',
#  'HCAR',
#  'HCARU',
#  'HCARW',
#  'HCCCU',
#  'HCCH',
#  'HCCHR',
#  'HCCHU',
#  'HCCHW',
#  'HCCOU',
#  'HCDI',
#  'HCICU',
#  'HEC',
#  'HECCU',
#  'HECCW',
#  'HERD',
#  'HERO',
#  'HFEN',
#  'HGBL',
#  'HLAHU',
#  'HLXA',
#  'HMCOU',
#  'HOL',
#  'HOLUU',
#  'HOLUW',
#  'HRMY',
#  'HSAQ',
#  'HTIA',
#  'HTLFP',
#  'HTOO',
#  'HTOOW',
#  'HUDI',
#  'HUGE',
#  'HUIZ',
#  'HWCPZ',
#  'HYAC',
#  'HYACU',
#  'HYACW',
#  'HYFM',
#  'HYMCZ',
#  'IBBJ',
#  'IBEX',
#  'IBKR',
#  'IBTA',
#  'IBTB',
#  'IBTD',
#  'IBTE',
#  'IBTF',
#  'IBTG',
#  'IBTH',
#  'IBTI',
#  'IBTJ',
#  'IBTK',
#  'IGAC',
#  'IGACU',
#  'IGACW',
#  'IGMS',
#  'IHYF',
#  'IIIIU',
#  'IIVIP',
#  'IKT',
#  'IMAB',
#  'IMACW',
#  'IMNM',
#  'IMRA',
#  'IMTXW',
#  'IMVT',
#  'INAQ',
#  'INAQU',
#  'INAQW',
#  'INBKZ',
#  'INBX',
#  'INKAU',
#  'INM',
#  'INTZ',
#  'INVO',
#  'INZY',
#  'IPA',
#  'IPDN',
#  'IPHA',
#  'ISUN',
#  'ITAC',
#  'ITACU',
#  'ITACW',
#  'ITOS',
#  'IVA',
#  'JAMF',
#  'JCICU',
#  'JFU',
#  'JMPNZ',
#  'JOET',
#  'JUPW',
#  'JUPWW',
#  'JYAC',
#  'KAIRU',
#  'KBLMU',
#  'KBNT',
#  'KBNTW',
#  'KC',
#  'KELYB',
#  'KINZU',
#  'KLAQU',
#  'KMPH',
#  'KNTE',
#  'KOR',
#  'KRBP',
#  'KRKR',
#  'KRMD',
#  'KRON',
#  'KROS',
#  'KSMT',
#  'KSMTU',
#  'KSMTW',
#  'KYMR',
#  'LACQU',
#  'LANDO',
#  'LATN',
#  'LATNU',
#  'LATNW',
#  'LAZR',
#  'LAZRW',
#  'LBRDP',
#  'LBTYB',
#  'LCAHU',
#  'LCAP',
#  'LCAPU',
#  'LCAPW',
#  'LCY',
#  'LCYAU',
#  'LCYAW',
#  'LDEM',
#  'LEGN',
#  'LEGOU',
#  'LESL',
#  'LEVLP',
#  'LEXX',
#  'LEXXW',
#  'LFACU',
#  'LFACW',
#  'LFTR',
#  'LFTRU',
#  'LFTRW',
#  'LGHL',
#  'LGHLW',
#  'LI',
#  'LIVK',
#  'LIVKU',
#  'LIVKW',
#  'LIXT',
#  'LIXTW',
#  'LIZI',
#  'LJAQU',
#  'LMACU',
#  'LMFAW',
#  'LMNL',
#  'LMPX',
#  'LNSR',
#  'LOAC',
#  'LOACR',
#  'LOACU',
#  'LOACW',
#  'LOTZ',
#  'LOTZW',
#  'LPRO',
#  'LSAQ',
#  'LSEA',
#  'LSEAW',
#  'LSXMB',
#  'LTRN',
#  'LTRPB',
#  'LUNG',
#  'LUXA',
#  'LUXAU',
#  'LUXAW',
#  'LVGO',
#  'LWACU',
#  'LXEH',
#  'LYRA',
#  'MAAC',
#  'MAACU',
#  'MAACW',
#  'MACU',
#  'MACUU',
#  'MACUW',
#  'MASS',
#  'MAXN',
#  'MAYS',
#  'MBINO',
#  'MBNKP',
#  'MCAC',
#  'MCACR',
#  'MCACU',
#  'MCADU',
#  'MCBS',
#  'MCFE',
#  'MCMJ',
#  'MCMJW',
#  'MDGSW',
#  'MDIA',
#  'MDNA',
#  'MDRRP',
#  'MDWT',
#  'MDXG',
#  'METXW',
#  'MKD',
#  'MLAC',
#  'MLACU',
#  'MLACW',
#  'MNCLU',
#  'MNPR',
#  'MNSBP',
#  'MNTK',
#  'MODV',
#  'MOHO',
#  'MONCU',
#  'MOTN',
#  'MOTNU',
#  'MOTNW',
#  'MRACU',
#  'MRM',
#  'MRVI',
#  'MSGM',
#  'MTACU',
#  'MTCR',
#  'MUDSU',
#  'NAACU',
#  'NARI',
#  'NBAC',
#  'NBACR',
#  'NBACU',
#  'NBACW',
#  'NBTX',
#  'NCNO',
#  'NEBCU',
#  'NEPH',
#  'NFIN',
#  'NFINU',
#  'NFINW',
#  'NGAC',
#  'NGACU',
#  'NGACW',
#  'NGMS',
#  'NHIC',
#  'NHICU',
#  'NHICW',
#  'NKTX',
#  'NMMC',
#  'NMMCU',
#  'NMMCW',
#  'NMTR',
#  'NNOX',
#  'NOACU',
#  'NOVS',
#  'NOVSU',
#  'NOVSW',
#  'NPA',
#  'NPAUU',
#  'NPAWW',
#  'NRIX',
#  'NTRSO',
#  'NUZE',
#  'NYMTM',
#  'OAS',
#  'OCAXU',
#  'OCFCP',
#  'OCG',
#  'OEPWU',
#  'OFSSG',
#  'OFSSI',
#  'OLB',
#  'OLMA',
#  'OM',
#  'OMEG',
#  'ONCR',
#  'ONDS',
#  'ONEM',
#  'ONEW',
#  'OPEN',
#  'OPENW',
#  'OPESU',
#  'OPINL',
#  'OPRT',
#  'OPT',
#  'ORIC',
#  'ORPH',
#  'ORSNR',
#  'ORSNU',
#  'OSTRU',
#  'OTRA',
#  'OTRAU',
#  'OTRAW',
#  'OTRKP',
#  'OXLCP',
#  'OYST',
#  'OZON',
#  'PACXU',
#  'PAEWW',
#  'PAIC',
#  'PAICU',
#  'PAICW',
#  'PAND',
#  'PAQCU',
#  'PASG',
#  'PAX',
#  'PAYA',
#  'PAYAW',
#  'PBLA',
#  'PCSA',
#  'PCVX',
#  'PDEV',
#  'PFHD',
#  'PGNY',
#  'PHAR',
#  'PHAT',
#  'PHIC',
#  'PHICU',
#  'PHICW',
#  'PLC',
#  'PLIN',
#  'PLRX',
#  'PLTK',
#  'PMVP',
#  'PNFPP',
#  'PNNTG',
#  'PNTG',
#  'POSH',
#  'POTX',
#  'POWRU',
#  'POWW',
#  'PPD',
#  'PPGHU',
#  'PRAX',
#  'PRCH',
#  'PRCHW',
#  'PRFX',
#  'PRLD',
#  'PROG',
#  'PRPLW',
#  'PRSRU',
#  'PRTC',
#  'PSAC',
#  'PSACU',
#  'PSACW',
#  'PSM',
#  'PSTX',
#  'PTACU',
#  'PTICU',
#  'PTON',
#  'PTPI',
#  'PTRS',
#  'PTVE',
#  'PUBM',
#  'PXSAP',
#  'PXSAW',
#  'PYPD',
#  'QELL',
#  'QELLU',
#  'QELLW',
#  'QH',
#  'QK',
#  'QLI',
#  'QMCO',
#  'QQC',
#  'QQD',
#  'QQQJ',
#  'QQQM',
#  'QQQN',
#  'QRTEP',
#  'QYLG',
#  'RAACU',
#  'RACA',
#  'RADI',
#  'RAPT',
#  'RCEL',
#  'RCHG',
#  'RCHGU',
#  'RCHGW',
#  'RDIB',
#  'REYN',
#  'RIDE',
#  'RIDEW',
#  'RILYL',
#  'RILYM',
#  'RILYN',
#  'RILYP',
#  'RLAY',
#  'RMGBU',
#  'RNA',
#  'RNLX',
#  'ROCC',
#  'ROCCU',
#  'ROCCW',
#  'ROCH',
#  'ROCHU',
#  'ROCHW',
#  'ROOT',
#  'RPRX',
#  'RPTX',
#  'RSSS',
#  'RSVA',
#  'RSVAU',
#  'RSVAW',
#  'RVMD',
#  'RVPH',
#  'RVPHW',
#  'RXT',
#  'RZLT',
#  'SABRP',
#  'SAII',
#  'SAIIU',
#  'SAIIW',
#  'SAMA',
#  'SAMAU',
#  'SAMAW',
#  'SBNYP',
#  'SBTX',
#  'SCOAU',
#  'SCPS',
#  'SDC',
#  'SDGR',
#  'SEER',
#  'SFT',
#  'SFTTW',
#  'SGAM',
#  'SGAMU',
#  'SGAMW',
#  'SGLBW',
#  'SGTX',
#  'SHACU',
#  'SHC',
#  'SHIPZ',
#  'SHLD',
#  'SIGIP',
#  'SITM',
#  'SIVBP',
#  'SJ',
#  'SKYU',
#  'SLCRU',
#  'SLN',
#  'SMCI',
#  'SMID',
#  'SMMC',
#  'SMMCU',
#  'SMMCW',
#  'SMTI',
#  'SNGXW',
#  'SNRHU',
#  'SNUG',
#  'SPQQ',
#  'SPRB',
#  'SPT',
#  'SQFT',
#  'SRAC',
#  'SRACU',
#  'SRACW',
#  'SRSA',
#  'SRSAU',
#  'SRSAW',
#  'SSPK',
#  'SSPKU',
#  'SSPKW',
#  'STEP',
#  'STRRP',
#  'STSA',
#  'STTK',
#  'STWO',
#  'STWOU',
#  'STWOW',
#  'SUMO',
#  'SV',
#  'SVAC',
#  'SVACU',
#  'SVACW',
#  'SVFAU',
#  'SVOKU',
#  'SVSVU',
#  'SVSVW',
#  'SWETU',
#  'SWKH',
#  'SWTX',
#  'SYTA',
#  'SYTAW',
#  'TARS',
#  'TBKCP',
#  'TDACU',
#  'TECTP',
#  'TEKK',
#  'TEKKU',
#  'TEKKW',
#  'TELA',
#  'TFFP',
#  'THBR',
#  'THBRU',
#  'THBRW',
#  'THCA',
#  'THCAU',
#  'THCAW',
#  'THCBU',
#  'THRY',
#  'THTX',
#  'TIG',
#  'TLMD',
#  'TLMDW',
#  'TLS',
#  'TMKRU',
#  'TMPM',
#  'TMPMU',
#  'TMPMW',
#  'TMTS',
#  'TMTSU',
#  'TMTSW',
#  'TOMZ',
#  'TOTA',
#  'TOTAR',
#  'TOTAW',
#  'TRIT',
#  'TRITW',
#  'TSHA',
#  'TSIA',
#  'TSIAU',
#  'TSIAW',
#  'TVACU',
#  'TWCT',
#  'TWCTU',
#  'TWCTW',
#  'TXG',
#  'TZACU',
#  'TZPSU',
#  'UCBIO',
#  'UCL',
#  'UCYB',
#  'UK',
#  'UKOMW',
#  'UPST',
#  'USAT',
#  'USXF',
#  'VACQ',
#  'VACQU',
#  'VACQW',
#  'VCKAU',
#  'VCVC',
#  'VCVCU',
#  'VCVCW',
#  'VERX',
#  'VERY',
#  'VETS',
#  'VIACA',
#  ...]

# %% [markdown]
# ### (Security autobreak)

# %%
#breaking_auto_run = #Bug on purpose: you might want to look at the companies (randomly) selected below

# %%
stocks_0_1_df = precise_stocks_selector_local(tickers_list=companies_0_1, random_sample=True, num_samp = 8, verbose=1)
# Out:
# ****** Starting browsing the '../../raw_data/processed/' directory ******
# aacqu.csv missing
# abcl.csv missing
# abnb.csv missing
# abst.csv missing
# acacu.csv missing
# acacw.csv missing
# acamu.csv missing
# acevu.csv missing
# ackiu.csv missing
# actcu.csv missing
# actcw.csv missing
# aderu.csv missing
# adoc.csv missing
# adocr.csv missing
# adocu.csv missing
# adocw.csv missing
# adtx.csv missing
# aeacu.csv missing
# afbi.csv missing
# afino.csv missing
# afrm.csv missing
# agbau.csv missing
# agcuu.csv missing
# agcww.csv missing
# ahacu.csv missing
# ahacw.csv missing
# akicu.csv missing
# aku.csv missing
# akus.csv missing
# alacu.csv missing
# algs.csv missing
# alrs.csv missing
# altuu.csv missing
# amciu.csv missing
# amhcu.csv missing
# amst.csv missing
# amyt.csv missing
# andau.csv missing
# annx.csv missing
# aout.csv missing
# apxt.csv missing
# apxtu.csv missing
# arbg.csv missing
# arbgu.csv missing
# arbgw.csv missing
# arko.csv missing
# arkow.csv missing
# arqt.csv missing
# avir.csv missing
# bcab.csv missing
# bcypu.csv missing
# bdsx.csv missing
# bdtx.csv missing
# beneu.csv missing
# bhfan.csv missing
# bhse.csv missing
# bhseu.csv missing
# bhsew.csv missing
# blct.csv missing
# bltsu.csv missing
# blu.csv missing
# bluwu.csv missing
# bntx.csv missing
# bowx.csv missing
# bowxu.csv missing
# brez.csv missing
# brezr.csv missing
# brezu.csv missing
# brezw.csv missing
# brliu.csv missing
# brpau.csv missing
# brqs.csv missing
# bscu.csv missing
# bsjs.csv missing
# bsms.csv missing
# bsmt.csv missing
# bsmu.csv missing
# btaqu.csv missing
# btbt.csv missing
# btrs.csv missing
# btrsw.csv missing
# btwnu.csv missing
# btwnw.csv missing
# bwac.csv missing
# bwacu.csv missing
# bwacw.csv missing
# bwmx.csv missing
# bxrx.csv missing
# calt.csv missing
# capau.csv missing
# capaw.csv missing
# cert.csv missing
# cfac.csv missing
# cfacu.csv missing
# cfacw.csv missing
# cffau.csv missing
# cfiiu.csv missing
# cfiiw.csv missing
# cfivu.csv missing
# cgem.csv missing
# cgrou.csv missing
# chpmu.csv missing
# ciicu.csv missing
# cleu.csv missing
# clnn.csv missing
# clnnw.csv missing
# clov.csv missing
# clovw.csv missing
# clvr.csv missing
# clvrw.csv missing
# cmctp.csv missing
# cmlfu.csv missing
# cmlfw.csv missing
# cmps.csv missing
# cnxc.csv missing
# cofs.csv missing
# coms.csv missing
# comsw.csv missing
# conx.csv missing
# conxu.csv missing
# conxw.csv missing
# coolu.csv missing
# crsau.csv missing
# ctaqu.csv missing
# ctec.csv missing
# cvlb.csv missing
# cyth.csv missing
# cythw.csv missing
# dbdr.csv missing
# dbdru.csv missing
# dbdrw.csv missing
# dcbo.csv missing
# dcrbu.csv missing
# dcrbw.csv missing
# dct.csv missing
# ddmxu.csv missing
# demz.csv missing
# dfht.csv missing
# dfhtu.csv missing
# dfphu.csv missing
# dgns.csv missing
# dlcau.csv missing
# dphcu.csv missing
# drtt.csv missing
# drvn.csv missing
# dsac.csv missing
# dsacu.csv missing
# dsacw.csv missing
# duneu.csv missing
# duot.csv missing
# dwcr.csv missing
# dwus.csv missing
# eacpu.csv missing
# edtxu.csv missing
# edut.csv missing
# eldn.csv missing
# emxf.csv missing
# enfau.csv missing
# enviu.csv missing
# eosew.csv missing
# ephyu.csv missing
# eqos.csv missing
# eres.csv missing
# eresu.csv missing
# esscu.csv missing
# etacu.csv missing
# eucr.csv missing
# eucru.csv missing
# eucrw.csv missing
# eusgu.csv missing
# eweb.csv missing
# expcu.csv missing
# fcacu.csv missing
# fcacw.csv missing
# fdmt.csv missing
# fhtx.csv missing
# fics.csv missing
# fiiiu.csv missing
# finmu.csv missing
# flacu.csv missing
# flux.csv missing
# fmtx.csv missing
# foxwu.csv missing
# fsrvu.csv missing
# ftcvu.csv missing
# ftivu.csv missing
# ftivw.csv missing
# ftocu.csv missing
# fultp.csv missing
# gbny.csv missing
# gbs.csv missing
# gdrx.csv missing
# gfnsz.csv missing
# ghivu.csv missing
# ghviu.csv missing
# glaqu.csv missing
# gmbtu.csv missing
# gmhiu.csv missing
# gmiiu.csv missing
# gnacu.csv missing
# gnrs.csv missing
# gnrsu.csv missing
# govx.csv missing
# gpacu.csv missing
# grcl.csv missing
# grcyu.csv missing
# grnvu.csv missing
# grsvu.csv missing
# grtx.csv missing
# gsaqu.csv missing
# gwac.csv missing
# gwacu.csv missing
# gwacw.csv missing
# gxgx.csv missing
# gxgxu.csv missing
# haac.csv missing
# haacu.csv missing
# haacw.csv missing
# hbt.csv missing
# hcacu.csv missing
# hcar.csv missing
# hcaru.csv missing
# hcarw.csv missing
# hcccu.csv missing
# hcchu.csv missing
# hccou.csv missing
# hcicu.csv missing
# heccu.csv missing
# hfen.csv missing
# hlahu.csv missing
# hmcou.csv missing
# holuu.csv missing
# holuw.csv missing
# htoo.csv missing
# htoow.csv missing
# hudi.csv missing
# hyacu.csv missing
# hyfm.csv missing
# ibex.csv missing
# ibtk.csv missing
# igacu.csv missing
# igacw.csv missing
# igms.csv missing
# ihyf.csv missing
# iiiiu.csv missing
# ikt.csv missing
# imvt.csv missing
# inaqu.csv missing
# inaqw.csv missing
# inbx.csv missing
# inkau.csv missing
# inm.csv missing
# invo.csv missing
# ipa.csv missing
# isun.csv missing
# itacu.csv missing
# itacw.csv missing
# itos.csv missing
# jcicu.csv missing
# jfu.csv missing
# joet.csv missing
# jupw.csv missing
# jupww.csv missing
# jyac.csv missing
# kairu.csv missing
# kblmu.csv missing
# kbnt.csv missing
# kinzu.csv missing
# klaqu.csv missing
# kmph.csv missing
# knte.csv missing
# kros.csv missing
# ksmt.csv missing
# ksmtu.csv missing
# lacqu.csv missing
# latnu.csv missing
# lbrdp.csv missing
# lcahu.csv missing
# lcapu.csv missing
# lcapw.csv missing
# lcy.csv missing
# lcyau.csv missing
# lcyaw.csv missing
# legou.csv missing
# lexx.csv missing
# lexxw.csv missing
# lfacu.csv missing
# lftru.csv missing
# lftrw.csv missing
# livku.csv missing
# lixt.csv missing
# lixtw.csv missing
# ljaqu.csv missing
# lmacu.csv missing
# lmpx.csv missing
# loacu.csv missing
# lotz.csv missing
# lotzw.csv missing
# lsaq.csv missing
# lsea.csv missing
# lseaw.csv missing
# luxau.csv missing
# luxaw.csv missing
# lwacu.csv missing
# maacu.csv missing
# maacw.csv missing
# macu.csv missing
# macuu.csv missing
# macuw.csv missing
# mass.csv missing
# mays.csv missing
# mcacu.csv missing
# mcadu.csv missing
# mcbs.csv missing
# mdwt.csv missing
# mdxg.csv missing
# mlacu.csv missing
# mnclu.csv missing
# mntk.csv missing
# modv.csv missing
# moncu.csv missing
# motnu.csv missing
# motnw.csv missing
# mracu.csv missing
# mrm.csv missing
# mrvi.csv missing
# msgm.csv missing
# mtacu.csv missing
# mudsu.csv missing
# naacu.csv missing
# nbacu.csv missing
# nbtx.csv missing
# nebcu.csv missing
# nfinu.csv missing
# ngacu.csv missing
# ngacw.csv missing
# ngms.csv missing
# nhicu.csv missing
# nktx.csv missing
# nmmcu.csv missing
# nmmcw.csv missing
# nnox.csv missing
# noacu.csv missing
# novs.csv missing
# novsu.csv missing
# npauu.csv missing
# nrix.csv missing
# oas.csv missing
# ocaxu.csv missing
# ocg.csv missing
# oepwu.csv missing
# olma.csv missing
# omeg.csv missing
# onds.csv missing
# openw.csv missing
# opesu.csv missing
# oprt.csv missing
# opt.csv missing
# orsnu.csv missing
# ostru.csv missing
# otra.csv missing
# otrau.csv missing
# otraw.csv missing
# oyst.csv missing
# ozon.csv missing
# pacxu.csv missing
# paic.csv missing
# paicu.csv missing
# paicw.csv missing
# paqcu.csv missing
# pax.csv missing
# pcvx.csv missing
# pdev.csv missing
# phar.csv missing
# phat.csv missing
# phic.csv missing
# phicu.csv missing
# phicw.csv missing
# plrx.csv missing
# pltk.csv missing
# posh.csv missing
# potx.csv missing
# powru.csv missing
# poww.csv missing
# ppghu.csv missing
# prax.csv missing
# prfx.csv missing
# prsru.csv missing
# prtc.csv missing
# psacu.csv missing
# pstx.csv missing
# ptacu.csv missing
# pticu.csv missing
# ptpi.csv missing
# ptrs.csv missing
# pubm.csv missing
# pxsap.csv missing
# pxsaw.csv missing
# qellu.csv missing
# qellw.csv missing
# qli.csv missing
# qqc.csv missing
# qqd.csv missing
# raacu.csv missing
# rapt.csv missing
# rchgu.csv missing
# rchgw.csv missing
# rmgbu.csv missing
# rnlx.csv missing
# rocc.csv missing
# roccu.csv missing
# roccw.csv missing
# rochu.csv missing
# root.csv missing
# rprx.csv missing
# rptx.csv missing
# rsss.csv missing
# rsva.csv missing
# rsvau.csv missing
# rsvaw.csv missing
# rxt.csv missing
# rzlt.csv missing
# saiiu.csv missing
# samau.csv missing
# sbnyp.csv missing
# sbtx.csv missing
# scoau.csv missing
# scps.csv missing
# seer.csv missing
# sft.csv missing
# sgam.csv missing
# sgamu.csv missing
# sgamw.csv missing
# sgtx.csv missing
# shacu.csv missing
# shc.csv missing
# shld.csv missing
# sigip.csv missing
# skyu.csv missing
# slcru.csv missing
# sln.csv missing
# smid.csv missing
# smmcu.csv missing
# smti.csv missing
# snrhu.csv missing
# spt.csv missing
# sqft.csv missing
# sracu.csv missing
# srsau.csv missing
# srsaw.csv missing
# sspku.csv missing
# stwou.csv missing
# stwow.csv missing
# sv.csv missing
# svacu.csv missing
# svacw.csv missing
# svfau.csv missing
# svoku.csv missing
# svsvu.csv missing
# svsvw.csv missing
# swetu.csv missing
# swtx.csv missing
# tars.csv missing
# tdacu.csv missing
# tekku.csv missing
# tekkw.csv missing
# thbru.csv missing
# thcau.csv missing
# thcbu.csv missing
# thtx.csv missing
# tls.csv missing
# tmkru.csv missing
# tmpm.csv missing
# tmpmu.csv missing
# tmpmw.csv missing
# tmts.csv missing
# tmtsu.csv missing
# tmtsw.csv missing
# trit.csv missing
# tritw.csv missing
# tsia.csv missing
# tsiau.csv missing
# tsiaw.csv missing
# tvacu.csv missing
# twct.csv missing
# twctu.csv missing
# twctw.csv missing
# tzacu.csv missing
# tzpsu.csv missing
# ucyb.csv missing
# upst.csv missing
# usat.csv missing
# vacqu.csv missing
# vacqw.csv missing
# vckau.csv missing
# vcvc.csv missing
# vcvcu.csv missing
# vcvcw.csv missing
# verx.csv missing
# vets.csv missing
# vih.csv missing
# vihau.csv missing
# vihaw.csv missing
# viiau.csv missing
# vincu.csv missing
# viri.csv missing
# vldrw.csv missing
# vmacu.csv missing
# vmar.csv missing
# vosou.csv missing
# vpn.csv missing
# vrdn.csv missing
# vs.csv missing
# vspru.csv missing
# vsprw.csv missing
# vssyw.csv missing
# vtaqu.csv missing
# vtiqu.csv missing
# vtrn.csv missing
# vtrs.csv missing
# vtru.csv missing
# vvos.csv missing
# wint.csv missing
# wish.csv missing
# wnw.csv missing
# woof.csv missing
# xog.csv missing
# xomap.csv missing
# yq.csv missing
# ysacu.csv missing
# ysacw.csv missing
# zgyhu.csv missing
# znte.csv missing
# znteu.csv missing
# zntew.csv missing
#
#    *** Complete sampling ***
#
#
# ****** Starting stocks DataFrame creation the sample ******
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 535
#
# ['aacqu.csv', 'abcl.csv', 'abnb.csv', 'abst.csv', 'acacu.csv', 'acacw.csv', 'acamu.csv', 'acevu.csv', 'ackiu.csv', 'actcu.csv', 'actcw.csv', 'aderu.csv', 'adoc.csv', 'adocr.csv', 'adocu.csv', 'adocw.csv', 'adtx.csv', 'aeacu.csv', 'afbi.csv', 'afino.csv', 'afrm.csv', 'agbau.csv', 'agcuu.csv', 'agcww.csv', 'ahacu.csv', 'ahacw.csv', 'akicu.csv', 'aku.csv', 'akus.csv', 'alacu.csv', 'algs.csv', 'alrs.csv', 'altuu.csv', 'amciu.csv', 'amhcu.csv', 'amst.csv', 'amyt.csv', 'andau.csv', 'annx.csv', 'aout.csv', 'apxt.csv', 'apxtu.csv', 'arbg.csv', 'arbgu.csv', 'arbgw.csv', 'arko.csv', 'arkow.csv', 'arqt.csv', 'avir.csv', 'bcab.csv', 'bcypu.csv', 'bdsx.csv', 'bdtx.csv', 'beneu.csv', 'bhfan.csv', 'bhse.csv', 'bhseu.csv', 'bhsew.csv', 'blct.csv', 'bltsu.csv', 'blu.csv', 'bluwu.csv', 'bntx.csv', 'bowx.csv', 'bowxu.csv', 'brez.csv', 'brezr.csv', 'brezu.csv', 'brezw.csv', 'brliu.csv', 'brpau.csv', 'brqs.csv', 'bscu.csv', 'bsjs.csv', 'bsms.csv', 'bsmt.csv', 'bsmu.csv', 'btaqu.csv', 'btbt.csv', 'btrs.csv', 'btrsw.csv', 'btwnu.csv', 'btwnw.csv', 'bwac.csv', 'b
iu.csv', 'ikt.csv', 'imvt.csv', 'inaqu.csv', 'inaqw.csv', 'inbx.csv', 'inkau.csv', 'inm.csv', 'invo.csv', 'ipa.csv', 'isun.csv', 'itacu.csv', 'itacw.csv', 'itos.csv', 'jcicu.csv', 'jfu.csv', 'joet.csv', 'jupw.csv', 'jupww.csv', 'jyac.csv', 'kairu.csv', 'kblmu.csv', 'kbnt.csv', 'kinzu.csv', 'klaqu.csv', 'kmph.csv', 'knte.csv', 'kros.csv', 'ksmt.csv', 'ksmtu.csv', 'lacqu.csv', 'latnu.csv', 'lbrdp.csv', 'lcahu.csv', 'lcapu.csv', 'lcapw.csv', 'lcy.csv', 'lcyau.csv', 'lcyaw.csv', 'legou.csv', 'lexx.csv', 'lexxw.csv', 'lfacu.csv', 'lftru.csv', 'lftrw.csv', 'livku.csv', 'lixt.csv', 'lixtw.csv', 'ljaqu.csv', 'lmacu.csv', 'lmpx.csv', 'loacu.csv', 'lotz.csv', 'lotzw.csv', 'lsaq.csv', 'lsea.csv', 'lseaw.csv', 'luxau.csv', 'luxaw.csv', 'lwacu.csv', 'maacu.csv', 'maacw.csv', 'macu.csv', 'macuu.csv', 'macuw.csv', 'mass.csv', 'mays.csv', 'mcacu.csv', 'mcadu.csv', 'mcbs.csv', 'mdwt.csv', 'mdxg.csv', 'mlacu.csv', 'mnclu.csv', 'mntk ...

# %% [markdown]
# ### Companies (randomly) selected

# %%
stocks_0_1_df.ticker.unique()
# Out:
# array(['QQQM', 'FXNC', 'LESL', 'XBIOW', 'LBTYB', 'EOSE', 'MDNA', 'MCACR'],
#       dtype=object)

# %% [markdown]
# ### Setting date to `datetime` type

# %%
stocks_0_1_df['date'] = pd.to_datetime(stocks_0_1_df['date'])

# %% [markdown]
# ### Standard Scaling

# %%
scaled_stocks_0_1_df = std_scaler(stocks_0_1_df)
scaled_stocks_0_1_df
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#    ticker       date       RSI  Stochastic  Stochastic_signal       ADI  \
# 0    QQQM 2020-12-01  1.617462    1.434031           1.654388 -0.180061
# 1    QQQM 2020-12-02  1.643227    1.469267           1.658726 -0.132015
# 2    QQQM 2020-12-03  1.683924    1.418655           1.605140 -0.144801
# 3    QQQM 2020-12-04  1.783675    1.608941           1.669778 -0.122440
# 4    QQQM 2020-12-07  1.872499    1.478859           1.673323 -0.127587
# 5    QQQM 2020-12-08  2.049285    1.637402           1.754161 -0.110039
# 6    QQQM 2020-12-09  0.697818    0.568114           1.369522 -0.150081
# 7    QQQM 2020-12-10  0.818261    0.727246           1.091762 -0.119059
# 8    QQQM 2020-12-11  0.690181    0.614689           0.713817 -0.099795
# 9    QQQM 2020-12-14  0.974789    0.905337           0.838438 -0.127713
# 10   QQQM 2020-12-15  1.346550    1.397104           1.085985 -0.103126
# 11   QQQM 2020-12-16  1.519322    1.506502           1.415556 -0.087629
# 12   QQQM 2020-12-17  1.724970    1.668905           1.697734 -0.067207
# 13   QQQM 2020-12-18  1.549216    1.292828           1.659198 -0.060164
# 14   QQQM 2020-12-21  1.261567    0.983752           1.466015 -0.032770
# 7      3.295138    0.028167     0.023580     0.039594
# 8      3.301472    0.027910     0.036380     0.041704
# 9      3.288601    0.016014     0.029946     0.039635
# 10     3.298236    0.008001     0.018221     0.023053
# 11     3.334912   -0.001970     0.015759     0.009377
# 12     3.405225   -0.004461    -0.005322     0.017768
# 13     3.474896    0.008240     0.005219     0.044260
# 14     3.515818    0.013713    -0.004413     0.057215
# 15     3.539313    0.010138     0.017447     0.051399
# 16     3.524577    0.017764     0.035370     0.062924
# 0      0.053206   -0.045696    -0.092696    -0.116897
# 1      0.076935   -0.065799    -0.107615    -0.136175
# 2      0.058794   -0.004892    -0.041839    -0.076237
# 3      0.035997   -0.026162    -0.082722    -0.121151
# 4     -0.005409   -0.019488    -0.048289    -0.124418
# 5     -0.056370   -0.049251    -0.048289    -0.142995
# 6     -0.115634   -0.044761    -0.050171    -0.064972
# 7     -0.178847   -0.037128    -0.059354    -0.085471
# 8     -0.233496   -0.058080    -0.048771    -0.079025
# 9     -0.291669   -0.029374    -0.029374    -0.100563
# 10    -0.366594    0.001012    -0.026673    -0.063675
# 11    -0.449402   -0.005664    -0.032005    -0.097938
# 12    -0.529199   -0.023083    -0.035900    -0.026167
# ..          ...         ...          ...          ...
# 14    -0.012029    0.085832     0.111687     0.456393
# 15    -0.014910    0.066665     0.100000     0.326833
# 16    -0.017354    0.112673     0.143331     0.407125
# 17    -0.019537    0.083333     0.166667     0.383333
# 18    -0.020235    0.000000     0.093750     0.285313
# 19    -0.020302    0.023811     0.126984     0.327143
# 20    -0.019688    0.031252     0.125002     0.250002
# 21    -0.017734    0.027553     0.116906     0.183920
# 22    -0.015741    0.076923     0.118000     0.261538
# 23    -0.014175    0.093750     0.144844     0.320312
# 24    -0.012845    0.100773     0.310074     0.479688
# 25    -0.011313    0.090909     0.206212     0.424394
# 26    -0.008855    0.086957     0.230725     0.290000
# 27    -0.005690    0.038143     0.185714     0.327716
# 28    -0.002308    0.046714     0.175143     0.300143
# 29     0.001273    0.190139     0.177606     0.302817
# 30     0.005025    0.105694     0.111111     0.361111
# 31     0.009529    0.132267     0.060000     0.200533
# 32     0.013453    0.142149     0.128389     0.307417
# 33     0.016889    0.122697     0.153269     0.351167
# 34     0.023199   -0.010531     0.129469     0.171836
# 35     0.029342    0.004899     0.180882     0.293807
# 36     0.036559   -0.063825     0.048163     0.307113
# 37     0.043321   -0.012048     0.119760     0.325301
# 38     0.049041    0.027231     0.106370     0.349380
# 39     0.054041    0.141490     0.106327     0.363234
# 40     0.057014    0.175125     0.225000     0.375000
# 41     0.058203    0.119623     0.132579     0.383648
# 42     0.058778    0.133416     0.158659     0.353659
# 43     0.059504    0.077041     0.171598     0.337278
#
# [604 rows x 17 columns]

# %% [markdown]
# ### Encoding the Returns

# %%
clean_stocks_0_1_df = thresholds_encoding(scaled_stocks_0_1_df)
clean_stocks_0_1_df
# Out:
#    ticker       date       RSI  Stochastic  Stochastic_signal       ADI  \
# 0    QQQM 2020-12-01  1.617462    1.434031           1.654388 -0.180061
# 37 -0.042184 -0.899464  0.626094  1.316367 -1.430802  0.061125   0.058564
# 38 -0.051569 -0.900783  0.773732  1.079219 -1.266278  0.062600   0.047034
# 39 -0.050070 -0.902790  0.906123  0.886504 -1.289260  0.064608   0.039057
# 40 -0.059789 -0.903001  1.035588  0.753737 -1.351103  0.059741   0.016613
# 41 -0.068542 -0.902037  1.062777  0.460548 -0.985286  0.054101  -0.003147
# 42 -0.048931 -0.900697  1.127961  0.774840 -1.088152  0.052318  -0.009946
# 43 -0.043382 -0.903909  1.188489  0.646527 -1.127217  0.053577  -0.008278
#
#     MACD_signal  5TD_return  10TD_return  20TD_return
# 0      1.809084           1            1            1
# 1      2.071398           0            1            1
# 2      2.335120           0            1            1
# 3      2.593801           0            1            1
# 4      2.841529           0            1            1
# 5      3.086822           0            1            1
# 6      3.225422           1            1            1
# 7      3.295138           1            1            1
# 8      3.301472           1            1            1
# 9      3.288601           1            1            1
# 10     3.298236           1            1            1
# 11     3.334912           0            1            1
# 12     3.405225           0            0            1
# 13     3.474896           1            1            1
# 14     3.515818           1            0            1
# 15     3.539313           1            1            1
# 16     3.524577           1            1            1
# 0      0.053206           0            0            0
# 1      0.076935           0            0            0
# 2      0.058794           0            0            0
# 3      0.035997           0            0            0
# 4     -0.005409           0            0            0
# 5     -0.056370           0            0            0
# 6     -0.115634           0            0            0
# 7     -0.178847           0            0            0
# 8     -0.233496           0            0            0
# 9     -0.291669           0            0            0
# 10    -0.366594           1            0            0
# 11    -0.449402           0            0            0
# 12    -0.529199           0            0            0
# ..          ...         ...          ...          ...
# 14    -0.012029           1            1            1
# 15    -0.014910           1            1            1
# 16    -0.017354           1            1            1
# 17    -0.019537           1            1            1
# 18    -0.020235           0            1            1
# 19    -0.020302           1            1            1
# 20    -0.019688           1            1            1
# 21    -0.017734           1            1            1
# 22    -0.015741           1            1            1
# 23    -0.014175           1            1            1
# 24    -0.012845           1            1            1
# 25    -0.011313           1            1            1
# 26    -0.008855           1            1            1
# 27    -0.005690           1            1            1
# 28    -0.002308           1            1            1
# 29     0.001273           1            1            1
# 30     0.005025           1            1            1
# 31     0.009529           1            1            1
# 32     0.013453           1            1            1
# 33     0.016889           1            1            1
# 34     0.023199           0            1            1
# 35     0.029342           1            1            1
# 36     0.036559           0            1            1
# 37     0.043321           0            1            1
# 38     0.049041           1            1            1
# 39     0.054041           1            1            1
# 40     0.057014           1            1            1
# 41     0.058203           1            1            1
# 42     0.058778           1            1            1
# 43     0.059504           1            1            1
#
# [604 rows x 17 columns]

# %% [markdown]
# ### Getting `X_train`, `y_train`, `X_test`, `y_test`

# %%
train, test = train_test_split(clean_stocks_0_1_df, '1M')

# %%
train.shape
# Out:
# (314, 17)

# %%
test.shape
# Out:
# (86, 17)

# %%
X_train, y_train = build_input_arrays(train)
X_test, y_test = build_input_arrays(test)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Initialisation

# %%
X_train.shape[1:]
# Out:
# (5, 12)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers, models 
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import Precision

precision = Precision()


optim = RMSprop(learning_rate=0.0001)

def init_model(X_train):
    model = Sequential()
    reg_l1 = regularizers.l1(0.001)
    reg_l2 = regularizers.l2(0.001)
    reg_l1_l2 = regularizers.l1_l2(l1=0.001, l2=0.0001)
    
    model.add(layers.LSTM(200, return_sequences=True, input_shape=X_train.shape[1:], activation='tanh'))
    model.add(layers.LSTM(200, activation='tanh'))
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(200, activation='tanh', kernel_regularizer=reg_l1))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(100, activation='tanh', bias_regularizer=reg_l2))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(50, activation='relu', activity_regularizer=reg_l1_l2))
    model.add(layers.Dropout(0.3))
    #model.add(layers.Dense(25, activation='relu'))
    #model.add(layers.BatchNormalization())
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=[precision, 'accuracy'])
    
    return model

# %%
model = init_model(X_train)

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=10, restore_best_weights=True)

model.fit(X_train, y_train, 
          epochs=500, 
          batch_size=8,
          validation_split=0.25,
          callbacks=[es]
         )
# Out:
# Epoch 1/500
# 10/10 [==============================] - 2s 189ms/step - loss: 3.1548 - precision: 0.5758 - accuracy: 0.5769 - val_loss: 3.1119 - val_precision: 0.6316 - val_accuracy: 0.6154
# Epoch 2/500
# 10/10 [==============================] - 0s 31ms/step - loss: 3.0812 - precision: 0.6207 - accuracy: 0.6282 - val_loss: 3.1018 - val_precision: 0.6471 - val_accuracy: 0.6154
# Epoch 3/500
# 10/10 [==============================] - 0s 36ms/step - loss: 3.2006 - precision: 0.5439 - accuracy: 0.5128 - val_loss: 3.0975 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 4/500
# 10/10 [==============================] - 0s 35ms/step - loss: 3.0896 - precision: 0.6545 - accuracy: 0.6667 - val_loss: 3.0906 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 5/500
# 10/10 [==============================] - 0s 34ms/step - loss: 3.0921 - precision: 0.5965 - accuracy: 0.5897 - val_loss: 3.0830 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 6/500
# 10/10 [==============================] - 0s 34ms/step - loss: 3.1397 - precision: 0.6182 - accuracy: 0.6154 - val_loss: 3.0782 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 7/500
# 10/10 [==============================] - 0s 35ms/step - loss: 3.1769 - precision: 0.5741 - accuracy: 0.5513 - val_loss: 3.0767 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 8/500
# 10/10 [==============================] - 0s 35ms/step - loss: 3.0371 - precision: 0.6875 - accuracy: 0.6795 - val_loss: 3.0712 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 9/500
# 10/10 [==============================] - 0s 35ms/step - loss: 3.0461 - precision: 0.6800 - accuracy: 0.6795 - val_loss: 3.0655 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 10/500
# 10/10 [==============================] - 0s 33ms/step - loss: 3.0253 - precision: 0.6071 - accuracy: 0.6026 - val_loss: 3.0594 - val_precision: 0.6667 - val_accuracy: 0.6154
# Epoch 11/500
# 10/10 [==============================] - 0s 30ms/step - loss: 3.0165 - precision: 0.6667 - accuracy: 0.6667 - val_loss: 3.0494 - val_precision: 0.7143 - val_accuracy: 0.6538
# Epoch 27/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.9008 - precision: 0.7556 - accuracy: 0.7436 - val_loss: 2.9425 - val_precision: 0.6500 - val_accuracy: 0.6538
# Epoch 28/500
# 10/10 [==============================] - 1s 67ms/step - loss: 2.8213 - precision: 0.7556 - accuracy: 0.7436 - val_loss: 2.9381 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 29/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.8651 - precision: 0.7292 - accuracy: 0.7308 - val_loss: 2.9392 - val_precision: 0.5909 - val_accuracy: 0.5769
# Epoch 30/500
# 10/10 [==============================] - 1s 57ms/step - loss: 2.9223 - precision: 0.7174 - accuracy: 0.7051 - val_loss: 2.9371 - val_precision: 0.5909 - val_accuracy: 0.5769
# Epoch 31/500
# 10/10 [==============================] - 0s 49ms/step - loss: 2.8383 - precision: 0.7347 - accuracy: 0.7436 - val_loss: 2.9442 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 32/500
# 10/10 [==============================] - 1s 76ms/step - loss: 2.8244 - precision: 0.7333 - accuracy: 0.7179 - val_loss: 2.9401 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 33/500
# 10/10 [==============================] - 1s 77ms/step - loss: 2.8145 - precision: 0.6981 - accuracy: 0.7179 - val_loss: 2.9216 - val_precision: 0.6000 - val_accuracy: 0.5769
# Epoch 34/500
# 10/10 [==============================] - 1s 85ms/step - loss: 2.8542 - precision: 0.7143 - accuracy: 0.7179 - val_loss: 2.9176 - val_precision: 0.6000 - val_accuracy: 0.5769
# Epoch 35/500
# 10/10 [==============================] - 1s 89ms/step - loss: 2.8304 - precision: 0.7292 - accuracy: 0.7308 - val_loss: 2.9235 - val_precision: 0.6000 - val_accuracy: 0.5769
# Epoch 36/500
# 10/10 [==============================] - 1s 74ms/step - loss: 2.7604 - precision: 0.7708 - accuracy: 0.7821 - val_loss: 2.9381 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 37/500
# 10/10 [==============================] - 1s 77ms/step - loss: 2.7561 - precision: 0.7778 - accuracy: 0.7692 - val_loss: 2.9367 - val_precision: 0.6000 - val_accuracy: 0.5769
# Epoch 38/500
# 10/10 [==============================] - 1s 69ms/step - loss: 2.7693 - precision: 0.8182 - accuracy: 0.8077 - val_loss: 2.9634 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 39/500
# 10/10 [==============================] - 1s 80ms/step - loss: 2.7859 - precision: 0.7000 - accuracy: 0.7051 - val_loss: 2.9386 - val_precision: 0.6364 - val_accuracy: 0.6538
# Epoch 40/500
# 10/10 [==============================] - 1s 66ms/step - loss: 2.7668 - precision: 0.7200 - accuracy: 0.7308 - val_loss: 2.9300 - val_precision: 0.6364 - val_accuracy: 0.6538
# Epoch 41/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.7374 - precision: 0.7826 - accuracy: 0.7821 - val_loss: 2.9257 - val_precision: 0.6364 - val_accuracy: 0.6538
# Epoch 42/500
# 10/10 [==============================] - 1s 61ms/step - loss: 2.7548 - precision: 0.7083 - accuracy: 0.7051 - val_loss: 2.9222 - val_precision: 0.6190 - val_accuracy: 0.6154
# Epoch 43/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.7032 - precision: 0.8372 - accuracy: 0.8205 - val_loss: 2.9187 - val_precision: 0.6364 - val_accuracy: 0.6538
# Epoch 44/500
# 10/10 [==============================] - 1s 70ms/step - loss: 2.7981 - precision: 0.7037 - accuracy: 0.7308 - val_loss: 2.9256 - val_precision: 0.6364 - val_accuracy: 0.6538

# %% [markdown]
# ### Model Evalutation

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (28, 1)

# %%
y_test.sum()/len(y_test)
# Out:
# 0.7142857142857143

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9385 - precision: 0.7308 - accuracy: 0.7143
# [2.938516855239868, 0.7307692170143127, 0.7142857313156128]

# %% [markdown]
# ### Model Score Saving

# %%
model_runs_history = runs_history_loading()
# Out:
# Previous models scores:
#  [('tickers', ['loss', 'precision', 'accuracy']), (['NHIC', 'NFINW', 'PNTG', 'XP', 'ZGYHR', 'CHPMW', 'ACTC', 'BEAM'], [1.117479681968689, 0.7142857313156128, 0.6052631735801697]), (['MAXN', 'BUG', 'BRLI', 'FITBP', 'GOODN', 'TFFP', 'MDGSW', 'GRSVW'], [2.9750754833221436, 0.6486486196517944, 0.5813953280448914]), (['INAQ', 'MKD', 'ACAM', 'CABA', 'FTIV', 'ONCR', 'RADI', 'NFINW'], [2.2389369010925293, 0.8333333134651184, 0.7631579041481018])]

# %%
model_runs_history
# Out:
# [('tickers', ['loss', 'precision', 'accuracy']),
#  (['NHIC', 'NFINW', 'PNTG', 'XP', 'ZGYHR', 'CHPMW', 'ACTC', 'BEAM'],
#   [1.117479681968689, 0.7142857313156128, 0.6052631735801697]),
#  (['MAXN', 'BUG', 'BRLI', 'FITBP', 'GOODN', 'TFFP', 'MDGSW', 'GRSVW'],
#   [2.9750754833221436, 0.6486486196517944, 0.5813953280448914]),
#  (['INAQ', 'MKD', 'ACAM', 'CABA', 'FTIV', 'ONCR', 'RADI', 'NFINW'],
#   [2.2389369010925293, 0.8333333134651184, 0.7631579041481018])]

# %%
model_runs_history.append((list(stocks_0_1_df.ticker.unique()),model.evaluate(X_test, y_test)))
# Out:
# 1/1 [==============================] - ETA: 0s - loss: 2.9385 - precision: 0.7308 - accuracy: 0.71 - 0s 3ms/step - loss: 2.9385 - precision: 0.7308 - accuracy: 0.7143

# %%
runs_history_saving(model_runs_history)
# Out:
# History Saving Complete!
# File saved as: charles_companies_0_1_model_history
# File location:models_histories

# %%
[(['CHB', 'LESL', 'CDAK', 'HYAC'],
  [1.73867666721344, 0.8999999761581421, 0.9166666865348816]),
 (['CHB', 'LESL', 'CDAK', 'HYAC'],
  ['loss', 'precision', 'accuracy'],
  [1.73867666721344, 0.8999999761581421, 0.9166666865348816])]
# Out:
# [(['CHB', 'LESL', 'CDAK', 'HYAC'],
#   [1.73867666721344, 0.8999999761581421, 0.9166666865348816]),
#  (['CHB', 'LESL', 'CDAK', 'HYAC'],
#   ['loss', 'precision', 'accuracy'],
#   [1.73867666721344, 0.8999999761581421, 0.9166666865348816])]
