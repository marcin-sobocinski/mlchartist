# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import joblib
import os
import random

# %% [markdown]
# ====================================================================================================
#
# **Goal : gather similar companies according to their features and number of trading days**
#
# **Use : provide coherent and meaningful data to model**
#
#
# **(_Ideal_ : develop tailored model to each type of groups)**
#
# ====================================================================================================

# %% [markdown]
# # Anaysis of Companies Age from `nasdaq_us_stats.xls`

# %%
#!!!Path might not be the same!!!

meta_df = pd.read_csv('../raw_data/metadata/nasdaq_us_stats.xls')

# %%
meta_df.head()
# Out:
#    Unnamed: 0     stock  days  min_close  max_close  start_date    end_date
# 0           0   AACG.US  3165    0.21703      3.850  2008-01-28  2021-01-25
# 1           1   AACQ.US    96    9.62000     11.070  2020-09-08  2021-01-25
# 2           2  AACQU.US   134   10.00000     11.900  2020-07-15  2021-01-25
# 3           3  AACQW.US    95    1.07500      2.580  2020-09-09  2021-01-25
# 4           4    AAL.US  1793    9.04000     56.989  2013-12-10  2021-01-25

# %%
meta_df.describe()
# Out:
#         Unnamed: 0          days    min_close     max_close
# count  3921.000000   3921.000000  3921.000000  3.921000e+03
# mean   1960.000000   1876.186942     8.257047  6.181576e+06
# std    1132.039531   1795.084440    16.268917  3.863434e+08
# min       0.000000      1.000000     0.001000  2.400000e-01
# 25%     980.000000    312.000000     1.490000  1.438700e+01
# 50%    1960.000000   1286.000000     5.010000  2.880000e+01
# 75%    2940.000000   3775.000000    10.384000  6.533000e+01
# max    3920.000000  12879.000000   647.290000  2.419200e+10

# %%
meta_df = meta_df[['stock', 'days', 'min_close', 'max_close']]

# %% [markdown]
# ## Company age classification

# %%
meta_df['range_price'] = meta_df['max_close'] - meta_df['min_close']
meta_df['years'] = meta_df['days']/365

# %%
clean_meta_df = meta_df[['stock', 'years', 'range_price']]

# %%
sns.histplot(clean_meta_df['years'], binwidth=1)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %% [markdown]
# 👆👆**Anomaly at less than 1 year and 10 year old companies**👆👆

# %%
bins = [0, 1, 5, 10, 15, 20, 25, 30, 40]

clean_meta_df['company_vintage'] = pd.cut(meta_df['years'].copy(), 
                                          bins)                            # A company aged of 1Y and one day is
                                          #labels=['(0, 1]','(1, 5]',       # part of the '(1, 5]' class
                                          #        '(5, 10]', '(10, 15]',
                                          #        '(15, 20]', '(20, 25]',
                                          #        '(25, 30]', '(30, 40]'])
print(clean_meta_df['company_vintage'])
# Out:
# 0        (5, 10]
# 1         (0, 1]
# 2         (0, 1]
# 3         (0, 1]
# 4         (1, 5]
# 5        (5, 10]
# 6        (5, 10]
# 7       (10, 15]
# 8       (25, 30]
# 9       (10, 15]
# 10      (10, 15]
# 11      (10, 15]
# 12        (0, 1]
# 13        (0, 1]
# 14        (1, 5]
# 15      (10, 15]
# 16      (10, 15]
# 17        (0, 1]
# 18        (0, 1]
# 19        (1, 5]
# 20       (5, 10]
# 21        (0, 1]
# 22        (0, 1]
# 23        (0, 1]
# 24      (10, 15]
# 25        (0, 1]
# 26        (0, 1]
# 27        (0, 1]
# 28        (1, 5]
# 29        (0, 1]
#           ...
# 3891     (5, 10]
# 3892     (5, 10]
# 3893      (0, 1]
# 3894      (0, 1]
# 3895      (0, 1]
# 3896      (0, 1]
# 3897      (0, 1]
# 3898      (1, 5]
# 3899    (20, 25]
# 3900      (1, 5]
# 3901      (0, 1]
# 3902      (0, 1]
# 3903      (0, 1]
# 3904    (10, 15]
# 3905    (10, 15]
# 3906      (1, 5]
# 3907      (1, 5]
# 3908      (1, 5]
# 3909     (5, 10]
# 3910      (0, 1]
# 3911      (0, 1]
# 3912      (0, 1]
# 3913      (0, 1]
# 3914      (1, 5]
# 3915      (1, 5]
# 3916    (10, 15]
# 3917     (5, 10]
# 3918      (1, 5]
# 3919      (1, 5]
# 3920      (1, 5]
# Name: company_vintage, Length: 3921, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 5] < (5, 10] < (10, 15] < (15, 20] < (20, 25] < (25, 30] < (30, 40]]
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
clean_meta_df['company_vintage'].apply(str)
print(clean_meta_df.info())
clean_meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
# stock              3921 non-null object
# years              3921 non-null float64
# range_price        3921 non-null float64
# company_vintage    3921 non-null category
# dtypes: category(1), float64(2), object(1)
# memory usage: 95.9+ KB
# None
#       stock     years  range_price company_vintage
# 0   AACG.US  8.671233      3.63297         (5, 10]
# 1   AACQ.US  0.263014      1.45000          (0, 1]
# 2  AACQU.US  0.367123      1.90000          (0, 1]
# 3  AACQW.US  0.260274      1.50500          (0, 1]
# 4    AAL.US  4.912329     47.94900          (1, 5]

# %% [markdown]
# ## Classification Results

# %%
sns.histplot(data=clean_meta_df, x='years', binwidth=1, hue='company_vintage')
#plt.savefig('companies_age_classification.pdf', dpi=1200)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Count'>

# %%
clean_meta_df.groupby('company_vintage')['stock'].count()
# Out:
# company_vintage
# (0, 1]      1069
# (1, 5]      1252
# (5, 10]      564
# (10, 15]     950
# (15, 20]      32
# (20, 25]      37
# (25, 30]      13
# (30, 40]       4
# Name: stock, dtype: int64

# %% [markdown]
# ### Saving List of Companies Name via `joblib`

# %%
stocks_bin_1 = []
stocks_bin_2 = []
stocks_bin_3 = []
stocks_bin_4 = []
stocks_bin_5 = []
stocks_bin_6 = []
stocks_bin_7 = []
stocks_bin_8 = []

for idx, row in clean_meta_df.iterrows():
    x = row['years']                                            # <=> ['days']/365
    st = row['stock'].replace('.US', '')
    
    #print(idx, x, row['stock'])
    if x <= 1 : stocks_bin_1.append(st)
    elif x > 1 and x <= 5: stocks_bin_2.append(st)
    elif x > 5 and x <= 10: stocks_bin_3.append(st)
    elif x > 10 and x <= 15: stocks_bin_4.append(st)        
    elif x > 15 and x <= 20: stocks_bin_5.append(st)        
    elif x > 20 and x <= 25: stocks_bin_6.append(st)        
    elif x > 25 and x <= 30: stocks_bin_7.append(st)        
    elif x > 30: stocks_bin_8.append(st)
    
print(f"Number of companies with less than a year of history: {len(stocks_bin_1)}")
print(f"Number of companies with between a year and 5 years of history: {len(stocks_bin_2)}")    
print(f"Number of companies with between 5 years and 10 years of history: {len(stocks_bin_3)}")
print(f"Number of companies with between 10 years and 15 years of history: {len(stocks_bin_4)}")
print(f"Number of companies with between 15 years and 20 years of history: {len(stocks_bin_5)}")
print(f"Number of companies with between 20 years and 25 years of history: {len(stocks_bin_6)}")
print(f"Number of companies with between 25 years and 30 years of history: {len(stocks_bin_7)}")
print(f"Number of companies with more than 30 years of history: {len(stocks_bin_8)}")

stock_bins = [stocks_bin_1, stocks_bin_2, stocks_bin_3,
              stocks_bin_4, stocks_bin_5, stocks_bin_6,
              stocks_bin_7, stocks_bin_8]
# Out:
# Number of companies with less than a year of history: 1069
# Number of companies with between a year and 5 years of history: 1252
# Number of companies with between 5 years and 10 years of history: 564
# Number of companies with between 10 years and 15 years of history: 950
# Number of companies with between 15 years and 20 years of history: 32
# Number of companies with between 20 years and 25 years of history: 37
# Number of companies with between 25 years and 30 years of history: 13
# Number of companies with more than 30 years of history: 4

# %%
stock_bins
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# ❗❗❗**You should check the path you want to save the `stock_bins` list**❗❗❗
#
# (The `metadata` directory is where I saved the `nasdaq_us_stats.xls` csv file of Ian)

# %%
joblib.dump(stock_bins, '../raw_data/metadata/tickers_per_history_lenght__list')
# Out:
# ['../raw_data/metadata/tickers_per_history_lenght__list']

# %%
stocks_tickers = joblib.load('../raw_data/metadata/tickers_per_history_lenght__list')
stocks_tickers
# Out:
# [['AACQ',
#   'AACQU',
#   'AACQW',
#   'ABCL',
#   'ABCM',
#   'ABNB',
#   'ABST',
#   'ACAC',
#   'ACACU',
#   'ACACW',
#   'ACAM',
#   'ACAMU',
#   'ACAMW',
#   'ACCD',
#   'ACEV',
#   'ACEVU',
#   'ACEVW',
#   'ACKIU',
#   'ACTC',
#   'ACTCU',
#   'ACTCW',
#   'ADERU',
#   'ADILW',
#   'ADOC',
#   'ADOCR',
#   'ADOCU',
#   'ADOCW',
#   'ADTX',
#   'ADV',
#   'ADVWW',
#   'ADXN',
#   'AEACU',
#   'AEPPZ',
#   'AFBI',
#   'AFIB',
#   'AFINO',
#   'AFRM',
#   'AGBA',
#   'AGBAR',
#   'AGBAU',
#   'AGBAW',
#   'AGC',
#   'AGCUU',
#   'AGCWW',
#   'AGNCO',
#   'AGNCP',
#   'AHAC',
#   'AHACU',
#   'AHACW',
#   'AIH',
#   'AIRTP',
#   'AIRTW',
#   'AKICU',
#   'AKU',
#   'AKUS',
#   'ALAC',
#   'ALACR',
#   'ALACU',
#   'ALGM',
#   'ALGS',
#   'ALRS',
#   'ALTUU',
#   'ALVR',
#   'ALXO',
#   'AMCIU',
#   'AMCIW',
#   'AMHC',
#   'AMHCU',
#   'AMHCW',
#   'AMST',
#   'AMTI',
#   'AMYT',
#   'ANDA',
#   'ANDAR',
#   'ANDAU',
#   'ANDAW',
#   'ANNX',
#   'ANPC',
#   'AOUT',
#   'API',
#   'APRE',
#   'APXT',
#   'APXTU',
#   'APXTW',
#   'ARBG',
#   'ARBGU',
#   'ARBGW',
#   'ARKO',
#   'ARKOW',
#   'ARQT',
#   'ARRY',
#   'ARTLW',
#   'ARYA',
#   'ASLE',
#   'ASLEW',
#   'ASO',
#   'ATCXW',
#   'ATHA',
#   'ATNF',
#   'AUBAP',
#   'AUVI',
#   'AVCTW',
#   'AVGOP',
#   'AVIR',
#   'AVO',
#   'AYLA',
#   'AZYO',
#   'BCAB',
#   'BCDA',
#   'BCDAW',
#   'BCTG',
#   'BCYPU',
#   'BDSX',
#   'BDTX',
#   'BEAM',
#   'BEEMW',
#   'BENEU',
#   'BFRA',
#   'BHFAN',
#   'BHFAO',
#   'BHSE',
#   'BHSEU',
#   'BHSEW',
#   'BIGC',
#   'BIVI',
#   'BLCT',
#   'BLI',
#   'BLSA',
#   'BLTSU',
#   'BLU',
#   'BLUWU',
#   'BNR',
#   'BNTX',
#   'BOWX',
#   'BOWXU',
#   'BOWXW',
#   'BPYPN',
#   'BPYPO',
#   'BREZ',
#   'BREZR',
#   'BREZU',
#   'BREZW',
#   'BRLI',
#   'BRLIR',
#   'BRLIU',
#   'BRLIW',
#   'BRP',
#   'BRPA',
#   'BRPAR',
#   'BRPAU',
#   'BRPAW',
#   'BRQS',
#   'BSBK',
#   'BSCU',
#   'BSJS',
#   'BSML',
#   'BSMM',
#   'BSMN',
#   'BSMO',
#   'BSMP',
#   'BSMQ',
#   'BSMR',
#   'BSMS',
#   'BSMT',
#   'BSMU',
#   'BSY',
#   'BTAQ',
#   'BTAQU',
#   'BTAQW',
#   'BTBT',
#   'BTRS',
#   'BTRSW',
#   'BTWN',
#   'BTWNU',
#   'BTWNW',
#   'BUG',
#   'BWAC',
#   'BWACU',
#   'BWACW',
#   'BWMX',
#   'BXRX',
#   'CABA',
#   'CALB',
#   'CALT',
#   'CAN',
#   'CAPA',
#   'CAPAU',
#   'CAPAW',
#   'CCCC',
#   'CCNEP',
#   'CD',
#   'CDAK',
#   'CEFA',
#   'CERE',
#   'CEREW',
#   'CERT',
#   'CFAC',
#   'CFACU',
#   'CFACW',
#   'CFB',
#   'CFFAU',
#   'CFII',
#   'CFIIU',
#   'CFIIW',
#   'CFIVU',
#   'CGEM',
#   'CGRO',
#   'CGROU',
#   'CGROW',
#   'CHB',
#   'CHPM',
#   'CHPMU',
#   'CHPMW',
#   'CIIC',
#   'CIICU',
#   'CIICW',
#   'CLDB',
#   'CLEU',
#   'CLNN',
#   'CLNNW',
#   'CLOV',
#   'CLOVW',
#   'CLSK',
#   'CLVR',
#   'CLVRW',
#   'CMCTP',
#   'CMLF',
#   'CMLFU',
#   'CMLFW',
#   'CMPI',
#   'CMPS',
#   'CNNB',
#   'CNSP',
#   'CNTG',
#   'CNXC',
#   'COFS',
#   'COMS',
#   'COMSW',
#   'CONX',
#   'CONXU',
#   'CONXW',
#   'COOLU',
#   'CPZ',
#   'CREXW',
#   'CRNC',
#   'CRSA',
#   'CRSAU',
#   'CRSAW',
#   'CRSR',
#   'CRTD',
#   'CRTDW',
#   'CSSEN',
#   'CTAQU',
#   'CTEC',
#   'CURI',
#   'CURIW',
#   'CVAC',
#   'CVLB',
#   'CXDO',
#   'CYTH',
#   'CYTHW',
#   'DADA',
#   'DBDR',
#   'DBDRU',
#   'DBDRW',
#   'DCBO',
#   'DCOMP',
#   'DCRB',
#   'DCRBU',
#   'DCRBW',
#   'DCT',
#   'DCTH',
#   'DDMXU',
#   'DDOG',
#   'DEMZ',
#   'DFH',
#   'DFHT',
#   'DFHTU',
#   'DFHTW',
#   'DFPH',
#   'DFPHU',
#   'DFPHW',
#   'DGNS',
#   'DKNG',
#   'DLCAU',
#   'DLPNW',
#   'DMXF',
#   'DPHCU',
#   'DRTT',
#   'DRVN',
#   'DSAC',
#   'DSACU',
#   'DSACW',
#   'DUNEU',
#   'DUO',
#   'DUOT',
#   'DWAW',
#   'DWCR',
#   'DWEQ',
#   'DWUS',
#   'DYN',
#   'EACPU',
#   'EAR',
#   'EBC',
#   'EBON',
#   'ECOLW',
#   'ECOW',
#   'EDOC',
#   'EDTK',
#   'EDTXU',
#   'EDUT',
#   'EH',
#   'ELDN',
#   'EMXF',
#   'ENFAU',
#   'ENTXW',
#   'ENVIU',
#   'EOSE',
#   'EOSEW',
#   'EPHYU',
#   'EQOS',
#   'EQOSW',
#   'ERES',
#   'ERESU',
#   'ERESW',
#   'ESSC',
#   'ESSCR',
#   'ESSCU',
#   'ESSCW',
#   'ETAC',
#   'ETACU',
#   'ETACW',
#   'ETNB',
#   'EUCR',
#   'EUCRU',
#   'EUCRW',
#   'EUSGU',
#   'EWEB',
#   'EWJE',
#   'EWJV',
#   'EXPC',
#   'EXPCU',
#   'EXPCW',
#   'FATBP',
#   'FATBW',
#   'FCAC',
#   'FCACU',
#   'FCACW',
#   'FCNCP',
#   'FDMT',
#   'FDUSG',
#   'FHTX',
#   'FICS',
#   'FIII',
#   'FIIIU',
#   'FIIIW',
#   'FINMU',
#   'FITBO',
#   'FITBP',
#   'FLACU',
#   'FLUX',
#   'FMBIO',
#   'FMBIP',
#   'FMTX',
#   'FOXWU',
#   'FPXE',
#   'FREE',
#   'FREEW',
#   'FREQ',
#   'FRG',
#   'FRGAP',
#   'FRHC',
#   'FRLN',
#   'FROG',
#   'FSDC',
#   'FSEA',
#   'FSRV',
#   'FSRVU',
#   'FSRVW',
#   'FTCVU',
#   'FTHM',
#   'FTIV',
#   'FTIVU',
#   'FTIVW',
#   'FTOC',
#   'FTOCU',
#   'FTOCW',
#   'FULTP',
#   'FUSN',
#   'FVAM',
#   'FXNC',
#   'GAN',
#   'GBIO',
#   'GBNY',
#   'GBS',
#   'GCMG',
#   'GDRX',
#   'GDYNW',
#   'GFNSZ',
#   'GHIV',
#   'GHIVU',
#   'GHIVW',
#   'GHVIU',
#   'GLADL',
#   'GLAQU',
#   'GLSI',
#   'GLTO',
#   'GMBL',
#   'GMBLW',
#   'GMBTU',
#   'GMHIU',
#   'GMIIU',
#   'GNACU',
#   'GNOG',
#   'GNOGW',
#   'GNRS',
#   'GNRSU',
#   'GNRSW',
#   'GOCO',
#   'GOODN',
#   'GOVX',
#   'GOVXW',
#   'GP',
#   'GPACU',
#   'GRAY',
#   'GRCL',
#   'GRCY',
#   'GRCYU',
#   'GRCYW',
#   'GRIL',
#   'GRNV',
#   'GRNVR',
#   'GRNVU',
#   'GRNVW',
#   'GRSV',
#   'GRSVU',
#   'GRSVW',
#   'GRTX',
#   'GRWG',
#   'GSAQU',
#   'GTH',
#   'GWAC',
#   'GWACU',
#   'GWACW',
#   'GXGX',
#   'GXGXU',
#   'GXGXW',
#   'GXTG',
#   'HAAC',
#   'HAACU',
#   'HAACW',
#   'HAPP',
#   'HBT',
#   'HCACU',
#   'HCAR',
#   'HCARU',
#   'HCARW',
#   'HCCCU',
#   'HCCH',
#   'HCCHR',
#   'HCCHU',
#   'HCCHW',
#   'HCCOU',
#   'HCDI',
#   'HCICU',
#   'HEC',
#   'HECCU',
#   'HECCW',
#   'HERD',
#   'HERO',
#   'HFEN',
#   'HGBL',
#   'HLAHU',
#   'HLXA',
#   'HMCOU',
#   'HOL',
#   'HOLUU',
#   'HOLUW',
#   'HRMY',
#   'HSAQ',
#   'HTIA',
#   'HTLFP',
#   'HTOO',
#   'HTOOW',
#   'HUDI',
#   'HUGE',
#   'HUIZ',
#   'HWCPZ',
#   'HYAC',
#   'HYACU',
#   'HYACW',
#   'HYFM',
#   'HYMCZ',
#   'IBBJ',
#   'IBEX',
#   'IBKR',
#   'IBTA',
#   'IBTB',
#   'IBTD',
#   'IBTE',
#   'IBTF',
#   'IBTG',
#   'IBTH',
#   'IBTI',
#   'IBTJ',
#   'IBTK',
#   'IGAC',
#   'IGACU',
#   'IGACW',
#   'IGMS',
#   'IHYF',
#   'IIIIU',
#   'IIVIP',
#   'IKT',
#   'IMAB',
#   'IMACW',
#   'IMNM',
#   'IMRA',
#   'IMTXW',
#   'IMVT',
#   'INAQ',
#   'INAQU',
#   'INAQW',
#   'INBKZ',
#   'INBX',
#   'INKAU',
#   'INM',
#   'INTZ',
#   'INVO',
#   'INZY',
#   'IPA',
#   'IPDN',
#   'IPHA',
#   'ISUN',
#   'ITAC',
#   'ITACU',
#   'ITACW',
#   'ITOS',
#   'IVA',
#   'JAMF',
#   'JCICU',
#   'JFU',
#   'JMPNZ',
#   'JOET',
#   'JUPW',
#   'JUPWW',
#   'JYAC',
#   'KAIRU',
#   'KBLMU',
#   'KBNT',
#   'KBNTW',
#   'KC',
#   'KELYB',
#   'KINZU',
#   'KLAQU',
#   'KMPH',
#   'KNTE',
#   'KOR',
#   'KRBP',
#   'KRKR',
#   'KRMD',
#   'KRON',
#   'KROS',
#   'KSMT',
#   'KSMTU',
#   'KSMTW',
#   'KYMR',
#   'LACQU',
#   'LANDO',
#   'LATN',
#   'LATNU',
#   'LATNW',
#   'LAZR',
#   'LAZRW',
#   'LBRDP',
#   'LBTYB',
#   'LCAHU',
#   'LCAP',
#   'LCAPU',
#   'LCAPW',
#   'LCY',
#   'LCYAU',
#   'LCYAW',
#   'LDEM',
#   'LEGN',
#   'LEGOU',
#   'LESL',
#   'LEVLP',
#   'LEXX',
#   'LEXXW',
#   'LFACU',
#   'LFACW',
#   'LFTR',
#   'LFTRU',
#   'LFTRW',
#   'LGHL',
#   'LGHLW',
#   'LI',
#   'LIVK',
#   'LIVKU',
#   'LIVKW',
#   'LIXT',
#   'LIXTW',
#   'LIZI',
#   'LJAQU',
#   'LMACU',
#   'LMFAW',
#   'LMNL',
#   'LMPX',
#   'LNSR',
#   'LOAC',
#   'LOACR',
#   'LOACU',
#   'LOACW',
#   'LOTZ',
#   'LOTZW',
#   'LPRO',
#   'LSAQ',
#   'LSEA',
#   'LSEAW',
#   'LSXMB',
#   'LTRN',
#   'LTRPB',
#   'LUNG',
#   'LUXA',
#   'LUXAU',
#   'LUXAW',
#   'LVGO',
#   'LWACU',
#   'LXEH',
#   'LYRA',
#   'MAAC',
#   'MAACU',
#   'MAACW',
#   'MACU',
#   'MACUU',
#   'MACUW',
#   'MASS',
#   'MAXN',
#   'MAYS',
#   'MBINO',
#   'MBNKP',
#   'MCAC',
#   'MCACR',
#   'MCACU',
#   'MCADU',
#   'MCBS',
#   'MCFE',
#   'MCMJ',
#   'MCMJW',
#   'MDGSW',
#   'MDIA',
#   'MDNA',
#   'MDRRP',
#   'MDWT',
#   'MDXG',
#   'METXW',
#   'MKD',
#   'MLAC',
#   'MLACU',
#   'MLACW',
#   'MNCLU',
#   'MNPR',
#   'MNSBP',
#   'MNTK',
#   'MODV',
#   'MOHO',
#   'MONCU',
#   'MOTN',
#   'MOTNU',
#   'MOTNW',
#   'MRACU',
#   'MRM',
#   'MRVI',
#   'MSGM',
#   'MTACU',
#   'MTCR',
#   'MUDSU',
#   'NAACU',
#   'NARI',
#   'NBAC',
#   'NBACR',
#   'NBACU',
#   'NBACW',
#   'NBTX',
#   'NCNO',
#   'NEBCU',
#   'NEPH',
#   'NFIN',
#   'NFINU',
#   'NFINW',
#   'NGAC',
#   'NGACU',
#   'NGACW',
#   'NGMS',
#   'NHIC',
#   'NHICU',
#   'NHICW',
#   'NKTX',
#   'NMMC',
#   'NMMCU',
#   'NMMCW',
#   'NMTR',
#   'NNOX',
#   'NOACU',
#   'NOVS',
#   'NOVSU',
#   'NOVSW',
#   'NPA',
#   'NPAUU',
#   'NPAWW',
#   'NRIX',
#   'NTRSO',
#   'NUZE',
#   'NYMTM',
#   'OAS',
#   'OCAXU',
#   'OCFCP',
#   'OCG',
#   'OEPWU',
#   'OFSSG',
#   'OFSSI',
#   'OLB',
#   'OLMA',
#   'OM',
#   'OMEG',
#   'ONCR',
#   'ONDS',
#   'ONEM',
#   'ONEW',
#   'OPEN',
#   'OPENW',
#   'OPESU',
#   'OPINL',
#   'OPRT',
#   'OPT',
#   'ORIC',
#   'ORPH',
#   'ORSNR',
#   'ORSNU',
#   'OSTRU',
#   'OTRA',
#   'OTRAU',
#   'OTRAW',
#   'OTRKP',
#   'OXLCP',
#   'OYST',
#   'OZON',
#   'PACXU',
#   'PAEWW',
#   'PAIC',
#   'PAICU',
#   'PAICW',
#   'PAND',
#   'PAQCU',
#   'PASG',
#   'PAX',
#   'PAYA',
#   'PAYAW',
#   'PBLA',
#   'PCSA',
#   'PCVX',
#   'PDEV',
#   'PFHD',
#   'PGNY',
#   'PHAR',
#   'PHAT',
#   'PHIC',
#   'PHICU',
#   'PHICW',
#   'PLC',
#   'PLIN',
#   'PLRX',
#   'PLTK',
#   'PMVP',
#   'PNFPP',
#   'PNNTG',
#   'PNTG',
#   'POSH',
#   'POTX',
#   'POWRU',
#   'POWW',
#   'PPD',
#   'PPGHU',
#   'PRAX',
#   'PRCH',
#   'PRCHW',
#   'PRFX',
#   'PRLD',
#   'PROG',
#   'PRPLW',
#   'PRSRU',
#   'PRTC',
#   'PSAC',
#   'PSACU',
#   'PSACW',
#   'PSM',
#   'PSTX',
#   'PTACU',
#   'PTICU',
#   'PTON',
#   'PTPI',
#   'PTRS',
#   'PTVE',
#   'PUBM',
#   'PXSAP',
#   'PXSAW',
#   'PYPD',
#   'QELL',
#   'QELLU',
#   'QELLW',
#   'QH',
#   'QK',
#   'QLI',
#   'QMCO',
#   'QQC',
#   'QQD',
#   'QQQJ',
#   'QQQM',
#   'QQQN',
#   'QRTEP',
#   'QYLG',
#   'RAACU',
#   'RACA',
#   'RADI',
#   'RAPT',
#   'RCEL',
#   'RCHG',
#   'RCHGU',
#   'RCHGW',
#   'RDIB',
#   'REYN',
#   'RIDE',
#   'RIDEW',
#   'RILYL',
#   'RILYM',
#   'RILYN',
#   'RILYP',
#   'RLAY',
#   'RMGBU',
#   'RNA',
#   'RNLX',
#   'ROCC',
#   'ROCCU',
#   'ROCCW',
#   'ROCH',
#   'ROCHU',
#   'ROCHW',
#   'ROOT',
#   'RPRX',
#   'RPTX',
#   'RSSS',
#   'RSVA',
#   'RSVAU',
#   'RSVAW',
#   'RVMD',
#   'RVPH',
#   'RVPHW',
#   'RXT',
#   'RZLT',
#   'SABRP',
#   'SAII',
#   'SAIIU',
#   'SAIIW',
#   'SAMA',
#   'SAMAU',
#   'SAMAW',
#   'SBNYP',
#   'SBTX',
#   'SCOAU',
#   'SCPS',
#   'SDC',
#   'SDGR',
#   'SEER',
#   'SFT',
#   'SFTTW',
#   'SGAM',
#   'SGAMU',
#   'SGAMW',
#   'SGLBW',
#   'SGTX',
#   'SHACU',
#   'SHC',
#   'SHIPZ',
#   'SHLD',
#   'SIGIP',
#   'SITM',
#   'SIVBP',
#   'SJ',
#   'SKYU',
#   'SLCRU',
#   'SLN',
#   'SMCI',
#   'SMID',
#   'SMMC',
#   'SMMCU',
#   'SMMCW',
#   'SMTI',
#   'SNGXW',
#   'SNRHU',
#   'SNUG',
#   'SPQQ',
#   'SPRB',
#   'SPT',
#   'SQFT',
#   'SRAC',
#   'SRACU',
#   'SRACW',
#   'SRSA',
#   'SRSAU',
#   'SRSAW',
#   'SSPK',
#   'SSPKU',
#   'SSPKW',
#   'STEP',
#   'STRRP',
#   'STSA',
#   'STTK',
#   'STWO',
#   'STWOU',
#   'STWOW',
#   'SUMO',
#   'SV',
#   'SVAC',
#   'SVACU',
#   'SVACW',
#   'SVFAU',
#   'SVOKU',
#   'SVSVU',
#   'SVSVW',
#   'SWETU',
#   'SWKH',
#   'SWTX',
#   'SYTA',
#   'SYTAW',
#   'TARS',
#   'TBKCP',
#   'TDACU',
#   'TECTP',
#   'TEKK',
#   'TEKKU',
#   'TEKKW',
#   'TELA',
#   'TFFP',
#   'THBR',
#   'THBRU',
#   'THBRW',
#   'THCA',
#   'THCAU',
#   'THCAW',
#   'THCBU',
#   'THRY',
#   'THTX',
#   'TIG',
#   'TLMD',
#   'TLMDW',
#   'TLS',
#   'TMKRU',
#   'TMPM',
#   'TMPMU',
#   'TMPMW',
#   'TMTS',
#   'TMTSU',
#   'TMTSW',
#   'TOMZ',
#   'TOTA',
#   'TOTAR',
#   'TOTAW',
#   'TRIT',
#   'TRITW',
#   'TSHA',
#   'TSIA',
#   'TSIAU',
#   'TSIAW',
#   'TVACU',
#   'TWCT',
#   'TWCTU',
#   'TWCTW',
#   'TXG',
#   'TZACU',
#   'TZPSU',
#   'UCBIO',
#   'UCL',
#   'UCYB',
#   'UK',
#   'UKOMW',
#   'UPST',
#   'USAT',
#   'USXF',
#   'VACQ',
#   'VACQU',
#   'VACQW',
#   'VCKAU',
#   'VCVC',
#   'VCVCU',
#   'VCVCW',
#   'VERX',
#   'VERY',
#   'VETS',
#   'VIACA',
#   ...],
#  ['AAL',
#   'ABEO',
#   'ABTX',
#   'ACBI',
#   'ACET',
#   'ACGLO',
#   'ACGLP',
#   'ACIA',
#   'ACIU',
#   'ACMR',
#   'ACRS',
#   'ADAP',
#   'ADES',
#   'ADIL',
#   'ADMA',
#   'ADMS',
#   'ADPT',
#   'ADVM',
#   'AEMD',
#   'AEPPL',
#   'AERI',
#   'AESE',
#   'AEYE',
#   'AFIN',
#   'AFINP',
#   'AFMD',
#   'AFYA',
#   'AGFS',
#   'AGLE',
#   'AGMH',
#   'AGNCM',
#   'AGNCN',
#   'AGRX',
#   'AGTC',
#   'AHCO',
#   'AIHS',
#   'AIQ',
#   'AIRG',
#   'AKBA',
#   'AKER',
#   'AKRO',
#   'AKTS',
#   'AKTX',
#   'ALACW',
#   'ALDX',
#   'ALEC',
#   'ALJJ',
#   'ALLK',
#   'ALLO',
#   'ALNA',
#   'ALPN',
#   'ALRM',
#   'ALRN',
#   'ALTA',
#   'ALTM',
#   'ALTR',
#   'ALTY',
#   'ALYA',
#   'AMAL',
#   'AMCA',
#   'AMCI',
#   'AMEH',
#   'AMPH',
#   'AMRHW',
#   'AMRK',
#   'AMTB',
#   'AMTBB',
#   'ANAB',
#   'ANCN',
#   'ANY',
#   'APHA',
#   'APLS',
#   'APLT',
#   'APM',
#   'APOP',
#   'APOPW',
#   'APPF',
#   'APPN',
#   'APTX',
#   'APVO',
#   'AQB',
#   'AQMS',
#   'AQST',
#   'ARAV',
#   'ARCE',
#   'ARDS',
#   'ARDX',
#   'AREC',
#   'ARGX',
#   'ARPO',
#   'ARTL',
#   'ARVN',
#   'ASET',
#   'ASLN',
#   'ASND',
#   'ASPU',
#   'ASRVP',
#   'ATCX',
#   'ATEX',
#   'ATIF',
#   'ATNFW',
#   'ATNX',
#   'ATOM',
#   'ATRA',
#   'ATXI',
#   'AUPH',
#   'AUTL',
#   'AVCO',
#   'AVCT',
#   'AVGR',
#   'AVRO',
#   'AVXL',
#   'AXLA',
#   'AXNX',
#   'AXSM',
#   'AY',
#   'AYTU',
#   'AZRX',
#   'BAND',
#   'BANFP',
#   'BANX',
#   'BATRA',
#   'BATRK',
#   'BBCP',
#   'BBIG',
#   'BBIO',
#   'BCEL',
#   'BCLI',
#   'BCOW',
#   'BCYC',
#   'BFC',
#   'BFI',
#   'BFIIW',
#   'BFIT',
#   'BFST',
#   'BGNE',
#   'BGRN',
#   'BHAT',
#   'BHF',
#   'BHFAL',
#   'BHFAP',
#   'BHTG',
#   'BILI',
#   'BIOC',
#   'BKYI',
#   'BL',
#   'BLBD',
#   'BLCM',
#   'BLCN',
#   'BLFS',
#   'BLNK',
#   'BLNKW',
#   'BLPH',
#   'BMLP',
#   'BMRA',
#   'BNDW',
#   'BNGO',
#   'BNGOW',
#   'BNTC',
#   'BOKFL',
#   'BOMN',
#   'BOTZ',
#   'BOXL',
#   'BPMC',
#   'BPRN',
#   'BPYPP',
#   'BPYU',
#   'BPYUP',
#   'BROG',
#   'BROGW',
#   'BRY',
#   'BSGM',
#   'BSJQ',
#   'BSVN',
#   'BTAI',
#   'BTEC',
#   'BVXV',
#   'BWAY',
#   'BWB',
#   'BWFG',
#   'BYND',
#   'BYSI',
#   'BZUN',
#   'CACG',
#   'CALA',
#   'CARA',
#   'CARE',
#   'CARG',
#   'CARV',
#   'CASA',
#   'CATB',
#   'CATC',
#   'CATH',
#   'CBAY',
#   'CBFV',
#   'CBMB',
#   'CBNK',
#   'CBTX',
#   'CCAP',
#   'CCB',
#   'CCD',
#   'CCNC',
#   'CCRC',
#   'CDC',
#   'CDEV',
#   'CDK',
#   'CDL',
#   'CDLX',
#   'CDMOP',
#   'CDNA',
#   'CDTX',
#   'CELC',
#   'CELH',
#   'CERC',
#   'CETX',
#   'CETXP',
#   'CETXW',
#   'CEY',
#   'CEZ',
#   'CFA',
#   'CFBI',
#   'CFMS',
#   'CFO',
#   'CFRX',
#   'CGBD',
#   'CGC',
#   'CHEK',
#   'CHEKZ',
#   'CHMA',
#   'CHNA',
#   'CHNG',
#   'CHNGU',
#   'CHRS',
#   'CHSCL',
#   'CHSCM',
#   'CHSCN',
#   'CHX',
#   'CIBR',
#   'CID',
#   'CIGI',
#   'CIH',
#   'CIL',
#   'CIZ',
#   'CKPT',
#   'CLBK',
#   'CLGN',
#   'CLLS',
#   'CLOU',
#   'CLPS',
#   'CLPT',
#   'CLRBZ',
#   'CLRG',
#   'CLSD',
#   'CLXT',
#   'CMBM',
#   'CMFNL',
#   'CMLS',
#   'CNCE',
#   'CNCR',
#   'CNDT',
#   'CNFR',
#   'CNFRL',
#   'CNST',
#   'COCP',
#   'CODA',
#   'CODX',
#   'COGT',
#   'COLL',
#   'COMM',
#   'COOP',
#   'COUP',
#   'COWNL',
#   'COWNZ',
#   'CPSH',
#   'CPTAG',
#   'CPTAL',
#   'CRBP',
#   'CREX',
#   'CRNX',
#   'CRON',
#   'CRSP',
#   'CRTO',
#   'CRTX',
#   'CRVS',
#   'CRWD',
#   'CSA',
#   'CSB',
#   'CSBR',
#   'CSF',
#   'CSML',
#   'CSSE',
#   'CSSEP',
#   'CSTL',
#   'CSTR',
#   'CSWCL',
#   'CSWI',
#   'CTMX',
#   'CTRE',
#   'CTRM',
#   'CTXR',
#   'CTXRW',
#   'CUE',
#   'CVET',
#   'CWBR',
#   'CYAD',
#   'CYBR',
#   'CYCCP',
#   'CYCN',
#   'CZR',
#   'DALI',
#   'DARE',
#   'DAX',
#   'DBVT',
#   'DBX',
#   'DCPH',
#   'DDIV',
#   'DFFN',
#   'DFNL',
#   'DGICB',
#   'DHCNI',
#   'DHCNL',
#   'DINT',
#   'DISCB',
#   'DLPN',
#   'DLTH',
#   'DMAC',
#   'DMTK',
#   'DNLI',
#   'DOCU',
#   'DOGZ',
#   'DOMO',
#   'DOOO',
#   'DOYU',
#   'DRIOW',
#   'DRIV',
#   'DRNA',
#   'DSKE',
#   'DSKEW',
#   'DTEA',
#   'DTIL',
#   'DTSS',
#   'DUSA',
#   'DVLU',
#   'DVOL',
#   'DWAT',
#   'DWFI',
#   'DWLD',
#   'DWMC',
#   'DWPP',
#   'DWSH',
#   'DYAI',
#   'EARS',
#   'EAST',
#   'EBAYL',
#   'EBIZ',
#   'ECOR',
#   'EDIT',
#   'EDRY',
#   'EDSA',
#   'EFAS',
#   'EGRX',
#   'EIDX',
#   'EIGI',
#   'EIGR',
#   'EKSO',
#   'ELOX',
#   'EMXC',
#   'ENLV',
#   'ENOB',
#   'ENTX',
#   'ENVB',
#   'EOLS',
#   'EPIX',
#   'EPSN',
#   'EQ',
#   'EQBK',
#   'EQRR',
#   'ERYP',
#   'ESGD',
#   'ESGE',
#   'ESGRO',
#   'ESGRP',
#   'ESGU',
#   'ESPO',
#   'ESQ',
#   'ESTA',
#   'ETON',
#   'ETSY',
#   'ETTX',
#   'EVBG',
#   'EVER',
#   'EVFM',
#   'EVGN',
#   'EVLO',
#   'EVOP',
#   'EXPI',
#   'EYE',
#   'EYEG',
#   'EYEN',
#   'EYES',
#   'EYESW',
#   'FAAR',
#   'FALN',
#   'FAMI',
#   'FAT',
#   'FBIOP',
#   'FBRX',
#   'FCAL',
#   'FCBP',
#   'FCEF',
#   'FCVT',
#   'FDBC',
#   'FDNI',
#   'FDUSL',
#   'FDUSZ',
#   'FENC',
#   'FFBW',
#   'FFWM',
#   'FGBI',
#   'FGEN',
#   'FGF',
#   'FGFPP',
#   'FHB',
#   'FID',
#   'FINX',
#   'FITBI',
#   'FIVN',
#   'FIXD',
#   'FIXX',
#   'FLGT',
#   'FLMN',
#   'FLMNW',
#   'FLXN',
#   'FMAO',
#   'FMHI',
#   'FNCB',
#   'FNKO',
#   'FNWB',
#   'FOCS',
#   'FORK',
#   'FOX',
#   'FOXA',
#   'FPAY',
#   'FRAF',
#   'FRPT',
#   'FRSX',
#   'FRTA',
#   'FSTX',
#   'FSV',
#   'FTDR',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FULC',
#   'FUTU',
#   'FUV',
#   'FVC',
#   'FVCB',
#   'FWONK',
#   'FWP',
#   'GAINL',
#   'GAINM',
#   'GBLIL',
#   'GBT',
#   'GCMGW',
#   'GDS',
#   'GDYN',
#   'GECC',
#   'GECCL',
#   'GECCM',
#   'GECCN',
#   'GENY',
#   'GFNCP',
#   'GFNSL',
#   'GH',
#   'GHSI',
#   'GIGE',
#   'GLADD',
#   'GLG',
#   'GLIBA',
#   'GLIBP',
#   'GLMD',
#   'GLPI',
#   'GLYC',
#   'GMAB',
#   'GMDA',
#   'GMLPP',
#   'GNCA',
#   'GNFT',
#   'GNLN',
#   'GNOM',
#   'GNPX',
#   'GNTY',
#   'GNUS',
#   'GO',
#   'GOEV',
#   'GOEVW',
#   'GOODM',
#   'GOOG',
#   'GOSS',
#   'GPP',
#   'GPRO',
#   'GRIN',
#   'GRNQ',
#   'GRTS',
#   'GSHD',
#   'GSKY',
#   'GSMG',
#   'GSMGW',
#   'GSUM',
#   'GTEC',
#   'GTHX',
#   'GTYH',
#   'GWGH',
#   'GWRS',
#   'HARP',
#   'HBANN',
#   'HBANO',
#   'HBMD',
#   'HBP',
#   'HCAPZ',
#   'HCAT',
#   'HCM',
#   'HEPA',
#   'HFFG',
#   'HGEN',
#   'HHR',
#   'HJLI',
#   'HJLIW',
#   'HLAL',
#   'HLG',
#   'HLNE',
#   'HMHC',
#   'HNDL',
#   'HNNA',
#   'HOFV',
#   'HOFVW',
#   'HONE',
#   'HOOK',
#   'HOTH',
#   'HPK',
#   'HPKEW',
#   'HQI',
#   'HQY',
#   'HRTX',
#   'HSDT',
#   'HTGM',
#   'HUSN',
#   'HVBC',
#   'HWCPL',
#   'HX',
#   'HYMC',
#   'HYMCW',
#   'HYRE',
#   'HYXF',
#   'ICBK',
#   'ICCH',
#   'ICHR',
#   'ICLK',
#   'ICMB',
#   'IDLB',
#   'IDYA',
#   'IEA',
#   'IEAWW',
#   'IFMK',
#   'IFRX',
#   'IGIC',
#   'IGICW',
#   'IHRT',
#   'IIIV',
#   'ILPT',
#   'IMAC',
#   'IMRN',
#   'IMRNW',
#   'IMTE',
#   'IMTX',
#   'IMUX',
#   'IMV',
#   'IMXI',
#   'INBKL',
#   'INFR',
#   'INGN',
#   'INMB',
#   'INMD',
#   'INOV',
#   'INSE',
#   'IPLDP',
#   'IPWR',
#   'IQ',
#   'IRMD',
#   'IRTC',
#   'ISDX',
#   'ISEM',
#   'ISTR',
#   'ITCI',
#   'ITMR',
#   'ITRM',
#   'IUS',
#   'IUSS',
#   'IZEA',
#   'JAGX',
#   'JD',
#   'JFIN',
#   'JG',
#   'JMPNL',
#   'JNCE',
#   'JRSH',
#   'JRVR',
#   'JSMD',
#   'JSML',
#   'JYNT',
#   'KALA',
#   'KALV',
#   'KBLMR',
#   'KBSF',
#   'KCAPL',
#   'KDMN',
#   'KDNY',
#   'KE',
#   'KERN',
#   'KERNW',
#   'KHC',
#   'KIDS',
#   'KIN',
#   'KLDO',
#   'KLXE',
#   'KNSA',
#   'KNSL',
#   'KOD',
#   'KPTI',
#   'KRMA',
#   'KRNT',
#   'KRTX',
#   'KRUS',
#   'KRYS',
#   'KTOVW',
#   'KTRA',
#   'KURA',
#   'KXIN',
#   'KZR',
#   'LACQ',
#   'LACQW',
#   'LANDP',
#   'LASR',
#   'LAUR',
#   'LAZY',
#   'LBC',
#   'LBRDA',
#   'LBRDK',
#   'LDSF',
#   'LE',
#   'LEGH',
#   'LEGR',
#   'LEVL',
#   'LFAC',
#   'LGIH',
#   'LIFE',
#   'LILA',
#   'LILAK',
#   'LIND',
#   'LIQT',
#   'LITE',
#   'LIVN',
#   'LIVX',
#   'LJPC',
#   'LKCO',
#   'LMB',
#   'LMFA',
#   'LMRK',
#   'LMRKN',
#   'LMRKO',
#   'LMRKP',
#   'LNGR',
#   'LNTH',
#   'LOB',
#   'LOCO',
#   'LOGC',
#   'LOOP',
#   'LOVE',
#   'LPCN',
#   'LPTX',
#   'LQDA',
#   'LRGE',
#   'LRMR',
#   'LSXMA',
#   'LSXMK',
#   'LTRPA',
#   'LVHD',
#   'LX',
#   'LYFT',
#   'LYL',
#   'MARA',
#   'MBCN',
#   'MBIN',
#   'MBINP',
#   'MBIO',
#   'MBRX',
#   'MBUU',
#   'MCEF',
#   'MCFT',
#   'MCRB',
#   'MDB',
#   'MDGS',
#   'MDJH',
#   'MDRR',
#   'MDWD',
#   'MEDP',
#   'MEDS',
#   'MESA',
#   'MESO',
#   'METC',
#   'METX',
#   'MFH',
#   'MFINL',
#   'MGEN',
#   'MGNI',
#   'MGTA',
#   'MGTX',
#   'MIK',
#   'MILN',
#   'MIME',
#   'MINDP',
#   'MIRM',
#   'MIST',
#   'MITO',
#   'MKGI',
#   'MMAC',
#   'MNSB',
#   'MOBL',
#   'MOGO',
#   'MOMO',
#   'MOR',
#   'MORF',
#   'MOTS',
#   'MOXC',
#   'MRAM',
#   'MRBK',
#   'MRCCL',
#   'MREO',
#   'MRKR',
#   'MRNA',
#   'MRNS',
#   'MRSN',
#   'MRUS',
#   'MSBI',
#   'MSVB',
#   'MTBC',
#   'MTBCP',
#   'MTC',
#   'MTCH',
#   'MTLS',
#   'MTP',
#   'MVBF',
#   'MWK',
#   'MYFW',
#   'MYOK',
#   'MYSZ',
#   'MYT',
#   'NAKD',
#   'NAOV',
#   'NAVI',
#   'NBEV',
#   'NBLX',
#   'NBRV',
#   'NCBS',
#   'NCNA',
#   'NCSM',
#   'NDRA',
#   'NDRAW',
#   'NEOS',
#   'NERV',
#   'NESR',
#   'NESRW',
#   'NEWA',
#   'NEWTI',
#   'NEWTL',
#   'NEXT',
#   'NFE',
#   'NFTY',
#   'NGHC',
#   'NGHCN',
#   'NGHCO',
#   'NGHCP',
#   'NGHCZ',
#   'NGM',
#   'NH',
#   'NHLD',
#   'NHLDW',
#   'NHTC',
#   'NISN',
#   'NIU',
#   'NK',
#   'NKLA',
#   'NLTX',
#   'NMCI',
#   'NMFCL',
#   'NMIH',
#   'NMRD',
#   'NMRK',
#   'NNDM',
#   'NODK',
#   'NOVN',
#   'NRBO',
#   'NTEC',
#   'NTLA',
#   'NTNX',
#   'NTRA',
#   'NTRP',
#   'NVCR',
#   'NVEE',
#   'NVFY',
#   'NVUS',
#   'NXTC',
#   'NYMTN',
#   'NYMTO',
#   'OBLN',
#   'OBNK',
#   'OBSV',
#   'OCCI',
#   'OCCIP',
#   'OCGN',
#   'OCUL',
#   'ODT',
#   'OFED',
#   'OFSSL',
#   'OFSSZ',
#   'OGI',
#   'OKTA',
#   'OLD',
#   'OLLI',
#   'OMP',
#   'ONCY',
#   'ONTXW',
#   'OPBK',
#   'OPGN',
#   'OPINI',
#   'OPNT',
#   'OPRA',
#   'OPRX',
#   'OPTN',
#   'ORGO',
#   'ORGS',
#   'ORTX',
#   'OSMT',
#   'OSS',
#   'OSW',
#   'OTIC',
#   'OTLK',
#   'OTLKW',
#   'OVID',
#   'OXBR',
#   'OXBRW',
#   'OXFD',
#   'OXLCM',
#   'OXSQL',
#   'OXSQZ',
#   'PAE',
#   'PAHC',
#   'PANL',
#   'PATI',
#   'PAVM',
#   'PAVMW',
#   'PAVMZ',
#   'PAYS',
#   'PBCTP',
#   'PBFS',
#   'PBTS',
#   'PCB',
#   'PCSB',
#   'PCTY',
#   'PDD',
#   'PDLB',
#   'PDSB',
#   'PECK',
#   'PETQ',
#   'PETZ',
#   'PFIE',
#   'PFIS',
#   'PHAS',
#   'PHCF',
#   'PHIOW',
#   'PHUN',
#   'PHUNW',
#   'PI',
#   'PIRS',
#   'PIXY',
#   'PLAY',
#   'PLL',
#   'PLMR',
#   'PLSE',
#   'PLXP',
#   'PLYA',
#   'POLA',
#   'PPBT',
#   'PPSI',
#   'PRAH',
#   'PROF',
#   'PRPL',
#   'PRPO',
#   'PRQR',
#   'PRTH',
#   'PRVB',
#   'PRVL',
#   'PS',
#   'PSC',
#   'PSET',
#   'PSNL',
#   'PT',
#   'PTC',
#   'PTGX',
#   'PULM',
#   'PUYI',
#   'PVAC',
#   'PVBC',
#   'PXS',
#   'PY',
#   'PYPL',
#   'QFIN',
#   'QLGN',
#   'QRVO',
#   'QTNT',
#   'QTRX',
#   'QTT',
#   'QURE',
#   'RARE',
#   'RBB',
#   'RBKB',
#   'RBNC',
#   'RCKT',
#   'RCM',
#   'RDFN',
#   'RDUS',
#   'RDVT',
#   'REAL',
#   'REDU',
#   'REKR',
#   'REPH',
#   'REPL',
#   'RESN',
#   'RETA',
#   'RETO',
#   'RFAP',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RGNX',
#   'RIBT',
#   'RILY',
#   'RILYG',
#   'RILYH',
#   'RILYI',
#   'RILYO',
#   'RILYZ',
#   'RIVE',
#   'RKDA',
#   'RLMD',
#   'RMBI',
#   'RMBL',
#   'RMNI',
#   'RMR',
#   'RNDB',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAD',
#   'ROBT',
#   'ROKU',
#   'RPAY',
#   'RPD',
#   'RRBI',
#   'RRR',
#   'RTLR',
#   'RUBY',
#   'RUHN',
#   'RUN',
#   'RVNC',
#   'RWLK',
#   'RYTM',
#   'SABR',
#   'SAGE',
#   'SBBP',
#   'SBLKZ',
#   'SBT',
#   'SCKT',
#   'SCOR',
#   'SCPH',
#   'SCPL',
#   'SCWX',
#   'SCYX',
#   'SDG',
#   'SDVY',
#   'SECO',
#   'SEDG',
#   ...],
#  ['AACG',
#   'AAME',
#   'AAOI',
#   'ABUS',
#   'ACHC',
#   'ACNB',
#   'ACRX',
#   'ACST',
#   'ADUS',
#   'AEGN',
#   'AEHL',
#   'AGIO',
#   'AGNC',
#   'AHPI',
#   'AIKI',
#   'AIMC',
#   'ALBO',
#   'ALGT',
#   'ALIM',
#   'ALLT',
#   'AMBA',
#   'AMCX',
#   'AMRS',
#   'AMTX',
#   'ANGI',
#   'ANTE',
#   'AOSL',
#   'APEI',
#   'APEN',
#   'APPS',
#   'APTO',
#   'APWC',
#   'ARAY',
#   'ARCT',
#   'ARWR',
#   'ASMB',
#   'ASPS',
#   'ATHX',
#   'ATOS',
#   'AUBN',
#   'AVAV',
#   'AVEO',
#   'AVGO',
#   'AVNW',
#   'AWH',
#   'BANR',
#   'BCBP',
#   'BCML',
#   'BCOV',
#   'BEAT',
#   'BEEM',
#   'BELFA',
#   'BIMI',
#   'BJK',
#   'BKCC',
#   'BKEP',
#   'BKEPP',
#   'BKSC',
#   'BLIN',
#   'BLMN',
#   'BLRX',
#   'BLUE',
#   'BMCH',
#   'BNFT',
#   'BNSO',
#   'BOSC',
#   'BOTJ',
#   'BPOPM',
#   'BPOPN',
#   'BPTH',
#   'BPY',
#   'BRID',
#   'BYFC',
#   'CAPR',
#   'CATM',
#   'CBAN',
#   'CBLI',
#   'CBMG',
#   'CBPO',
#   'CCLP',
#   'CCXI',
#   'CDW',
#   'CDXC',
#   'CDXS',
#   'CEMI',
#   'CENTA',
#   'CFBK',
#   'CFFI',
#   'CG',
#   'CGIX',
#   'CHEF',
#   'CHFS',
#   'CHMG',
#   'CHSCO',
#   'CHSCP',
#   'CHTR',
#   'CHUY',
#   'CHW',
#   'CIZN',
#   'CJJD',
#   'CLIR',
#   'CLNE',
#   'CLRB',
#   'CLVS',
#   'CMRX',
#   'CNET',
#   'CONE',
#   'CPAH',
#   'CPHC',
#   'CPIX',
#   'CPLP',
#   'CPRX',
#   'CPTA',
#   'CRDF',
#   'CSCW',
#   'CSIQ',
#   'CSOD',
#   'CSTE',
#   'CTIB',
#   'CTIC',
#   'CTSO',
#   'CVCY',
#   'CVLT',
#   'CVLY',
#   'CWBC',
#   'CXDC',
#   'CXSE',
#   'CYRX',
#   'CZWI',
#   'DISCK',
#   'DJCO',
#   'DMRC',
#   'DNKN',
#   'DRIO',
#   'DWAS',
#   'EA',
#   'EBMT',
#   'EBSB',
#   'ECHO',
#   'EFOI',
#   'EGAN',
#   'EHTH',
#   'ELSE',
#   'ELYS',
#   'EMCF',
#   'ENPH',
#   'ENSG',
#   'ENTA',
#   'EPZM',
#   'ERII',
#   'ESBK',
#   'ESEA',
#   'ESGR',
#   'ESPR',
#   'ESSA',
#   'ESXB',
#   'EVK',
#   'EVOK',
#   'EXLS',
#   'FANG',
#   'FANH',
#   'FATE',
#   'FB',
#   'FBIO',
#   'FBIZ',
#   'FBMS',
#   'FBSS',
#   'FCAP',
#   'FCCO',
#   'FCCY',
#   'FCRD',
#   'FDUS',
#   'FEYE',
#   'FFHL',
#   'FFNW',
#   'FIBK',
#   'FIVE',
#   'FLDM',
#   'FLNT',
#   'FMBH',
#   'FMNB',
#   'FOLD',
#   'FORTY',
#   'FOXF',
#   'FPRX',
#   'FRANQ',
#   'FRBA',
#   'FRGI',
#   'FSBW',
#   'FSFG',
#   'FSLR',
#   'FTAG',
#   'FTFT',
#   'FTNT',
#   'FTRI',
#   'FUSB',
#   'GALT',
#   'GARS',
#   'GBDC',
#   'GCBC',
#   'GENE',
#   'GEVO',
#   'GFED',
#   'GFN',
#   'GLBS',
#   'GLBZ',
#   'GLPG',
#   'GLRE',
#   'GLUU',
#   'GMLP',
#   'GNMK',
#   'GOGO',
#   'GRBK',
#   'GRFS',
#   'GRPN',
#   'GSIT',
#   'GSM',
#   'GTIM',
#   'GTLS',
#   'GURE',
#   'GWPH',
#   'GYRO',
#   'HAFC',
#   'HBCP',
#   'HCAP',
#   'HCCI',
#   'HDS',
#   'HEAR',
#   'HFBL',
#   'HGSH',
#   'HIFS',
#   'HMNF',
#   'HMST',
#   'HMTV',
#   'HNRG',
#   'HOPE',
#   'HOVNP',
#   'HROW',
#   'HRZN',
#   'HSTO',
#   'HTBI',
#   'HTBX',
#   'HTHT',
#   'HWBK',
#   'HZNP',
#   'IBTX',
#   'ICCC',
#   'ICFI',
#   'ICPT',
#   'IDEX',
#   'IESC',
#   'IGIB',
#   'IGSB',
#   'III',
#   'IKNX',
#   'IMMP',
#   'IMOS',
#   'INBK',
#   'INDT',
#   'INFN',
#   'INPX',
#   'INSM',
#   'INTG',
#   'IOVA',
#   'IPGP',
#   'IPHI',
#   'IRCP',
#   'IRDM',
#   'IROQ',
#   'IRWD',
#   'ISEE',
#   'ITIC',
#   'JAZZ',
#   'JCTCF',
#   'JSM',
#   'KBWB',
#   'KBWD',
#   'KBWR',
#   'KBWY',
#   'KDP',
#   'KEQU',
#   'KFFB',
#   'KINS',
#   'KMDA',
#   'KNDI',
#   'KOSS',
#   'KZIA',
#   'LAND',
#   'LARK',
#   'LCNB',
#   'LEDS',
#   'LFVN',
#   'LLIT',
#   'LLNW',
#   'LMAT',
#   'LMNR',
#   'LMST',
#   'LOAN',
#   'LOGI',
#   'LOPE',
#   'LPLA',
#   'LSBK',
#   'LULU',
#   'LUMO',
#   'MACK',
#   'MASI',
#   'MBII',
#   'MBOT',
#   'MCEP',
#   'MDGL',
#   'MDLZ',
#   'MDVL',
#   'MELI',
#   'MFNC',
#   'MGNX',
#   'MGYR',
#   'MHLD',
#   'MICT',
#   'MLCO',
#   'MLND',
#   'MLVF',
#   'MMYT',
#   'MNOV',
#   'MNST',
#   'MOFG',
#   'MPB',
#   'MRCC',
#   'MRIN',
#   'MRTX',
#   'MTSI',
#   'MTSL',
#   'MYRG',
#   'NBN',
#   'NBSE',
#   'NCMI',
#   'NDLS',
#   'NEO',
#   'NEON',
#   'NEPT',
#   'NETE',
#   'NFBK',
#   'NMFC',
#   'NNBR',
#   'NRC',
#   'NSEC',
#   'NSTG',
#   'NSYS',
#   'NURO',
#   'NVCN',
#   'NVIV',
#   'NWFL',
#   'NWS',
#   'NWSA',
#   'NXPI',
#   'NXTD',
#   'NXTG',
#   'NYMTP',
#   'OBAS',
#   'OCC',
#   'OCSI',
#   'OCSL',
#   'OCUP',
#   'OESX',
#   'OFS',
#   'OMAB',
#   'OMER',
#   'ONCS',
#   'ONTX',
#   'ONVO',
#   'OPHC',
#   'OPI',
#   'OPOF',
#   'OPTT',
#   'ORBC',
#   'ORMP',
#   'OSN',
#   'OTEL',
#   'OTRK',
#   'OVBC',
#   'OVLY',
#   'OXLC',
#   'OXLCO',
#   'PACB',
#   'PAGP',
#   'PBHC',
#   'PBIP',
#   'PBPB',
#   'PBYI',
#   'PCRX',
#   'PDCE',
#   'PDP',
#   'PEBK',
#   'PEIX',
#   'PERI',
#   'PEZ',
#   'PFBC',
#   'PFI',
#   'PFIN',
#   'PFLT',
#   'PFMT',
#   'PFPT',
#   'PGEN',
#   'PHIO',
#   'PIE',
#   'PINC',
#   'PIZ',
#   'PKW',
#   'PLBC',
#   'PLUG',
#   'PLW',
#   'PME',
#   'PNBK',
#   'PNNT',
#   'PNRG',
#   'POAI',
#   'PODD',
#   'PRIM',
#   'PRTA',
#   'PRTS',
#   'PSHG',
#   'PSL',
#   'PTCT',
#   'PTF',
#   'PTH',
#   'PTMN',
#   'PTVCA',
#   'PXI',
#   'PYZ',
#   'QADA',
#   'QADB',
#   'QIWI',
#   'QLYS',
#   'QNST',
#   'QQQX',
#   'QRHC',
#   'QRTEB',
#   'RAND',
#   'RBCN',
#   'RCON',
#   'RDHL',
#   'REED',
#   'REGI',
#   'RGCO',
#   'RGLS',
#   'RIOT',
#   'RNET',
#   'RNWK',
#   'ROIC',
#   'RP',
#   'SAL',
#   'SAMG',
#   'SANW',
#   'SATS',
#   'SFM',
#   'SFST',
#   'SGOC',
#   'SGRP',
#   'SHIP',
#   'SHSP',
#   'SIEB',
#   'SINO',
#   'SLCT',
#   'SLMBP',
#   'SLRC',
#   'SLS',
#   'SMBC',
#   'SMIT',
#   'SNCA',
#   'SNOA',
#   'SNSS',
#   'SONA',
#   'SONN',
#   'SPCB',
#   'SPLK',
#   'SPSC',
#   'SPWR',
#   'SQBG',
#   'SREV',
#   'SSBI',
#   'SSNC',
#   'SSSS',
#   'STRS',
#   'SUNS',
#   'SUNW',
#   'SUPN',
#   'SVVC',
#   'SYNC',
#   'TA',
#   'TAIT',
#   'TAOP',
#   'TAST',
#   'TATT',
#   'TBNK',
#   'TCBIL',
#   'TCBIP',
#   'TCCO',
#   'TCPC',
#   'TEUM',
#   'TFSL',
#   'TGLS',
#   'TGTX',
#   'TIPT',
#   'TITN',
#   'TMUS',
#   'TNAV',
#   'TNXP',
#   'TOPS',
#   'TREE',
#   'TRIL',
#   'TRIP',
#   'TRNS',
#   'TRS',
#   'TSC',
#   'TSLA',
#   'TSRI',
#   'TTGT',
#   'TVTX',
#   'TXMD',
#   'UBOH',
#   'UCBI',
#   'UIHC',
#   'ULTA',
#   'UNAM',
#   'UNB',
#   'UNTY',
#   'UONE',
#   'USCR',
#   'USIG',
#   'VBFC',
#   'VBIV',
#   'VC',
#   'VEON',
#   'VISL',
#   'VIVE',
#   'VJET',
#   'VNET',
#   'VRA',
#   'VRME',
#   'VRSK',
#   'VRTS',
#   'VRTU',
#   'VSTM',
#   'VTNR',
#   'VXRT',
#   'WDAY',
#   'WETF',
#   'WHF',
#   'WHLR',
#   'WIFI',
#   'WLDN',
#   'WMGI',
#   'WVFC',
#   'XLRN',
#   'XONE',
#   'XSPA',
#   'YNDX',
#   'YRCW',
#   'YTEN',
#   'YY',
#   'ZAGG',
#   'ZG',
#   'ZGNX',
#   'ZNGA',
#   'ZVO'],
#  ['AAON',
#   'AAWW',
#   'AAXN',
#   'ABCB',
#   'ABIO',
#   'ABMD',
#   'ACAD',
#   'ACER',
#   'ACGL',
#   'ACHV',
#   'ACIW',
#   'ACLS',
#   'ACOR',
#   'ACTG',
#   'ADTN',
#   'ADXS',
#   'AEHR',
#   'AEIS',
#   'AEY',
#   'AEZS',
#   'AGEN',
#   'AGYS',
#   'AINV',
#   'AIRT',
#   'AKAM',
#   'ALCO',
#   'ALGN',
#   'ALKS',
#   'ALNY',
#   'ALOT',
#   'ALSK',
#   'ALT',
#   'ALXN',
#   'AMAG',
#   'AMED',
#   'AMKR',
#   'AMNB',
#   'AMOT',
#   'AMRB',
#   'AMRN',
#   'AMSC',
#   'AMSF',
#   'AMSWA',
#   'AMWD',
#   'ANAT',
#   'ANDE',
#   'ANGO',
#   'ANIK',
#   'ANIP',
#   'ANSS',
#   'APDN',
#   'APEX',
#   'APOG',
#   'APYX',
#   'ARCB',
#   'ARCC',
#   'ARKR',
#   'ARLP',
#   'ARNA',
#   'AROW',
#   'ARTNA',
#   'ARTW',
#   'ASML',
#   'ASRT',
#   'ASRV',
#   'ASTC',
#   'ASTE',
#   'ASUR',
#   'ASYS',
#   'ATAX',
#   'ATEC',
#   'ATHE',
#   'ATLC',
#   'ATLO',
#   'ATNI',
#   'ATRC',
#   'ATRI',
#   'ATRS',
#   'ATSG',
#   'ATVI',
#   'AUB',
#   'AUDC',
#   'AUTO',
#   'AVDL',
#   'AVID',
#   'AVT',
#   'AWRE',
#   'AXAS',
#   'AXDX',
#   'AXTI',
#   'AYRO',
#   'AZN',
#   'AZPN',
#   'BANF',
#   'BASI',
#   'BBGI',
#   'BBI',
#   'BBQ',
#   'BBSI',
#   'BCOR',
#   'BCPC',
#   'BCRX',
#   'BDGE',
#   'BDSI',
#   'BECN',
#   'BELFB',
#   'BFIN',
#   'BGCP',
#   'BGFV',
#   'BIDU',
#   'BIOL',
#   'BJRI',
#   'BKNG',
#   'BLDP',
#   'BLDR',
#   'BLKB',
#   'BMRC',
#   'BMRN',
#   'BMTC',
#   'BOCH',
#   'BOKF',
#   'BOOM',
#   'BPFH',
#   'BPOP',
#   'BRKL',
#   'BRKR',
#   'BRKS',
#   'BSET',
#   'BSQR',
#   'BSRR',
#   'BSTC',
#   'BUSE',
#   'BWEN',
#   'CAAS',
#   'CAC',
#   'CACC',
#   'CAKE',
#   'CALM',
#   'CAMP',
#   'CAMT',
#   'CAR',
#   'CASH',
#   'CASI',
#   'CASS',
#   'CASY',
#   'CATY',
#   'CBAT',
#   'CBIO',
#   'CBRL',
#   'CBSH',
#   'CCBG',
#   'CCMP',
#   'CCNE',
#   'CCOI',
#   'CCRN',
#   'CDMO',
#   'CDNS',
#   'CDZI',
#   'CECE',
#   'CENT',
#   'CENX',
#   'CERN',
#   'CERS',
#   'CEVA',
#   'CFFN',
#   'CGEN',
#   'CGNX',
#   'CGO',
#   'CHCI',
#   'CHCO',
#   'CHDN',
#   'CHI',
#   'CHNR',
#   'CHY',
#   'CIDM',
#   'CIVB',
#   'CLAR',
#   'CLBS',
#   'CLCT',
#   'CLDX',
#   'CLFD',
#   'CLMT',
#   'CLRO',
#   'CLSN',
#   'CLWT',
#   'CMCO',
#   'CMCT',
#   'CME',
#   'CMPR',
#   'CMTL',
#   'CNBKA',
#   'CNOB',
#   'CNSL',
#   'CNTY',
#   'CNXN',
#   'COHR',
#   'COHU',
#   'COKE',
#   'COLB',
#   'COLM',
#   'CONN',
#   'CORE',
#   'CORT',
#   'COWN',
#   'CPRT',
#   'CPSI',
#   'CPSS',
#   'CPST',
#   'CRAI',
#   'CREE',
#   'CREG',
#   'CRESY',
#   'CRIS',
#   'CRMT',
#   'CRNT',
#   'CROX',
#   'CRUS',
#   'CRVL',
#   'CRWS',
#   'CSGP',
#   'CSGS',
#   'CSII',
#   'CSPI',
#   'CSQ',
#   'CSWC',
#   'CTBI',
#   'CTG',
#   'CTHR',
#   'CTRN',
#   'CTSH',
#   'CUBA',
#   'CUTR',
#   'CVBF',
#   'CVCO',
#   'CVGI',
#   'CVGW',
#   'CVLG',
#   'CVV',
#   'CWCO',
#   'CWST',
#   'CYAN',
#   'CYBE',
#   'CYCC',
#   'CYRN',
#   'CYTK',
#   'CZNC',
#   'DAIO',
#   'DAKT',
#   'DCOM',
#   'DENN',
#   'DGICA',
#   'DGII',
#   'DGLY',
#   'DHC',
#   'DHIL',
#   'DIOD',
#   'DISCA',
#   'DLHC',
#   'DMLP',
#   'DORM',
#   'DOX',
#   'DRRX',
#   'DSGX',
#   'DSPG',
#   'DSWL',
#   'DVAX',
#   'DWSN',
#   'DXCM',
#   'DXLG',
#   'DXPE',
#   'DXYN',
#   'DYNT',
#   'DZSI',
#   'EBIX',
#   'EBTC',
#   'ECOL',
#   'ECPG',
#   'EDAP',
#   'EDUC',
#   'EEFT',
#   'EFSC',
#   'EGBN',
#   'EGLE',
#   'EGOV',
#   'ELTK',
#   'EMKR',
#   'EML',
#   'ENDP',
#   'ENG',
#   'ENTG',
#   'EPAY',
#   'EQIX',
#   'ERIC',
#   'ERIE',
#   'ESCA',
#   'ESLT',
#   'EVOL',
#   'EWBC',
#   'EXAS',
#   'EXEL',
#   'EXFO',
#   'EXPE',
#   'EXPO',
#   'EXTR',
#   'EYPT',
#   'EZPW',
#   'FARM',
#   'FARO',
#   'FBNC',
#   'FCBC',
#   'FCEL',
#   'FCFS',
#   'FCNCA',
#   'FEIM',
#   'FELE',
#   'FFBC',
#   'FFIC',
#   'FFIN',
#   'FFIV',
#   'FISI',
#   'FIZZ',
#   'FLIC',
#   'FLIR',
#   'FLL',
#   'FLWS',
#   'FLXS',
#   'FMBI',
#   'FNHC',
#   'FNLC',
#   'FONR',
#   'FORD',
#   'FORM',
#   'FORR',
#   'FOSL',
#   'FRBK',
#   'FRME',
#   'FRPH',
#   'FSTR',
#   'FTEK',
#   'FULT',
#   'FUNC',
#   'FUND',
#   'FVE',
#   'FWONA',
#   'FWRD',
#   'GABC',
#   'GAIA',
#   'GAIN',
#   'GASS',
#   'GBCI',
#   'GBLI',
#   'GDEN',
#   'GEG',
#   'GENC',
#   'GEOS',
#   'GERN',
#   'GGAL',
#   'GIFI',
#   'GIGM',
#   'GIII',
#   'GILT',
#   'GLAD',
#   'GLDD',
#   'GLNG',
#   'GNSS',
#   'GOGL',
#   'GOOD',
#   'GOOGL',
#   'GPORQ',
#   'GPRE',
#   'GRMN',
#   'GROW',
#   'GRVY',
#   'GSBC',
#   'GVP',
#   'HA',
#   'HAIN',
#   'HALL',
#   'HALO',
#   'HAYN',
#   'HBIO',
#   'HBNC',
#   'HCKT',
#   'HCSG',
#   'HDSN',
#   'HEES',
#   'HELE',
#   'HFWA',
#   'HIBB',
#   'HIHO',
#   'HIMX',
#   'HLIO',
#   'HLIT',
#   'HMSY',
#   'HOFT',
#   'HOLI',
#   'HOLX',
#   'HOMB',
#   'HSII',
#   'HSKA',
#   'HSON',
#   'HST',
#   'HSTM',
#   'HTBK',
#   'HTLD',
#   'HTLF',
#   'HUBG',
#   'HURC',
#   'HURN',
#   'HWC',
#   'HWCC',
#   'HWKN',
#   'IART',
#   'IBCP',
#   'IBOC',
#   'ICAD',
#   'ICLR',
#   'ICON',
#   'ICUI',
#   'IDCC',
#   'IDN',
#   'IDRA',
#   'IDXG',
#   'IDXX',
#   'IEC',
#   'IEP',
#   'IIIN',
#   'IIN',
#   'IIVI',
#   'ILMN',
#   'IMBI',
#   'IMGN',
#   'IMKTA',
#   'IMMR',
#   'INCY',
#   'INDB',
#   'INFI',
#   'INO',
#   'INOD',
#   'INSG',
#   'INVA',
#   'INVE',
#   'IONS',
#   'IOSP',
#   'IPAR',
#   'IRBT',
#   'IRIX',
#   'ISBC',
#   'ISIG',
#   'ISNS',
#   'ISRG',
#   'ISSC',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'IVAC',
#   'JACK',
#   'JAKK',
#   'JAN',
#   'JBHT',
#   'JBLU',
#   'JBSS',
#   'JCOM',
#   'JCS',
#   'JJSF',
#   'JKHY',
#   'JOBS',
#   'JOUT',
#   'JRJC',
#   'JVA',
#   'KALU',
#   'KELYA',
#   'KFRC',
#   'KIRK',
#   'KLIC',
#   'KOPN',
#   'KRNY',
#   'KSPN',
#   'KTCC',
#   'KTOS',
#   'KVHI',
#   'LAKE',
#   'LANC',
#   'LAWS',
#   'LBAI',
#   'LBTYA',
#   'LBTYK',
#   'LCUT',
#   'LECO',
#   'LFUS',
#   'LGND',
#   'LHCG',
#   'LINC',
#   'LIVE',
#   'LKFN',
#   'LKQ',
#   'LMNX',
#   'LNDC',
#   'LNT',
#   'LORL',
#   'LPSN',
#   'LPTH',
#   'LQDT',
#   'LSCC',
#   'LSTR',
#   'LTBR',
#   'LTRX',
#   'LUNA',
#   'LWAY',
#   'LXRX',
#   'LYTS',
#   'MAGS',
#   'MANH',
#   'MANT',
#   'MARK',
#   'MARPS',
#   'MATW',
#   'MBWM',
#   'MCBC',
#   'MCHX',
#   'MCRI',
#   'MDCA',
#   'MDRX',
#   'MEIP',
#   'MEOH',
#   'MERC',
#   'MFIN',
#   'MGEE',
#   'MGI',
#   'MGIC',
#   'MGLN',
#   'MGPI',
#   'MGRC',
#   'MIDD',
#   'MIND',
#   'MKSI',
#   'MKTX',
#   'MLAB',
#   'MLHR',
#   'MMLP',
#   'MMSI',
#   'MNDO',
#   'MNKD',
#   'MNRO',
#   'MNTX',
#   'MORN',
#   'MOSY',
#   'MPAA',
#   'MPWR',
#   'MRCY',
#   'MRLN',
#   'MRTN',
#   'MRVL',
#   'MSEX',
#   'MSON',
#   'MSTR',
#   'MTEM',
#   'MTEX',
#   'MTRX',
#   'MTSC',
#   'MVIS',
#   'MYGN',
#   'MYL',
#   'NAII',
#   'NATH',
#   'NATI',
#   'NATR',
#   'NBIX',
#   'NBTB',
#   'NCTY',
#   'NDAQ',
#   'NDSN',
#   'NEOG',
#   'NEWT',
#   'NFLX',
#   'NICE',
#   'NICK',
#   'NKSH',
#   'NKTR',
#   'NOVT',
#   'NRIM',
#   'NSIT',
#   'NSSC',
#   'NTCT',
#   'NTES',
#   'NTGR',
#   'NTIC',
#   'NTUS',
#   'NTWK',
#   'NUAN',
#   'NUVA',
#   'NVAX',
#   'NVEC',
#   'NVMI',
#   'NWBI',
#   'NWE',
#   'NWLI',
#   'NWPX',
#   'NXGN',
#   'NXST',
#   'NYMT',
#   'NYMX',
#   'OBCI',
#   'OCFC',
#   'ODFL',
#   'OEG',
#   'OFIX',
#   'OFLX',
#   'OIIM',
#   'OLED',
#   'OMCL',
#   'OMEX',
#   'ON',
#   'ONB',
#   'ONCT',
#   'OPCH',
#   'OPK',
#   'ORLY',
#   'ORRF',
#   'OSBC',
#   'OSIS',
#   'OSPN',
#   'OSTK',
#   'OSUR',
#   'OTEX',
#   'OTTR',
#   'OXSQ',
#   'OZK',
#   'PAA',
#   'PAAS',
#   'PACW',
#   'PATK',
#   'PBCT',
#   'PCH',
#   'PCOM',
#   'PCTI',
#   'PCYG',
#   'PCYO',
#   'PDEX',
#   'PDFS',
#   'PDLI',
#   'PEBO',
#   'PEGA',
#   'PENN',
#   'PESI',
#   'PETS',
#   'PEY',
#   'PFBI',
#   'PFC',
#   'PFG',
#   'PFM',
#   'PFSW',
#   'PGC',
#   'PGJ',
#   'PHO',
#   'PICO',
#   'PID',
#   'PKBK',
#   'PKOH',
#   'PLAB',
#   'PLCE',
#   'PLPC',
#   'PLUS',
#   'PLXS',
#   'PMBC',
#   'PMD',
#   'PNFP',
#   'POOL',
#   'POWI',
#   'POWL',
#   'PPBI',
#   'PPC',
#   'PPIH',
#   'PRAA',
#   'PRCP',
#   'PRFT',
#   'PRGS',
#   'PRGX',
#   'PROV',
#   'PRPH',
#   'PRSC',
#   'PRTK',
#   'PSEC',
#   'PSMT',
#   'PSTI',
#   'PSTV',
#   'PTE',
#   'PTNR',
#   'PTSI',
#   'PTVCB',
#   'PUI',
#   'PWFL',
#   'PWOD',
#   'PXLW',
#   'PZZA',
#   'QCRH',
#   'QDEL',
#   'QRTEA',
#   'QUIK',
#   'QUMU',
#   'RADA',
#   'RAIL',
#   'RAVN',
#   'RBBN',
#   'RBCAA',
#   'RCII',
#   'RCKY',
#   'RCMT',
#   'RDCM',
#   'RDI',
#   'RDNT',
#   'RDWR',
#   'REFR',
#   'REG',
#   'REGN',
#   'RELL',
#   'RELV',
#   'RFIL',
#   'RGEN',
#   'RGLD',
#   'RGP',
#   'RICK',
#   'RIGL',
#   'RMBS',
#   'RMCF',
#   'RMRM',
#   'RMTI',
#   'RNST',
#   'ROCK',
#   'ROLL',
#   'RRGB',
#   'RTH',
#   'RUSHA',
#   'RUSHB',
#   'RUTH',
#   'RVSB',
#   'SAFM',
#   'SAFT',
#   'SAIA',
#   'SALM',
#   'SASR',
#   'SAVA',
#   'SBAC',
#   'SBCF',
#   'SBFG',
#   'SBGI',
#   'SBLK',
#   'SBNY',
#   'SBRA',
#   'SBSI',
#   'SCHL',
#   'SCHN',
#   'SCSC',
#   'SCVL',
#   'SEAC',
#   'SEED',
#   'SEEL',
#   'SEIC',
#   'SENEA',
#   'SFNC',
#   'SGA',
#   'SGC',
#   'SGEN',
#   'SGMA',
#   'SGMO',
#   'SGMS',
#   'SHBI',
#   'SHEN',
#   'SHOO',
#   'SHYF',
#   'SIFY',
#   'SIGI',
#   'SILC',
#   'SIMO',
#   'SINA',
#   'SIRI',
#   'SIVB',
#   'SKYW',
#   'SLAB',
#   'SLGN',
#   'SLP',
#   'SMED',
#   'SMMF',
#   'SMSI',
#   'SMTC',
#   'SMTX',
#   'SNBR',
#   'SNEX',
#   'SNFCA',
#   'SNY',
#   'SOHO',
#   'SOHU',
#   'SP',
#   'SPNS',
#   'SPOK',
#   'SPPI',
#   'SPRT',
#   'SPTN',
#   'SRCE',
#   'SRCL',
#   'SRDX',
#   'SRGA',
#   'SRPT',
#   'SSB',
#   'SSKN',
#   'SSP',
#   'SSRM',
#   'SSYS',
#   'STAA',
#   'STBA',
#   'STCN',
#   'STFC',
#   'STKL',
#   'STLD',
#   'STMP',
#   'STRA',
#   'STRL',
#   'STRM',
#   'STRR',
#   'STRT',
#   'STX',
#   'SUMR',
#   'SVBI',
#   'SVC',
#   'SVRA',
#   'SWBI',
#   'SWIR',
#   'SWKS',
#   'SYBT',
#   'SYKE',
#   'SYNA',
#   'SYNL',
#   'SYPR',
#   'TACT',
#   'TAYD',
#   'TBBK',
#   'TCBI',
#   'TCBK',
#   'TCF',
#   'TCFCP',
#   'TCOM',
#   'TCX',
#   'TECH',
#   'TELL',
#   'TENX',
#   'TESS',
#   'TGA',
#   'THFF',
#   'THMO',
#   'THRM',
#   'TILE',
#   'TLGT',
#   'TOWN',
#   'TRIB',
#   'TRMB',
#   'TRMK',
#   'TRST',
#   'TSBK',
#   'TSCO',
#   'TSEM',
#   'TTEC',
#   'TTEK',
#   'TTMI',
#   'TTWO',
#   'TURN',
#   'TVTY',
#   'TWIN',
#   'TXRH',
#   'TZOO',
#   'UAL',
#   'UBCP',
#   'UBFO',
#   'UBSI',
#   'UCTT',
#   'UEIC',
#   'UEPS',
#   'UFCS',
#   'UFPI',
#   'UFPT',
#   'UG',
#   'UHAL',
#   'ULBI',
#   'ULH',
#   'UMBF',
#   'UMPQ',
#   'UONEK',
#   'URBN',
#   'USAK',
#   'USAP',
#   'USAU',
#   'USEG',
#   'USLM',
#   'UTHR',
#   'UTMD',
#   'UTSI',
#   'UVSP',
#   'VALU',
#   'VCEL',
#   'VECO',
#   'VERU',
#   'VG',
#   'VIAC',
#   'VICR',
#   'VIRC',
#   'VIVO',
#   'VLGEA',
#   'VLY',
#   'VNDA',
#   'VOD',
#   'VOXX',
#   'VRNT',
#   'VRTX',
#   'VSAT',
#   'VSEC',
#   'WABC',
#   'WAFD',
#   'WASH',
#   'WDC',
#   'WDFC',
#   'WERN',
#   'WEYS',
#   'WILC',
#   'WINA',
#   'WIRE',
#   'WLFC',
#   'WLTW',
#   'WNEB',
#   'WPRT',
#   'WRLD',
#   'WSBC',
#   'WSBF',
#   'WSFS',
#   'WSTG',
#   'WTBA',
#   'WTFC',
#   'WVVI',
#   'WW',
#   'WWD',
#   'WWR',
#   'WYNN',
#   'XEL',
#   'XOMA',
#   'XPER',
#   'YORW',
#   'YVR',
#   'ZBRA',
#   'ZEUS',
#   'ZIOP',
#   'ZIXI',
#   'ZUMZ'],
#  ['ADMP',
#   'AMZN',
#   'AXGN',
#   'BBBY',
#   'CHKP',
#   'CHRW',
#   'CTXS',
#   'DISH',
#   'DLTR',
#   'EBAY',
#   'FLEX',
#   'GILD',
#   'HSIC',
#   'IAC',
#   'INTU',
#   'LAMR',
#   'MAR',
#   'MCHP',
#   'MITK',
#   'NTAP',
#   'NVDA',
#   'PDCO',
#   'PRDO',
#   'PTEN',
#   'RAVE',
#   'RYAAY',
#   'SANM',
#   'SBUX',
#   'SNPS',
#   'TTNP',
#   'VIAV',
#   'VRSN'],
#  ['ADBE',
#   'ADSK',
#   'ANIX',
#   'ATRO',
#   'BIIB',
#   'CINF',
#   'CMCSA',
#   'COST',
#   'CSCO',
#   'CTAS',
#   'EXPD',
#   'FAST',
#   'FISV',
#   'FITB',
#   'GNTX',
#   'HAS',
#   'HBAN',
#   'KBAL',
#   'KLAC',
#   'LRCX',
#   'MSFT',
#   'MU',
#   'MXIM',
#   'NLOK',
#   'NTRS',
#   'ODP',
#   'PAYX',
#   'PCAR',
#   'QCOM',
#   'ROST',
#   'SLM',
#   'TER',
#   'TROW',
#   'WBA',
#   'XLNX',
#   'XRAY',
#   'ZION'],
#  ['AAPL',
#   'ADI',
#   'ADP',
#   'AMAT',
#   'AMD',
#   'AMGN',
#   'APA',
#   'CSX',
#   'EXC',
#   'MAT',
#   'NWL',
#   'TXN',
#   'WEN'],
#  ['AEP', 'GT', 'INTC', 'PEP']]

# %% [markdown]
# # Looking at Potential similarities in the Features of the Companies

# %% [markdown]
# ## Functions definitions

# %%
from termcolor import colored

def precise_stocks_selector_local(tickers_list=[], path_files='../raw_data/processed/',
                                  random_sample=False, num_samp = 2, verbose=1):
    """
    Returns a concatened DataFrame of the stocks data which tickers' list were passed
    
    If random_sample = True, return a DataFrame with random sample of stocks from the tickers' list passed
    
    Example:
    INPUT: ['AEP', 'GT', 'INTC', 'PEP']
    OUTPUT: df.tickers.unique() ==> ['GT', 'INTC']
   
    """
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        
    t = []
    for ticker in tickers_list:
        ticker = f"{ticker}.csv".lower()
        t.append(ticker)
    tickers_list = t
    
    if verbose == 2:
        print(colored(tickers_list, 'yellow'))
        print()
        print()
    
    if verbose >= 1:
        print(colored(f"****** Starting browsing the '{path_files}' directory ******", 'magenta'))
        
    filenames = []
    missing_stock_csv = []

    
    if random_sample:
        for file in os.listdir(path_files):
            if file.endswith('.csv'):
                if file in tickers_list:
                    filenames.append(file)
        
        for ticker in tickers_list:
            #print(ticker)
            #print(missing_stock_csv)
            if ticker not in filenames:
                missing_stock_csv.append(ticker)
                print(colored(f"{ticker} missing", 'red'))
            else:
                pass
        
        #print(missing_stock_csv)
        
        for missed in missing_stock_csv:
            if missed not in tickers_list:
                missing_stock_csv.remove(missed)
        #print(missing_stock_csv)
        
        if len(filenames) < num_samp:
            print(colored('\nSample size bigger that nuber of companies available\n','red'))
        else:
            sample = random.sample(filenames, num_samp)
            
        if verbose >= 1:
            print(colored("\n   *** Complete sampling ***", 'green'))
            
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting stocks DataFrame creation the sample ******", 'magenta'))
        
        dfs = []

        for ticker in sample:
            ticker_df = pd.read_csv('../raw_data/processed/'+ticker)
            dfs.append(ticker_df)
            if verbose == 2:
                print(colored(f"{ticker} DataFrame created", 'yellow'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
            
            
    else: 
        for file in os.listdir(path_files):
            if (file.endswith('.csv')):
                filenames.append(file)
                #print(f"{file}")
        
        if verbose >= 1:
            print(colored("\n   *** Complete file selection ***", 'green'))
        
        dfs = []
        
        if verbose == 2:
            print(colored(f"\nfilenames lenght: {len(filenames)}", "yellow"))
        
        if verbose >= 1:
            print(colored(f"****** Starting stocks DataFrame creation the sample ******", 'magenta'))
      
        for ticker in tickers_list:
            if ticker in filenames:
                #print(f"{ticker}")
                ticker_df = pd.read_csv('../raw_data/processed/'+ticker)
                dfs.append(ticker_df)
                if verbose == 2:
                    print(colored(f"{ticker} DataFrame created", 'yellow'))
            else:
                missing_stock_csv.append(ticker)
                print(colored(f"\n{ticker} missing", 'red'))
        
        if verbose >= 1:
            print(colored(f"\n\n****** Starting concatenating the sample ******", 'magenta'))
    
    
    if len(missing_stock_csv) !=0:
        
        print(colored("""\n\n##### Problematic Issue: following stocks not in local database! #####""", "red"))
        print(colored(f"Number of missed stocks: {len(missing_stock_csv)}", "red"))
        print(colored(f"""\n{missing_stock_csv}""", "red"))
    
    return pd.concat(dfs)

# %% [markdown]
# ## Exploring Companies per Vintage - The oldest ones

# %%
old_companies = stocks_tickers[-1]
old_companies
# Out:
# ['AEP', 'GT', 'INTC', 'PEP']

# %%
old_df = precise_stocks_selector_local(tickers_list=old_companies, verbose=1)
# Out:
# ****** Starting browsing the '../raw_data/processed/' directory ******
#
#    *** Complete file selection ***
# ****** Starting stocks DataFrame creation the sample ******
#
# gt.csv missing
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 1
#
# ['gt.csv']

# %%
stock_list = list(old_df.ticker.unique())
stock_list
# Out:
# ['AEP', 'INTC', 'PEP']

# %% [markdown]
# ### Separating the DataFrames by appending them to a list `dfs`

# %%
old_df.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0    AEP  1970-02-18  48.822370   61.204013          25.641026 -40370.981710
# 1    AEP  1970-02-19  45.751097   46.153846          41.025641 -66331.981710
# 2    AEP  1970-02-20  49.193068   61.204013          56.187291 -47478.981710
# 3    AEP  1970-02-24  46.046768   46.153846          51.170569 -73582.981710
# 4    AEP  1970-02-25  62.973359   94.996374          67.451411 -47841.530522
#
#      OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0  43797  0.032633  20.679157  22.455757  20.527434 -0.019653   0.002427
# 1  17836  0.031780  19.783309  23.032849  19.566425 -0.017977   0.003282
# 2  36689  0.031460  18.386579  21.596831  21.498109 -0.015383   0.004702
# 3  10585  0.031192  17.623847  23.489003  20.126938 -0.014251   0.004666
# 4  42056  0.035857  18.769133  32.719739  16.240707 -0.006055   0.010290
#
#    MACD_signal  5TD_return  10TD_return  20TD_return
# 0    -0.022080    0.052433     0.093986     0.052433
# 1    -0.021260    0.073658     0.078925     0.078925
# 2    -0.020084    0.110003     0.067921     0.062708
# 3    -0.018918    0.110526     0.073658     0.078925
# 4    -0.016345    0.049653     0.004930     0.054154

# %%
dfs = []

for stock in stock_list:
    df = old_df[old_df['ticker']==stock]
    df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    dfs.append(df)

# %%
dfs[0].head()
# Out:
#          RSI  Stochastic  Stochastic_signal           ADI    OBV       ATR  \
# 0  48.822370   61.204013          25.641026 -40370.981710  43797  0.032633
# 1  45.751097   46.153846          41.025641 -66331.981710  17836  0.031780
# 2  49.193068   61.204013          56.187291 -47478.981710  36689  0.031460
# 3  46.046768   46.153846          51.170569 -73582.981710  10585  0.031192
# 4  62.973359   94.996374          67.451411 -47841.530522  42056  0.035857
#
#          ADX    ADX_pos    ADX_neg      MACD  MACD_diff  MACD_signal
# 0  20.679157  22.455757  20.527434 -0.019653   0.002427    -0.022080
# 1  19.783309  23.032849  19.566425 -0.017977   0.003282    -0.021260
# 2  18.386579  21.596831  21.498109 -0.015383   0.004702    -0.020084
# 3  17.623847  23.489003  20.126938 -0.014251   0.004666    -0.018918
# 4  18.769133  32.719739  16.240707 -0.006055   0.010290    -0.016345

# %% [markdown]
# ### Characterizing features of stocks with PCA

# %% [markdown]
# df = np.array(scaler.fit_transform(dfs[0]))
# stock_pca = pca.fit(dfs[0])
# stock_pca = np.array(pca.transform(dfs[0]))
# pd.DataFrame(stock_pca)
#
# #print(stock_pca.shape)
# pca_stocks_dict[f"{stock_list[idx]}"].append(stock_pca)

# %% [markdown]
# #### Gathering the `PCA` and `explained_variance_ratio`

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
pca = PCA()

pca_stocks_dict = dict.fromkeys(stock_list)
id_stocks_dict = dict.fromkeys(stock_list)

id_stocks_df = pd.DataFrame()

for idx, df in enumerate(dfs):
    df = scaler.fit_transform(df)
    stock_pca = pca.fit_transform(df)
    #print(stock_pca.shape)
    pca_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(stock_pca, columns=list(dfs[0]))
    id_stocks_df[f"{stock_list[idx]} Explained Variance"] = pca.explained_variance_ratio_
    #id_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(data=pca.explained_variance_ratio_,
    #                                                    columns=[f"{stock_list[idx]} Explained Variance"])
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
pca_stocks_dict["AEP"].head()
# Out:
#         RSI  Stochastic  Stochastic_signal       ADI       OBV       ATR  \
# 0  0.704710   -1.395126          -0.025896 -0.427799  0.145325  0.390084
# 1  0.713352   -1.392542          -0.048640 -0.518458  0.141620  0.493142
# 2  0.351074   -1.383137           0.266423 -0.685701  0.268222 -0.161742
# 3  0.569584   -1.369444           0.062437 -0.701878  0.247080  0.364842
# 4 -1.575296   -1.449260           0.966741 -0.277787  0.906085  0.287631
#
#         ADX   ADX_pos   ADX_neg      MACD  MACD_diff   MACD_signal
# 0  0.295818 -0.083142 -0.714485 -0.555554   0.232602  1.820058e-14
# 1  0.271985 -0.066459  0.064238 -0.384376   0.236296 -1.546517e-14
# 2  0.378541  0.031167  0.029876 -0.208445   0.234954 -1.035423e-15
# 3  0.403467 -0.054593  0.313530 -0.272598   0.245166  9.533447e-16
# 4  0.867119 -0.240445 -0.415212 -0.447068   0.276098 -2.400901e-15

# %%
#id_stocks_dict["AEP"]

# %%
id_stocks_df
# Out:
#     AEP Explained Variance  INTC Explained Variance  PEP Explained Variance
# 0             4.006194e-01             3.581493e-01            4.004766e-01
# 1             2.239743e-01             1.826784e-01            2.225360e-01
# 2             1.295831e-01             1.265498e-01            1.241734e-01
# 3             8.822495e-02             9.845204e-02            9.038749e-02
# 4             5.913470e-02             6.266229e-02            5.602719e-02
# 5             3.358664e-02             5.783798e-02            3.585996e-02
# 6             3.217122e-02             3.722506e-02            3.002935e-02
# 7             1.877908e-02             3.401319e-02            2.356600e-02
# 8             7.626794e-03             2.697486e-02            8.543224e-03
# 9             4.688155e-03             8.870888e-03            4.355192e-03
# 10            1.611698e-03             6.586242e-03            4.045677e-03
# 11            6.700011e-33             7.072799e-33            3.139036e-33

# %%
id_stocks_cumsum_df = id_stocks_df.cumsum()
id_stocks_cumsum_df
# Out:
#     AEP Explained Variance  INTC Explained Variance  PEP Explained Variance
# 0                 0.400619                 0.358149                0.400477
# 1                 0.624594                 0.540828                0.623013
# 2                 0.754177                 0.667377                0.747186
# 3                 0.842402                 0.765829                0.837573
# 4                 0.901536                 0.828492                0.893601
# 5                 0.935123                 0.886330                0.929461
# 6                 0.967294                 0.923555                0.959490
# 7                 0.986073                 0.957568                0.983056
# 8                 0.993700                 0.984543                0.991599
# 9                 0.998388                 0.993414                0.995954
# 10                1.000000                 1.000000                1.000000
# 11                1.000000                 1.000000                1.000000

# %%
for stock in list(id_stocks_cumsum_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_cumsum_df[stock], label=stock);
    plt.legend();

# %%
id_stocks_df_T = id_stocks_df.T
id_stocks_df_T
# Out:
#                                0         1         2         3         4   \
# AEP Explained Variance   0.400619  0.223974  0.129583  0.088225  0.059135
# INTC Explained Variance  0.358149  0.182678  0.126550  0.098452  0.062662
# PEP Explained Variance   0.400477  0.222536  0.124173  0.090387  0.056027
#
#                                5         6         7         8         9   \
# AEP Explained Variance   0.033587  0.032171  0.018779  0.007627  0.004688
# INTC Explained Variance  0.057838  0.037225  0.034013  0.026975  0.008871
# PEP Explained Variance   0.035860  0.030029  0.023566  0.008543  0.004355
#
#                                10            11
# AEP Explained Variance   0.001612  6.700011e-33
# INTC Explained Variance  0.006586  7.072799e-33
# PEP Explained Variance   0.004046  3.139036e-33

# %% [markdown]
# #### Plotting the `explained_variance_ratio` of the vintage set

# %%
for stock in list(id_stocks_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df[stock], label=stock);
    plt.legend();

# %%
for feature in list(id_stocks_df_T):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df_T[feature], label=feature);
    plt.legend();

# %% [markdown]
# ## Exploring Companies per Vintage - (25, 30]

# %%
old_companies = stocks_tickers[-2]
old_companies
# Out:
# ['AAPL',
#  'ADI',
#  'ADP',
#  'AMAT',
#  'AMD',
#  'AMGN',
#  'APA',
#  'CSX',
#  'EXC',
#  'MAT',
#  'NWL',
#  'TXN',
#  'WEN']

# %%
old_df = precise_stocks_selector_local(tickers_list=old_companies, verbose=1)
# Out:
# ****** Starting browsing the '../raw_data/processed/' directory ******
#
#    *** Complete file selection ***
# ****** Starting stocks DataFrame creation the sample ******
#
# amat.csv missing
#
# csx.csv missing
#
# mat.csv missing
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 3
#
# ['amat.csv', 'csx.csv', 'mat.csv']

# %%
stock_list = list(old_df.ticker.unique())
stock_list
# Out:
# ['AAPL', 'ADI', 'ADP', 'AMD', 'AMGN', 'APA', 'EXC', 'NWL', 'TXN', 'WEN']

# %% [markdown]
# ### Separating the DataFrames by appending them to a list `dfs`

# %%
old_df.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0   AAPL  1984-10-24  57.978007   76.690103          69.424914 -5.139242e+09
# 1   AAPL  1984-10-25  49.247645   56.625203          68.325221 -5.322591e+09
# 2   AAPL  1984-10-26  44.483899   43.374797          58.896701 -5.425815e+09
# 3   AAPL  1984-10-29  45.183124   44.997296          48.332432 -5.484525e+09
# 4   AAPL  1984-10-30  48.093222   51.703624          46.691906 -5.570994e+09
#
#          OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0  387549732  0.003297  19.036526  35.250645  23.135370 -0.000432   0.001254
# 1  204200382  0.003326  18.051296  32.458308  29.224107 -0.000390   0.001037
# 2   71070262  0.003286  17.088681  30.521333  33.447714 -0.000548   0.000704
# 3  129780480  0.003117  16.194824  29.881216  32.746222 -0.000641   0.000488
# 4  216248865  0.003048  15.133939  31.950924  31.104445 -0.000608   0.000417
#
#    MACD_signal  5TD_return  10TD_return  20TD_return
# 0    -0.001687   -0.052010    -0.018263    -0.119206
# 1    -0.001427   -0.009378    -0.022156    -0.060181
# 2    -0.001251    0.009726    -0.055397    -0.026218
# 3    -0.001129    0.000000    -0.025925    -0.003162
# 4    -0.001025    0.048060    -0.060959     0.035265

# %%
dfs = []

for stock in stock_list:
    df = old_df[old_df['ticker']==stock]
    df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    dfs.append(df)

# %%
dfs[0].head()
# Out:
#          RSI  Stochastic  Stochastic_signal           ADI        OBV  \
# 0  57.978007   76.690103          69.424914 -5.139242e+09  387549732
# 1  49.247645   56.625203          68.325221 -5.322591e+09  204200382
# 2  44.483899   43.374797          58.896701 -5.425815e+09   71070262
# 3  45.183124   44.997296          48.332432 -5.484525e+09  129780480
# 4  48.093222   51.703624          46.691906 -5.570994e+09  216248865
#
#         ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  MACD_signal
# 0  0.003297  19.036526  35.250645  23.135370 -0.000432   0.001254    -0.001687
# 1  0.003326  18.051296  32.458308  29.224107 -0.000390   0.001037    -0.001427
# 2  0.003286  17.088681  30.521333  33.447714 -0.000548   0.000704    -0.001251
# 3  0.003117  16.194824  29.881216  32.746222 -0.000641   0.000488    -0.001129
# 4  0.003048  15.133939  31.950924  31.104445 -0.000608   0.000417    -0.001025

# %% [markdown]
# ### Characterizing features of stocks with PCA

# %% [markdown]
# df = np.array(scaler.fit_transform(dfs[0]))
# stock_pca = pca.fit(dfs[0])
# stock_pca = np.array(pca.transform(dfs[0]))
# pd.DataFrame(stock_pca)
#
# #print(stock_pca.shape)
# pca_stocks_dict[f"{stock_list[idx]}"].append(stock_pca)

# %% [markdown]
# #### Gathering the `PCA` and `explained_variance_ratio`

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
pca = PCA()

pca_stocks_dict = dict.fromkeys(stock_list)
id_stocks_dict = dict.fromkeys(stock_list)

id_stocks_df = pd.DataFrame()

for idx, df in enumerate(dfs):
    df = scaler.fit_transform(df)
    stock_pca = pca.fit_transform(df)
    #print(stock_pca.shape)
    pca_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(stock_pca, columns=list(dfs[0]))
    id_stocks_df[f"{stock_list[idx]} Explained Variance"] = pca.explained_variance_ratio_
    #id_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(data=pca.explained_variance_ratio_,
    #                                                    columns=[f"{stock_list[idx]} Explained Variance"])
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#pca_stocks_dict["AEP"].head()

# %%
#id_stocks_dict["AEP"]

# %%
id_stocks_df
# Out:
#     AAPL Explained Variance  ADI Explained Variance  ADP Explained Variance  \
# 0              4.038844e-01            4.068285e-01            3.877856e-01
# 1              2.037635e-01            2.004476e-01            2.169302e-01
# 2              1.236452e-01            1.231866e-01            1.332155e-01
# 3              8.699544e-02            8.016999e-02            8.885689e-02
# 4              7.015398e-02            6.447515e-02            6.303831e-02
# 5              4.504773e-02            4.194975e-02            3.896450e-02
# 6              2.759370e-02            3.227088e-02            3.396730e-02
# 7              2.464081e-02            2.711069e-02            2.026613e-02
# 8              6.853247e-03            1.153206e-02            8.324882e-03
# 9              4.402536e-03            8.106420e-03            4.550480e-03
# 10             3.019524e-03            3.922348e-03            4.100211e-03
# 11             5.391279e-33            6.428170e-33            7.369804e-33
#
#     AMD Explained Variance  AMGN Explained Variance  APA Explained Variance  \
# 0             4.441846e-01             4.030477e-01            4.260171e-01
# 1             1.567854e-01             1.986642e-01            2.099019e-01
# 2             1.023830e-01             1.228988e-01            1.251681e-01
# 3             9.222861e-02             7.979144e-02            7.847961e-02
# 4             7.831339e-02             6.267198e-02            5.634440e-02
# 5             5.317011e-02             5.109276e-02            3.097231e-02
# 6             2.584804e-02             3.389747e-02            2.886155e-02
# 7             2.243996e-02             2.757610e-02            2.522602e-02
# 8             1.503679e-02             8.687461e-03            7.980112e-03
# 9             6.630295e-03             7.941447e-03            7.522417e-03
# 10            2.979871e-03             3.730640e-03            3.526501e-03
# 11            4.284626e-33             4.892046e-33            7.316473e-33
#
#     EXC Explained Variance  NWL Explained Variance  TXN Explained Variance  \
# 0             4.058229e-01            4.424583e-01            4.108351e-01
# 1             2.161360e-01            2.011034e-01            2.019193e-01
# 2             1.296668e-01            1.227890e-01            1.213542e-01
# 3             8.505894e-02            8.461407e-02            8.214711e-02
# 4             5.509455e-02            4.466385e-02            6.575949e-02
# 5             3.607542e-02            3.869077e-02            4.136685e-02
# 6             3.126343e-02            2.750598e-02            2.929188e-02
# 7             2.544441e-02            2.526349e-02            2.423707e-02
# 8             7.851428e-03            7.171216e-03            1.181106e-02
# 9             5.305767e-03            3.358868e-03            7.623320e-03
# 10            2.280326e-03            2.381064e-03            3.654742e-03
# 11            7.405542e-33            9.281514e-33            5.458175e-33
#
#     WEN Explained Variance
# 0             3.865519e-01
# 1             2.068700e-01
# 2             1.264539e-01
# 3             8.687059e-02
# 4             6.507457e-02
# 5             4.037412e-02
# 6             3.789923e-02
# 7             3.333184e-02
# 8             8.856134e-03
# 9             4.805326e-03
# 10            2.912451e-03
# 11            5.117985e-33

# %%
id_stocks_cumsum_df = id_stocks_df.cumsum()
id_stocks_cumsum_df
# Out:
#     AAPL Explained Variance  ADI Explained Variance  ADP Explained Variance  \
# 0                  0.403884                0.406828                0.387786
# 1                  0.607648                0.607276                0.604716
# 2                  0.731293                0.730463                0.737931
# 3                  0.818288                0.810633                0.826788
# 4                  0.888442                0.875108                0.889826
# 5                  0.933490                0.917058                0.928791
# 6                  0.961084                0.949328                0.962758
# 7                  0.985725                0.976439                0.983024
# 8                  0.992578                0.987971                0.991349
# 9                  0.996980                0.996078                0.995900
# 10                 1.000000                1.000000                1.000000
# 11                 1.000000                1.000000                1.000000
#
#     AMD Explained Variance  AMGN Explained Variance  APA Explained Variance  \
# 0                 0.444185                 0.403048                0.426017
# 1                 0.600970                 0.601712                0.635919
# 2                 0.703353                 0.724611                0.761087
# 3                 0.795582                 0.804402                0.839567
# 4                 0.873895                 0.867074                0.895911
# 5                 0.927065                 0.918167                0.926883
# 6                 0.952913                 0.952064                0.955745
# 7                 0.975353                 0.979640                0.980971
# 8                 0.990390                 0.988328                0.988951
# 9                 0.997020                 0.996269                0.996473
# 10                1.000000                 1.000000                1.000000
# 11                1.000000                 1.000000                1.000000
#
#     EXC Explained Variance  NWL Explained Variance  TXN Explained Variance  \
# 0                 0.405823                0.442458                0.410835
# 1                 0.621959                0.643562                0.612754
# 2                 0.751626                0.766351                0.734108
# 3                 0.836685                0.850965                0.816256
# 4                 0.891779                0.895629                0.882015
# 5                 0.927855                0.934319                0.923382
# 6                 0.959118                0.961825                0.952674
# 7                 0.984562                0.987089                0.976911
# 8                 0.992414                0.994260                0.988722
# 9                 0.997720                0.997619                0.996345
# 10                1.000000                1.000000                1.000000
# 11                1.000000                1.000000                1.000000
#
#     WEN Explained Variance
# 0                 0.386552
# 1                 0.593422
# 2                 0.719876
# 3                 0.806746
# 4                 0.871821
# 5                 0.912195
# 6                 0.950094
# 7                 0.983426
# 8                 0.992282
# 9                 0.997088
# 10                1.000000
# 11                1.000000

# %%
for stock in list(id_stocks_cumsum_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_cumsum_df[stock], label=stock);
    plt.legend();

# %%
id_stocks_df_T = id_stocks_df.T
id_stocks_df_T
# Out:
#                                0         1         2         3         4   \
# AAPL Explained Variance  0.403884  0.203763  0.123645  0.086995  0.070154
# ADI Explained Variance   0.406828  0.200448  0.123187  0.080170  0.064475
# ADP Explained Variance   0.387786  0.216930  0.133216  0.088857  0.063038
# AMD Explained Variance   0.444185  0.156785  0.102383  0.092229  0.078313
# AMGN Explained Variance  0.403048  0.198664  0.122899  0.079791  0.062672
# APA Explained Variance   0.426017  0.209902  0.125168  0.078480  0.056344
# EXC Explained Variance   0.405823  0.216136  0.129667  0.085059  0.055095
# NWL Explained Variance   0.442458  0.201103  0.122789  0.084614  0.044664
# TXN Explained Variance   0.410835  0.201919  0.121354  0.082147  0.065759
# WEN Explained Variance   0.386552  0.206870  0.126454  0.086871  0.065075
#
#                                5         6         7         8         9   \
# AAPL Explained Variance  0.045048  0.027594  0.024641  0.006853  0.004403
# ADI Explained Variance   0.041950  0.032271  0.027111  0.011532  0.008106
# ADP Explained Variance   0.038964  0.033967  0.020266  0.008325  0.004550
# AMD Explained Variance   0.053170  0.025848  0.022440  0.015037  0.006630
# AMGN Explained Variance  0.051093  0.033897  0.027576  0.008687  0.007941
# APA Explained Variance   0.030972  0.028862  0.025226  0.007980  0.007522
# EXC Explained Variance   0.036075  0.031263  0.025444  0.007851  0.005306
# NWL Explained Variance   0.038691  0.027506  0.025263  0.007171  0.003359
# TXN Explained Variance   0.041367  0.029292  0.024237  0.011811  0.007623
# WEN Explained Variance   0.040374  0.037899  0.033332  0.008856  0.004805
#
#                                10            11
# AAPL Explained Variance  0.003020  5.391279e-33
# ADI Explained Variance   0.003922  6.428170e-33
# ADP Explained Variance   0.004100  7.369804e-33
# AMD Explained Variance   0.002980  4.284626e-33
# AMGN Explained Variance  0.003731  4.892046e-33
# APA Explained Variance   0.003527  7.316473e-33
# EXC Explained Variance   0.002280  7.405542e-33
# NWL Explained Variance   0.002381  9.281514e-33
# TXN Explained Variance   0.003655  5.458175e-33
# WEN Explained Variance   0.002912  5.117985e-33

# %% [markdown]
# #### Plotting the `explained_variance_ratio` of the vintage set

# %%
for stock in list(id_stocks_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df[stock], label=stock);
    plt.legend()

# %%
for feature in list(id_stocks_df_T):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df_T[feature], label=feature);
    plt.legend();

# %% [markdown]
# ## Exploring Companies per Vintage - (20, 25]

# %%
old_companies = stocks_tickers[-3]
old_companies
# Out:
# ['ADBE',
#  'ADSK',
#  'ANIX',
#  'ATRO',
#  'BIIB',
#  'CINF',
#  'CMCSA',
#  'COST',
#  'CSCO',
#  'CTAS',
#  'EXPD',
#  'FAST',
#  'FISV',
#  'FITB',
#  'GNTX',
#  'HAS',
#  'HBAN',
#  'KBAL',
#  'KLAC',
#  'LRCX',
#  'MSFT',
#  'MU',
#  'MXIM',
#  'NLOK',
#  'NTRS',
#  'ODP',
#  'PAYX',
#  'PCAR',
#  'QCOM',
#  'ROST',
#  'SLM',
#  'TER',
#  'TROW',
#  'WBA',
#  'XLNX',
#  'XRAY',
#  'ZION']

# %%
old_df = precise_stocks_selector_local(tickers_list=old_companies, verbose=1)
# Out:
# ****** Starting browsing the '../raw_data/processed/' directory ******
#
#    *** Complete file selection ***
# ****** Starting stocks DataFrame creation the sample ******
#
# anix.csv missing
#
# cost.csv missing
#
# ctas.csv missing
#
# fast.csv missing
#
# gntx.csv missing
#
# has.csv missing
#
# lrcx.csv missing
#
# msft.csv missing
#
# mu.csv missing
#
# ntrs.csv missing
#
# payx.csv missing
#
# rost.csv missing
#
# xlnx.csv missing
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 13
#
# ['anix.csv', 'cost.csv', 'ctas.csv', 'fast.csv', 'gntx.csv', 'has.csv', 'lrcx.csv', 'msft.csv', 'mu.csv', 'ntrs.csv', 'payx.csv', 'rost.csv', 'xlnx.csv']

# %%
stock_list = list(old_df.ticker.unique())
stock_list
# Out:
# ['ADBE',
#  'ADSK',
#  'ATRO',
#  'BIIB',
#  'CINF',
#  'CMCSA',
#  'CSCO',
#  'EXPD',
#  'FISV',
#  'FITB',
#  'HBAN',
#  'KBAL',
#  'KLAC',
#  'MXIM',
#  'NLOK',
#  'ODP',
#  'PCAR',
#  'QCOM',
#  'SLM',
#  'TER',
#  'TROW',
#  'WBA',
#  'XRAY',
#  'ZION']

# %% [markdown]
# ### Separating the DataFrames by appending them to a list `dfs`

# %%
old_df.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal         ADI  \
# 0   ADBE  1986-10-01  57.523855   50.000000          54.761905 -58035200.0
# 1   ADBE  1986-10-02  57.523855   25.000000          44.047619 -58483200.0
# 2   ADBE  1986-10-03  57.523855    0.000000          25.000000 -58572800.0
# 3   ADBE  1986-10-06  63.434871   33.333333          19.444444 -58828800.0
# 4   ADBE  1986-10-07  63.434871   33.333333          22.222222 -59225600.0
#
#         OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0  49049600  0.015385  31.226183  24.162357  16.293037  0.009684  -0.002270
# 1  49497600  0.015714  30.385159  21.978650  14.820531  0.009007  -0.002358
# 2  49587200  0.016020  29.604207  20.029236  13.506012  0.008374  -0.002393
# 3  49843200  0.016305  28.879039  18.282881  12.328419  0.008580  -0.001749
# 4  50240000  0.015854  28.205667  17.463017  11.775572  0.008644  -0.001348
#
#    MACD_signal  5TD_return  10TD_return  20TD_return
# 0     0.011954        0.04     0.040000     0.400000
# 1     0.011364        0.04     0.040000     0.360000
# 2     0.010766        0.04     0.040000     0.320000
# 3     0.010329        0.00     0.038462     0.269231
# 4     0.009992        0.00     0.038462     0.230769

# %%
dfs = []

for stock in stock_list:
    df = old_df[old_df['ticker']==stock]
    df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    dfs.append(df)

# %%
dfs[0].head()
# Out:
#          RSI  Stochastic  Stochastic_signal         ADI       OBV       ATR  \
# 0  57.523855   50.000000          54.761905 -58035200.0  49049600  0.015385
# 1  57.523855   25.000000          44.047619 -58483200.0  49497600  0.015714
# 2  57.523855    0.000000          25.000000 -58572800.0  49587200  0.016020
# 3  63.434871   33.333333          19.444444 -58828800.0  49843200  0.016305
# 4  63.434871   33.333333          22.222222 -59225600.0  50240000  0.015854
#
#          ADX    ADX_pos    ADX_neg      MACD  MACD_diff  MACD_signal
# 0  31.226183  24.162357  16.293037  0.009684  -0.002270     0.011954
# 1  30.385159  21.978650  14.820531  0.009007  -0.002358     0.011364
# 2  29.604207  20.029236  13.506012  0.008374  -0.002393     0.010766
# 3  28.879039  18.282881  12.328419  0.008580  -0.001749     0.010329
# 4  28.205667  17.463017  11.775572  0.008644  -0.001348     0.009992

# %% [markdown]
# ### Characterizing features of stocks with PCA

# %% [markdown]
# df = np.array(scaler.fit_transform(dfs[0]))
# stock_pca = pca.fit(dfs[0])
# stock_pca = np.array(pca.transform(dfs[0]))
# pd.DataFrame(stock_pca)
#
# #print(stock_pca.shape)
# pca_stocks_dict[f"{stock_list[idx]}"].append(stock_pca)

# %% [markdown]
# #### Gathering the `PCA` and `explained_variance_ratio`

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
pca = PCA()

pca_stocks_dict = dict.fromkeys(stock_list)
id_stocks_dict = dict.fromkeys(stock_list)

id_stocks_df = pd.DataFrame()

for idx, df in enumerate(dfs):
    df = scaler.fit_transform(df)
    stock_pca = pca.fit_transform(df)
    #print(stock_pca.shape)
    pca_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(stock_pca, columns=list(dfs[0]))
    id_stocks_df[f"{stock_list[idx]} Explained Variance"] = pca.explained_variance_ratio_
    #id_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(data=pca.explained_variance_ratio_,
    #                                                    columns=[f"{stock_list[idx]} Explained Variance"])
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#pca_stocks_dict["AEP"].head()

# %%
#id_stocks_dict["AEP"]

# %%
id_stocks_df
# Out:
#     ADBE Explained Variance  ADSK Explained Variance  ATRO Explained Variance  \
# 0              3.967471e-01             4.089742e-01             3.520424e-01
# 1              2.172641e-01             2.177947e-01             2.240085e-01
# 2              1.163434e-01             1.153014e-01             1.186777e-01
# 3              8.623521e-02             8.719154e-02             9.766209e-02
# 4              6.493466e-02             6.541248e-02             5.904108e-02
# 5              4.938399e-02             4.000065e-02             5.456082e-02
# 6              3.081194e-02             2.862842e-02             3.984846e-02
# 7              2.270841e-02             2.337127e-02             2.915737e-02
# 8              7.721417e-03             7.486311e-03             1.099985e-02
# 9              4.645698e-03             3.649120e-03             8.972942e-03
# 10             3.204105e-03             2.189957e-03             5.028778e-03
# 11             4.478135e-33             3.391583e-33             8.935068e-33
#
#     BIIB Explained Variance  CINF Explained Variance  \
# 0              3.982663e-01             3.977872e-01
# 1              2.233003e-01             2.132585e-01
# 2              1.231792e-01             1.298821e-01
# 3              8.056447e-02             8.772952e-02
# 4              6.075310e-02             5.784532e-02
# 5              3.821553e-02             3.836130e-02
# 6              3.209422e-02             3.136971e-02
# 7              2.822487e-02             2.745981e-02
# 8              7.932867e-03             8.245322e-03
# 9              3.947656e-03             4.489573e-03
# 10             3.521561e-03             3.571603e-03
# 11             8.213305e-33             6.225611e-33
#
#     CMCSA Explained Variance  CSCO Explained Variance  \
# 0               4.242981e-01             4.328603e-01
# 1               2.149700e-01             1.763965e-01
# 2               1.200133e-01             1.200468e-01
# 3               8.622412e-02             8.766845e-02
# 4               5.256461e-02             5.333200e-02
# 5               3.129090e-02             4.668764e-02
# 6               2.801584e-02             2.968101e-02
# 7               2.481366e-02             2.435292e-02
# 8               7.890749e-03             1.743170e-02
# 9               6.188377e-03             7.547141e-03
# 10              3.730433e-03             3.995493e-03
# 11              2.789101e-33             2.869090e-32
#
#     EXPD Explained Variance  FISV Explained Variance  FITB Explained Variance  \
# 0              4.138215e-01             3.755423e-01             3.834362e-01
# 1              2.317488e-01             2.254898e-01             1.374642e-01
# 2              1.212323e-01             1.347982e-01             1.139043e-01
# 3              7.664508e-02             8.639015e-02             9.000826e-02
# 4              4.468965e-02             6.493188e-02             8.323295e-02
# 5              3.619470e-02             3.843653e-02             6.151065e-02
# 6              3.415648e-02             3.185761e-02             4.623830e-02
# SLM Explained Variance    0.034896  0.029690  0.025397  0.018874  0.007543
# TER Explained Variance    0.062768  0.029832  0.024645  0.012929  0.007116
# TROW Explained Variance   0.029571  0.026822  0.023071  0.014286  0.007924
# WBA Explained Variance    0.029916  0.027837  0.018154  0.007962  0.005633
# XRAY Explained Variance   0.031017  0.028917  0.012968  0.008065  0.003977
# ZION Explained Variance   0.036386  0.034343  0.020597  0.009488  0.007408
#
#                                 10            11
# ADBE Explained Variance   0.003204  4.478135e-33
# ADSK Explained Variance   0.002190  3.391583e-33
# ATRO Explained Variance   0.005029  8.935068e-33
# BIIB Explained Variance   0.003522  8.213305e-33
# CINF Explained Variance   0.003572  6.225611e-33
# CMCSA Explained Variance  0.003730  2.789101e-33
# CSCO Explained Variance   0.003995  2.869090e-32
# EXPD Explained Variance   0.004643  1.565523e-32
# FISV Explained Variance   0.001155  4.782634e-33
# FITB Explained Variance   0.008090  6.711883e-33
# HBAN Explained Variance   0.003584  2.764361e-33
# KBAL Explained Variance   0.004405  7.442041e-33
# KLAC Explained Variance   0.003613  8.242896e-33
# MXIM Explained Variance   0.003907  5.992151e-32
# NLOK Explained Variance   0.003410  3.873685e-33
# ODP Explained Variance    0.003239  1.486961e-32
# PCAR Explained Variance   0.003223  9.858855e-33
# QCOM Explained Variance   0.003423  6.689089e-33
# SLM Explained Variance    0.003592  9.248168e-33
# TER Explained Variance    0.003392  4.582270e-33
# TROW Explained Variance   0.003619  4.229412e-33
# WBA Explained Variance    0.003293  7.905001e-33
# XRAY Explained Variance   0.003267  3.949527e-33
# ZION Explained Variance   0.004048  3.532651e-33

# %%
id_stocks_cumsum_df = id_stocks_df.cumsum()
id_stocks_cumsum_df
# Out:
#     ADBE Explained Variance  ADSK Explained Variance  ATRO Explained Variance  \
# 0                  0.396747                 0.408974                 0.352042
# 1                  0.614011                 0.626769                 0.576051
# 2                  0.730355                 0.742070                 0.694729
# 3                  0.816590                 0.829262                 0.792391
# 4                  0.881524                 0.894674                 0.851432
# 5                  0.930908                 0.934675                 0.905993
# 6                  0.961720                 0.963303                 0.945841
# 7                  0.984429                 0.986675                 0.974998
# 8                  0.992150                 0.994161                 0.985998
# 9                  0.996796                 0.997810                 0.994971
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     BIIB Explained Variance  CINF Explained Variance  \
# 0                  0.398266                 0.397787
# 1                  0.621567                 0.611046
# 2                  0.744746                 0.740928
# 3                  0.825310                 0.828657
# 4                  0.886063                 0.886503
# 5                  0.924279                 0.924864
# 6                  0.956373                 0.956234
# 7                  0.984598                 0.983694
# 8                  0.992531                 0.991939
# 9                  0.996478                 0.996428
# 10                 1.000000                 1.000000
# 11                 1.000000                 1.000000
#
#     CMCSA Explained Variance  CSCO Explained Variance  \
# 0                   0.424298                 0.432860
# 1                   0.639268                 0.609257
# 2                   0.759281                 0.729304
# 3                   0.845505                 0.816972
# 4                   0.898070                 0.870304
# 5                   0.929361                 0.916992
# 6                   0.957377                 0.946673
# 7                   0.982190                 0.971026
# 8                   0.990081                 0.988457
# 9                   0.996270                 0.996005
# 10                  1.000000                 1.000000
# 11                  1.000000                 1.000000
#
#     EXPD Explained Variance  FISV Explained Variance  FITB Explained Variance  \
# 0                  0.413821                 0.375542                 0.383436
# 1                  0.645570                 0.601032                 0.520900
# 2                  0.766803                 0.735830                 0.634805
# 3                  0.843448                 0.822221                 0.724813
# 4                  0.888137                 0.887152                 0.808046
# 5                  0.924332                 0.925589                 0.869557
# 6                  0.958489                 0.957447                 0.915795
# 7                  0.976330                 0.985169                 0.950981
# 8                  0.986754                 0.994515                 0.980548
# 9                  0.995357                 0.998845                 0.991910
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     ...  NLOK Explained Variance  ODP Explained Variance  \
# 0   ...                 0.446722                0.450643
# 1   ...                 0.666375                0.597286
# 2   ...                 0.780102                0.713581
# 3   ...                 0.857795                0.803039
# 4   ...                 0.904830                0.883115
# 5   ...                 0.935559                0.919532
# 6   ...                 0.961739                0.948476
# 7   ...                 0.981099                0.974470
# 8   ...                 0.989008                0.990035
# 9   ...                 0.996590                0.996761
# 10  ...                 1.000000                1.000000
# 11  ...                 1.000000                1.000000
#
#     PCAR Explained Variance  QCOM Explained Variance  SLM Explained Variance  \
# 0                  0.414932                 0.428662                0.428153
# 1                  0.646449                 0.626176                0.618509
# 2                  0.768536                 0.747353                0.745320
# 3                  0.849844                 0.829778                0.831910
# 4                  0.905342                 0.883750                0.880008
# 5                  0.939711                 0.923971                0.914904
# 6                  0.966661                 0.952417                0.944594
# 7                  0.982468                 0.976068                0.969992
# 8                  0.990273                 0.988939                0.988865
# 9                  0.996777                 0.996577                0.996408
# 10                 1.000000                 1.000000                1.000000
# 11                 1.000000                 1.000000                1.000000
#
#     TER Explained Variance  TROW Explained Variance  WBA Explained Variance  \
# 0                 0.428561                 0.416609                0.434572
# 1                 0.597485                 0.630844                0.655945
# 2                 0.709758                 0.753567                0.775434
# 3                 0.792751                 0.838499                0.860405
# 4                 0.859320                 0.894707                0.907205
# 5                 0.922087                 0.924277                0.937120
# 6                 0.951919                 0.951099                0.964958
# 7                 0.976564                 0.974170                0.983112
# 8                 0.989492                 0.988457                0.991074
# 9                 0.996608                 0.996381                0.996707
# 10                1.000000                 1.000000                1.000000
# 11                1.000000                 1.000000                1.000000
#
#     XRAY Explained Variance  ZION Explained Variance
# 0                  0.420499                 0.431287
# 1                  0.658149                 0.609341
# 2                  0.783394                 0.730098
# 3                  0.868549                 0.814759
# 4                  0.911789                 0.887731
# 5                  0.942806                 0.924117
# 6                  0.971723                 0.958460
# 7                  0.984691                 0.979057
# 8                  0.992756                 0.988544
# 9                  0.996733                 0.995952
# 10                 1.000000                 1.000000
# 11                 1.000000                 1.000000
#
# [12 rows x 24 columns]

# %%
for stock in list(id_stocks_cumsum_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_cumsum_df[stock])#,label=stock);
    #plt.legend();

# %% [markdown]
# #### Plotting the `explained_variance_ratio` of the vintage set

# %%
for stock in list(id_stocks_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df[stock])#,label=stock);
    #plt.legend();

# %%
for feature in list(id_stocks_df_T):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df_T[feature], label=feature);
    plt.legend();

# %% [markdown]
# ## Exploring Companies per Vintage - (15, 20]

# %%
companies = stocks_tickers[-4]
companies
# Out:
# ['ADMP',
#  'AMZN',
#  'AXGN',
#  'BBBY',
#  'CHKP',
#  'CHRW',
#  'CTXS',
#  'DISH',
#  'DLTR',
#  'EBAY',
#  'FLEX',
#  'GILD',
#  'HSIC',
#  'IAC',
#  'INTU',
#  'LAMR',
#  'MAR',
#  'MCHP',
#  'MITK',
#  'NTAP',
#  'NVDA',
#  'PDCO',
#  'PRDO',
#  'PTEN',
#  'RAVE',
#  'RYAAY',
#  'SANM',
#  'SBUX',
#  'SNPS',
#  'TTNP',
#  'VIAV',
#  'VRSN']

# %%
companies_df = precise_stocks_selector_local(tickers_list=companies, verbose=1)
# Out:
# ****** Starting browsing the '../raw_data/processed/' directory ******
#
#    *** Complete file selection ***
# ****** Starting stocks DataFrame creation the sample ******
#
# ctxs.csv missing
#
# flex.csv missing
#
# intu.csv missing
#
# sbux.csv missing
#
# snps.csv missing
#
#
# ****** Starting concatenating the sample ******
#
#
# ##### Problematic Issue: following stocks not in local database! #####
# Number of missed stocks: 5
#
# ['ctxs.csv', 'flex.csv', 'intu.csv', 'sbux.csv', 'snps.csv']

# %%
stock_list = list(companies_df.ticker.unique())
stock_list
# Out:
# ['ADMP',
#  'AMZN',
#  'AXGN',
#  'BBBY',
#  'CHKP',
#  'CHRW',
#  'DISH',
#  'DLTR',
#  'EBAY',
#  'GILD',
#  'HSIC',
#  'IAC',
#  'LAMR',
#  'MAR',
#  'MCHP',
#  'MITK',
#  'NTAP',
#  'NVDA',
#  'PDCO',
#  'PRDO',
#  'PTEN',
#  'RAVE',
#  'RYAAY',
#  'SANM',
#  'TTNP',
#  'VIAV',
#  'VRSN']

# %% [markdown]
# ### Separating the DataFrames by appending them to a list `dfs`

# %%
companies_df.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal          ADI  \
# 0   ADMP  1995-09-29  39.278296   13.793103       9.195402e+00 -2328.909441
# 1   ADMP  1995-10-03  37.232995    0.000000       9.195402e+00 -2365.909441
# 2   ADMP  1995-10-05  37.232995    0.000000       4.597701e+00 -2365.909441
# 3   ADMP  1995-10-06  37.232995    0.000000       5.921189e-15 -2374.909441
# 4   ADMP  1995-10-09  37.232995    0.000000       5.921189e-15 -2384.909441
#
#     OBV        ATR       ADX    ADX_pos    ADX_neg       MACD  MACD_diff  \
# 0  3865  63.250157  9.136276  15.840928  18.273836 -32.032222 -10.539257
# 1  3828  60.189431  9.444997  15.455462  20.262522 -35.002950 -10.807988
# 2  3852  55.890186  9.731667  15.455462  20.262522 -36.931550 -10.189271
# 3  3861  54.812316  9.181119  19.972402  19.179962 -38.021689  -9.023528
# 4  3871  52.354293  8.669895  19.413898  18.643617 -38.442491  -7.555464
#
#    MACD_signal  5TD_return  10TD_return  20TD_return
# 0   -21.492965    0.024000     0.124000     0.174000
# 1   -24.194962    0.049180     0.178279     0.256148
# 2   -26.742280    0.024590     0.229508     0.202869
# 3   -28.998162    0.075820     0.217213     0.280738
# 4   -30.887028    0.178279     0.151639     0.229508

# %%
dfs = []

for stock in stock_list:
    df = companies_df[companies_df['ticker']==stock]
    df = df.drop(columns=['ticker', 'date', '5TD_return', '10TD_return', '20TD_return'])
    dfs.append(df)

# %%
dfs[0].head()
# Out:
#          RSI  Stochastic  Stochastic_signal          ADI   OBV        ATR  \
# 0  39.278296   13.793103       9.195402e+00 -2328.909441  3865  63.250157
# 1  37.232995    0.000000       9.195402e+00 -2365.909441  3828  60.189431
# 2  37.232995    0.000000       4.597701e+00 -2365.909441  3852  55.890186
# 3  37.232995    0.000000       5.921189e-15 -2374.909441  3861  54.812316
# 4  37.232995    0.000000       5.921189e-15 -2384.909441  3871  52.354293
#
#         ADX    ADX_pos    ADX_neg       MACD  MACD_diff  MACD_signal
# 0  9.136276  15.840928  18.273836 -32.032222 -10.539257   -21.492965
# 1  9.444997  15.455462  20.262522 -35.002950 -10.807988   -24.194962
# 2  9.731667  15.455462  20.262522 -36.931550 -10.189271   -26.742280
# 3  9.181119  19.972402  19.179962 -38.021689  -9.023528   -28.998162
# 4  8.669895  19.413898  18.643617 -38.442491  -7.555464   -30.887028

# %% [markdown]
# ### Characterizing features of stocks with PCA

# %% [markdown]
# df = np.array(scaler.fit_transform(dfs[0]))
# stock_pca = pca.fit(dfs[0])
# stock_pca = np.array(pca.transform(dfs[0]))
# pd.DataFrame(stock_pca)
#
# #print(stock_pca.shape)
# pca_stocks_dict[f"{stock_list[idx]}"].append(stock_pca)

# %%
tesdfd = pd.DataFrame(scaler.fit_transform(dfs[0]))
tesdfd
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#             0         1         2         3         4         5         6   \
# 0    -0.788839 -1.111153 -1.397298 -0.313692 -0.286209  1.150914 -1.373507
# 1    -0.960323 -1.586773 -1.397298 -0.313700 -0.286211  1.058022 -1.348303
# 2    -0.960323 -1.586773 -1.571789 -0.313700 -0.286210  0.927540 -1.324899
# 3    -0.960323 -1.586773 -1.746280 -0.313702 -0.286210  0.894827 -1.369846
# 4    -0.960323 -1.586773 -1.746280 -0.313704 -0.286209  0.820227 -1.411583
# 5    -0.313722 -0.468423 -1.335991 -0.313694 -0.286207  0.795179 -1.408443
# 6    -0.313722 -0.468423 -0.925701 -0.313688 -0.286205  0.771920 -1.405527
# 7    -0.564354 -1.027598 -0.720556 -0.313684 -0.286206  0.750323 -1.402820
# 8     0.067553  0.471050 -0.375891 -0.313675 -0.286204  0.778177 -1.315474
# 9     0.993033  1.861471  0.478878 -0.313658 -0.286200  0.899861 -1.120294
# 10    0.700381  1.346216  1.349761 -0.313650 -0.286202  0.872810 -0.939056
# 11    0.910980  1.861471  1.859866 -0.313631 -0.286197  0.847692 -0.747027
# 12    1.277275  1.861471  1.859866 -0.313583 -0.286186  0.824367 -0.528995
# 13    1.131723  1.676744  1.981126 -0.313553 -0.286200  0.802709 -0.326537
# 14    0.428184  0.691531  1.551910 -0.313579 -0.286206  0.808395 -0.203662
# 15   -0.015072 -0.047378  0.851609 -0.313589 -0.286208  0.784192 -0.194544
# 16    0.201913  0.322077  0.354622 -0.313634 -0.286198  0.809628 -0.156174
# 6197 -0.791344  2.381561  0.029760 -0.004506  0.033403
# 6198 -0.819652  2.284593  0.029587 -0.004265  0.033136
# 6199 -0.839291  2.217320  0.029484 -0.003900  0.032901
# 6200 -0.869872  2.185696  0.029448 -0.003438  0.032705
# 6201 -0.365167  1.851038  0.029511 -0.002824  0.032561
# 6202 -0.409591  1.746693  0.029608 -0.002244  0.032467
# 6203 -0.446670  1.659597  0.029703 -0.001788  0.032412
# 6204  0.669198  1.085877  0.030039 -0.000818  0.032440
# 6205  0.401983  0.754324  0.030242 -0.000377  0.032506
# 6206  0.301359  0.629473  0.030382 -0.000181  0.032589
# 6207  0.208074  0.513728  0.030537  0.000016  0.032688
# 6208  0.187994  0.386385  0.030680  0.000141  0.032798
# 6209  0.241915  0.206508  0.030854  0.000319  0.032924
# 6210  0.124721  0.145209  0.030998  0.000385  0.033055
# 6211  0.736452 -0.164620  0.031273  0.000767  0.033218
# 6212  0.539733 -0.319760  0.031421  0.000754  0.033381
# 6213  0.431573 -0.405060  0.031569  0.000747  0.033543
# 6214  0.309527 -0.347280  0.031669  0.000618  0.033694
# 6215  0.250421 -0.273306  0.031729  0.000415  0.033828
# 6216  0.433539 -0.372232  0.031836  0.000370  0.033957
# 6217  0.324453 -0.318047  0.031867  0.000145  0.034068
# 6218  0.238670 -0.391495  0.031903 -0.000023  0.034164
# 6219  0.152958 -0.152632  0.031919 -0.000209  0.034244
# 6220  1.386843 -0.573756  0.032024 -0.000132  0.034331
#
# [6221 rows x 12 columns]

# %% [markdown]
# #### Gathering the `PCA` and `explained_variance_ratio`

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
pca = PCA()

pca_stocks_dict = dict.fromkeys(stock_list)
id_stocks_dict = dict.fromkeys(stock_list)

id_stocks_df = pd.DataFrame()

for idx, df in enumerate(dfs):
    df = scaler.fit_transform(df)
    stock_pca = pca.fit_transform(df)
    #print(stock_pca.shape)
    pca_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(stock_pca, columns=list(dfs[0]))
    id_stocks_df[f"{stock_list[idx]} Explained Variance"] = pca.explained_variance_ratio_
    #id_stocks_dict[f"{stock_list[idx]}"] = pd.DataFrame(data=pca.explained_variance_ratio_,
    #                                                    columns=[f"{stock_list[idx]} Explained Variance"])
# Out:
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bob/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#pca_stocks_dict["AAPL"].head()

# %%
#id_stocks_dict["AAPL"]

# %%
id_stocks_df
# Out:
#     ADMP Explained Variance  AMZN Explained Variance  AXGN Explained Variance  \
# 0              3.476057e-01             4.046198e-01             3.384031e-01
# 1              1.694750e-01             2.210315e-01             1.877775e-01
# 2              1.223164e-01             1.161361e-01             1.289895e-01
# 3              8.968923e-02             8.648349e-02             1.012999e-01
# 4              7.481402e-02             6.396926e-02             6.519468e-02
# 5              6.865966e-02             4.486419e-02             5.693575e-02
# 6              5.344335e-02             2.885005e-02             5.250982e-02
# 7              5.029459e-02             1.879879e-02             2.971278e-02
# 8              9.192061e-03             7.342277e-03             1.990464e-02
# 9              7.855152e-03             5.048399e-03             1.134094e-02
# 10             6.654720e-03             2.856075e-03             7.931354e-03
# 11             7.898675e-33             1.008365e-32             1.613041e-32
# 4              7.405060e-02              6.647090e-02
# 5              6.662464e-02              4.561245e-02
# 6              5.314380e-02              3.440456e-02
# 7              4.367419e-02              2.566020e-02
# 8              2.696288e-02              2.035884e-02
# 9              1.080873e-02              6.764033e-03
# 10             6.755366e-03              3.138167e-03
# 11             4.125327e-32              7.248059e-33
#
#     SANM Explained Variance  TTNP Explained Variance  VIAV Explained Variance  \
# 0              4.251299e-01             3.443481e-01             3.640949e-01
# 1              1.344013e-01             1.714245e-01             1.483018e-01
# 2              1.177323e-01             1.280788e-01             1.377446e-01
# 3              9.659526e-02             9.932730e-02             8.840845e-02
# 4              7.456364e-02             8.558825e-02             8.055851e-02
# 5              5.567543e-02             7.150113e-02             7.385285e-02
# 6              3.151028e-02             4.931295e-02             4.133559e-02
# 7              2.943142e-02             2.926035e-02             2.752491e-02
# 8              2.455343e-02             7.822394e-03             2.593284e-02
# 9              7.335325e-03             7.265590e-03             7.810293e-03
# 10             3.071686e-03             6.070597e-03             4.435207e-03
# 11             4.135871e-33             9.695784e-33             5.920888e-33
#
#     VRSN Explained Variance
# 0              4.153146e-01
# 1              1.559607e-01
# 2              1.254368e-01
# 3              8.691365e-02
# 4              8.091706e-02
# 5              6.581944e-02
# 6              3.329811e-02
# 7              2.199991e-02
# 8              7.263616e-03
# 9              3.659474e-03
# 10             3.416708e-03
# 11             2.064102e-32
#
# [12 rows x 27 columns]

# %%
id_stocks_cumsum_df = id_stocks_df.cumsum()
id_stocks_cumsum_df
# Out:
#     ADMP Explained Variance  AMZN Explained Variance  AXGN Explained Variance  \
# 0                  0.347606                 0.404620                 0.338403
# 1                  0.517081                 0.625651                 0.526181
# 2                  0.639397                 0.741787                 0.655170
# 3                  0.729086                 0.828271                 0.756470
# 4                  0.803900                 0.892240                 0.821665
# 5                  0.872560                 0.937104                 0.878600
# 6                  0.926003                 0.965954                 0.931110
# 7                  0.976298                 0.984753                 0.960823
# 8                  0.985490                 0.992096                 0.980728
# 9                  0.993345                 0.997144                 0.992069
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     BBBY Explained Variance  CHKP Explained Variance  CHRW Explained Variance  \
# 0                  0.459064                 0.427686                 0.441570
# 1                  0.675122                 0.614568                 0.664538
# 2                  0.789796                 0.730847                 0.788832
# 3                  0.871860                 0.816366                 0.863340
# 4                  0.904400                 0.870997                 0.898569
# 5                  0.931668                 0.912452                 0.931795
# 6                  0.955806                 0.946505                 0.960729
# 7                  0.975168                 0.972829                 0.986843
# 8                  0.989824                 0.988624                 0.994747
# 9                  0.997316                 0.996506                 0.998328
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     DISH Explained Variance  DLTR Explained Variance  EBAY Explained Variance  \
# 0                  0.436919                 0.425951                 0.461176
# 1                  0.619323                 0.643354                 0.642816
# 2                  0.737905                 0.758626                 0.766181
# 3                  0.820341                 0.846386                 0.843962
# 4                  0.883671                 0.900662                 0.910178
# 5                  0.925264                 0.931987                 0.944948
# 6                  0.957186                 0.963025                 0.966235
# 7                  0.984934                 0.982216                 0.986878
# 8                  0.992293                 0.990095                 0.994055
# 9                  0.996617                 0.996551                 0.997530
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     GILD Explained Variance  ...  NVDA Explained Variance  \
# 0                  0.402983  ...                 0.409912
# 1                  0.630924  ...                 0.620452
# 2                  0.754354  ...                 0.719085
# 3                  0.837037  ...                 0.802923
# 4                  0.894693  ...                 0.873897
# 5                  0.930975  ...                 0.922319
# 6                  0.961267  ...                 0.950408
# 7                  0.985286  ...                 0.971099
# 8                  0.993723  ...                 0.990287
# 9                  0.997443  ...                 0.997154
# 10                 1.000000  ...                 1.000000
# 11                 1.000000  ...                 1.000000
#
#     PDCO Explained Variance  PRDO Explained Variance  PTEN Explained Variance  \
# 0                  0.434934                 0.430937                 0.464029
# 1                  0.640827                 0.617436                 0.656522
# 2                  0.762591                 0.737569                 0.772532
# 3                  0.843574                 0.821010                 0.852189
# 4                  0.880523                 0.880133                 0.906993
# 5                  0.913006                 0.926546                 0.936518
# 6                  0.943697                 0.959162                 0.963959
# 7                  0.970761                 0.983310                 0.985413
# 8                  0.988718                 0.990001                 0.992731
# 9                  0.996493                 0.996226                 0.996558
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     RAVE Explained Variance  RYAAY Explained Variance  \
# 0                  0.355635                  0.435833
# 1                  0.504969                  0.591563
# 2                  0.628021                  0.712436
# 3                  0.717980                  0.797591
# 4                  0.792030                  0.864062
# 5                  0.858655                  0.909674
# 6                  0.911799                  0.944079
# 7                  0.955473                  0.969739
# 8                  0.982436                  0.990098
# 9                  0.993245                  0.996862
# 10                 1.000000                  1.000000
# 11                 1.000000                  1.000000
#
#     SANM Explained Variance  TTNP Explained Variance  VIAV Explained Variance  \
# 0                  0.425130                 0.344348                 0.364095
# 1                  0.559531                 0.515773                 0.512397
# 2                  0.677264                 0.643851                 0.650141
# 3                  0.773859                 0.743179                 0.738550
# 4                  0.848422                 0.828767                 0.819108
# 5                  0.904098                 0.900268                 0.892961
# 6                  0.935608                 0.949581                 0.934297
# 7                  0.965040                 0.978841                 0.961822
# 8                  0.989593                 0.986664                 0.987754
# 9                  0.996928                 0.993929                 0.995565
# 10                 1.000000                 1.000000                 1.000000
# 11                 1.000000                 1.000000                 1.000000
#
#     VRSN Explained Variance
# 0                  0.415315
# 1                  0.571275
# 2                  0.696712
# 3                  0.783626
# 4                  0.864543
# 5                  0.930362
# 6                  0.963660
# 7                  0.985660
# 8                  0.992924
# 9                  0.996583
# 10                 1.000000
# 11                 1.000000
#
# [12 rows x 27 columns]

# %%
for stock in list(id_stocks_cumsum_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_cumsum_df[stock])#,label=stock);
    #plt.legend();

# %% [markdown]
# #### Plotting the `explained_variance_ratio` of the vintage set

# %%
for stock in list(id_stocks_df):
    #sns.lineplot(id_stocks_df[stock]);
    plt.plot(id_stocks_df[stock]);
    #plt.legend((f'{stock}',f'{stock}'));

# %% [markdown]
# ## To be done..
