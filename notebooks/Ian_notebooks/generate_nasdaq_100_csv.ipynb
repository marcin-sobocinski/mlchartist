# %%
from mlchartist.features import transform_file, save_ticker, build_data
# %load_ext autoreload
# %autoreload 2

import pandas as pd

# %%
df = transform_file('../../raw_data/data/daily/us/nasdaq stocks/1/aapl.us.txt')
# Out:
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])

# %%
df.head()
# Out:
#   ticker       date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0   AAPL 2020-12-23  66.468844   75.833041          81.267982  6.954094e+10
# 1   AAPL 2020-12-22  69.105683   82.286917          79.135547  6.960991e+10
# 2   AAPL 2020-12-21  63.817814   85.683987          82.742858  6.962042e+10
# 3   AAPL 2020-12-18  61.153688   69.435737          85.978511  6.950316e+10
# 4   AAPL 2020-12-17  67.111474   93.108849          96.114229  6.962657e+10
#
#             OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  \
# 0  257617492699  3.203636  19.725858  34.524874  18.680217  3.169309
# 1  257705716391  3.323147  18.952436  35.843505  19.393683  3.011667
# 2  257536364566  3.103773  18.119520  26.223295  22.361683  2.672979
# 3  257415113013  2.968602  18.901932  29.526363  18.257190  2.573448
# 4  257607654509  2.967725  18.541790  31.807016  14.677821  2.569341
#
#    MACD_diff  MACD_signal  5TD_return  10TD_return  20TD_return  \
# ...

# %%
save_ticker(df, '../../raw_data/processed/AAPL.csv')

# %%
nasdaq100 = pd.read_csv('../../raw_data/nasdaq100.csv', header=None)

# %%
nasdaq100_list = list(nasdaq100.values.flatten())

# %%
for ticker in nasdaq100_list:
    print(ticker)
# Out:
# ATVI
# ADBE
# AMD
# ALGN
# ALXN
# AMZN
# AMGN
# AAL
# ADI
# AAPL
# AMAT
# ASML
# ADSK
# ADP
# AVGO
# BIDU
# BIIB
# BMRN
# CDNS
# CERN
# CHKP
# CHTR
# TCOM
# CTAS
# CSCO
# CTXS
# CMCSA
# COST
# CSX
# CTSH
# DLTR
# EA
# EBAY
# EXC
# EXPE
# FAST
# FB
# FISV
# GILD
# GOOG
# GOOGL
# HAS
# HSIC
# ILMN
# INCY
# INTC
# INTU
# ISRG
# IDXX
# JBHT
# JD
# KLAC
# KHC
# LRCX
# LBTYA
# LBTYK
# LULU
# MELI
# MAR
# MCHP
# MDLZ
# MNST
# MSFT
# MU
# MXIM
# MYL
# NTAP
# NFLX
# NTES
# NVDA
# NXPI
# ORLY
# PAYX
# PCAR
# BKNG
# PYPL
# PEP
# QCOM
# REGN
# ROST
# SIRI
# SWKS
# SBUX
# NLOK
# SNPS
# TTWO
# TSLA
# TXN
# TMUS
# ULTA
# UAL
# VRSN
# VRSK
# VRTX
# WBA
# WDC
# WDAY
# WYNN
# XEL
# XLNX

# %%
for ticker in nasdaq100_list:
    df = transform_file('../../raw_data/data/daily/us/nasdaq stocks/all/' + ticker.strip().lower() + '.us.txt')
    save_ticker(df, '../../raw_data/processed/'+ ticker.strip().lower() + '.csv')
# Out:
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# c:\users\owner\.venvs\lewagon\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# ...
