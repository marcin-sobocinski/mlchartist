# %%
import pandas as pd
import io
from io import StringIO # python3; python2: BytesIO 
import boto3
from botocore.config import Config

# %%
import configparser

config = configparser.ConfigParser()

config.read('../../config/credentials.ini')

client = boto3.client(
    's3',
    aws_access_key_id=config['aws']['aws_access_key_id'],
    aws_secret_access_key=config['aws']['aws_secret_access_key']
)

# %%
bucket='mlchartist'
file_name='processed_files/googl.csv'
obj = client.get_object(Bucket=bucket, Key=file_name)

# %%
initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()), encoding='utf8')
initial_df.head()
# Out:
#   ticker        date        RSI  Stochastic  Stochastic_signal           ADI  \
# 0  GOOGL  2004-10-06  79.392834   94.195356          95.604489  3.034408e+07
# 1  GOOGL  2004-10-07  80.562469   95.543055          96.381058  3.573270e+07
# 2  GOOGL  2004-10-08  77.562524   90.680537          93.472983  3.056731e+07
# 3  GOOGL  2004-10-11  71.260329   79.973992          88.732528  2.598509e+07
# 4  GOOGL  2004-10-12  73.285616   89.151356          86.601962  3.649734e+07
#
#          OBV       ATR        ADX    ADX_pos    ADX_neg      MACD  MACD_diff  \
# 0  219815800  2.309207  46.875131  38.657801   9.714233  4.037139   0.718543
# 1  233945000  2.263192  47.937358  38.886086   9.196722  4.159932   0.673068
# 2  222864400  2.196536  48.923713  37.182097   8.793721  4.164058   0.541756
# 3  212381800  2.218569  48.580415  34.147042  13.240725  4.021318   0.319213
# 4  224059000  2.210457  48.092929  31.798148  13.065187  3.949014   0.197527
#
#    MACD_signal  5TD_return  10TD_return  20TD_return
# 0     3.318596    0.027867     0.024876     0.398235
# 1     3.486863    0.022686     0.075837     0.330212
# 2     3.622302    0.046323     0.251942     0.229580
# 3     3.702105    0.102765     0.385480     0.275691
# 4     3.751487    0.076710     0.323144     0.227802

# %%
upload_file_bucket = 'lewagon-mlscraper-files'
upload_file_key = csv_file_path
client.upload_file(csv_file_path, upload_file_bucket, upload_file_key)
