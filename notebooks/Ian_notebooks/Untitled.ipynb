# %%
import pandas as pd
import io
from io import StringIO # python3; python2: BytesIO 
import boto3

# %%
access_key = 'AKIAZNQGCJBVWW7WE2EE'
secret_access_key = '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'

client = boto3.client('s3',
                     aws_access_key_id = access_key,
                     aws_secret_access_key = secret_access_key)

# %%
bucket='mlchartist'
file_name='processed_files/googl.csv'
obj = client.get_object(Bucket=bucket, Key=file_name)

# %%
obj['Body'].read()
# Out:
# b'ticker,date,RSI,Stochastic,Stochastic_signal,ADI,OBV,ATR,ADX,ADX_pos,ADX_neg,MACD,MACD_diff,MACD_signal,5TD_return,10TD_return,20TD_return\r\nGOOGL,2004-10-06,79.3928343163754,94.19535628502807,95.6044888404162,30344084.210438322,219815800,2.309206895322597,46.875130584725795,38.65780125772945,9.714232662667845,4.037139228467353,0.7185429696208416,3.3185962588465117,0.02786693901371451,0.02487598482637865,0.3982346075284504\r\nGOOGL,2004-10-07,80.56246858193975,95.54305495456512,96.38105771478503,35732698.02425209,233945000,2.2631921170852682,47.937358311574734,38.88608554694809,9.196721956696656,4.15993177235061,0.6730684108032787,3.4868633615473317,0.022686352178610036,0.07583723442563928,0.33021245948865685\r\nGOOGL,2004-10-08,77.56252426041917,90.68053749458167,93.47298291139161,30567305.54304892,222864400,2.1965355372934634,48.92371262936303,37.182096503482065,8.793721417311058,4.164057762317832,0.5417555206163995,3.622302241701432,0.0463225150657085,0.25194220576490256,0.2295
# ...

# %%
initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()), encoding='utf8')
initial_df.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-20-966d7a4fbf46> in <module>
# ----> 1 initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()), encoding='utf8')
#       2 initial_df.head()
#
# c:\users\owner\.venvs\lewagon\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
upload_file_bucket = 'lewagon-mlscraper-files'
upload_file_key = csv_file_path
client.upload_file(csv_file_path, upload_file_bucket, upload_file_key)

# %% [markdown]
# #1
# pass scaler --> use a scaler
# scaler=None
#
# #2
# get_full_ds_scaler + train/test
# - full 100 NASDAQ
# - holdout 10 companies --> holdount=[]
#
# split function(split=False)
# - input X companies
# - X companies -> train/test sets
# - remove outliers on train
# - fit scaler on train
# output - scaler, train, test
#
#
#
# fit_train_scaler
# - input train
# - remove outliers
# - fit scaler
# - output scaler
#
#
# 90 compainies --> 15 companies X 6 models
#
# build_arrays_new
# - inputs -> full dataframe (without holdout), take in train/test/scaler
#
# - split the data -> train/test
# - if scaler not provided then call fit_train_scaler
# - scale the train set
#
#
#
#
# - fits on outlier free all 100 companies
